# %% [markdown]
# ## Validate HED in a BIDS dataset.
#
# Validating annotations HED as you develop them makes the annotation process much easier and
# faster to debug. This notebook validates HED in a BIDS dataset.
#
# The tool creates a `BidsDataset` object, which represents the information from a BIDS
# dataset that is relevant to HED, including the `dataset_description.json`,
# all `events.tsv` files, and all `events.json` sidecar files.
#
# The `validate` method of `BidsDataset` first validates all of the `events.json` sidecars
# and then assembles the relevant sidecars for each `events.tsv` file and validates it.
# The validation uses the HED schemas specified in the `HEDVersion` field of the
# dataset's `dataset_description.json` file.
#
# The script does the following steps:
#
# 1. Set the dataset location (`bids_root_path`) to the absolute path of the root of your BIDS dataset.
# 2. Indicates whether to check for warnings during validation (`check_for_warnings`).
# 3. Create a `BidsDataset` for the dataset.
# 4. Validate the dataset and output the issues.
#
# **Note:** This validation pertains to event files and HED annotation only. It does not do a full BIDS validation.
#
# The example below uses a
# [small version](https://github.com/hed-standard/hed-examples/tree/main/datasets/eeg_ds003654s_hed)
# of the Wakeman-Hanson face-processing dataset available on openNeuro as
# [ds003654](https://openneuro.org/datasets/ds003645/versions/2.0.0).
#
# This dataset has no validation errors, but since we have set `check_for_warnings` to `True`,
# validation returns warnings that the `sample` column does not have any metadata.
#
# For validation of a single `events.json` files during annotation development,
# users often find the [online sidecar tools](https://hedtools.ucsd.edu/hed/sidecar)
# convenient, but the online tool does not provide complete dataset-level validation.

# %%
import os
from hed.errors import get_printable_issue_string
from hed.tools import BidsDataset

## Set the dataset location and the check_for_warnings flag
check_for_warnings = False
# bids_root_path = os.path.abspath(os.path.join(os.path.dirname(os.path.abspath('')), '../../datasets/eeg_ds003654s_hed'))
bids_root_path = 'G:/AttentionShift/AttentionShiftWorkingPhaseTwo'
print(f"Bids root path: {bids_root_path}")

## Validate the dataset
bids = BidsDataset(bids_root_path)
issue_list = bids.validate(check_for_warnings=check_for_warnings)
if issue_list:
    issue_str = get_printable_issue_string(issue_list, "HED validation errors: ", skip_filename=False)
else:
    issue_str = "No HED validation errors"
print(issue_str)
# Out:
# Bids root path: G:/AttentionShift/AttentionShiftWorkingPhaseTwo
# HED validation errors:
#
# Errors in file 'G:\AttentionShift\AttentionShiftWorkingPhaseTwo\sub-001\eeg\sub-001_task-AuditoryVisualShift_run-01_events.tsv'
# 	Issues in row 12:
# 		hed string: Time-block/2,Experimental-trial/9,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 177, 189
# 	Issues in row 37:
# 		hed string: Time-block/4,Experimental-trial/29,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 60:
# 		hed string: Time-block/6,Experimental-trial/50,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 89:
# 		hed string: Time-block/8,Experimental-trial/74,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 112:
# 		hed string: Time-block/10,Experimental-trial/92,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 179, 191
# 	Issues in row 133:
# 		hed string: Time-block/12,Experimental-trial/109,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 161:
# 		hed string: Time-block/14,Experimental-trial/131,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 189:
# 		hed string: Time-block/16,Experimental-trial/155,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 214:
# 		hed string: Time-block/18,Experimental-trial/175,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 239:
# 		hed string: Time-block/20,Experimental-trial/195,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 264:
# 		hed string: Time-block/22,Experimental-trial/214,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 284:
# 		hed string: Time-block/24,Experimental-trial/232,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 307:
# 		hed string: Time-block/26,Experimental-trial/251,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 320:
# 		hed string: Time-block/28,Experimental-trial/261,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 351:
# 		hed string: Time-block/30,Experimental-trial/287,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 377:
# 		hed string: Time-block/32,Experimental-trial/308,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 404:
# 		hed string: Time-block/34,Experimental-trial/332,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 432:
# 		hed string: Time-block/36,Experimental-trial/356,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 456:
# 		hed string: Time-block/38,Experimental-trial/376,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 477:
# 		hed string: Time-block/40,Experimental-trial/392,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 502:
# 		hed string: Time-block/42,Experimental-trial/411,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 525:
# 		hed string: Time-block/44,Experimental-trial/432,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 546:
# 		hed string: Time-block/46,Experimental-trial/450,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 572:
# 		hed string: Time-block/48,Experimental-trial/471,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 4143:
# 		hed string: Time-block/337,Experimental-trial/3365,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4166:
# 		hed string: Time-block/339,Experimental-trial/3383,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4194:
# 		hed string: Time-block/341,Experimental-trial/3408,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4217:
# 		hed string: Time-block/343,Experimental-trial/3427,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4245:
# 		hed string: Time-block/345,Experimental-trial/3450,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4266:
# 		hed string: Time-block/347,Experimental-trial/3468,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4296:
# 		hed string: Time-block/349,Experimental-trial/3492,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4320:
# 		hed string: Time-block/351,Experimental-trial/3511,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4342:
# 		hed string: Time-block/353,Experimental-trial/3529,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4364:
# 		hed string: Time-block/355,Experimental-trial/3548,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4386:
# 		hed string: Time-block/357,Experimental-trial/3567,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4410:
# 		hed string: Time-block/359,Experimental-trial/3586,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4432:
# 		hed string: Time-block/361,Experimental-trial/3604,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4453:
# 		hed string: Time-block/363,Experimental-trial/3621,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4484:
# 		hed string: Time-block/365,Experimental-trial/3646,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4509:
# 		hed string: Time-block/367,Experimental-trial/3668,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4526:
# 		hed string: Time-block/369,Experimental-trial/3682,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4550:
# 		hed string: Time-block/371,Experimental-trial/3703,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4578:
# 		hed string: Time-block/373,Experimental-trial/3726,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4598:
# 		hed string: Time-block/375,Experimental-trial/3744,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4626:
# 		hed string: Time-block/377,Experimental-trial/3766,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4650:
# 		hed string: Time-block/379,Experimental-trial/3785,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4668:
# 		hed string: Time-block/381,Experimental-trial/3801,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4690:
# 		hed string: Time-block/383,Experimental-trial/3820,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4716:
# 		hed string: Time-block/385,Experimental-trial/3842,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4739:
# 		hed string: Time-block/387,Experimental-trial/3862,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4763:
# 		hed string: Time-block/389,Experimental-trial/3882,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4787:
# 		hed string: Time-block/391,Experimental-trial/3902,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4818:
# 		hed string: Time-block/393,Experimental-trial/3927,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4847:
# 		hed string: Time-block/395,Experimental-trial/3950,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4871:
# 		hed string: Time-block/397,Experimental-trial/3971,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4892:
# 		hed string: Time-block/399,Experimental-trial/3990,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4909:
# 		hed string: Time-block/401,Experimental-trial/4004,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4932:
# 		hed string: Time-block/403,Experimental-trial/4023,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4956:
# 		hed string: Time-block/405,Experimental-trial/4042,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4980:
# 		hed string: Time-block/407,Experimental-trial/4062,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5007:
# 		hed string: Time-block/409,Experimental-trial/4085,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5033:
# 		hed string: Time-block/411,Experimental-trial/4107,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5051:
# 		hed string: Time-block/413,Experimental-trial/4122,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5074:
# 		hed string: Time-block/415,Experimental-trial/4141,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5100:
# 		hed string: Time-block/417,Experimental-trial/4162,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5135:
# 		hed string: Time-block/419,Experimental-trial/4191,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5160:
# 		hed string: Time-block/421,Experimental-trial/4211,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5187:
# 		hed string: Time-block/423,Experimental-trial/4235,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5210:
# 		hed string: Time-block/425,Experimental-trial/4254,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5235:
# 		hed string: Time-block/427,Experimental-trial/4274,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5249:
# 		hed string: Time-block/429,Experimental-trial/4285,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5272:
# 		hed string: Time-block/431,Experimental-trial/4304,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5290:
# 		hed string: Time-block/433,Experimental-trial/4320,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5311:
# 		hed string: Time-block/435,Experimental-trial/4338,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5328:
# 		hed string: Time-block/437,Experimental-trial/4352,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5355:
# 		hed string: Time-block/439,Experimental-trial/4375,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5388:
# 		hed string: Time-block/441,Experimental-trial/4402,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5411:
# 		hed string: Time-block/443,Experimental-trial/4422,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5438:
# 		hed string: Time-block/445,Experimental-trial/4444,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5462:
# 		hed string: Time-block/447,Experimental-trial/4464,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5482:
# 		hed string: Time-block/449,Experimental-trial/4482,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5513:
# 		hed string: Time-block/451,Experimental-trial/4506,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5536:
# 		hed string: Time-block/453,Experimental-trial/4525,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5558:
# 		hed string: Time-block/455,Experimental-trial/4544,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5583:
# 		hed string: Time-block/457,Experimental-trial/4565,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5602:
# 		hed string: Time-block/459,Experimental-trial/4580,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5634:
# 		hed string: Time-block/461,Experimental-trial/4605,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5658:
# 		hed string: Time-block/463,Experimental-trial/4625,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5678:
# 		hed string: Time-block/465,Experimental-trial/4641,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5700:
# 		hed string: Time-block/467,Experimental-trial/4660,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5725:
# 		hed string: Time-block/469,Experimental-trial/4680,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5749:
# 		hed string: Time-block/471,Experimental-trial/4702,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5773:
# 		hed string: Time-block/473,Experimental-trial/4723,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5796:
# 		hed string: Time-block/475,Experimental-trial/4743,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5824:
# 		hed string: Time-block/477,Experimental-trial/4766,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5841:
# 		hed string: Time-block/479,Experimental-trial/4780,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
#
# Errors in file 'G:\AttentionShift\AttentionShiftWorkingPhaseTwo\sub-002\eeg\sub-002_task-AuditoryVisualShift_run-01_events.tsv'
# 	Issues in row 11:
# 		hed string: Time-block/2,Experimental-trial/9,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 177, 189
# 	Issues in row 35:
# 		hed string: Time-block/4,Experimental-trial/29,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 59:
# 		hed string: Time-block/6,Experimental-trial/50,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 86:
# 		hed string: Time-block/8,Experimental-trial/74,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 109:
# 		hed string: Time-block/10,Experimental-trial/92,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 179, 191
# 	Issues in row 129:
# 		hed string: Time-block/12,Experimental-trial/109,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 155:
# 		hed string: Time-block/14,Experimental-trial/131,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 186:
# 		hed string: Time-block/16,Experimental-trial/155,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 209:
# 		hed string: Time-block/18,Experimental-trial/175,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 235:
# 		hed string: Time-block/20,Experimental-trial/195,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 258:
# 		hed string: Time-block/22,Experimental-trial/214,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 279:
# 		hed string: Time-block/24,Experimental-trial/232,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 301:
# 		hed string: Time-block/26,Experimental-trial/251,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 314:
# 		hed string: Time-block/28,Experimental-trial/261,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 345:
# 		hed string: Time-block/30,Experimental-trial/287,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 371:
# 		hed string: Time-block/32,Experimental-trial/308,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 398:
# 		hed string: Time-block/34,Experimental-trial/332,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 426:
# 		hed string: Time-block/36,Experimental-trial/356,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 450:
# 		hed string: Time-block/38,Experimental-trial/376,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 471:
# 		hed string: Time-block/40,Experimental-trial/392,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 496:
# 		hed string: Time-block/42,Experimental-trial/411,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 519:
# 		hed string: Time-block/44,Experimental-trial/432,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 540:
# 		hed string: Time-block/46,Experimental-trial/450,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 566:
# 		hed string: Time-block/48,Experimental-trial/471,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 178, 190
# 	Issues in row 4155:
# 		hed string: Time-block/338,Experimental-trial/3368,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4179:
# 		hed string: Time-block/340,Experimental-trial/3387,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4207:
# 		hed string: Time-block/342,Experimental-trial/3412,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4230:
# 		hed string: Time-block/344,Experimental-trial/3431,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 4258:
# ...
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 4909:
# 		hed string: Time-block/401,Experimental-trial/4008,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 4932:
# 		hed string: Time-block/403,Experimental-trial/4028,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 4960:
# 		hed string: Time-block/405,Experimental-trial/4051,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 4977:
# 		hed string: Time-block/407,Experimental-trial/4065,(Selective-attention,Visual-presentation),Sensory-presentation,(Word,Label/Word-hear),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Visual-focus,(Focused-attention,Visual-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 180, 192
# 	Issues in row 5004:
# 		hed string: Time-block/409,Experimental-trial/4088,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5033:
# 		hed string: Time-block/412,Experimental-trial/4112,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5057:
# 		hed string: Time-block/414,Experimental-trial/4131,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5086:
# 		hed string: Time-block/416,Experimental-trial/4156,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5109:
# 		hed string: Time-block/418,Experimental-trial/4175,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5137:
# 		hed string: Time-block/420,Experimental-trial/4198,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5158:
# 		hed string: Time-block/422,Experimental-trial/4216,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5188:
# 		hed string: Time-block/424,Experimental-trial/4240,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5212:
# 		hed string: Time-block/426,Experimental-trial/4259,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5235:
# 		hed string: Time-block/428,Experimental-trial/4278,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5257:
# 		hed string: Time-block/430,Experimental-trial/4297,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5279:
# 		hed string: Time-block/432,Experimental-trial/4316,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5303:
# 		hed string: Time-block/434,Experimental-trial/4335,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5326:
# 		hed string: Time-block/436,Experimental-trial/4353,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5347:
# 		hed string: Time-block/438,Experimental-trial/4370,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5378:
# 		hed string: Time-block/440,Experimental-trial/4395,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5403:
# 		hed string: Time-block/442,Experimental-trial/4417,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5420:
# 		hed string: Time-block/444,Experimental-trial/4431,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5444:
# 		hed string: Time-block/446,Experimental-trial/4452,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5472:
# 		hed string: Time-block/448,Experimental-trial/4475,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5492:
# 		hed string: Time-block/450,Experimental-trial/4493,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5520:
# 		hed string: Time-block/452,Experimental-trial/4515,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5544:
# 		hed string: Time-block/454,Experimental-trial/4534,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5563:
# 		hed string: Time-block/456,Experimental-trial/4550,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5585:
# 		hed string: Time-block/458,Experimental-trial/4569,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5612:
# 		hed string: Time-block/460,Experimental-trial/4591,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5635:
# 		hed string: Time-block/462,Experimental-trial/4611,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5660:
# 		hed string: Time-block/464,Experimental-trial/4631,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5684:
# 		hed string: Time-block/466,Experimental-trial/4651,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5715:
# 		hed string: Time-block/468,Experimental-trial/4676,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5744:
# 		hed string: Time-block/470,Experimental-trial/4699,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5768:
# 		hed string: Time-block/472,Experimental-trial/4720,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5789:
# 		hed string: Time-block/474,Experimental-trial/4739,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5806:
# 		hed string: Time-block/476,Experimental-trial/4753,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5829:
# 		hed string: Time-block/478,Experimental-trial/4772,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5853:
# 		hed string: Time-block/480,Experimental-trial/4791,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
# 	Issues in row 5878:
# 		hed string: Time-block/482,Experimental-trial/4811,(Selective-attention,Auditory-presentation),Sensory-presentation,(Word,Label/Word-look),Auditory-presentation,Visual-presentation,Think/Ignore,Think/Ignore,(Condition-variable/Auditory-focus,(Focused-attention,Auditory-presentation))
# 		ERROR: Repeated tag - "Think/Ignore"  Problem spans string indexes: 182, 194
