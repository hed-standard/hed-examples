# %% [markdown]
# ## Preliminary column summary of events
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# In order to compare the events coming from the BIDS events files and those
# from the EEG.set files, the script creates dictionaries of `key` to full path
# for each type of file.  The `key` is of the form `sub-xxx_run-y` which
# uniquely specify each event file in the dataset. If a dataset contains
# multiple sessions for each subject, the `key` should include additional
# parts of the file name to uniquely specify each subject.
#
# Keys are specified by a `name_indices` tuple which consists of the
# pieces of the file name to include. Here pieces are separated by the
# underbar character.
#
# For a file name `sub-001_ses-3_task-target_run-01_events.tsv`,
# the tuple (0, 2) gives a key of `sub-001_task-target`,
# while the tuple (0, 3) gives a key of `sub-001_run-01`.
# The use of dictionaries of file names with such keys makes it
# easier to associate related files in the BIDS naming structure.

# %%
import os
from hed.util import get_file_list, make_file_dict

bids_root_path = 'G:\ImaginedEmotion\ImaginedEmotionWorking'
name_indices = (0, 1)
# bids_skip = ['onset', 'duration', 'sample', 'response_time', 'stim_file']
# eeg_skip = ['latency', 'duration', 'sample', 'response_time', 'stim_file']
bids_skip = ['onset']
eeg_skip = ['latency']

print(f"Summarizing {bids_root_path}...")
event_files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events")
bids_file_dict = make_file_dict(event_files_bids, name_indices=name_indices)
print(f"\n{len(list(bids_file_dict))} BIDS style event files")
for key, value in bids_file_dict.items():
    print(f"{key}: {os.path.basename(value)}")

# Construct the dictionary for EEG.event files
event_files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp")
eeg_file_dict = make_file_dict(event_files_eeg, name_indices=name_indices)
print(f"\n{len(list(eeg_file_dict))} EEG.event style event files")
for key, value in eeg_file_dict.items():
    print(f"{key}: {os.path.basename(value)}")
# Out:
# Summarizing G:\ImaginedEmotion\ImaginedEmotionWorking...
#
# 34 BIDS style event files
# sub-01_task-ImaginedEmotion: sub-01_task-ImaginedEmotion_events.tsv
# sub-02_task-ImaginedEmotion: sub-02_task-ImaginedEmotion_events.tsv
# sub-03_task-ImaginedEmotion: sub-03_task-ImaginedEmotion_events.tsv
# sub-04_task-ImaginedEmotion: sub-04_task-ImaginedEmotion_events.tsv
# sub-05_task-ImaginedEmotion: sub-05_task-ImaginedEmotion_events.tsv
# sub-06_task-ImaginedEmotion: sub-06_task-ImaginedEmotion_events.tsv
# sub-07_task-ImaginedEmotion: sub-07_task-ImaginedEmotion_events.tsv
# sub-08_task-ImaginedEmotion: sub-08_task-ImaginedEmotion_events.tsv
# sub-09_task-ImaginedEmotion: sub-09_task-ImaginedEmotion_events.tsv
# sub-10_task-ImaginedEmotion: sub-10_task-ImaginedEmotion_events.tsv
# sub-11_task-ImaginedEmotion: sub-11_task-ImaginedEmotion_events.tsv
# sub-12_task-ImaginedEmotion: sub-12_task-ImaginedEmotion_events.tsv
# sub-13_task-ImaginedEmotion: sub-13_task-ImaginedEmotion_events.tsv
# sub-14_task-ImaginedEmotion: sub-14_task-ImaginedEmotion_events.tsv
# sub-15_task-ImaginedEmotion: sub-15_task-ImaginedEmotion_events.tsv
# sub-16_task-ImaginedEmotion: sub-16_task-ImaginedEmotion_events.tsv
# sub-17_task-ImaginedEmotion: sub-17_task-ImaginedEmotion_events.tsv
# sub-18_task-ImaginedEmotion: sub-18_task-ImaginedEmotion_events.tsv
# sub-19_task-ImaginedEmotion: sub-19_task-ImaginedEmotion_events.tsv
# sub-20_task-ImaginedEmotion: sub-20_task-ImaginedEmotion_events.tsv
# sub-21_task-ImaginedEmotion: sub-21_task-ImaginedEmotion_events.tsv
# sub-23_task-ImaginedEmotion: sub-23_task-ImaginedEmotion_events.tsv
# sub-24_task-ImaginedEmotion: sub-24_task-ImaginedEmotion_events.tsv
# sub-25_task-ImaginedEmotion: sub-25_task-ImaginedEmotion_events.tsv
# sub-26_task-ImaginedEmotion: sub-26_task-ImaginedEmotion_events.tsv
# sub-27_task-ImaginedEmotion: sub-27_task-ImaginedEmotion_events.tsv
# sub-28_task-ImaginedEmotion: sub-28_task-ImaginedEmotion_events.tsv
# sub-29_task-ImaginedEmotion: sub-29_task-ImaginedEmotion_events.tsv
# sub-30_task-ImaginedEmotion: sub-30_task-ImaginedEmotion_events.tsv
# sub-31_task-ImaginedEmotion: sub-31_task-ImaginedEmotion_events.tsv
# sub-32_task-ImaginedEmotion: sub-32_task-ImaginedEmotion_events.tsv
# sub-33_task-ImaginedEmotion: sub-33_task-ImaginedEmotion_events.tsv
# sub-34_task-ImaginedEmotion: sub-34_task-ImaginedEmotion_events.tsv
# sub-35_task-ImaginedEmotion: sub-35_task-ImaginedEmotion_events.tsv
#
# 34 EEG.event style event files
# sub-01_task-ImaginedEmotion: sub-01_task-ImaginedEmotion_events_temp.tsv
# sub-02_task-ImaginedEmotion: sub-02_task-ImaginedEmotion_events_temp.tsv
# sub-03_task-ImaginedEmotion: sub-03_task-ImaginedEmotion_events_temp.tsv
# sub-04_task-ImaginedEmotion: sub-04_task-ImaginedEmotion_events_temp.tsv
# sub-05_task-ImaginedEmotion: sub-05_task-ImaginedEmotion_events_temp.tsv
# sub-06_task-ImaginedEmotion: sub-06_task-ImaginedEmotion_events_temp.tsv
# sub-07_task-ImaginedEmotion: sub-07_task-ImaginedEmotion_events_temp.tsv
# sub-08_task-ImaginedEmotion: sub-08_task-ImaginedEmotion_events_temp.tsv
# sub-09_task-ImaginedEmotion: sub-09_task-ImaginedEmotion_events_temp.tsv
# sub-10_task-ImaginedEmotion: sub-10_task-ImaginedEmotion_events_temp.tsv
# sub-11_task-ImaginedEmotion: sub-11_task-ImaginedEmotion_events_temp.tsv
# sub-12_task-ImaginedEmotion: sub-12_task-ImaginedEmotion_events_temp.tsv
# sub-13_task-ImaginedEmotion: sub-13_task-ImaginedEmotion_events_temp.tsv
# sub-14_task-ImaginedEmotion: sub-14_task-ImaginedEmotion_events_temp.tsv
# sub-15_task-ImaginedEmotion: sub-15_task-ImaginedEmotion_events_temp.tsv
# sub-16_task-ImaginedEmotion: sub-16_task-ImaginedEmotion_events_temp.tsv
# sub-17_task-ImaginedEmotion: sub-17_task-ImaginedEmotion_events_temp.tsv
# sub-18_task-ImaginedEmotion: sub-18_task-ImaginedEmotion_events_temp.tsv
# sub-19_task-ImaginedEmotion: sub-19_task-ImaginedEmotion_events_temp.tsv
# sub-20_task-ImaginedEmotion: sub-20_task-ImaginedEmotion_events_temp.tsv
# sub-21_task-ImaginedEmotion: sub-21_task-ImaginedEmotion_events_temp.tsv
# sub-23_task-ImaginedEmotion: sub-23_task-ImaginedEmotion_events_temp.tsv
# sub-24_task-ImaginedEmotion: sub-24_task-ImaginedEmotion_events_temp.tsv
# sub-25_task-ImaginedEmotion: sub-25_task-ImaginedEmotion_events_temp.tsv
# sub-26_task-ImaginedEmotion: sub-26_task-ImaginedEmotion_events_temp.tsv
# sub-27_task-ImaginedEmotion: sub-27_task-ImaginedEmotion_events_temp.tsv
# sub-28_task-ImaginedEmotion: sub-28_task-ImaginedEmotion_events_temp.tsv
# sub-29_task-ImaginedEmotion: sub-29_task-ImaginedEmotion_events_temp.tsv
# sub-30_task-ImaginedEmotion: sub-30_task-ImaginedEmotion_events_temp.tsv
# sub-31_task-ImaginedEmotion: sub-31_task-ImaginedEmotion_events_temp.tsv
# sub-32_task-ImaginedEmotion: sub-32_task-ImaginedEmotion_events_temp.tsv
# sub-33_task-ImaginedEmotion: sub-33_task-ImaginedEmotion_events_temp.tsv
# sub-34_task-ImaginedEmotion: sub-34_task-ImaginedEmotion_events_temp.tsv
# sub-35_task-ImaginedEmotion: sub-35_task-ImaginedEmotion_events_temp.tsv

# %%
print("Verifying that both dictionaries have the same keys")
keys_bids = set(bids_file_dict.keys())
keys_eeg = set(eeg_file_dict.keys())
list_bids = list(keys_bids.difference(keys_eeg))
list_eeg = list(keys_eeg.difference(keys_bids))
print(f"Bids extra keys {str(list_bids)}")
print(f"EEG extra keys {str(list_eeg)}")
# Out:
# Verifying that both dictionaries have the same keys
# Bids extra keys []
# EEG extra keys []

# %%
from hed.util import get_new_dataframe

print(f"\nBIDS style event file columns:")
bids_count_dict = {}
for key, file in bids_file_dict.items():
    df = get_new_dataframe(file)
    bids_count_dict[key] = len(df.index)
    print(f"{key} [{len(df.index)} events]: {str(list(df.columns.values))}")

print(f"\nEEG.event style event file columns:")
eeg_count_dict = {}
for key, file in eeg_file_dict.items():
    df = get_new_dataframe(file)
    eeg_count_dict[key] = len(df.index)
    print(f"{key} [{len(df.index)} events]: {str(list(df.columns.values))}")
# Out:
# BIDS style event file columns:
# sub-01_task-ImaginedEmotion [201 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-02_task-ImaginedEmotion [204 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-03_task-ImaginedEmotion [94 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-04_task-ImaginedEmotion [150 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-05_task-ImaginedEmotion [94 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-06_task-ImaginedEmotion [94 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-07_task-ImaginedEmotion [82 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-08_task-ImaginedEmotion [73 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-09_task-ImaginedEmotion [71 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-10_task-ImaginedEmotion [107 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-11_task-ImaginedEmotion [100 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-12_task-ImaginedEmotion [91 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-13_task-ImaginedEmotion [73 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-14_task-ImaginedEmotion [74 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-15_task-ImaginedEmotion [74 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-16_task-ImaginedEmotion [74 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-17_task-ImaginedEmotion [78 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-18_task-ImaginedEmotion [75 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-19_task-ImaginedEmotion [89 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-20_task-ImaginedEmotion [83 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-21_task-ImaginedEmotion [75 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-23_task-ImaginedEmotion [83 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-24_task-ImaginedEmotion [104 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-25_task-ImaginedEmotion [118 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-26_task-ImaginedEmotion [93 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-27_task-ImaginedEmotion [81 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-28_task-ImaginedEmotion [72 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-29_task-ImaginedEmotion [75 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-30_task-ImaginedEmotion [76 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-31_task-ImaginedEmotion [85 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-32_task-ImaginedEmotion [72 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-33_task-ImaginedEmotion [55 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-34_task-ImaginedEmotion [71 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-35_task-ImaginedEmotion [70 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
#
# EEG.event style event file columns:
# sub-01_task-ImaginedEmotion [201 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-02_task-ImaginedEmotion [204 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-03_task-ImaginedEmotion [94 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-04_task-ImaginedEmotion [150 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-05_task-ImaginedEmotion [94 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-06_task-ImaginedEmotion [94 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-07_task-ImaginedEmotion [82 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-08_task-ImaginedEmotion [73 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-09_task-ImaginedEmotion [71 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-10_task-ImaginedEmotion [107 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-11_task-ImaginedEmotion [100 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-12_task-ImaginedEmotion [91 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-13_task-ImaginedEmotion [73 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-14_task-ImaginedEmotion [74 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-15_task-ImaginedEmotion [74 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-16_task-ImaginedEmotion [74 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-17_task-ImaginedEmotion [78 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-18_task-ImaginedEmotion [75 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-19_task-ImaginedEmotion [89 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-20_task-ImaginedEmotion [83 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-21_task-ImaginedEmotion [75 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-23_task-ImaginedEmotion [83 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-24_task-ImaginedEmotion [104 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-25_task-ImaginedEmotion [118 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-26_task-ImaginedEmotion [93 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-27_task-ImaginedEmotion [81 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-28_task-ImaginedEmotion [72 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-29_task-ImaginedEmotion [75 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-30_task-ImaginedEmotion [76 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-31_task-ImaginedEmotion [85 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-32_task-ImaginedEmotion [72 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-33_task-ImaginedEmotion [55 events]: ['latency', 'type', 'urevent']
# sub-34_task-ImaginedEmotion [71 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']
# sub-35_task-ImaginedEmotion [70 events]: ['latency', 'type', 'chanindex', 'duration', 'urevent']

# %%
from hed.tools import ColumnSummary
print('\nBIDS events summary:')
bids_dicts_all, bids_dicts =  ColumnSummary.make_combined_dicts(bids_file_dict, skip_cols=bids_skip)
bids_dicts_all.print()

print('\nEEG.event events summary:')
eeg_dicts_all, eeg_dicts =  ColumnSummary.make_combined_dicts(eeg_file_dict, skip_cols=eeg_skip)
eeg_dicts_all.print()
# Out:
# BIDS events summary:
# Summary for column dictionary :
#   Categorical columns (7):
#     HED (1 distinct values):
#       n/a: 3111
#     duration (121 distinct values):
#       0.0: 2674
#       100200.0: 1
#       100903.0: 1
#       102768.0: 1
#       105297.0: 1
#       105825.0: 1
#       106693.0: 1
#       110158.0: 1
#       120151.0: 1
#       123021.0: 1
#       130138.0: 1
#       13040.0: 1
#       130640.0: 1
#       14217.0: 1
#       14649.0: 1
#       149586.0: 1
#       150400.0: 1
#       15511.0: 1
#       158423.0: 1
#       158741.0: 1
#       161556.0: 1
#       161719.0: 1
#       161729.0: 1
#       165468.0: 1
#       166072.0: 1
#       16634.0: 1
#       166524.0: 1
#       169623.0: 1
#       17123.0: 1
#       173532.0: 1
#       174786.0: 1
#       176835.0: 1
#       178041.0: 1
#       178107.0: 1
#       178123.0: 1
#       181557.0: 1
#       188.0: 1
#       195255.0: 1
#       195257.0: 1
#       195303.0: 1
#       196159.0: 1
#       196161.0: 1
#       199056.0: 1
#       203648.0: 1
#       20721.0: 1
#       207522.0: 1
#       2113.0: 1
#       221560.0: 1
#       228666.0: 1
#       232291.0: 1
#       244628.0: 1
#       254342.0: 1
#       254396.0: 1
#       26419.0: 1
#       27347.0: 1
#       3.0: 144
#       30262.0: 1
#       31864.0: 1
#       37067.0: 1
#       4.0: 119
#       41801.0: 1
#       42607.0: 1
#       44216.0: 1
#       44273.0: 1
#       48325.0: 1
#       49184.0: 1
#       49187.0: 1
#       49192.0: 1
#       50950.0: 2
#       50952.0: 1
#       51595.0: 1
#       51596.0: 1
#       51597.0: 1
#       52453.0: 1
#       52686.0: 1
#       52703.0: 1
#       52757.0: 1
#       53970.0: 1
#       55730.0: 1
#       55731.0: 1
#       55812.0: 1
#       58425.0: 1
#       58426.0: 1
#       58966.0: 1
#       59011.0: 1
#       59014.0: 1
#       60402.0: 1
#       60403.0: 1
#       60405.0: 1
#       6110.0: 1
#       61493.0: 1
#       62033.0: 1
#       63597.0: 1
#       63598.0: 1
#       64619.0: 1
#       65718.0: 1
#       65802.0: 1
#       65803.0: 1
#       68358.0: 2
#       68359.0: 1
#       70292.0: 1
#       70325.0: 1
#       70353.0: 1
#       70354.0: 1
#       70356.0: 1
#       72655.0: 1
#       78295.0: 1
#       80387.0: 1
#       82305.0: 1
#       88293.0: 1
#       88534.0: 1
#       88642.0: 1
#       89152.0: 1
#       91093.0: 1
#       91375.0: 1
#       94712.0: 1
#       9535.0: 1
#       96539.0: 1
#       98722.0: 1
#       99400.0: 1
#       n/a: 55
#     response_time (1 distinct values):
#       n/a: 3111
#     sample (1 distinct values):
#       n/a: 3111
#     stim_file (1 distinct values):
#       n/a: 3111
#     trial_type (1 distinct values):
#       n/a: 3111
#     value (30 distinct values):
#       ExitThankYou: 34
#       FeelingItInstructionsButton: 18
#       FeelingItInstructionsNoButton: 19
#       ImaginationSuggestions: 34
#       InitialInstructions: 31
#       InstructionsForEnding: 34
#       anger: 34
#       awe: 35
#       compassion: 34
#       content: 34
#       disgust: 34
#       enter: 508
#       excite: 34
#       exit: 558
#       fear: 34
#       frustration: 34
#       grief: 34
#       happy: 34
#       jealousy: 34
#       joy: 34
#       love: 34
#       postbase: 34
#       postbase_instruct: 34
#       prebase: 34
#       prebase_instruct: 33
#       press: 703
#       press1: 492
#       relax: 34
#       relief: 34
#       sad: 34
#   Value columns (0):
#
# EEG.event events summary:
# Summary for column dictionary :
#   Categorical columns (4):
#     chanindex (2 distinct values):
#       : 1198
#       0: 1858
#     duration (120 distinct values):
#       0: 2674
#       100200: 1
#       100903: 1
#       102768: 1
#       105297: 1
#       105825: 1
#       106693: 1
#       110158: 1
#       120151: 1
#       123021: 1
#       130138: 1
#       13040: 1
#       130640: 1
#       14217: 1
#       14649: 1
#       149586: 1
#       150400: 1
#       15511: 1
#       158423: 1
#       158741: 1
#       161556: 1
#       161719: 1
#       161729: 1
#       165468: 1
#       166072: 1
#       16634: 1
#       166524: 1
#       169623: 1
#       17123: 1
#       173532: 1
#       174786: 1
#       176835: 1
#       178041: 1
#       178107: 1
#       178123: 1
#       181557: 1
#       188: 1
#       195255: 1
#       195257: 1
#       195303: 1
#       196159: 1
#       196161: 1
#       199056: 1
#       203648: 1
#       20721: 1
#       207522: 1
#       2113: 1
#       221560: 1
#       228666: 1
#       232291: 1
#       244628: 1
#       254342: 1
#       254396: 1
#       26419: 1
#       27347: 1
#       3: 144
#       30262: 1
#       31864: 1
#       37067: 1
#       4: 119
#       41801: 1
#       42607: 1
#       44216: 1
#       44273: 1
#       48325: 1
#       49184: 1
#       49187: 1
#       49192: 1
#       50950: 2
#       50952: 1
#       51595: 1
#       51596: 1
#       51597: 1
#       52453: 1
#       52686: 1
#       52703: 1
#       52757: 1
#       53970: 1
#       55730: 1
#       55731: 1
#       55812: 1
#       58425: 1
#       58426: 1
#       58966: 1
#       59011: 1
#       59014: 1
#       60402: 1
#       60403: 1
#       60405: 1
#       6110: 1
#       61493: 1
#       62033: 1
#       63597: 1
#       63598: 1
#       64619: 1
#       65718: 1
#       65802: 1
#       65803: 1
#       68358: 2
#       68359: 1
#       70292: 1
#       70325: 1
#       70353: 1
#       70354: 1
#       70356: 1
#       72655: 1
#       78295: 1
#       80387: 1
#       82305: 1
#       88293: 1
#       88534: 1
#       88642: 1
#       89152: 1
#       91093: 1
#       91375: 1
#       94712: 1
#       9535: 1
#       96539: 1
#       98722: 1
#       99400: 1
#     type (30 distinct values):
#       ExitThankYou: 34
#       FeelingItInstructionsButton: 18
#       FeelingItInstructionsNoButton: 19
#       ImaginationSuggestions: 34
#       InitialInstructions: 31
#       InstructionsForEnding: 34
#       anger: 34
#       awe: 35
#       compassion: 34
#       content: 34
#       disgust: 34
#       enter: 508
#       excite: 34
#       exit: 558
#       fear: 34
#       frustration: 34
#       grief: 34
#       happy: 34
#       jealousy: 34
#       joy: 34
#       love: 34
#       postbase: 34
#       postbase_instruct: 34
#       prebase: 34
#       prebase_instruct: 33
#       press: 703
#       press1: 492
#       relax: 34
#       relief: 34
#       sad: 34
#     urevent (148 distinct values):
#       : 1198
#       1: 9
#       10: 8
#       100: 15
#       101: 9
#       102: 14
#       103: 10
#       104: 10
#       105: 12
#       106: 10
#       107: 11
#       108: 8
#       109: 13
#       11: 33
#       110: 9
#       111: 14
#       112: 8
#       113: 19
#       114: 10
#       115: 15
#       116: 6
#       117: 3
#       118: 2
#       119: 1
#       12: 8
#       120: 2
#       124: 2
#       126: 1
#       128: 1
#       13: 33
#       130: 2
#       133: 1
#       134: 1
#       136: 1
#       137: 1
#       139: 1
#       14: 9
#       140: 1
#       142: 1
#       144: 1
#       146: 2
#       148: 1
#       15: 32
#       150: 1
#       151: 1
#       154: 1
#       155: 1
#       156: 1
#       157: 1
#       16: 9
#       161: 2
#       163: 1
#       165: 3
#       167: 1
#       17: 33
#       171: 1
#       173: 1
#       175: 2
#       18: 10
#       19: 29
#       2: 10
#       20: 6
#       21: 25
#       22: 13
#       23: 23
#       24: 19
#       25: 20
#       26: 21
#       27: 9
#       28: 28
#       29: 11
#       3: 36
#       30: 28
#       31: 10
#       32: 27
#       33: 11
#       34: 30
#       35: 8
#       36: 30
#       37: 10
#       38: 27
#       39: 12
#       4: 8
#       40: 23
#       41: 12
#       42: 23
#       43: 17
#       44: 23
#       45: 18
#       46: 16
#       47: 21
#       48: 18
#       49: 19
#       5: 36
#       50: 21
#       51: 19
#       52: 16
#       53: 23
#       54: 16
#       55: 24
#       56: 14
#       57: 24
#       58: 13
#       59: 21
#       6: 9
#       60: 15
#       61: 17
#       62: 12
#       63: 18
#       64: 12
#       65: 18
#       66: 10
#       67: 16
#       68: 11
#       69: 15
#       7: 54
#       70: 8
#       71: 15
#       72: 11
#       73: 14
#       74: 15
#       75: 15
#       76: 13
#       77: 11
#       78: 12
#       79: 15
#       8: 9
#       80: 12
#       81: 12
#       82: 12
#       83: 9
#       84: 16
#       85: 11
#       86: 14
#       87: 10
#       88: 16
#       89: 9
#       9: 36
#       90: 17
#       91: 7
#       92: 16
#       93: 12
#       94: 14
#       95: 13
#       96: 12
#       97: 10
#       98: 12
#       99: 11
#   Value columns (0):
