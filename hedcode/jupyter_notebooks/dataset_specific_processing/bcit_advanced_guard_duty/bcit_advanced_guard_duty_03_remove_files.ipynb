# %% [markdown]
# ## Remove the extra files
#
# This script assumes that you have copied the AdvancedGuardDutyWorking directory into
# the AdvancedGuardDutyWorkingPhaseTwo directory.
#
# This script removes `_events.tsv` and `_events_temp.tsv` and then
# renames `_events_temp1.tsv` to `_events.tsv`.

# %%
import os
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list, get_new_dataframe, get_value_dict, replace_values

# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/AdvancedGuardDutyWorkingPhaseTwo'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
log_file_name = 'bcit_advanced_guard_duty_03_remove_files_log.json'


# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary("Bids event files", files_bids, entities=entities)
sampling_dict = get_value_dict(sampling_rate_file)

# Set logger and remove the appropriate files
logger = HedLogger()

for key, file in bids_dict.iter_files():
    # Remove events.tsv
    filename = file.file_path
    os.remove(filename)
    logger.add(key, f"Remove {filename}")

    # Remove events_temp.tsv
    filename_temp = filename[:-4] + "_temp.tsv"
    if os.path.isfile(filename_temp):
        os.remove(filename_temp)
        logger.add(key, f"Removed {filename_temp}")
    else:
        logger.add(key, f"{filename_temp} does not exist and could not be removed", level="WARNING", also_print=True)

    # Move events_temp1.tsv to events.tsv
    filename_temp1 = filename[:-4] + "_temp1.tsv"
    if os.path.isfile(filename_temp1):
        os.rename(filename_temp1, filename)
        logger.add(key, f"Renamed {filename_temp1}\n\t\tto {filename}")
    else:
        logger.add(key, f"{filename_temp1} does not exist and could not be moved", level="WARNING", also_print=True)

# Now make sure there aren't any unexpected leftovers
temp_files = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp",
                           exclude_dirs=exclude_dirs)
if temp_files:
    for file in temp_files:
        logger.add('', f"{file} is unexpectedly left over", level="WARNING", also_print=True)

temp1_files = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp1",
                           exclude_dirs=exclude_dirs)
if temp1_files:
    for file in temp1_files:
        logger.add('', f"{file} is unexpectedly left over", level="WARNING", also_print=True)

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nWARNING Summary:")
logger.print_log(level="WARNING")
# Out:
# sub-01_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-01\ses-01\eeg\sub-01_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-01\ses-01\eeg\sub-01_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-01\ses-01\eeg\sub-01_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-01\ses-01\eeg\sub-01_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-02_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-02\ses-01\eeg\sub-02_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-02\ses-01\eeg\sub-02_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-02\ses-01\eeg\sub-02_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-02\ses-01\eeg\sub-02_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-03_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-03\ses-01\eeg\sub-03_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-03\ses-01\eeg\sub-03_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-03\ses-01\eeg\sub-03_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-03\ses-01\eeg\sub-03_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-04_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-04\ses-01\eeg\sub-04_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-04\ses-01\eeg\sub-04_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-04\ses-01\eeg\sub-04_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-04\ses-01\eeg\sub-04_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-05_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-05\ses-01\eeg\sub-05_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-05\ses-01\eeg\sub-05_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-05\ses-01\eeg\sub-05_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-05\ses-01\eeg\sub-05_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-06_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-06\ses-01\eeg\sub-06_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-06\ses-01\eeg\sub-06_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-06\ses-01\eeg\sub-06_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-06\ses-01\eeg\sub-06_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-07_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-07\ses-01\eeg\sub-07_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-07\ses-01\eeg\sub-07_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-07\ses-01\eeg\sub-07_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-07\ses-01\eeg\sub-07_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-08_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-08\ses-01\eeg\sub-08_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-08\ses-01\eeg\sub-08_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-08\ses-01\eeg\sub-08_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-08\ses-01\eeg\sub-08_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-09_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-09\ses-01\eeg\sub-09_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-09\ses-01\eeg\sub-09_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-09\ses-01\eeg\sub-09_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-09\ses-01\eeg\sub-09_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-10_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-10\ses-01\eeg\sub-10_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-10\ses-01\eeg\sub-10_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-10\ses-01\eeg\sub-10_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-10\ses-01\eeg\sub-10_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-11_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-11\ses-01\eeg\sub-11_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-11\ses-01\eeg\sub-11_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-11\ses-01\eeg\sub-11_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-11\ses-01\eeg\sub-11_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-12_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-12\ses-01\eeg\sub-12_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-12\ses-01\eeg\sub-12_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-12\ses-01\eeg\sub-12_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-12\ses-01\eeg\sub-12_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-13_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-13\ses-01\eeg\sub-13_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-13\ses-01\eeg\sub-13_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-13\ses-01\eeg\sub-13_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-13\ses-01\eeg\sub-13_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-14_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-14\ses-01\eeg\sub-14_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-14\ses-01\eeg\sub-14_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-14\ses-01\eeg\sub-14_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-14\ses-01\eeg\sub-14_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-15_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-15\ses-01\eeg\sub-15_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-15\ses-01\eeg\sub-15_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-15\ses-01\eeg\sub-15_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-15\ses-01\eeg\sub-15_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-16_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-16\ses-01\eeg\sub-16_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-16\ses-01\eeg\sub-16_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-16\ses-01\eeg\sub-16_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-16\ses-01\eeg\sub-16_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-17_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-17_ses-01_run-2:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-2_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-2_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-2_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-17\ses-01\eeg\sub-17_ses-01_task-GuardDuty_run-2_events.tsv]
# sub-18_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-18\ses-01\eeg\sub-18_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-18\ses-01\eeg\sub-18_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-18\ses-01\eeg\sub-18_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-18\ses-01\eeg\sub-18_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-19_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-19\ses-01\eeg\sub-19_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-19\ses-01\eeg\sub-19_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-19\ses-01\eeg\sub-19_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-19\ses-01\eeg\sub-19_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-20_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-20\ses-01\eeg\sub-20_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-20\ses-01\eeg\sub-20_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-20\ses-01\eeg\sub-20_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-20\ses-01\eeg\sub-20_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-21_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-21\ses-01\eeg\sub-21_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-21\ses-01\eeg\sub-21_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-21\ses-01\eeg\sub-21_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-21\ses-01\eeg\sub-21_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-22_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-22\ses-01\eeg\sub-22_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-22\ses-01\eeg\sub-22_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-22\ses-01\eeg\sub-22_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-22\ses-01\eeg\sub-22_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-23_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-23\ses-01\eeg\sub-23_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-23\ses-01\eeg\sub-23_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-23\ses-01\eeg\sub-23_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-23\ses-01\eeg\sub-23_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-24_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-24\ses-01\eeg\sub-24_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-24\ses-01\eeg\sub-24_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-24\ses-01\eeg\sub-24_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-24\ses-01\eeg\sub-24_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-25_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-25_ses-01_run-2:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-2_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-2_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-2_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-25\ses-01\eeg\sub-25_ses-01_task-GuardDuty_run-2_events.tsv]
# sub-26_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-26\ses-01\eeg\sub-26_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-26\ses-01\eeg\sub-26_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-26\ses-01\eeg\sub-26_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-26\ses-01\eeg\sub-26_ses-01_task-GuardDuty_run-1_events.tsv]
# sub-27_ses-01_run-1:
# 	[ Remove F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-27\ses-01\eeg\sub-27_ses-01_task-GuardDuty_run-1_events.tsv]
# 	[ Removed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-27\ses-01\eeg\sub-27_ses-01_task-GuardDuty_run-1_events_temp.tsv]
# 	[ Renamed F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-27\ses-01\eeg\sub-27_ses-01_task-GuardDuty_run-1_events_temp1.tsv
# 		to F:\ARLBidsStart\AdvancedGuardDutyWorkingPhaseTwo\sub-27\ses-01\eeg\sub-27_ses-01_task-GuardDuty_run-1_events.tsv]
#
# WARNING Summary:
# sub-01_ses-01_run-1:
# sub-02_ses-01_run-1:
# sub-03_ses-01_run-1:
# sub-04_ses-01_run-1:
# sub-05_ses-01_run-1:
# sub-06_ses-01_run-1:
# sub-07_ses-01_run-1:
# sub-08_ses-01_run-1:
# sub-09_ses-01_run-1:
# sub-10_ses-01_run-1:
# sub-11_ses-01_run-1:
# sub-12_ses-01_run-1:
# sub-13_ses-01_run-1:
# sub-14_ses-01_run-1:
# sub-15_ses-01_run-1:
# sub-16_ses-01_run-1:
# sub-17_ses-01_run-1:
# sub-17_ses-01_run-2:
# sub-18_ses-01_run-1:
# sub-19_ses-01_run-1:
# sub-20_ses-01_run-1:
# sub-21_ses-01_run-1:
# sub-22_ses-01_run-1:
# sub-23_ses-01_run-1:
# sub-24_ses-01_run-1:
# sub-25_ses-01_run-1:
# sub-25_ses-01_run-2:
# sub-26_ses-01_run-1:
# sub-27_ses-01_run-1:
