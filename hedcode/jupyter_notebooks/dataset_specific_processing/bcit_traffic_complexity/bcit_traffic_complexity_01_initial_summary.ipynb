# %% [markdown]
# ## Initial summary of event files
#
# **Dataset** BCIT Traffic Complexity (in process)
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
# Keys are specified by a `entities` tuple lists the BIDS entity names
# to include in the key.
# BIDS base file names are constructed of entity *name*-*value* pairs separated
# by underbars and followed by an ending *_suffix*.
#
# For a file name `sub-001_ses-3_task-target_run-01_events.tsv`,
# the tuple ('sub', 'task') gives a key of `sub-001_task-target`,
# while the tuple ('sub', 'ses', 'run) gives a key of `sub-001_ses-3_run-01`.
# The use of dictionaries of file names with such keys makes it
# easier to associate related files in the BIDS naming structure.
#
# The setup requires the setting of the following variables for your dataset:
#
# | Variable | Purpose |
# | -------- | ------- |
# | bids_root_path | Full path to root directory of dataset.|
# | exclude_dirs | List of directories to exclude when constructing file lists. |
# | entities  | Tuple of entity names used to construct a unique keys representing filenames. <br>(See [Dictionaries of filenames](https://hed-examples.readthedocs.io/en/latest/HedInPython.html#dictionaries-of-filenames-anchor) for examples of how to choose the keys.)|
# | bids_skip_columns  |  List of column names in the `events.tsv` files to skip in the analysis. |
# | eeg_skip_columns  | List of column names in the `events_temp.tsv` files form EEG.events to skip in analysis.|
# | log_file_name | Name of the log file (saved in the `code` subdirectory). |

# %%
import os
from hed.tools import BidsTsvDictionary, BidsTsvSummary, HedLogger, report_tsv_diffs
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/TrafficComplexityWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
bids_skip_columns = ['onset']
eeg_skip_columns = ['latency', 'urevent', 'usertags']
log_file_name = 'bcit_traffic_complexity_01_initial_summary_log.json'

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary("Bids event files", files_bids, entities=entities)
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary("EEG event files", files_eeg, entities=entities)

# Set logger and Output a list of files for the two cases
logger = HedLogger()
report_tsv_diffs(bids_dict, eeg_dict, logger)

# Create summary dictionaries of the original BIDS events files and output column names
bids_sum_all, bids_sum =  BidsTsvSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip_columns)
bids_sum_all.print('\nBIDS events summary')

eeg_sum_all, eeg_sum =  BidsTsvSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip_columns)
eeg_sum_all.print('\nEEG.event events summary')

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# Summarizing Bids event files...
#
# Bids event files event files (30 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-19_ses-01_run-2: sub-19_ses-01_task-DriveWithComplexity_run-2_events.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-22_ses-01_run-1: sub-22_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-23_ses-01_run-1: sub-23_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-24_ses-01_run-1: sub-24_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-25_ses-01_run-1: sub-25_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-26_ses-01_run-1: sub-26_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-27_ses-01_run-1: sub-27_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-28_ses-01_run-1: sub-28_ses-01_task-DriveWithComplexity_run-1_events.tsv
# sub-29_ses-01_run-1: sub-29_ses-01_task-DriveWithComplexity_run-1_events.tsv
#
# EEG event files event files (30 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-19_ses-01_run-2: sub-19_ses-01_task-DriveWithComplexity_run-2_events_temp.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-22_ses-01_run-1: sub-22_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-23_ses-01_run-1: sub-23_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-24_ses-01_run-1: sub-24_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-25_ses-01_run-1: sub-25_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-26_ses-01_run-1: sub-26_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-27_ses-01_run-1: sub-27_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-28_ses-01_run-1: sub-28_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
# sub-29_ses-01_run-1: sub-29_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv
#
# Bids event files event file columns:
# sub-01_ses-01_run-1 []: Bids event files: [978 events] ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-1 []: Bids event files: [1042 events] ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-1 []: Bids event files: [1050 events] ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-1 []: Bids event files: [911 events] ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-1 []: Bids event files: [1024 events] ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-1 []: Bids event files: [1046 events] ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-1 []: Bids event files: [685 events] ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-1 []: Bids event files: [1034 events] ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-1 []: Bids event files: [1113 events] ['onset', 'duration', 'event_code']
# sub-10_ses-01_run-1 []: Bids event files: [1018 events] ['onset', 'duration', 'event_code']
# sub-11_ses-01_run-1 []: Bids event files: [1060 events] ['onset', 'duration', 'event_code']
# sub-12_ses-01_run-1 []: Bids event files: [987 events] ['onset', 'duration', 'event_code']
# sub-13_ses-01_run-1 []: Bids event files: [1028 events] ['onset', 'duration', 'event_code']
# sub-14_ses-01_run-1 []: Bids event files: [1061 events] ['onset', 'duration', 'event_code']
# sub-15_ses-01_run-1 []: Bids event files: [950 events] ['onset', 'duration', 'event_code']
# sub-16_ses-01_run-1 []: Bids event files: [1040 events] ['onset', 'duration', 'event_code']
# sub-17_ses-01_run-1 []: Bids event files: [1014 events] ['onset', 'duration', 'event_code']
# sub-18_ses-01_run-1 []: Bids event files: [1081 events] ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-1 []: Bids event files: [1088 events] ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-2 []: Bids event files: [1088 events] ['onset', 'duration', 'event_code']
# sub-20_ses-01_run-1 []: Bids event files: [1119 events] ['onset', 'duration', 'event_code']
# sub-21_ses-01_run-1 []: Bids event files: [1085 events] ['onset', 'duration', 'event_code']
# sub-22_ses-01_run-1 []: Bids event files: [1209 events] ['onset', 'duration', 'event_code']
# sub-23_ses-01_run-1 []: Bids event files: [1061 events] ['onset', 'duration', 'event_code']
# sub-24_ses-01_run-1 []: Bids event files: [1001 events] ['onset', 'duration', 'event_code']
# sub-25_ses-01_run-1 []: Bids event files: [993 events] ['onset', 'duration', 'event_code']
# sub-26_ses-01_run-1 []: Bids event files: [916 events] ['onset', 'duration', 'event_code']
# sub-27_ses-01_run-1 []: Bids event files: [1301 events] ['onset', 'duration', 'event_code']
# sub-28_ses-01_run-1 []: Bids event files: [1036 events] ['onset', 'duration', 'event_code']
# sub-29_ses-01_run-1 []: Bids event files: [718 events] ['onset', 'duration', 'event_code']
#
# EEG event files event file columns:
# sub-01_ses-01_run-1 []: EEG event files: [978 events] ['type', 'latency', 'urevent', 'usertags']
# sub-02_ses-01_run-1 []: EEG event files: [1042 events] ['type', 'latency', 'urevent', 'usertags']
# sub-03_ses-01_run-1 []: EEG event files: [1050 events] ['type', 'latency', 'urevent', 'usertags']
# sub-04_ses-01_run-1 []: EEG event files: [911 events] ['type', 'latency', 'urevent', 'usertags']
# sub-05_ses-01_run-1 []: EEG event files: [1024 events] ['type', 'latency', 'urevent', 'usertags']
# sub-06_ses-01_run-1 []: EEG event files: [1046 events] ['type', 'latency', 'urevent', 'usertags']
# sub-07_ses-01_run-1 []: EEG event files: [685 events] ['type', 'latency', 'urevent', 'usertags']
# sub-08_ses-01_run-1 []: EEG event files: [1034 events] ['type', 'latency', 'urevent', 'usertags']
# sub-09_ses-01_run-1 []: EEG event files: [1113 events] ['type', 'latency', 'urevent', 'usertags']
# sub-10_ses-01_run-1 []: EEG event files: [1018 events] ['type', 'latency', 'urevent', 'usertags']
# sub-11_ses-01_run-1 []: EEG event files: [1060 events] ['type', 'latency', 'urevent', 'usertags']
# sub-12_ses-01_run-1 []: EEG event files: [987 events] ['type', 'latency', 'urevent', 'usertags']
# sub-13_ses-01_run-1 []: EEG event files: [1028 events] ['type', 'latency', 'urevent', 'usertags']
# sub-14_ses-01_run-1 []: EEG event files: [1061 events] ['type', 'latency', 'urevent', 'usertags']
# sub-15_ses-01_run-1 []: EEG event files: [950 events] ['type', 'latency', 'urevent', 'usertags']
# sub-16_ses-01_run-1 []: EEG event files: [1040 events] ['type', 'latency', 'urevent', 'usertags']
# sub-17_ses-01_run-1 []: EEG event files: [1014 events] ['type', 'latency', 'urevent', 'usertags']
# sub-18_ses-01_run-1 []: EEG event files: [1081 events] ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-1 []: EEG event files: [1102 events] ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-2 []: EEG event files: [1088 events] ['type', 'latency', 'urevent', 'usertags']
# sub-20_ses-01_run-1 []: EEG event files: [1119 events] ['type', 'latency', 'urevent', 'usertags']
# sub-21_ses-01_run-1 []: EEG event files: [1085 events] ['type', 'latency', 'urevent', 'usertags']
# sub-22_ses-01_run-1 []: EEG event files: [1209 events] ['type', 'latency', 'urevent', 'usertags']
# sub-23_ses-01_run-1 []: EEG event files: [1061 events] ['type', 'latency', 'urevent', 'usertags']
# sub-24_ses-01_run-1 []: EEG event files: [1001 events] ['type', 'latency', 'urevent', 'usertags']
# sub-25_ses-01_run-1 []: EEG event files: [993 events] ['type', 'latency', 'urevent', 'usertags']
# sub-26_ses-01_run-1 []: EEG event files: [916 events] ['type', 'latency', 'urevent', 'usertags']
# sub-27_ses-01_run-1 []: EEG event files: [1301 events] ['type', 'latency', 'urevent', 'usertags']
# sub-28_ses-01_run-1 []: EEG event files: [1036 events] ['type', 'latency', 'urevent', 'usertags']
# sub-29_ses-01_run-1 []: EEG event files: [718 events] ['type', 'latency', 'urevent', 'usertags']
#
# The number of Bids event files events and EEG event files events differ for the following files:
# sub-19_ses-01_run-1 [ERROR]: The Bids event files file has 1088 rows and the EEG event files event file has 1102 rows
#
# BIDS events summary
#   Categorical columns (2):
#     duration (1 distinct values):
#       n/a: 30737
#     event_code (37 distinct values):
#       1111: 1523
#       1112: 1523
#       1121: 1555
#       1122: 1555
#       1211: 30
#       1212: 30
#       2221: 524
#       2222: 524
#       2241: 328
#       2242: 328
#       2251: 273
#       2252: 273
#       2421: 5
#       2422: 5
#       2441: 53
#       2442: 53
#       2621: 758
#       2622: 758
#       2711: 115
#       2712: 115
#       2811: 456
#       2812: 456
#       3111: 30
#       3112: 30
#       3200: 50
#       3210: 522
#       3220: 491
#       3230: 504
#       3240: 489
#       3310: 30
#       4210: 5195
#       4220: 2471
#       4230: 2745
#       4311: 3047
#       4312: 3043
#       4411: 845
#       4421: 5
#   Value columns (0):
#
# EEG.event events summary
#   Categorical columns (1):
#     type (37 distinct values):
#       1111: 1524
#       1112: 1524
#       1121: 1569
#       1122: 1569
#       1211: 30
#       1212: 30
#       2221: 524
#       2222: 524
#       2241: 328
#       2242: 328
#       2251: 273
#       2252: 273
#       2421: 5
#       2422: 5
#       2441: 52
#       2442: 52
#       2621: 756
#       2622: 756
#       2711: 115
#       2712: 115
#       2811: 456
#       2812: 456
#       3111: 30
#       3112: 30
#       3200: 49
#       3210: 522
#       3220: 491
#       3230: 504
#       3240: 487
#       3310: 30
#       4210: 5172
#       4220: 2447
#       4230: 2747
#       4311: 3063
#       4312: 3059
#       4411: 850
#       4421: 6
#   Value columns (0):
# overall:
# 	[ Bids event files has 30 event files]
# 	[ EEG event files has 30 event files]
# sub-01_ses-01_run-1:
# 	[ Bids event files: sub-01_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [978 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [978 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-02_ses-01_run-1:
# 	[ Bids event files: sub-02_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1042 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1042 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-03_ses-01_run-1:
# 	[ Bids event files: sub-03_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-03_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1050 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1050 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-04_ses-01_run-1:
# 	[ Bids event files: sub-04_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-04_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [911 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [911 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-05_ses-01_run-1:
# 	[ Bids event files: sub-05_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-05_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1024 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1024 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-06_ses-01_run-1:
# 	[ Bids event files: sub-06_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-06_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1046 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1046 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-07_ses-01_run-1:
# 	[ Bids event files: sub-07_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-07_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [685 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [685 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-08_ses-01_run-1:
# 	[ Bids event files: sub-08_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1034 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1034 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-09_ses-01_run-1:
# 	[ Bids event files: sub-09_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1113 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1113 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-10_ses-01_run-1:
# 	[ Bids event files: sub-10_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1018 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1018 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-11_ses-01_run-1:
# 	[ Bids event files: sub-11_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-11_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1060 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1060 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-12_ses-01_run-1:
# 	[ Bids event files: sub-12_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-12_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [987 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [987 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-13_ses-01_run-1:
# 	[ Bids event files: sub-13_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-13_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1028 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1028 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-14_ses-01_run-1:
# 	[ Bids event files: sub-14_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-14_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1061 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1061 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-15_ses-01_run-1:
# 	[ Bids event files: sub-15_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-15_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [950 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [950 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-16_ses-01_run-1:
# 	[ Bids event files: sub-16_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-16_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1040 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1040 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-17_ses-01_run-1:
# 	[ Bids event files: sub-17_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-17_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1014 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1014 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-18_ses-01_run-1:
# 	[ Bids event files: sub-18_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-18_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1081 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1081 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-19_ses-01_run-1:
# 	[ Bids event files: sub-19_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-19_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1088 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1102 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1088 rows and the EEG event files event file has 1102 rows]
# sub-19_ses-01_run-2:
# 	[ Bids event files: sub-19_ses-01_task-DriveWithComplexity_run-2_events.tsv]
# 	[ EEG event files: sub-19_ses-01_task-DriveWithComplexity_run-2_events_temp.tsv]
# 	[ Bids event files: [1088 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1088 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-20_ses-01_run-1:
# 	[ Bids event files: sub-20_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-20_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1119 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1119 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-21_ses-01_run-1:
# 	[ Bids event files: sub-21_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-21_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1085 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1085 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-22_ses-01_run-1:
# 	[ Bids event files: sub-22_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-22_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1209 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1209 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-23_ses-01_run-1:
# 	[ Bids event files: sub-23_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-23_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1061 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1061 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-24_ses-01_run-1:
# 	[ Bids event files: sub-24_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-24_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1001 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1001 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-25_ses-01_run-1:
# 	[ Bids event files: sub-25_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-25_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [993 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [993 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-26_ses-01_run-1:
# 	[ Bids event files: sub-26_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-26_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [916 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [916 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-27_ses-01_run-1:
# 	[ Bids event files: sub-27_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-27_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1301 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1301 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-28_ses-01_run-1:
# 	[ Bids event files: sub-28_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-28_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [1036 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1036 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-29_ses-01_run-1:
# 	[ Bids event files: sub-29_ses-01_task-DriveWithComplexity_run-1_events.tsv]
# 	[ EEG event files: sub-29_ses-01_task-DriveWithComplexity_run-1_events_temp.tsv]
# 	[ Bids event files: [718 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [718 events] ['type', 'latency', 'urevent', 'usertags']]
#
# ERROR Summary:
# overall:
# sub-01_ses-01_run-1:
# sub-02_ses-01_run-1:
# sub-03_ses-01_run-1:
# sub-04_ses-01_run-1:
# sub-05_ses-01_run-1:
# sub-06_ses-01_run-1:
# sub-07_ses-01_run-1:
# sub-08_ses-01_run-1:
# sub-09_ses-01_run-1:
# sub-10_ses-01_run-1:
# sub-11_ses-01_run-1:
# sub-12_ses-01_run-1:
# sub-13_ses-01_run-1:
# sub-14_ses-01_run-1:
# sub-15_ses-01_run-1:
# sub-16_ses-01_run-1:
# sub-17_ses-01_run-1:
# sub-18_ses-01_run-1:
# sub-19_ses-01_run-1:
# 	[ERROR The Bids event files file has 1088 rows and the EEG event files event file has 1102 rows]
# sub-19_ses-01_run-2:
# sub-20_ses-01_run-1:
# sub-21_ses-01_run-1:
# sub-22_ses-01_run-1:
# sub-23_ses-01_run-1:
# sub-24_ses-01_run-1:
# sub-25_ses-01_run-1:
# sub-26_ses-01_run-1:
# sub-27_ses-01_run-1:
# sub-28_ses-01_run-1:
# sub-29_ses-01_run-1:
