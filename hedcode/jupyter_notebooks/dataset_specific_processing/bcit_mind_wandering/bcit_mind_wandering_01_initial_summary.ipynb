# %% [markdown]
# ## Initial summary of event files
#
# **Dataset** BCIT Mind Wandering (in process)
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
# Keys are specified by a `entities` tuple lists the BIDS entity names
# to include in the key.
# BIDS base file names are constructed of entity *name*-*value* pairs separated
# by underbars and followed by an ending *_suffix*.
#
# For a file name `sub-001_ses-3_task-target_run-01_events.tsv`,
# the tuple ('sub', 'task') gives a key of `sub-001_task-target`,
# while the tuple ('sub', 'ses', 'run) gives a key of `sub-001_ses-3_run-01`.
# The use of dictionaries of file names with such keys makes it
# easier to associate related files in the BIDS naming structure.
#
# The setup requires the setting of the following variables for your dataset:
#
# | Variable | Purpose |
# | -------- | ------- |
# | bids_root_path | Full path to root directory of dataset.|
# | exclude_dirs | List of directories to exclude when constructing file lists. |
# | entities  | Tuple of entity names used to construct a unique keys representing filenames. <br>(See [Dictionaries of filenames](https://hed-examples.readthedocs.io/en/latest/HedInPython.html#dictionaries-of-filenames-anchor) for examples of how to choose the keys.)|
# | bids_skip_columns  |  List of column names in the `events.tsv` files to skip in the analysis. |
# | eeg_skip_columns  | List of column names in the `events_temp.tsv` files form EEG.events to skip in analysis.|
# | log_file_name | Name of the log file (saved in the `code` subdirectory). |

# %%
import os
from hed.tools import BidsTsvDictionary, BidsTsvSummary, HedLogger, report_tsv_diffs
from hed.util import get_file_list

# Variables to set for the specific dataset
# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/MindWanderingWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
bids_skip_columns = ['onset']
eeg_skip_columns = ['latency', 'urevent', 'usertags']
log_file_name = 'bcit_mind_wandering_01_initial_summary_log.json'

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary("Bids event files", files_bids, entities=entities)
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary("EEG event files", files_eeg, entities=entities)

# Set logger and Output a list of files for the two cases
logger = HedLogger()
report_tsv_diffs(bids_dict, eeg_dict, logger)

# Create summary dictionaries of the original BIDS events files and output column names
bids_sum_all, bids_sum =  BidsTsvSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip_columns)
bids_sum_all.print('\nBIDS events summary')

eeg_sum_all, eeg_sum =  BidsTsvSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip_columns)
eeg_sum_all.print('\nEEG.event events summary')

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# Summarizing Bids event files...
#
# Bids event files event files (60 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-01_ses-01_run-2: sub-01_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-01_ses-01_run-3: sub-01_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-02_ses-01_run-2: sub-02_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-02_ses-01_run-3: sub-02_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-03_ses-01_run-2: sub-03_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-03_ses-01_run-3: sub-03_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-04_ses-01_run-2: sub-04_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-04_ses-01_run-3: sub-04_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-05_ses-01_run-2: sub-05_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-05_ses-01_run-3: sub-05_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-06_ses-01_run-2: sub-06_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-06_ses-01_run-3: sub-06_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-07_ses-01_run-2: sub-07_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-07_ses-01_run-3: sub-07_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-08_ses-01_run-2: sub-08_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-09_ses-01_run-2: sub-09_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-09_ses-01_run-3: sub-09_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-11_ses-01_run-2: sub-11_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-11_ses-01_run-3: sub-11_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-12_ses-01_run-2: sub-12_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-12_ses-01_run-3: sub-12_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-13_ses-01_run-2: sub-13_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-13_ses-01_run-3: sub-13_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-14_ses-01_run-2: sub-14_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-14_ses-01_run-3: sub-14_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-15_ses-01_run-2: sub-15_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-15_ses-01_run-3: sub-15_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-16_ses-01_run-2: sub-16_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-16_ses-01_run-3: sub-16_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-17_ses-01_run-2: sub-17_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-17_ses-01_run-3: sub-17_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-18_ses-01_run-2: sub-18_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-18_ses-01_run-3: sub-18_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-19_ses-01_run-2: sub-19_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-19_ses-01_run-3: sub-19_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-20_ses-01_run-2: sub-20_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-20_ses-01_run-3: sub-20_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-DriveWithTaskAudio_run-1_events.tsv
# sub-21_ses-01_run-2: sub-21_ses-01_task-DriveWithTaskAudio_run-2_events.tsv
# sub-21_ses-01_run-3: sub-21_ses-01_task-DriveWithTaskAudio_run-3_events.tsv
#
# EEG event files event files (60 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-01_ses-01_run-2: sub-01_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-01_ses-01_run-3: sub-01_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-02_ses-01_run-2: sub-02_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-02_ses-01_run-3: sub-02_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-03_ses-01_run-2: sub-03_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-03_ses-01_run-3: sub-03_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-04_ses-01_run-2: sub-04_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-04_ses-01_run-3: sub-04_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-05_ses-01_run-2: sub-05_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-05_ses-01_run-3: sub-05_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-06_ses-01_run-2: sub-06_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-06_ses-01_run-3: sub-06_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-07_ses-01_run-2: sub-07_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-07_ses-01_run-3: sub-07_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-08_ses-01_run-2: sub-08_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-09_ses-01_run-2: sub-09_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-09_ses-01_run-3: sub-09_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-11_ses-01_run-2: sub-11_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-11_ses-01_run-3: sub-11_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-12_ses-01_run-2: sub-12_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-12_ses-01_run-3: sub-12_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-13_ses-01_run-2: sub-13_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-13_ses-01_run-3: sub-13_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-14_ses-01_run-2: sub-14_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-14_ses-01_run-3: sub-14_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-15_ses-01_run-2: sub-15_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-15_ses-01_run-3: sub-15_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-16_ses-01_run-2: sub-16_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-16_ses-01_run-3: sub-16_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-17_ses-01_run-2: sub-17_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-17_ses-01_run-3: sub-17_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-18_ses-01_run-2: sub-18_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-18_ses-01_run-3: sub-18_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-19_ses-01_run-2: sub-19_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-19_ses-01_run-3: sub-19_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-20_ses-01_run-2: sub-20_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-20_ses-01_run-3: sub-20_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv
# sub-21_ses-01_run-2: sub-21_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv
# sub-21_ses-01_run-3: sub-21_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv
#
# Bids event files event file columns:
# sub-01_ses-01_run-1 []: Bids event files: [1420 events] ['onset', 'duration', 'event_code']
# sub-01_ses-01_run-2 []: Bids event files: [1420 events] ['onset', 'duration', 'event_code']
# sub-01_ses-01_run-3 []: Bids event files: [1420 events] ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-1 []: Bids event files: [1466 events] ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-2 []: Bids event files: [1466 events] ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-3 []: Bids event files: [1466 events] ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-1 []: Bids event files: [1383 events] ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-2 []: Bids event files: [1383 events] ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-3 []: Bids event files: [1383 events] ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-1 []: Bids event files: [1308 events] ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-2 []: Bids event files: [1308 events] ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-3 []: Bids event files: [1308 events] ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-1 []: Bids event files: [1355 events] ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-2 []: Bids event files: [1355 events] ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-3 []: Bids event files: [1355 events] ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-1 []: Bids event files: [1364 events] ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-2 []: Bids event files: [1364 events] ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-3 []: Bids event files: [1364 events] ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-1 []: Bids event files: [1384 events] ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-2 []: Bids event files: [1384 events] ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-3 []: Bids event files: [1384 events] ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-1 []: Bids event files: [930 events] ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-2 []: Bids event files: [930 events] ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-1 []: Bids event files: [1387 events] ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-2 []: Bids event files: [1387 events] ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-3 []: Bids event files: [1387 events] ['onset', 'duration', 'event_code']
# sub-10_ses-01_run-1 []: Bids event files: [230 events] ['onset', 'duration', 'event_code']
# sub-11_ses-01_run-1 []: Bids event files: [1346 events] ['onset', 'duration', 'event_code']
# sub-11_ses-01_run-2 []: Bids event files: [1346 events] ['onset', 'duration', 'event_code']
# sub-11_ses-01_run-3 []: Bids event files: [1346 events] ['onset', 'duration', 'event_code']
# sub-12_ses-01_run-1 []: Bids event files: [1474 events] ['onset', 'duration', 'event_code']
# sub-12_ses-01_run-2 []: Bids event files: [1474 events] ['onset', 'duration', 'event_code']
# sub-12_ses-01_run-3 []: Bids event files: [1474 events] ['onset', 'duration', 'event_code']
# sub-13_ses-01_run-1 []: Bids event files: [1361 events] ['onset', 'duration', 'event_code']
# sub-13_ses-01_run-2 []: Bids event files: [1361 events] ['onset', 'duration', 'event_code']
# sub-13_ses-01_run-3 []: Bids event files: [1361 events] ['onset', 'duration', 'event_code']
# sub-14_ses-01_run-1 []: Bids event files: [1383 events] ['onset', 'duration', 'event_code']
# sub-14_ses-01_run-2 []: Bids event files: [1383 events] ['onset', 'duration', 'event_code']
# sub-14_ses-01_run-3 []: Bids event files: [1383 events] ['onset', 'duration', 'event_code']
# sub-15_ses-01_run-1 []: Bids event files: [1336 events] ['onset', 'duration', 'event_code']
# sub-15_ses-01_run-2 []: Bids event files: [1336 events] ['onset', 'duration', 'event_code']
# sub-15_ses-01_run-3 []: Bids event files: [1336 events] ['onset', 'duration', 'event_code']
# sub-16_ses-01_run-1 []: Bids event files: [1380 events] ['onset', 'duration', 'event_code']
# sub-16_ses-01_run-2 []: Bids event files: [1380 events] ['onset', 'duration', 'event_code']
# sub-16_ses-01_run-3 []: Bids event files: [1380 events] ['onset', 'duration', 'event_code']
# sub-17_ses-01_run-1 []: Bids event files: [1399 events] ['onset', 'duration', 'event_code']
# sub-17_ses-01_run-2 []: Bids event files: [1399 events] ['onset', 'duration', 'event_code']
# sub-17_ses-01_run-3 []: Bids event files: [1399 events] ['onset', 'duration', 'event_code']
# sub-18_ses-01_run-1 []: Bids event files: [1235 events] ['onset', 'duration', 'event_code']
# sub-18_ses-01_run-2 []: Bids event files: [1235 events] ['onset', 'duration', 'event_code']
# sub-18_ses-01_run-3 []: Bids event files: [1235 events] ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-1 []: Bids event files: [1432 events] ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-2 []: Bids event files: [1432 events] ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-3 []: Bids event files: [1432 events] ['onset', 'duration', 'event_code']
# sub-20_ses-01_run-1 []: Bids event files: [1399 events] ['onset', 'duration', 'event_code']
# sub-20_ses-01_run-2 []: Bids event files: [1399 events] ['onset', 'duration', 'event_code']
# sub-20_ses-01_run-3 []: Bids event files: [1399 events] ['onset', 'duration', 'event_code']
# sub-21_ses-01_run-1 []: Bids event files: [1422 events] ['onset', 'duration', 'event_code']
# sub-21_ses-01_run-2 []: Bids event files: [1422 events] ['onset', 'duration', 'event_code']
# sub-21_ses-01_run-3 []: Bids event files: [1422 events] ['onset', 'duration', 'event_code']
#
# EEG event files event file columns:
# sub-01_ses-01_run-1 []: EEG event files: [1458 events] ['type', 'latency', 'urevent', 'usertags']
# sub-01_ses-01_run-2 []: EEG event files: [1499 events] ['type', 'latency', 'urevent', 'usertags']
# sub-01_ses-01_run-3 []: EEG event files: [1420 events] ['type', 'latency', 'urevent', 'usertags']
# sub-02_ses-01_run-1 []: EEG event files: [1472 events] ['type', 'latency', 'urevent', 'usertags']
# sub-02_ses-01_run-2 []: EEG event files: [1438 events] ['type', 'latency', 'urevent', 'usertags']
# sub-02_ses-01_run-3 []: EEG event files: [1466 events] ['type', 'latency', 'urevent', 'usertags']
# sub-03_ses-01_run-1 []: EEG event files: [1385 events] ['type', 'latency', 'urevent', 'usertags']
# sub-03_ses-01_run-2 []: EEG event files: [1345 events] ['type', 'latency', 'urevent', 'usertags']
# sub-03_ses-01_run-3 []: EEG event files: [1383 events] ['type', 'latency', 'urevent', 'usertags']
# sub-04_ses-01_run-1 []: EEG event files: [1243 events] ['type', 'latency', 'urevent', 'usertags']
# sub-04_ses-01_run-2 []: EEG event files: [1305 events] ['type', 'latency', 'urevent', 'usertags']
# sub-04_ses-01_run-3 []: EEG event files: [1308 events] ['type', 'latency', 'urevent', 'usertags']
# sub-05_ses-01_run-1 []: EEG event files: [1491 events] ['type', 'latency', 'urevent', 'usertags']
# sub-05_ses-01_run-2 []: EEG event files: [1345 events] ['type', 'latency', 'urevent', 'usertags']
# sub-05_ses-01_run-3 []: EEG event files: [1355 events] ['type', 'latency', 'urevent', 'usertags']
# sub-06_ses-01_run-1 []: EEG event files: [1360 events] ['type', 'latency', 'urevent', 'usertags']
# sub-06_ses-01_run-2 []: EEG event files: [1362 events] ['type', 'latency', 'urevent', 'usertags']
# sub-06_ses-01_run-3 []: EEG event files: [1364 events] ['type', 'latency', 'urevent', 'usertags']
# sub-07_ses-01_run-1 []: EEG event files: [1469 events] ['type', 'latency', 'urevent', 'usertags']
# sub-07_ses-01_run-2 []: EEG event files: [1386 events] ['type', 'latency', 'urevent', 'usertags']
# sub-07_ses-01_run-3 []: EEG event files: [1384 events] ['type', 'latency', 'urevent', 'usertags']
# sub-08_ses-01_run-1 []: EEG event files: [1557 events] ['type', 'latency', 'urevent', 'usertags']
# sub-08_ses-01_run-2 []: EEG event files: [930 events] ['type', 'latency', 'urevent', 'usertags']
# sub-09_ses-01_run-1 []: EEG event files: [1319 events] ['type', 'latency', 'urevent', 'usertags']
# sub-09_ses-01_run-2 []: EEG event files: [1348 events] ['type', 'latency', 'urevent', 'usertags']
# sub-09_ses-01_run-3 []: EEG event files: [1387 events] ['type', 'latency', 'urevent', 'usertags']
# sub-10_ses-01_run-1 []: EEG event files: [230 events] ['type', 'latency', 'urevent', 'usertags']
# sub-11_ses-01_run-1 []: EEG event files: [1274 events] ['type', 'latency', 'urevent', 'usertags']
# sub-11_ses-01_run-2 []: EEG event files: [1280 events] ['type', 'latency', 'urevent', 'usertags']
# sub-11_ses-01_run-3 []: EEG event files: [1346 events] ['type', 'latency', 'urevent', 'usertags']
# sub-12_ses-01_run-1 []: EEG event files: [1482 events] ['type', 'latency', 'urevent', 'usertags']
# sub-12_ses-01_run-2 []: EEG event files: [1409 events] ['type', 'latency', 'urevent', 'usertags']
# sub-12_ses-01_run-3 []: EEG event files: [1474 events] ['type', 'latency', 'urevent', 'usertags']
# sub-13_ses-01_run-1 []: EEG event files: [1480 events] ['type', 'latency', 'urevent', 'usertags']
# sub-13_ses-01_run-2 []: EEG event files: [1468 events] ['type', 'latency', 'urevent', 'usertags']
# sub-13_ses-01_run-3 []: EEG event files: [1361 events] ['type', 'latency', 'urevent', 'usertags']
# sub-14_ses-01_run-1 []: EEG event files: [1470 events] ['type', 'latency', 'urevent', 'usertags']
# sub-14_ses-01_run-2 []: EEG event files: [1449 events] ['type', 'latency', 'urevent', 'usertags']
# sub-14_ses-01_run-3 []: EEG event files: [1383 events] ['type', 'latency', 'urevent', 'usertags']
# sub-15_ses-01_run-1 []: EEG event files: [576 events] ['type', 'latency', 'urevent', 'usertags']
# sub-15_ses-01_run-2 []: EEG event files: [1343 events] ['type', 'latency', 'urevent', 'usertags']
# sub-15_ses-01_run-3 []: EEG event files: [1336 events] ['type', 'latency', 'urevent', 'usertags']
# sub-16_ses-01_run-1 []: EEG event files: [1460 events] ['type', 'latency', 'urevent', 'usertags']
# sub-16_ses-01_run-2 []: EEG event files: [1343 events] ['type', 'latency', 'urevent', 'usertags']
# sub-16_ses-01_run-3 []: EEG event files: [1380 events] ['type', 'latency', 'urevent', 'usertags']
# sub-17_ses-01_run-1 []: EEG event files: [1518 events] ['type', 'latency', 'urevent', 'usertags']
# sub-17_ses-01_run-2 []: EEG event files: [1392 events] ['type', 'latency', 'urevent', 'usertags']
# sub-17_ses-01_run-3 []: EEG event files: [1399 events] ['type', 'latency', 'urevent', 'usertags']
# sub-18_ses-01_run-1 []: EEG event files: [1346 events] ['type', 'latency', 'urevent', 'usertags']
# sub-18_ses-01_run-2 []: EEG event files: [1250 events] ['type', 'latency', 'urevent', 'usertags']
# sub-18_ses-01_run-3 []: EEG event files: [1235 events] ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-1 []: EEG event files: [1463 events] ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-2 []: EEG event files: [1569 events] ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-3 []: EEG event files: [1432 events] ['type', 'latency', 'urevent', 'usertags']
# sub-20_ses-01_run-1 []: EEG event files: [1409 events] ['type', 'latency', 'urevent', 'usertags']
# sub-20_ses-01_run-2 []: EEG event files: [1366 events] ['type', 'latency', 'urevent', 'usertags']
# sub-20_ses-01_run-3 []: EEG event files: [1399 events] ['type', 'latency', 'urevent', 'usertags']
# sub-21_ses-01_run-1 []: EEG event files: [1553 events] ['type', 'latency', 'urevent', 'usertags']
# sub-21_ses-01_run-2 []: EEG event files: [1409 events] ['type', 'latency', 'urevent', 'usertags']
# sub-21_ses-01_run-3 []: EEG event files: [1422 events] ['type', 'latency', 'urevent', 'usertags']
#
# The number of Bids event files events and EEG event files events differ for the following files:
# sub-01_ses-01_run-1 [ERROR]: The Bids event files file has 1420 rows and the EEG event files event file has 1458 rows
# sub-01_ses-01_run-2 [ERROR]: The Bids event files file has 1420 rows and the EEG event files event file has 1499 rows
# sub-02_ses-01_run-1 [ERROR]: The Bids event files file has 1466 rows and the EEG event files event file has 1472 rows
# sub-02_ses-01_run-2 [ERROR]: The Bids event files file has 1466 rows and the EEG event files event file has 1438 rows
# sub-03_ses-01_run-1 [ERROR]: The Bids event files file has 1383 rows and the EEG event files event file has 1385 rows
# sub-03_ses-01_run-2 [ERROR]: The Bids event files file has 1383 rows and the EEG event files event file has 1345 rows
# sub-04_ses-01_run-1 [ERROR]: The Bids event files file has 1308 rows and the EEG event files event file has 1243 rows
# sub-04_ses-01_run-2 [ERROR]: The Bids event files file has 1308 rows and the EEG event files event file has 1305 rows
# sub-05_ses-01_run-1 [ERROR]: The Bids event files file has 1355 rows and the EEG event files event file has 1491 rows
# sub-05_ses-01_run-2 [ERROR]: The Bids event files file has 1355 rows and the EEG event files event file has 1345 rows
# sub-06_ses-01_run-1 [ERROR]: The Bids event files file has 1364 rows and the EEG event files event file has 1360 rows
# sub-06_ses-01_run-2 [ERROR]: The Bids event files file has 1364 rows and the EEG event files event file has 1362 rows
# sub-07_ses-01_run-1 [ERROR]: The Bids event files file has 1384 rows and the EEG event files event file has 1469 rows
# sub-07_ses-01_run-2 [ERROR]: The Bids event files file has 1384 rows and the EEG event files event file has 1386 rows
# sub-08_ses-01_run-1 [ERROR]: The Bids event files file has 930 rows and the EEG event files event file has 1557 rows
# sub-09_ses-01_run-1 [ERROR]: The Bids event files file has 1387 rows and the EEG event files event file has 1319 rows
# sub-09_ses-01_run-2 [ERROR]: The Bids event files file has 1387 rows and the EEG event files event file has 1348 rows
# sub-11_ses-01_run-1 [ERROR]: The Bids event files file has 1346 rows and the EEG event files event file has 1274 rows
# sub-11_ses-01_run-2 [ERROR]: The Bids event files file has 1346 rows and the EEG event files event file has 1280 rows
# sub-12_ses-01_run-1 [ERROR]: The Bids event files file has 1474 rows and the EEG event files event file has 1482 rows
# sub-12_ses-01_run-2 [ERROR]: The Bids event files file has 1474 rows and the EEG event files event file has 1409 rows
# sub-13_ses-01_run-1 [ERROR]: The Bids event files file has 1361 rows and the EEG event files event file has 1480 rows
# sub-13_ses-01_run-2 [ERROR]: The Bids event files file has 1361 rows and the EEG event files event file has 1468 rows
# sub-14_ses-01_run-1 [ERROR]: The Bids event files file has 1383 rows and the EEG event files event file has 1470 rows
# sub-14_ses-01_run-2 [ERROR]: The Bids event files file has 1383 rows and the EEG event files event file has 1449 rows
# sub-15_ses-01_run-1 [ERROR]: The Bids event files file has 1336 rows and the EEG event files event file has 576 rows
# sub-15_ses-01_run-2 [ERROR]: The Bids event files file has 1336 rows and the EEG event files event file has 1343 rows
# sub-16_ses-01_run-1 [ERROR]: The Bids event files file has 1380 rows and the EEG event files event file has 1460 rows
# sub-16_ses-01_run-2 [ERROR]: The Bids event files file has 1380 rows and the EEG event files event file has 1343 rows
# sub-17_ses-01_run-1 [ERROR]: The Bids event files file has 1399 rows and the EEG event files event file has 1518 rows
# sub-17_ses-01_run-2 [ERROR]: The Bids event files file has 1399 rows and the EEG event files event file has 1392 rows
# sub-18_ses-01_run-1 [ERROR]: The Bids event files file has 1235 rows and the EEG event files event file has 1346 rows
# sub-18_ses-01_run-2 [ERROR]: The Bids event files file has 1235 rows and the EEG event files event file has 1250 rows
# sub-19_ses-01_run-1 [ERROR]: The Bids event files file has 1432 rows and the EEG event files event file has 1463 rows
# sub-19_ses-01_run-2 [ERROR]: The Bids event files file has 1432 rows and the EEG event files event file has 1569 rows
# sub-20_ses-01_run-1 [ERROR]: The Bids event files file has 1399 rows and the EEG event files event file has 1409 rows
# sub-20_ses-01_run-2 [ERROR]: The Bids event files file has 1399 rows and the EEG event files event file has 1366 rows
# sub-21_ses-01_run-1 [ERROR]: The Bids event files file has 1422 rows and the EEG event files event file has 1553 rows
# sub-21_ses-01_run-2 [ERROR]: The Bids event files file has 1422 rows and the EEG event files event file has 1409 rows
#
# BIDS events summary
#   Categorical columns (2):
#     duration (1 distinct values):
#       n/a: 80792
#     event_code (43 distinct values):
#       1111: 4836
#       1112: 4836
#       1121: 5073
#       1122: 5073
#       1211: 63
#       1212: 63
#       1331: 23
#       1332: 23
#       1341: 15
#       1342: 15
#       1351: 22
#       1352: 22
#       2221: 673
#       2222: 673
#       2241: 621
#       2242: 621
#       2251: 606
#       2252: 606
#       2621: 349
#       2622: 349
#       2631: 295
#       2632: 295
#       2811: 1138
#       2812: 1138
#       3111: 60
#       3112: 60
#       3200: 2547
#       3310: 60
#       4210: 13428
#       4220: 6207
#       4230: 7251
#       4311: 9640
#       4312: 8584
#       4411: 1852
#       4421: 117
#       4611: 6
#       4612: 6
#       4621: 1182
#       4622: 1182
#       4710: 33
#       4720: 65
#       4730: 1064
#       4740: 20
#   Value columns (0):
#
# EEG.event events summary
#   Categorical columns (1):
#     type (43 distinct values):
#       1111: 4902
#       1112: 4902
#       1121: 5093
#       1122: 5093
#       1211: 61
#       1212: 59
#       1331: 20
#       1332: 18
#       1341: 19
#       1342: 19
#       1351: 21
#       1352: 21
#       2221: 682
#       2222: 682
#       2241: 608
#       2242: 608
#       2251: 604
#       2252: 604
#       2621: 351
#       2622: 351
#       2631: 301
#       2632: 301
#       2811: 1135
#       2812: 1135
#       3111: 60
#       3112: 58
#       3200: 2548
#       3310: 60
#       4210: 13551
#       4220: 6225
#       4230: 7352
#       4311: 9762
#       4312: 8607
#       4411: 1888
#       4421: 83
#       4611: 11
#       4612: 12
#       4621: 1226
#       4622: 1226
#       4710: 35
#       4720: 117
#       4730: 1055
#       4740: 19
#   Value columns (0):
# overall:
# 	[ Bids event files has 60 event files]
# 	[ EEG event files has 60 event files]
# sub-01_ses-01_run-1:
# 	[ Bids event files: sub-01_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1420 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1458 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1420 rows and the EEG event files event file has 1458 rows]
# sub-01_ses-01_run-2:
# 	[ Bids event files: sub-01_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-01_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1420 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1499 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1420 rows and the EEG event files event file has 1499 rows]
# sub-01_ses-01_run-3:
# 	[ Bids event files: sub-01_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-01_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1420 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1420 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-02_ses-01_run-1:
# 	[ Bids event files: sub-02_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1466 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1472 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1466 rows and the EEG event files event file has 1472 rows]
# sub-02_ses-01_run-2:
# 	[ Bids event files: sub-02_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-02_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1466 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1438 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1466 rows and the EEG event files event file has 1438 rows]
# sub-02_ses-01_run-3:
# 	[ Bids event files: sub-02_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-02_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1466 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1466 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-03_ses-01_run-1:
# 	[ Bids event files: sub-03_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-03_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1383 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1385 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1385 rows]
# sub-03_ses-01_run-2:
# 	[ Bids event files: sub-03_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-03_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1383 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1345 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1345 rows]
# sub-03_ses-01_run-3:
# 	[ Bids event files: sub-03_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-03_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1383 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1383 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-04_ses-01_run-1:
# 	[ Bids event files: sub-04_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-04_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1308 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1243 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1308 rows and the EEG event files event file has 1243 rows]
# sub-04_ses-01_run-2:
# 	[ Bids event files: sub-04_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-04_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1308 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1305 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1308 rows and the EEG event files event file has 1305 rows]
# sub-04_ses-01_run-3:
# 	[ Bids event files: sub-04_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-04_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1308 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1308 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-05_ses-01_run-1:
# 	[ Bids event files: sub-05_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-05_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1355 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1491 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1355 rows and the EEG event files event file has 1491 rows]
# sub-05_ses-01_run-2:
# 	[ Bids event files: sub-05_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-05_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1355 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1345 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1355 rows and the EEG event files event file has 1345 rows]
# sub-05_ses-01_run-3:
# 	[ Bids event files: sub-05_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-05_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1355 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1355 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-06_ses-01_run-1:
# 	[ Bids event files: sub-06_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-06_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1364 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1360 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1364 rows and the EEG event files event file has 1360 rows]
# sub-06_ses-01_run-2:
# 	[ Bids event files: sub-06_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-06_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1364 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1362 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1364 rows and the EEG event files event file has 1362 rows]
# sub-06_ses-01_run-3:
# 	[ Bids event files: sub-06_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-06_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1364 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1364 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-07_ses-01_run-1:
# 	[ Bids event files: sub-07_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-07_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1384 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1469 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1384 rows and the EEG event files event file has 1469 rows]
# sub-07_ses-01_run-2:
# 	[ Bids event files: sub-07_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-07_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1384 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1386 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1384 rows and the EEG event files event file has 1386 rows]
# sub-07_ses-01_run-3:
# 	[ Bids event files: sub-07_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-07_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1384 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1384 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-08_ses-01_run-1:
# 	[ Bids event files: sub-08_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [930 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1557 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 930 rows and the EEG event files event file has 1557 rows]
# sub-08_ses-01_run-2:
# 	[ Bids event files: sub-08_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-08_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [930 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [930 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-09_ses-01_run-1:
# 	[ Bids event files: sub-09_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1387 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1319 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1387 rows and the EEG event files event file has 1319 rows]
# sub-09_ses-01_run-2:
# 	[ Bids event files: sub-09_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-09_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1387 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1348 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1387 rows and the EEG event files event file has 1348 rows]
# sub-09_ses-01_run-3:
# 	[ Bids event files: sub-09_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-09_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1387 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1387 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-10_ses-01_run-1:
# 	[ Bids event files: sub-10_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [230 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [230 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-11_ses-01_run-1:
# 	[ Bids event files: sub-11_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-11_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1346 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1274 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1346 rows and the EEG event files event file has 1274 rows]
# sub-11_ses-01_run-2:
# 	[ Bids event files: sub-11_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-11_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1346 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1280 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1346 rows and the EEG event files event file has 1280 rows]
# sub-11_ses-01_run-3:
# 	[ Bids event files: sub-11_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-11_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1346 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1346 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-12_ses-01_run-1:
# 	[ Bids event files: sub-12_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-12_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1474 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1482 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1474 rows and the EEG event files event file has 1482 rows]
# sub-12_ses-01_run-2:
# 	[ Bids event files: sub-12_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-12_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1474 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1409 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1474 rows and the EEG event files event file has 1409 rows]
# sub-12_ses-01_run-3:
# 	[ Bids event files: sub-12_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-12_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1474 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1474 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-13_ses-01_run-1:
# 	[ Bids event files: sub-13_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-13_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1361 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1480 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1361 rows and the EEG event files event file has 1480 rows]
# sub-13_ses-01_run-2:
# 	[ Bids event files: sub-13_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-13_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1361 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1468 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1361 rows and the EEG event files event file has 1468 rows]
# sub-13_ses-01_run-3:
# 	[ Bids event files: sub-13_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-13_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1361 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1361 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-14_ses-01_run-1:
# 	[ Bids event files: sub-14_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-14_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1383 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1470 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1470 rows]
# sub-14_ses-01_run-2:
# 	[ Bids event files: sub-14_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-14_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1383 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1449 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1449 rows]
# sub-14_ses-01_run-3:
# 	[ Bids event files: sub-14_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-14_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1383 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1383 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-15_ses-01_run-1:
# 	[ Bids event files: sub-15_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-15_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1336 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [576 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1336 rows and the EEG event files event file has 576 rows]
# sub-15_ses-01_run-2:
# 	[ Bids event files: sub-15_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-15_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1336 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1343 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1336 rows and the EEG event files event file has 1343 rows]
# sub-15_ses-01_run-3:
# 	[ Bids event files: sub-15_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-15_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1336 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1336 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-16_ses-01_run-1:
# 	[ Bids event files: sub-16_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-16_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1380 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1460 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1380 rows and the EEG event files event file has 1460 rows]
# sub-16_ses-01_run-2:
# 	[ Bids event files: sub-16_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-16_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1380 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1343 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1380 rows and the EEG event files event file has 1343 rows]
# sub-16_ses-01_run-3:
# 	[ Bids event files: sub-16_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-16_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1380 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1380 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-17_ses-01_run-1:
# 	[ Bids event files: sub-17_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-17_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1399 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1518 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1518 rows]
# sub-17_ses-01_run-2:
# 	[ Bids event files: sub-17_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-17_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1399 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1392 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1392 rows]
# sub-17_ses-01_run-3:
# 	[ Bids event files: sub-17_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-17_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1399 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1399 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-18_ses-01_run-1:
# 	[ Bids event files: sub-18_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-18_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1235 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1346 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1235 rows and the EEG event files event file has 1346 rows]
# sub-18_ses-01_run-2:
# 	[ Bids event files: sub-18_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-18_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1235 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1250 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1235 rows and the EEG event files event file has 1250 rows]
# sub-18_ses-01_run-3:
# 	[ Bids event files: sub-18_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-18_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1235 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1235 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-19_ses-01_run-1:
# 	[ Bids event files: sub-19_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-19_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1432 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1463 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1432 rows and the EEG event files event file has 1463 rows]
# sub-19_ses-01_run-2:
# 	[ Bids event files: sub-19_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-19_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1432 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1569 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1432 rows and the EEG event files event file has 1569 rows]
# sub-19_ses-01_run-3:
# 	[ Bids event files: sub-19_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-19_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1432 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1432 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-20_ses-01_run-1:
# 	[ Bids event files: sub-20_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-20_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1399 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1409 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1409 rows]
# sub-20_ses-01_run-2:
# 	[ Bids event files: sub-20_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-20_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1399 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1366 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1366 rows]
# sub-20_ses-01_run-3:
# 	[ Bids event files: sub-20_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-20_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1399 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1399 events] ['type', 'latency', 'urevent', 'usertags']]
# sub-21_ses-01_run-1:
# 	[ Bids event files: sub-21_ses-01_task-DriveWithTaskAudio_run-1_events.tsv]
# 	[ EEG event files: sub-21_ses-01_task-DriveWithTaskAudio_run-1_events_temp.tsv]
# 	[ Bids event files: [1422 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1553 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1422 rows and the EEG event files event file has 1553 rows]
# sub-21_ses-01_run-2:
# 	[ Bids event files: sub-21_ses-01_task-DriveWithTaskAudio_run-2_events.tsv]
# 	[ EEG event files: sub-21_ses-01_task-DriveWithTaskAudio_run-2_events_temp.tsv]
# 	[ Bids event files: [1422 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1409 events] ['type', 'latency', 'urevent', 'usertags']]
# 	[ERROR The Bids event files file has 1422 rows and the EEG event files event file has 1409 rows]
# sub-21_ses-01_run-3:
# 	[ Bids event files: sub-21_ses-01_task-DriveWithTaskAudio_run-3_events.tsv]
# 	[ EEG event files: sub-21_ses-01_task-DriveWithTaskAudio_run-3_events_temp.tsv]
# 	[ Bids event files: [1422 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [1422 events] ['type', 'latency', 'urevent', 'usertags']]
#
# ERROR Summary:
# overall:
# sub-01_ses-01_run-1:
# 	[ERROR The Bids event files file has 1420 rows and the EEG event files event file has 1458 rows]
# sub-01_ses-01_run-2:
# 	[ERROR The Bids event files file has 1420 rows and the EEG event files event file has 1499 rows]
# sub-01_ses-01_run-3:
# sub-02_ses-01_run-1:
# 	[ERROR The Bids event files file has 1466 rows and the EEG event files event file has 1472 rows]
# sub-02_ses-01_run-2:
# 	[ERROR The Bids event files file has 1466 rows and the EEG event files event file has 1438 rows]
# sub-02_ses-01_run-3:
# sub-03_ses-01_run-1:
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1385 rows]
# sub-03_ses-01_run-2:
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1345 rows]
# sub-03_ses-01_run-3:
# sub-04_ses-01_run-1:
# 	[ERROR The Bids event files file has 1308 rows and the EEG event files event file has 1243 rows]
# sub-04_ses-01_run-2:
# 	[ERROR The Bids event files file has 1308 rows and the EEG event files event file has 1305 rows]
# sub-04_ses-01_run-3:
# sub-05_ses-01_run-1:
# 	[ERROR The Bids event files file has 1355 rows and the EEG event files event file has 1491 rows]
# sub-05_ses-01_run-2:
# 	[ERROR The Bids event files file has 1355 rows and the EEG event files event file has 1345 rows]
# sub-05_ses-01_run-3:
# sub-06_ses-01_run-1:
# 	[ERROR The Bids event files file has 1364 rows and the EEG event files event file has 1360 rows]
# sub-06_ses-01_run-2:
# 	[ERROR The Bids event files file has 1364 rows and the EEG event files event file has 1362 rows]
# sub-06_ses-01_run-3:
# sub-07_ses-01_run-1:
# 	[ERROR The Bids event files file has 1384 rows and the EEG event files event file has 1469 rows]
# sub-07_ses-01_run-2:
# 	[ERROR The Bids event files file has 1384 rows and the EEG event files event file has 1386 rows]
# sub-07_ses-01_run-3:
# sub-08_ses-01_run-1:
# 	[ERROR The Bids event files file has 930 rows and the EEG event files event file has 1557 rows]
# sub-08_ses-01_run-2:
# sub-09_ses-01_run-1:
# 	[ERROR The Bids event files file has 1387 rows and the EEG event files event file has 1319 rows]
# sub-09_ses-01_run-2:
# 	[ERROR The Bids event files file has 1387 rows and the EEG event files event file has 1348 rows]
# sub-09_ses-01_run-3:
# sub-10_ses-01_run-1:
# sub-11_ses-01_run-1:
# 	[ERROR The Bids event files file has 1346 rows and the EEG event files event file has 1274 rows]
# sub-11_ses-01_run-2:
# 	[ERROR The Bids event files file has 1346 rows and the EEG event files event file has 1280 rows]
# sub-11_ses-01_run-3:
# sub-12_ses-01_run-1:
# 	[ERROR The Bids event files file has 1474 rows and the EEG event files event file has 1482 rows]
# sub-12_ses-01_run-2:
# 	[ERROR The Bids event files file has 1474 rows and the EEG event files event file has 1409 rows]
# sub-12_ses-01_run-3:
# sub-13_ses-01_run-1:
# 	[ERROR The Bids event files file has 1361 rows and the EEG event files event file has 1480 rows]
# sub-13_ses-01_run-2:
# 	[ERROR The Bids event files file has 1361 rows and the EEG event files event file has 1468 rows]
# sub-13_ses-01_run-3:
# sub-14_ses-01_run-1:
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1470 rows]
# sub-14_ses-01_run-2:
# 	[ERROR The Bids event files file has 1383 rows and the EEG event files event file has 1449 rows]
# sub-14_ses-01_run-3:
# sub-15_ses-01_run-1:
# 	[ERROR The Bids event files file has 1336 rows and the EEG event files event file has 576 rows]
# sub-15_ses-01_run-2:
# 	[ERROR The Bids event files file has 1336 rows and the EEG event files event file has 1343 rows]
# sub-15_ses-01_run-3:
# sub-16_ses-01_run-1:
# 	[ERROR The Bids event files file has 1380 rows and the EEG event files event file has 1460 rows]
# sub-16_ses-01_run-2:
# 	[ERROR The Bids event files file has 1380 rows and the EEG event files event file has 1343 rows]
# sub-16_ses-01_run-3:
# sub-17_ses-01_run-1:
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1518 rows]
# sub-17_ses-01_run-2:
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1392 rows]
# sub-17_ses-01_run-3:
# sub-18_ses-01_run-1:
# 	[ERROR The Bids event files file has 1235 rows and the EEG event files event file has 1346 rows]
# sub-18_ses-01_run-2:
# 	[ERROR The Bids event files file has 1235 rows and the EEG event files event file has 1250 rows]
# sub-18_ses-01_run-3:
# sub-19_ses-01_run-1:
# 	[ERROR The Bids event files file has 1432 rows and the EEG event files event file has 1463 rows]
# sub-19_ses-01_run-2:
# 	[ERROR The Bids event files file has 1432 rows and the EEG event files event file has 1569 rows]
# sub-19_ses-01_run-3:
# sub-20_ses-01_run-1:
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1409 rows]
# sub-20_ses-01_run-2:
# 	[ERROR The Bids event files file has 1399 rows and the EEG event files event file has 1366 rows]
# sub-20_ses-01_run-3:
# sub-21_ses-01_run-1:
# 	[ERROR The Bids event files file has 1422 rows and the EEG event files event file has 1553 rows]
# sub-21_ses-01_run-2:
# 	[ERROR The Bids event files file has 1422 rows and the EEG event files event file has 1409 rows]
# sub-21_ses-01_run-3:
