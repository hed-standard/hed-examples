# %% [markdown]
# ## Combine columns of Sternberg bids and EEG events for processing
#
# This script starts with the Sternberg data.
# A copy of the EEG.event structure is dumped to the dataset as `_events_temp.tsv` files.
# The `sternberg_01_initial_summary.ipynb` has already been run and
# indicates that the corresponding versions of the event files have
# the same number of events.
#
# This notebook creates a `_events_temp1.tsv` for each:
# 1. Check that the respective event files have the same number of events.
# 2. Remove the `trial_type`, `response_time`, `stim_file` columns from the bids events file.
# 3. Save as `_events_temp1.tsv`.

# %%
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list, get_new_dataframe

# Set the specific variables for the Attention Shift dataset.
bids_root_path = 'G:\Sternberg\SternbergWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
bids_cols_remove = ['trial_type', 'response_time', 'stim_file']
final_columns = ['onset', 'duration', 'sample', 'value']
# Set up the logger and create the file dictionaries
status = HedLogger()
bids_files = get_file_list(bids_root_path, extensions=[".tsv"], exclude_dirs = ['sourcedata'],
                           name_suffix='_events')
bids_dict = BidsTsvDictionary(bids_files, entities=entities)
eeg_files = get_file_list(bids_root_path, extensions=[".tsv"], exclude_dirs = ['sourcedata'],
                          name_suffix="_events_temp")
eeg_dict = BidsTsvDictionary(eeg_files, entities=entities)

# Perform the operations to combine the two versions of the event files
fatal_error_keys = []
for key, file, rowcount, column_count in bids_dict.iter_tsv_info():
    df_bids = get_new_dataframe(file.file_path)
    status.add(key, f"Created a dataframe for {file.file_path}")

    df_eeg = get_new_dataframe(eeg_dict.get_file(key).file_path)
    status.add(key, f"Created a dataframe for {eeg_dict.get_file(key).file_path}")

    # Combine the two versions of the events file after verifying they have same number of rows
    if rowcount != eeg_dict.rowcount_dict[key]:
        status.add(key, f"---ERROR--- the BIDs file has {rowcount} has {rowcount} row and the EEG file has" +
                   f"{eeg_dict.rowcount_dict[key]} rows", also_print=True)
        fatal_error_keys.append(key)
        continue
    else:
        status.add(key, f"Bids event file and EEG.set event structure have the same number of events")

    # Drop the extra columns
    drop_columns = bids_cols_remove
    df_bids.drop(columns=drop_columns, inplace=True)
    status.add(key, f"Dropped {str(drop_columns)} columns")

    # Make sure the dataframe has the correct final columns
    extra_cols = set(df_bids.columns).symmetric_difference(set(final_columns))
    if extra_cols:
        status.add(key, f"---ERROR--- Columns {str(extra_cols)} do not match expected.", also_print=True)
        fatal_error_keys.append(key)
        continue

    # Do a final reordering for uniformity
    df_bids = df_bids[final_columns]
    status.add(key, f"Reordered the final columns as {str(final_columns)}")


    filename = file.file_path[:-4] + "_temp1.tsv"
    df_bids.to_csv(filename, sep='\t', index=False)
    status.add(key, f"Saved as {filename}")

if fatal_error_keys:
    print(f"There were fatal event file errors for {str(fatal_error_keys)}. These should be fixed before continuing")
    raise KeyboardInterrupt

# %%
key_dict = {
    'sub-001_ses-01_run-2': [0],
    'sub-001_ses-01_run-3': [0],
    'sub-001_ses-01_run-4': [0],
    'sub-002_ses-01_run-2': [0, 1],
    'sub-002_ses-01_run-3': [0],
    'sub-002_ses-01_run-4': [0],
    'sub-003_ses-01_run-2': [0],
    'sub-003_ses-01_run-3': [0],
    'sub-003_ses-01_run-4': [0],
    'sub-004_ses-01_run-2': [0],
    'sub-004_ses-01_run-3': [0],
    'sub-004_ses-01_run-4': [0],
    'sub-005_ses-01_run-2': [0],
    'sub-005_ses-01_run-3': [0],
    'sub-005_ses-01_run-4': [0],
    'sub-006_ses-01_run-2': [0],
    'sub-006_ses-01_run-3': [0],
    'sub-006_ses-01_run-4': [0],
    'sub-007_ses-01_run-2': [0],
    'sub-007_ses-01_run-3': [0],
    'sub-007_ses-01_run-4': [0],
    'sub-008_ses-01_run-2': [0],
    'sub-008_ses-01_run-3': [0],
    'sub-008_ses-01_run-4': [0],
    'sub-009_ses-01_run-2': [0],
    'sub-009_ses-01_run-3': [0],
    'sub-009_ses-01_run-4': [0],
    'sub-010_ses-01_run-2': [0, 1],
    'sub-010_ses-01_run-3': [0],
    'sub-010_ses-01_run-4': [0],
    'sub-011_ses-01_run-2': [0, 1],
    'sub-011_ses-01_run-3': [0],
    'sub-011_ses-01_run-4': [0],
    'sub-012_ses-01_run-2': [0],
    'sub-012_ses-01_run-3': [0],
    'sub-014_ses-01_run-2': [0],
    'sub-014_ses-01_run-3': [0],
    'sub-015_ses-01_run-2': [0],
    'sub-015_ses-01_run-3': [0],
    'sub-016_ses-01_run-2': [0],
    'sub-016_ses-01_run-3': [0],
    'sub-017_ses-01_run-2': [0],
    'sub-017_ses-01_run-3': [0],
    'sub-018_ses-01_run-2': [0],
    'sub-018_ses-01_run-3': [0],
    'sub-019_ses-01_run-2': [0],
    'sub-019_ses-01_run-3': [0],
    'sub-020_ses-01_run-2': [0],
    'sub-020_ses-01_run-3': [0],
    'sub-021_ses-01_run-2': [0],
    'sub-021_ses-01_run-3': [0],
    'sub-022_ses-01_run-1': [307],
    'sub-022_ses-01_run-2': [0, 196],
    'sub-022_ses-01_run-4': [0, 1],
    'sub-022_ses-01_run-4': [0],
    'sub-022_ses-01_run-5': [0, 1],
    'sub-022_ses-01_run-6': [0, 1],
    'sub-023_ses-01_run-2': [0],
    'sub-023_ses-01_run-3': [0],
    'sub-023_ses-01_run-4': [0, 1],
    'sub-023_ses-01_run-5': [0, 1],
    'sub-024_ses-01_run-2': [0],
    'sub-024_ses-01_run-3': [0]
}
# Fix boundary and empty events for several runs
for key, values in key_dict.items():
    file = bids_dict.get_file(key)
    filename = file.file_path[:-4] + "_temp1.tsv"
    df = get_new_dataframe(filename)
    status.add(key, f"Number of rows {len(df.index)}", also_print=True)
    for val in values:
        status.add(key, f"Dropping row {str(val)}:\n{df.loc[[val]]}", also_print=True)
        df.drop(axis=0, index=val, inplace=True)
        df.reset_index(inplace=True)
    status.add(key, f"Saving {filename}")
    df.to_csv(filename, sep='\t', index=False)
# Out:
# sub-001_ses-01_run-2: Number of rows 351
# sub-001_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-001_ses-01_run-3: Number of rows 351
# sub-001_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-001_ses-01_run-4: Number of rows 351
# sub-001_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-002_ses-01_run-2: Number of rows 352
# sub-002_ses-01_run-2: Dropping row 0:
#    onset           duration  sample     value
# 0 -0.002  181119.0000000000    -0.5  boundary
# sub-002_ses-01_run-2: Dropping row 1:
#    onset duration  sample     value
# 1  0.002      n/a     0.5  boundary
# sub-002_ses-01_run-3: Number of rows 351
# sub-002_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-002_ses-01_run-4: Number of rows 351
# sub-002_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-003_ses-01_run-2: Number of rows 351
# sub-003_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-003_ses-01_run-3: Number of rows 352
# sub-003_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-003_ses-01_run-4: Number of rows 351
# sub-003_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-004_ses-01_run-2: Number of rows 341
# sub-004_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-004_ses-01_run-3: Number of rows 351
# sub-004_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-004_ses-01_run-4: Number of rows 353
# sub-004_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-005_ses-01_run-2: Number of rows 326
# sub-005_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-005_ses-01_run-3: Number of rows 326
# sub-005_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-005_ses-01_run-4: Number of rows 326
# sub-005_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-006_ses-01_run-2: Number of rows 351
# sub-006_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-006_ses-01_run-3: Number of rows 350
# sub-006_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-006_ses-01_run-4: Number of rows 351
# sub-006_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-007_ses-01_run-2: Number of rows 347
# sub-007_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-007_ses-01_run-3: Number of rows 349
# sub-007_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-007_ses-01_run-4: Number of rows 349
# sub-007_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-008_ses-01_run-2: Number of rows 351
# sub-008_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-008_ses-01_run-3: Number of rows 351
# sub-008_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-008_ses-01_run-4: Number of rows 351
# sub-008_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-009_ses-01_run-2: Number of rows 351
# sub-009_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-009_ses-01_run-3: Number of rows 351
# sub-009_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-009_ses-01_run-4: Number of rows 352
# sub-009_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-010_ses-01_run-2: Number of rows 352
# sub-010_ses-01_run-2: Dropping row 0:
#    onset           duration  sample     value
# 0 -0.002  154875.0000000000    -0.5  boundary
# sub-010_ses-01_run-2: Dropping row 1:
#    onset duration  sample     value
# 1  0.002      n/a     0.5  boundary
# sub-010_ses-01_run-3: Number of rows 351
# sub-010_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-010_ses-01_run-4: Number of rows 351
# sub-010_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-011_ses-01_run-2: Number of rows 352
# sub-011_ses-01_run-2: Dropping row 0:
#    onset           duration  sample     value
# 0 -0.002  187845.0000000000    -0.5  boundary
# sub-011_ses-01_run-2: Dropping row 1:
#    onset duration  sample     value
# 1  0.002      n/a     0.5  boundary
# sub-011_ses-01_run-3: Number of rows 351
# sub-011_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-011_ses-01_run-4: Number of rows 351
# sub-011_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-012_ses-01_run-2: Number of rows 351
# sub-012_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-012_ses-01_run-3: Number of rows 351
# sub-012_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# sub-014_ses-01_run-2: Number of rows 338
# sub-014_ses-01_run-2: Dropping row 0:
#     onset duration  sample     value
# 0 -0.0005      n/a    -0.5  boundary
# sub-014_ses-01_run-3: Number of rows 341
# sub-014_ses-01_run-3: Dropping row 0:
#     onset duration  sample     value
# 0 -0.0005      n/a    -0.5  boundary
# sub-015_ses-01_run-2: Number of rows 351
# sub-015_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-015_ses-01_run-3: Number of rows 341
# sub-015_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-016_ses-01_run-2: Number of rows 351
# sub-016_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-016_ses-01_run-3: Number of rows 351
# sub-016_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-017_ses-01_run-2: Number of rows 351
# sub-017_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-017_ses-01_run-3: Number of rows 331
# sub-017_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-018_ses-01_run-2: Number of rows 351
# sub-018_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-018_ses-01_run-3: Number of rows 351
# sub-018_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-019_ses-01_run-2: Number of rows 351
# sub-019_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-019_ses-01_run-3: Number of rows 351
# sub-019_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-020_ses-01_run-2: Number of rows 351
# sub-020_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-020_ses-01_run-3: Number of rows 351
# sub-020_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-021_ses-01_run-2: Number of rows 352
# sub-021_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-021_ses-01_run-3: Number of rows 351
# sub-021_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-022_ses-01_run-1: Number of rows 308
# sub-022_ses-01_run-1: Dropping row 307:
#           onset  duration       sample  value
# 307  575.428986       0.0  287748.2564  empty
# sub-022_ses-01_run-2: Number of rows 197
# sub-022_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-022_ses-01_run-2: Dropping row 196:
#           onset      duration       sample  value
# 196  406.952175  0.0000000000  203499.9658  empty
# sub-022_ses-01_run-4: Number of rows 351
# sub-022_ses-01_run-4: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-022_ses-01_run-5: Number of rows 352
# sub-022_ses-01_run-5: Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1264383.0000000000    -0.5  boundary
# sub-022_ses-01_run-5: Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# sub-022_ses-01_run-6: Number of rows 342
# sub-022_ses-01_run-6: Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1612543.0000000000    -0.5  boundary
# sub-022_ses-01_run-6: Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# sub-023_ses-01_run-2: Number of rows 351
# sub-023_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-023_ses-01_run-3: Number of rows 351
# sub-023_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-023_ses-01_run-4: Number of rows 352
# sub-023_ses-01_run-4: Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1072127.0000000000    -0.5  boundary
# sub-023_ses-01_run-4: Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# sub-023_ses-01_run-5: Number of rows 352
# sub-023_ses-01_run-5: Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1411327.0000000000    -0.5  boundary
# sub-023_ses-01_run-5: Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# sub-024_ses-01_run-2: Number of rows 351
# sub-024_ses-01_run-2: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# sub-024_ses-01_run-3: Number of rows 351
# sub-024_ses-01_run-3: Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary

# %%
status.print_log()
status.save_log(bids_root_path, sub_path='code', log_name='as_hed_02_initial_combination_log.json')
# Out:
# sub-001_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-001_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-001_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-001_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-002_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-002_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset           duration  sample     value
# 0 -0.002  181119.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.002      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-002_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-002_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-003_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-003_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-003_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-003_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-004_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-004_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 341
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-004_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-004_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 353
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-005_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-005_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 326
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-005_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 326
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-005_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 326
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-006_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-006_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-006_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 350
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-006_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-007_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-007_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 347
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-007_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 349
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-007_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 349
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-008_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-008_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-008_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-008_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-009_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-009_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-009_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-009_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-010_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-010_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset           duration  sample     value
# 0 -0.002  154875.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.002      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-010_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-010_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-011_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-011_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset           duration  sample     value
# 0 -0.002  187845.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.002      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-011_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-011_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-012_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-012_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-012_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.002      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-014_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-014_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 338
# 	Dropping row 0:
#     onset duration  sample     value
# 0 -0.0005      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-014_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 341
# 	Dropping row 0:
#     onset duration  sample     value
# 0 -0.0005      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-015_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-015_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-015_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 341
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-016_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-016_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-016_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-017_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-017_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-017_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 331
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-018_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-018_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-018_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-019_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-019_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# ...
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-020_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-020_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-020_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-021_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-021_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-021_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-022_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-1_events_temp1.tsv
# 	Number of rows 308
# 	Dropping row 307:
#           onset  duration       sample  value
# 307  575.428986       0.0  287748.2564  empty
# 	Saving G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-022_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 197
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Dropping row 196:
#           onset      duration       sample  value
# 196  406.952175  0.0000000000  203499.9658  empty
# 	Saving G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-022_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-022_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-022_ses-01_run-5
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-5_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-5_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-5_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1264383.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-5_events_temp1.tsv
# sub-022_ses-01_run-6
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events_temp1.tsv
# 	Number of rows 342
# 	Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1612543.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events_temp1.tsv
# sub-023_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-023_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-023_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-3_events_temp1.tsv
# sub-023_ses-01_run-4
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-4_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-4_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-4_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1072127.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-4_events_temp1.tsv
# sub-023_ses-01_run-5
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events_temp1.tsv
# 	Number of rows 352
# 	Dropping row 0:
#    onset            duration  sample     value
# 0 -0.001  1411327.0000000000    -0.5  boundary
# 	Dropping row 1:
#    onset duration  sample     value
# 1  0.001      n/a     0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events_temp1.tsv
# sub-024_ses-01_run-1
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-1_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-1_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-1_events_temp1.tsv
# sub-024_ses-01_run-2
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-2_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-2_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-2_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-2_events_temp1.tsv
# sub-024_ses-01_run-3
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events.tsv
# 	Created a dataframe for G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events_temp.tsv
# 	Bids event file and EEG.set event structure have the same number of events
# 	Dropped ['trial_type', 'response_time', 'stim_file'] columns
# 	Reordered the final columns as ['onset', 'duration', 'sample', 'value']
# 	Saved as G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events_temp1.tsv
# 	Number of rows 351
# 	Dropping row 0:
#    onset duration  sample     value
# 0 -0.001      n/a    -0.5  boundary
# 	Saving G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events_temp1.tsv
