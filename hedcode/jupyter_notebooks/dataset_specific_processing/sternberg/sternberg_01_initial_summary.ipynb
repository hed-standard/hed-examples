# %%
import os
from hed.tools import BidsTsvDictionary, BidsTsvSummary, HedLogger, report_tsv_diffs
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 'G:/Sternberg/SternbergWorking/'
exclude_dirs = ['code', 'stimuli']
entities = ('sub', 'ses', 'run')
bids_skip_columns = ['onset', 'duration', 'sample', 'response_time', 'trial_type', 'stim_file']
eeg_skip_columns = ['Trial', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2',
                    'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset']
log_file_name = 'sternberg_01_initial_summary_log.json'

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary("Bids event files", files_bids, entities=entities)
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_eventstemp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary("EEG event files", files_eeg, entities=entities)

# Set logger and Output a list of files for the two cases
logger = HedLogger()
report_tsv_diffs(bids_dict, eeg_dict, logger)

# Create summary dictionaries of the original BIDS events files and output column names
bids_sum_all, bids_sum =  BidsTsvSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip_columns)
bids_sum_all.print('\nBIDS events summary')

eeg_sum_all, eeg_sum =  BidsTsvSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip_columns)
eeg_sum_all.print('\nEEG.event events summary')

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# Summarizing Bids event files...
#
# Bids event files event files (85 files)
# sub-001_ses-01_run-1: sub-001_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-001_ses-01_run-2: sub-001_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-001_ses-01_run-3: sub-001_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-001_ses-01_run-4: sub-001_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-002_ses-01_run-1: sub-002_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-002_ses-01_run-2: sub-002_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-002_ses-01_run-3: sub-002_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-002_ses-01_run-4: sub-002_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-003_ses-01_run-1: sub-003_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-003_ses-01_run-2: sub-003_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-003_ses-01_run-3: sub-003_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-003_ses-01_run-4: sub-003_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-004_ses-01_run-1: sub-004_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-004_ses-01_run-2: sub-004_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-004_ses-01_run-3: sub-004_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-004_ses-01_run-4: sub-004_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-005_ses-01_run-1: sub-005_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-005_ses-01_run-2: sub-005_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-005_ses-01_run-3: sub-005_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-005_ses-01_run-4: sub-005_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-006_ses-01_run-1: sub-006_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-006_ses-01_run-2: sub-006_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-006_ses-01_run-3: sub-006_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-006_ses-01_run-4: sub-006_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-007_ses-01_run-1: sub-007_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-007_ses-01_run-2: sub-007_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-007_ses-01_run-3: sub-007_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-007_ses-01_run-4: sub-007_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-008_ses-01_run-1: sub-008_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-008_ses-01_run-2: sub-008_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-008_ses-01_run-3: sub-008_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-008_ses-01_run-4: sub-008_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-009_ses-01_run-1: sub-009_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-009_ses-01_run-2: sub-009_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-009_ses-01_run-3: sub-009_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-009_ses-01_run-4: sub-009_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-010_ses-01_run-1: sub-010_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-010_ses-01_run-2: sub-010_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-010_ses-01_run-3: sub-010_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-010_ses-01_run-4: sub-010_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-011_ses-01_run-1: sub-011_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-011_ses-01_run-2: sub-011_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-011_ses-01_run-3: sub-011_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-011_ses-01_run-4: sub-011_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-012_ses-01_run-1: sub-012_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-012_ses-01_run-2: sub-012_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-012_ses-01_run-3: sub-012_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-014_ses-01_run-1: sub-014_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-014_ses-01_run-2: sub-014_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-014_ses-01_run-3: sub-014_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-015_ses-01_run-1: sub-015_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-015_ses-01_run-2: sub-015_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-015_ses-01_run-3: sub-015_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-016_ses-01_run-1: sub-016_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-016_ses-01_run-2: sub-016_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-016_ses-01_run-3: sub-016_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-017_ses-01_run-1: sub-017_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-017_ses-01_run-2: sub-017_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-017_ses-01_run-3: sub-017_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-018_ses-01_run-1: sub-018_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-018_ses-01_run-2: sub-018_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-018_ses-01_run-3: sub-018_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-019_ses-01_run-1: sub-019_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-019_ses-01_run-2: sub-019_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-019_ses-01_run-3: sub-019_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-020_ses-01_run-1: sub-020_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-020_ses-01_run-2: sub-020_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-020_ses-01_run-3: sub-020_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-021_ses-01_run-1: sub-021_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-021_ses-01_run-2: sub-021_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-021_ses-01_run-3: sub-021_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-022_ses-01_run-1: sub-022_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-022_ses-01_run-2: sub-022_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-022_ses-01_run-3: sub-022_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-022_ses-01_run-4: sub-022_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-022_ses-01_run-5: sub-022_ses-01_task-WorkingMemory_run-5_events.tsv
# sub-022_ses-01_run-6: sub-022_ses-01_task-WorkingMemory_run-6_events.tsv
# sub-023_ses-01_run-1: sub-023_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-023_ses-01_run-2: sub-023_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-023_ses-01_run-3: sub-023_ses-01_task-WorkingMemory_run-3_events.tsv
# sub-023_ses-01_run-4: sub-023_ses-01_task-WorkingMemory_run-4_events.tsv
# sub-023_ses-01_run-5: sub-023_ses-01_task-WorkingMemory_run-5_events.tsv
# sub-024_ses-01_run-1: sub-024_ses-01_task-WorkingMemory_run-1_events.tsv
# sub-024_ses-01_run-2: sub-024_ses-01_task-WorkingMemory_run-2_events.tsv
# sub-024_ses-01_run-3: sub-024_ses-01_task-WorkingMemory_run-3_events.tsv
#
# EEG event files event files (85 files)
# sub-001_ses-01_run-1: sub-001_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-001_ses-01_run-2: sub-001_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-001_ses-01_run-3: sub-001_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-001_ses-01_run-4: sub-001_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-002_ses-01_run-1: sub-002_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-002_ses-01_run-2: sub-002_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-002_ses-01_run-3: sub-002_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-002_ses-01_run-4: sub-002_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-003_ses-01_run-1: sub-003_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-003_ses-01_run-2: sub-003_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-003_ses-01_run-3: sub-003_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-003_ses-01_run-4: sub-003_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-004_ses-01_run-1: sub-004_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-004_ses-01_run-2: sub-004_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-004_ses-01_run-3: sub-004_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-004_ses-01_run-4: sub-004_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-005_ses-01_run-1: sub-005_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-005_ses-01_run-2: sub-005_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-005_ses-01_run-3: sub-005_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-005_ses-01_run-4: sub-005_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-006_ses-01_run-1: sub-006_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-006_ses-01_run-2: sub-006_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-006_ses-01_run-3: sub-006_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-006_ses-01_run-4: sub-006_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-007_ses-01_run-1: sub-007_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-007_ses-01_run-2: sub-007_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-007_ses-01_run-3: sub-007_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-007_ses-01_run-4: sub-007_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-008_ses-01_run-1: sub-008_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-008_ses-01_run-2: sub-008_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-008_ses-01_run-3: sub-008_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-008_ses-01_run-4: sub-008_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-009_ses-01_run-1: sub-009_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-009_ses-01_run-2: sub-009_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-009_ses-01_run-3: sub-009_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-009_ses-01_run-4: sub-009_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-010_ses-01_run-1: sub-010_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-010_ses-01_run-2: sub-010_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-010_ses-01_run-3: sub-010_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-010_ses-01_run-4: sub-010_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-011_ses-01_run-1: sub-011_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-011_ses-01_run-2: sub-011_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-011_ses-01_run-3: sub-011_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-011_ses-01_run-4: sub-011_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-012_ses-01_run-1: sub-012_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-012_ses-01_run-2: sub-012_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-012_ses-01_run-3: sub-012_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-014_ses-01_run-1: sub-014_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-014_ses-01_run-2: sub-014_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-014_ses-01_run-3: sub-014_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-015_ses-01_run-1: sub-015_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-015_ses-01_run-2: sub-015_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-015_ses-01_run-3: sub-015_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-016_ses-01_run-1: sub-016_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-016_ses-01_run-2: sub-016_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-016_ses-01_run-3: sub-016_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-017_ses-01_run-1: sub-017_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-017_ses-01_run-2: sub-017_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-017_ses-01_run-3: sub-017_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-018_ses-01_run-1: sub-018_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-018_ses-01_run-2: sub-018_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-018_ses-01_run-3: sub-018_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-019_ses-01_run-1: sub-019_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-019_ses-01_run-2: sub-019_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-019_ses-01_run-3: sub-019_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-020_ses-01_run-1: sub-020_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-020_ses-01_run-2: sub-020_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-020_ses-01_run-3: sub-020_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-021_ses-01_run-1: sub-021_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-021_ses-01_run-2: sub-021_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-021_ses-01_run-3: sub-021_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-022_ses-01_run-1: sub-022_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-022_ses-01_run-2: sub-022_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-022_ses-01_run-3: sub-022_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-022_ses-01_run-4: sub-022_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-022_ses-01_run-5: sub-022_ses-01_task-WorkingMemory_run-5_eventstemp.tsv
# sub-022_ses-01_run-6: sub-022_ses-01_task-WorkingMemory_run-6_eventstemp.tsv
# sub-023_ses-01_run-1: sub-023_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-023_ses-01_run-2: sub-023_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-023_ses-01_run-3: sub-023_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
# sub-023_ses-01_run-4: sub-023_ses-01_task-WorkingMemory_run-4_eventstemp.tsv
# sub-023_ses-01_run-5: sub-023_ses-01_task-WorkingMemory_run-5_eventstemp.tsv
# sub-024_ses-01_run-1: sub-024_ses-01_task-WorkingMemory_run-1_eventstemp.tsv
# sub-024_ses-01_run-2: sub-024_ses-01_task-WorkingMemory_run-2_eventstemp.tsv
# sub-024_ses-01_run-3: sub-024_ses-01_task-WorkingMemory_run-3_eventstemp.tsv
#
# Bids event files event file columns:
# sub-001_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-001_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-001_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-001_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_ses-01_run-2 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_ses-01_run-3 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_ses-01_run-2 []: Bids event files: [341 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_ses-01_run-4 []: Bids event files: [353 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_ses-01_run-1 []: Bids event files: [325 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_ses-01_run-2 []: Bids event files: [326 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_ses-01_run-3 []: Bids event files: [326 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_ses-01_run-4 []: Bids event files: [326 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_ses-01_run-1 []: Bids event files: [310 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_ses-01_run-3 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_ses-01_run-1 []: Bids event files: [349 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_ses-01_run-2 []: Bids event files: [347 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_ses-01_run-3 []: Bids event files: [349 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_ses-01_run-4 []: Bids event files: [349 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_ses-01_run-1 []: Bids event files: [340 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_ses-01_run-4 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_ses-01_run-2 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_ses-01_run-2 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_ses-01_run-1 []: Bids event files: [340 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_ses-01_run-2 []: Bids event files: [338 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_ses-01_run-3 []: Bids event files: [341 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_ses-01_run-3 []: Bids event files: [341 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_ses-01_run-3 []: Bids event files: [331 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_ses-01_run-2 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_ses-01_run-1 []: Bids event files: [308 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_ses-01_run-2 []: Bids event files: [197 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_ses-01_run-3 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_ses-01_run-4 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_ses-01_run-5 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_ses-01_run-6 []: Bids event files: [342 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_ses-01_run-1 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_ses-01_run-4 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_ses-01_run-5 []: Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_ses-01_run-1 []: Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_ses-01_run-2 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_ses-01_run-3 []: Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
#
# EEG event files event file columns:
# sub-001_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-001_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-001_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-001_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_ses-01_run-2 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_ses-01_run-3 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_ses-01_run-2 []: EEG event files: [341 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_ses-01_run-4 []: EEG event files: [353 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_ses-01_run-1 []: EEG event files: [325 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_ses-01_run-2 []: EEG event files: [326 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_ses-01_run-3 []: EEG event files: [326 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_ses-01_run-4 []: EEG event files: [326 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_ses-01_run-1 []: EEG event files: [310 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_ses-01_run-3 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_ses-01_run-1 []: EEG event files: [349 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_ses-01_run-2 []: EEG event files: [347 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_ses-01_run-3 []: EEG event files: [349 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_ses-01_run-4 []: EEG event files: [349 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_ses-01_run-1 []: EEG event files: [340 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_ses-01_run-4 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_ses-01_run-2 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_ses-01_run-2 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_ses-01_run-1 []: EEG event files: [340 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_ses-01_run-2 []: EEG event files: [338 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_ses-01_run-3 []: EEG event files: [341 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_ses-01_run-3 []: EEG event files: [341 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_ses-01_run-3 []: EEG event files: [331 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_ses-01_run-2 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-022_ses-01_run-1 []: EEG event files: [308 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_ses-01_run-2 []: EEG event files: [197 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_ses-01_run-3 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_ses-01_run-4 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_ses-01_run-5 []: EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_ses-01_run-6 []: EEG event files: [342 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-023_ses-01_run-1 []: EEG event files: [351 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_ses-01_run-2 []: EEG event files: [351 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_ses-01_run-3 []: EEG event files: [351 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_ses-01_run-4 []: EEG event files: [352 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_ses-01_run-5 []: EEG event files: [352 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_ses-01_run-1 []: EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_ses-01_run-2 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_ses-01_run-3 []: EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# overall []: The Bids event files event files and the EEG event files files have the same number of rows
#
# BIDS events summary
#   Categorical columns (1):
#     value (71 distinct values):
#       1: 2395
#       255: 1831
#       B: 333
#       C: 438
#       D: 594
#       F: 461
#       G: 533
#       H: 502
#       J: 428
#       K: 604
#       L: 566
#       M: 626
#       N: 441
#       P: 404
#       Q: 418
#       R: 630
#       S: 582
#       T: 445
#       V: 528
#       W: 464
#       WM: 2097
#       X: 408
#       Y: 484
#       Z: 601
#       boundary: 70
#       correct: 1868
#       empty: 2
#       gB: 314
#       gC: 505
#       gD: 269
#       gF: 293
#       gG: 336
#       gH: 400
#       gJ: 327
#       gK: 217
#       gL: 140
#       gM: 436
#       gN: 238
#       gP: 333
#       gQ: 362
#       gR: 293
#       gS: 204
#       gT: 343
#       gV: 214
#       gW: 305
#       gX: 240
#       gY: 186
#       gZ: 338
#       nonWM: 2111
#       rB: 179
#       rC: 83
#       rD: 55
#       rF: 82
#       rG: 115
#       rH: 62
#       rJ: 134
#       rK: 116
#       rL: 177
#       rM: 60
#       rN: 37
#       rP: 94
#       rQ: 133
#       rR: 152
#       rS: 97
#       rT: 45
#       rV: 114
#       rW: 50
#       rX: 103
#       rY: 82
#       rZ: 127
#       wrong: 133
#   Value columns (0):
#
# EEG.event events summary
#   Categorical columns (4):
#     Event_Type (5 distinct values):
#       : 70
#       Picture: 23088
#       Quit: 2
#       Response: 4226
#       Sound: 2001
#     cond_code (2 distinct values):
#       : 518
#       0: 3141
#     event_code (2 distinct values):
#       : 518
#       2: 3141
#     type (71 distinct values):
#       1: 2395
#       255: 1831
#       B: 333
#       C: 438
#       D: 594
#       F: 461
#       G: 533
#       H: 502
#       J: 428
#       K: 604
#       L: 566
#       M: 626
#       N: 441
#       P: 404
#       Q: 418
#       R: 630
#       S: 582
#       T: 445
#       V: 528
#       W: 464
#       WM: 2097
#       X: 408
#       Y: 484
#       Z: 601
#       boundary: 70
#       correct: 1868
#       empty: 2
#       gB: 314
#       gC: 505
#       gD: 269
#       gF: 293
#       gG: 336
#       gH: 400
#       gJ: 327
#       gK: 217
#       gL: 140
#       gM: 436
#       gN: 238
#       gP: 333
#       gQ: 362
#       gR: 293
#       gS: 204
#       gT: 343
#       gV: 214
#       gW: 305
#       gX: 240
#       gY: 186
#       gZ: 338
#       nonWM: 2111
#       rB: 179
#       rC: 83
#       rD: 55
#       rF: 82
#       rG: 115
#       rH: 62
#       rJ: 134
#       rK: 116
#       rL: 177
#       rM: 60
#       rN: 37
#       rP: 94
#       rQ: 133
#       rR: 152
#       rS: 97
#       rT: 45
#       rV: 114
#       rW: 50
#       rX: 103
#       rY: 82
#       rZ: 127
#       wrong: 133
#   Value columns (0):
# overall:
# 	[ Bids event files has 85 event files]
# 	[ EEG event files has 85 event files]
# 	[ The Bids event files event files and the EEG event files files have the same number of rows]
# sub-001_ses-01_run-1:
# 	[ Bids event files: sub-001_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-001_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-001_ses-01_run-2:
# 	[ Bids event files: sub-001_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-001_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-001_ses-01_run-3:
# 	[ Bids event files: sub-001_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-001_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-001_ses-01_run-4:
# 	[ Bids event files: sub-001_ses-01_task-WorkingMemory_run-4_events.tsv]
# 	[ EEG event files: sub-001_ses-01_task-WorkingMemory_run-4_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-002_ses-01_run-1:
# 	[ Bids event files: sub-002_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-002_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# ...
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-017_ses-01_run-2:
# 	[ Bids event files: sub-017_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-017_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-017_ses-01_run-3:
# 	[ Bids event files: sub-017_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-017_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [331 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [331 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-018_ses-01_run-1:
# 	[ Bids event files: sub-018_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-018_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-018_ses-01_run-2:
# 	[ Bids event files: sub-018_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-018_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-018_ses-01_run-3:
# 	[ Bids event files: sub-018_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-018_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-019_ses-01_run-1:
# 	[ Bids event files: sub-019_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-019_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-019_ses-01_run-2:
# 	[ Bids event files: sub-019_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-019_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-019_ses-01_run-3:
# 	[ Bids event files: sub-019_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-019_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-020_ses-01_run-1:
# 	[ Bids event files: sub-020_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-020_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-020_ses-01_run-2:
# 	[ Bids event files: sub-020_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-020_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-020_ses-01_run-3:
# 	[ Bids event files: sub-020_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-020_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-021_ses-01_run-1:
# 	[ Bids event files: sub-021_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-021_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-021_ses-01_run-2:
# 	[ Bids event files: sub-021_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-021_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-021_ses-01_run-3:
# 	[ Bids event files: sub-021_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-021_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-022_ses-01_run-1:
# 	[ Bids event files: sub-022_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-022_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [308 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [308 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']]
# sub-022_ses-01_run-2:
# 	[ Bids event files: sub-022_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-022_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [197 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [197 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']]
# sub-022_ses-01_run-3:
# 	[ Bids event files: sub-022_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-022_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']]
# sub-022_ses-01_run-4:
# 	[ Bids event files: sub-022_ses-01_task-WorkingMemory_run-4_events.tsv]
# 	[ EEG event files: sub-022_ses-01_task-WorkingMemory_run-4_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']]
# sub-022_ses-01_run-5:
# 	[ Bids event files: sub-022_ses-01_task-WorkingMemory_run-5_events.tsv]
# 	[ EEG event files: sub-022_ses-01_task-WorkingMemory_run-5_eventstemp.tsv]
# 	[ Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [352 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']]
# sub-022_ses-01_run-6:
# 	[ Bids event files: sub-022_ses-01_task-WorkingMemory_run-6_events.tsv]
# 	[ EEG event files: sub-022_ses-01_task-WorkingMemory_run-6_eventstemp.tsv]
# 	[ Bids event files: [342 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [342 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']]
# sub-023_ses-01_run-1:
# 	[ Bids event files: sub-023_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-023_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-023_ses-01_run-2:
# 	[ Bids event files: sub-023_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-023_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-023_ses-01_run-3:
# 	[ Bids event files: sub-023_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-023_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-023_ses-01_run-4:
# 	[ Bids event files: sub-023_ses-01_task-WorkingMemory_run-4_events.tsv]
# 	[ EEG event files: sub-023_ses-01_task-WorkingMemory_run-4_eventstemp.tsv]
# 	[ Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [352 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-023_ses-01_run-5:
# 	[ Bids event files: sub-023_ses-01_task-WorkingMemory_run-5_events.tsv]
# 	[ EEG event files: sub-023_ses-01_task-WorkingMemory_run-5_eventstemp.tsv]
# 	[ Bids event files: [352 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [352 events] ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-024_ses-01_run-1:
# 	[ Bids event files: sub-024_ses-01_task-WorkingMemory_run-1_events.tsv]
# 	[ EEG event files: sub-024_ses-01_task-WorkingMemory_run-1_eventstemp.tsv]
# 	[ Bids event files: [350 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [350 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-024_ses-01_run-2:
# 	[ Bids event files: sub-024_ses-01_task-WorkingMemory_run-2_events.tsv]
# 	[ EEG event files: sub-024_ses-01_task-WorkingMemory_run-2_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
# sub-024_ses-01_run-3:
# 	[ Bids event files: sub-024_ses-01_task-WorkingMemory_run-3_events.tsv]
# 	[ EEG event files: sub-024_ses-01_task-WorkingMemory_run-3_eventstemp.tsv]
# 	[ Bids event files: [351 events] ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']]
# 	[ EEG event files: [351 events] ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']]
#
# ERROR Summary:
# overall:
# sub-001_ses-01_run-1:
# sub-001_ses-01_run-2:
# sub-001_ses-01_run-3:
# sub-001_ses-01_run-4:
# sub-002_ses-01_run-1:
# sub-002_ses-01_run-2:
# sub-002_ses-01_run-3:
# sub-002_ses-01_run-4:
# sub-003_ses-01_run-1:
# sub-003_ses-01_run-2:
# sub-003_ses-01_run-3:
# sub-003_ses-01_run-4:
# sub-004_ses-01_run-1:
# sub-004_ses-01_run-2:
# sub-004_ses-01_run-3:
# sub-004_ses-01_run-4:
# sub-005_ses-01_run-1:
# sub-005_ses-01_run-2:
# sub-005_ses-01_run-3:
# sub-005_ses-01_run-4:
# sub-006_ses-01_run-1:
# sub-006_ses-01_run-2:
# sub-006_ses-01_run-3:
# sub-006_ses-01_run-4:
# sub-007_ses-01_run-1:
# sub-007_ses-01_run-2:
# sub-007_ses-01_run-3:
# sub-007_ses-01_run-4:
# sub-008_ses-01_run-1:
# sub-008_ses-01_run-2:
# sub-008_ses-01_run-3:
# sub-008_ses-01_run-4:
# sub-009_ses-01_run-1:
# sub-009_ses-01_run-2:
# sub-009_ses-01_run-3:
# sub-009_ses-01_run-4:
# sub-010_ses-01_run-1:
# sub-010_ses-01_run-2:
# sub-010_ses-01_run-3:
# sub-010_ses-01_run-4:
# sub-011_ses-01_run-1:
# sub-011_ses-01_run-2:
# sub-011_ses-01_run-3:
# sub-011_ses-01_run-4:
# sub-012_ses-01_run-1:
# sub-012_ses-01_run-2:
# sub-012_ses-01_run-3:
# sub-014_ses-01_run-1:
# sub-014_ses-01_run-2:
# sub-014_ses-01_run-3:
# sub-015_ses-01_run-1:
# sub-015_ses-01_run-2:
# sub-015_ses-01_run-3:
# sub-016_ses-01_run-1:
# sub-016_ses-01_run-2:
# sub-016_ses-01_run-3:
# sub-017_ses-01_run-1:
# sub-017_ses-01_run-2:
# sub-017_ses-01_run-3:
# sub-018_ses-01_run-1:
# sub-018_ses-01_run-2:
# sub-018_ses-01_run-3:
# sub-019_ses-01_run-1:
# sub-019_ses-01_run-2:
# sub-019_ses-01_run-3:
# sub-020_ses-01_run-1:
# sub-020_ses-01_run-2:
# sub-020_ses-01_run-3:
# sub-021_ses-01_run-1:
# sub-021_ses-01_run-2:
# sub-021_ses-01_run-3:
# sub-022_ses-01_run-1:
# sub-022_ses-01_run-2:
# sub-022_ses-01_run-3:
# sub-022_ses-01_run-4:
# sub-022_ses-01_run-5:
# sub-022_ses-01_run-6:
# sub-023_ses-01_run-1:
# sub-023_ses-01_run-2:
# sub-023_ses-01_run-3:
# sub-023_ses-01_run-4:
# sub-023_ses-01_run-5:
# sub-024_ses-01_run-1:
# sub-024_ses-01_run-2:
# sub-024_ses-01_run-3:
