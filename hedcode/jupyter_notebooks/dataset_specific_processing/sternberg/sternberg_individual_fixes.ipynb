# %% [markdown]
# ## Preliminary summary of the Sternberg dataset
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# In order to compare the events coming from the BIDS events files and those
# from the EEG.set files, the script creates dictionaries of `key` to full path
# for each type of file.  The `key` is of the form `sub-xxx_run-y` which
# uniquely specify each event file in the dataset. If a dataset contains
# multiple sessions for each subject, the `key` should include additional
# parts of the file name to uniquely specify each subject.
#
# ### Manual editing
#
#  1. `sub-022_run-1` and `sub-022_run-2` each had an event at the end of the
# file with value `empty`. These have been removed manually in `_events.tsv` and
# `_events_temp.tsv`.
#  2. The following had extra key press events at the beginning of the recording
# which were removed:  `sub-003_run-3`(2), `sub-004_run-2`(5), `sub-004_run-4`(3),
# `sub-006_run-1`(8), `sub-008_run-1`(4), `sub-009_run-4`(2), `sub-021_run-2`(2),
# `sub-021_run-2`(2).
#  3. `sub-015_run-3`(4) had extra key presses at the end of the file without a trial.
# These were removed as well as a beginning boundary event.
#  4. The EEG versions `sub-023_run-1`, `sub-023_run-2`, `sub-023_run-3`,
# `sub-023_run-4`, and `sub-023_run-5` had the following extra 'n/a' columns: `event_code`, `cond_code`,
# and `sample_offset` which were removed.

# %%
bids_root_path = 'G:/Sternberg/SternbergWorking/'
bids_skip = ['onset', 'duration', 'sample', 'response_time', 'trial_type', 'stim_file']
eeg_skip = ['latency', 'urevent', 'ReqTime', 'ReqDur', 'init_index', 'init_time',
            'event_code', 'cond_code', 'sample_offset', 'duration', 'TTime']

# %%
from hed.util import get_file_list, make_file_dict

# Construct the dictionary for BIDS events files
event_files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events")
bids_file_dict = make_file_dict(event_files_bids, name_indices=(0, 2))
print(f"\n{len(list(bids_file_dict))} Sternberg BIDS style event files")
for key, value in bids_file_dict.items():
    print(f"{key}: {value}")

# Construct the dictionary for EEG.event files
event_files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp")
eeg_file_dict = make_file_dict(event_files_eeg, name_indices=(0, 2))
print(f"\n{len(list(eeg_file_dict))} Sternberg EEG.event style event files")
for key, value in eeg_file_dict.items():
    print(f"{key}: {value}")
# Out:
# 23 Sternberg BIDS style event files
# sub-001_task-Experiment: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events.tsv
# sub-002_task-Experiment: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events.tsv
# sub-003_task-Experiment: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events.tsv
# sub-004_task-Experiment: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events.tsv
# sub-005_task-Experiment: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events.tsv
# sub-006_task-Experiment: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events.tsv
# sub-007_task-Experiment: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events.tsv
# sub-008_task-Experiment: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events.tsv
# sub-009_task-Experiment: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events.tsv
# sub-010_task-Experiment: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events.tsv
# sub-011_task-Experiment: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events.tsv
# sub-012_task-Experiment: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events.tsv
# sub-014_task-Experiment: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events.tsv
# sub-015_task-Experiment: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events.tsv
# sub-016_task-Experiment: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events.tsv
# sub-017_task-Experiment: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events.tsv
# sub-018_task-Experiment: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events.tsv
# sub-019_task-Experiment: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-3_events.tsv
# sub-020_task-Experiment: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events.tsv
# sub-021_task-Experiment: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events.tsv
# sub-022_task-Experiment: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events.tsv
# sub-023_task-Experiment: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events.tsv
# sub-024_task-Experiment: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events.tsv
#
# 23 Sternberg EEG.event style event files
# sub-001_task-Experiment: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-002_task-Experiment: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-003_task-Experiment: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-004_task-Experiment: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-005_task-Experiment: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-006_task-Experiment: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-007_task-Experiment: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-008_task-Experiment: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-009_task-Experiment: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-010_task-Experiment: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-011_task-Experiment: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-012_task-Experiment: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-014_task-Experiment: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-015_task-Experiment: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-016_task-Experiment: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-017_task-Experiment: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-018_task-Experiment: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-019_task-Experiment: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-020_task-Experiment: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-021_task-Experiment: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-022_task-Experiment: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events_temp.tsv
# sub-023_task-Experiment: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events_temp.tsv
# sub-024_task-Experiment: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events_temp.tsv

# %%
from hed.util.data_util import get_new_dataframe

print(f"\nBIDS style event file columns:")
for key, file in bids_file_dict.items():
    df = get_new_dataframe(file)
    print(f"{key}: {str(list(df.columns.values))}")

print(f"\nEEG.event style event file columns:")
for key, file in eeg_file_dict.items():
    df = get_new_dataframe(file)
    print(f"{key}: {str(list(df.columns.values))}")
# Out:
# BIDS style event file columns:
# sub-001_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_task-Experiment: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
#
# EEG.event style event file columns:
# sub-001_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-022_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-023_task-Experiment: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_task-Experiment: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']

# %%
from hed.tools import ColumnSummary

print('\nBIDS events summary:')
bids_dicts_all, bids_dicts =  ColumnSummary.make_combined_dicts(bids_file_dict, skip_cols=bids_skip)
bids_dicts_all.print()

print('\nEEG.event events summary:')
eeg_dicts_all, eeg_dicts =  ColumnSummary.make_combined_dicts(eeg_file_dict, skip_cols=eeg_skip)
eeg_dicts_all.print()
# Out:
# BIDS events summary:
# Summary for column dictionary :
#   Categorical columns (1):
#     value (70 distinct values):
#       1: 586
#       255: 567
#       B: 99
#       C: 123
#       D: 128
#       F: 125
#       G: 186
#       H: 151
#       J: 112
#       K: 166
#       L: 181
#       M: 187
#       N: 142
#       P: 100
#       Q: 115
#       R: 171
#       S: 144
#       T: 118
#       V: 133
#       W: 135
#       WM: 570
#       X: 74
#       Y: 138
#       Z: 142
#       boundary: 25
#       correct: 507
#       gB: 74
#       gC: 86
#       gD: 104
#       gF: 96
#       gG: 84
#       gH: 102
#       gJ: 108
#       gK: 69
#       gL: 22
#       gM: 135
#       gN: 92
#       gP: 84
#       gQ: 88
#       gR: 82
#       gS: 41
#       gT: 83
#       gV: 55
#       gW: 63
#       gX: 56
#       gY: 43
#       gZ: 123
#       nonWM: 575
#       rB: 57
#       rC: 23
#       rD: 27
#       rF: 31
#       rG: 20
#       rH: 31
#       rJ: 41
#       rK: 48
#       rL: 17
#       rM: 22
#       rN: 21
#       rP: 19
#       rQ: 25
#       rR: 33
#       rS: 26
#       rT: 9
#       rV: 36
#       rW: 20
#       rX: 12
#       rY: 30
#       rZ: 22
#       wrong: 41
#   Value columns (0):
#
# EEG.event events summary:
# Summary for column dictionary :
#   Categorical columns (5):
#     Event_Type (4 distinct values):
#       : 25
#       Picture: 6275
#       Response: 1153
#       Sound: 548
#     Trial (52 distinct values):
#       : 25
#       0: 3
#       1: 276
#       10: 45
#       11: 266
#       12: 45
#       13: 276
#       14: 45
#       15: 277
#       16: 55
#       17: 266
#       18: 55
#       19: 266
#       2: 45
#       20: 55
#       21: 266
#       22: 55
#       23: 266
#       24: 56
#       25: 276
#       26: 45
#       27: 276
#       28: 45
#       29: 276
#       3: 276
#       30: 45
#       31: 276
#       32: 45
#       33: 276
#       34: 45
#       35: 276
#       36: 45
#       37: 276
#       38: 45
#       39: 276
#       4: 45
#       40: 45
#       41: 276
#       42: 45
#       43: 266
#       44: 45
#       45: 276
#       46: 45
#       47: 276
#       48: 45
#       49: 254
#       5: 266
#       50: 43
#       6: 45
#       7: 276
#       8: 45
#       9: 266
#     Uncertainty (8 distinct values):
#       : 25
#       1: 3023
#       2: 4684
#       3: 190
#       4: 72
#       5: 5
#       6: 1
#       84: 1
#     Uncertainty2 (9 distinct values):
#       : 1726
#       14: 1
#       2: 1648
#       3: 3070
#       4: 1398
#       5: 125
#       6: 23
#       7: 5
#       8: 5
#     type (70 distinct values):
#       1: 586
#       255: 567
#       B: 99
#       C: 123
#       D: 128
#       F: 125
#       G: 186
#       H: 151
#       J: 112
#       K: 166
#       L: 181
#       M: 187
#       N: 142
#       P: 100
#       Q: 115
#       R: 171
#       S: 144
#       T: 118
#       V: 133
#       W: 135
#       WM: 570
#       X: 74
#       Y: 138
#       Z: 142
#       boundary: 25
#       correct: 507
#       gB: 74
#       gC: 86
#       gD: 104
#       gF: 96
#       gG: 84
#       gH: 102
#       gJ: 108
#       gK: 69
#       gL: 22
#       gM: 135
#       gN: 92
#       gP: 84
#       gQ: 88
#       gR: 82
#       gS: 41
#       gT: 83
#       gV: 55
#       gW: 63
#       gX: 56
#       gY: 43
#       gZ: 123
#       nonWM: 575
#       rB: 57
#       rC: 23
#       rD: 27
#       rF: 31
#       rG: 20
#       rH: 31
#       rJ: 41
#       rK: 48
#       rL: 17
#       rM: 22
#       rN: 21
#       rP: 19
#       rQ: 25
#       rR: 33
#       rS: 26
#       rT: 9
#       rV: 36
#       rW: 20
#       rX: 12
#       rY: 30
#       rZ: 22
#       wrong: 41
#   Value columns (0):
