# %% [markdown]
# ## Preliminary summary of the Sternberg dataset
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# In order to compare the events coming from the BIDS events files and those
# from the EEG.set files, the script creates dictionaries of `key` to full path
# for each type of file.  The `key` is of the form `sub-xxx_run-y` which
# uniquely specify each event file in the dataset. If a dataset contains
# multiple sessions for each subject, the `key` should include additional
# parts of the file name to uniquely specify each subject.

# %%
bids_root_path = 'G:/Sternberg/SternbergWorking/'
bids_skip = ['onset', 'duration', 'sample', 'response_time', 'trial_type', 'stim_file']
eeg_skip = ['latency', 'urevent', 'ReqTime', 'ReqDur', 'init_index', 'init_time',
            'event_code', 'cond_code', 'sample_offset', 'duration', 'TTime']

# %%
from hed.util import get_file_list, make_file_dict

# Construct the dictionary for BIDS events files
event_files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events")
bids_file_dict = make_file_dict(event_files_bids, name_indices=(0, 3))
print(f"\n{len(list(bids_file_dict))} Sternberg BIDS style event files")
for key, value in bids_file_dict.items():
    print(f"{key}: {value}")

# Construct the dictionary for EEG.event files
event_files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp")
eeg_file_dict = make_file_dict(event_files_eeg, name_indices=(0, 3))
print(f"\n{len(list(eeg_file_dict))} Sternberg EEG.event style event files")
for key, value in eeg_file_dict.items():
    print(f"{key}: {value}")
# Out:
# 85 Sternberg BIDS style event files
# sub-001_run-1: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-1_events.tsv
# sub-001_run-2: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-2_events.tsv
# sub-001_run-3: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-3_events.tsv
# sub-001_run-4: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events.tsv
# sub-002_run-1: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-1_events.tsv
# sub-002_run-2: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-2_events.tsv
# sub-002_run-3: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-3_events.tsv
# sub-002_run-4: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events.tsv
# sub-003_run-1: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-1_events.tsv
# sub-003_run-2: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-2_events.tsv
# sub-003_run-3: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-3_events.tsv
# sub-003_run-4: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events.tsv
# sub-004_run-1: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-1_events.tsv
# sub-004_run-2: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-2_events.tsv
# sub-004_run-3: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-3_events.tsv
# sub-004_run-4: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events.tsv
# sub-005_run-1: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-1_events.tsv
# sub-005_run-2: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-2_events.tsv
# sub-005_run-3: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-3_events.tsv
# sub-005_run-4: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events.tsv
# sub-006_run-1: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-1_events.tsv
# sub-006_run-2: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-2_events.tsv
# sub-006_run-3: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-3_events.tsv
# sub-006_run-4: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events.tsv
# sub-007_run-1: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-1_events.tsv
# sub-007_run-2: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-2_events.tsv
# sub-007_run-3: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-3_events.tsv
# sub-007_run-4: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events.tsv
# sub-008_run-1: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-1_events.tsv
# sub-008_run-2: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-2_events.tsv
# sub-008_run-3: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-3_events.tsv
# sub-008_run-4: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events.tsv
# sub-009_run-1: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-1_events.tsv
# sub-009_run-2: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-2_events.tsv
# sub-009_run-3: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-3_events.tsv
# sub-009_run-4: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events.tsv
# sub-010_run-1: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-1_events.tsv
# sub-010_run-2: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-2_events.tsv
# sub-010_run-3: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-3_events.tsv
# sub-010_run-4: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events.tsv
# sub-011_run-1: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-1_events.tsv
# sub-011_run-2: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-2_events.tsv
# sub-011_run-3: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-3_events.tsv
# sub-011_run-4: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events.tsv
# sub-012_run-1: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-1_events.tsv
# sub-012_run-2: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-2_events.tsv
# sub-012_run-3: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events.tsv
# sub-014_run-1: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-1_events.tsv
# sub-014_run-2: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-2_events.tsv
# sub-014_run-3: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events.tsv
# sub-015_run-1: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-1_events.tsv
# sub-015_run-2: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-2_events.tsv
# sub-015_run-3: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events.tsv
# sub-016_run-1: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-1_events.tsv
# sub-016_run-2: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-2_events.tsv
# sub-016_run-3: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events.tsv
# sub-017_run-1: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-1_events.tsv
# sub-017_run-2: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-2_events.tsv
# sub-017_run-3: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events.tsv
# sub-018_run-1: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-1_events.tsv
# sub-018_run-2: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-2_events.tsv
# sub-018_run-3: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events.tsv
# sub-019_run-1: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-1_events.tsv
# sub-019_run-2: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-2_events.tsv
# sub-019_run-3: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-3_events.tsv
# sub-020_run-1: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-1_events.tsv
# sub-020_run-2: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-2_events.tsv
# sub-020_run-3: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events.tsv
# sub-021_run-1: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-1_events.tsv
# sub-021_run-2: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-2_events.tsv
# sub-021_run-3: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events.tsv
# sub-022_run-1: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-1_events.tsv
# sub-022_run-2: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-2_events.tsv
# sub-022_run-3: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-3_events.tsv
# sub-022_run-4: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-4_events.tsv
# sub-022_run-5: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-5_events.tsv
# sub-022_run-6: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events.tsv
# sub-023_run-1: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-1_events.tsv
# sub-023_run-2: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-2_events.tsv
# sub-023_run-3: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-3_events.tsv
# sub-023_run-4: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-4_events.tsv
# sub-023_run-5: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events.tsv
# sub-024_run-1: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-1_events.tsv
# sub-024_run-2: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-2_events.tsv
# sub-024_run-3: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events.tsv
#
# 85 Sternberg EEG.event style event files
# sub-001_run-1: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-001_run-2: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-001_run-3: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-001_run-4: G:\Sternberg\SternbergWorking\sub-001\ses-01\eeg\sub-001_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-002_run-1: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-002_run-2: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-002_run-3: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-002_run-4: G:\Sternberg\SternbergWorking\sub-002\ses-01\eeg\sub-002_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-003_run-1: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-003_run-2: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-003_run-3: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-003_run-4: G:\Sternberg\SternbergWorking\sub-003\ses-01\eeg\sub-003_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-004_run-1: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-004_run-2: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-004_run-3: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-004_run-4: G:\Sternberg\SternbergWorking\sub-004\ses-01\eeg\sub-004_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-005_run-1: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-005_run-2: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-005_run-3: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-005_run-4: G:\Sternberg\SternbergWorking\sub-005\ses-01\eeg\sub-005_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-006_run-1: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-006_run-2: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-006_run-3: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-006_run-4: G:\Sternberg\SternbergWorking\sub-006\ses-01\eeg\sub-006_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-007_run-1: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-007_run-2: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-007_run-3: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-007_run-4: G:\Sternberg\SternbergWorking\sub-007\ses-01\eeg\sub-007_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-008_run-1: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-008_run-2: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-008_run-3: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-008_run-4: G:\Sternberg\SternbergWorking\sub-008\ses-01\eeg\sub-008_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-009_run-1: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-009_run-2: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-009_run-3: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-009_run-4: G:\Sternberg\SternbergWorking\sub-009\ses-01\eeg\sub-009_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-010_run-1: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-010_run-2: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-010_run-3: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-010_run-4: G:\Sternberg\SternbergWorking\sub-010\ses-01\eeg\sub-010_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-011_run-1: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-011_run-2: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-011_run-3: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-011_run-4: G:\Sternberg\SternbergWorking\sub-011\ses-01\eeg\sub-011_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-012_run-1: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-012_run-2: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-012_run-3: G:\Sternberg\SternbergWorking\sub-012\ses-01\eeg\sub-012_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-014_run-1: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-014_run-2: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-014_run-3: G:\Sternberg\SternbergWorking\sub-014\ses-01\eeg\sub-014_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-015_run-1: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-015_run-2: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-015_run-3: G:\Sternberg\SternbergWorking\sub-015\ses-01\eeg\sub-015_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-016_run-1: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-016_run-2: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-016_run-3: G:\Sternberg\SternbergWorking\sub-016\ses-01\eeg\sub-016_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-017_run-1: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-017_run-2: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-017_run-3: G:\Sternberg\SternbergWorking\sub-017\ses-01\eeg\sub-017_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-018_run-1: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-018_run-2: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-018_run-3: G:\Sternberg\SternbergWorking\sub-018\ses-01\eeg\sub-018_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-019_run-1: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-019_run-2: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-019_run-3: G:\Sternberg\SternbergWorking\sub-019\ses-01\eeg\sub-019_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-020_run-1: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-020_run-2: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-020_run-3: G:\Sternberg\SternbergWorking\sub-020\ses-01\eeg\sub-020_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-021_run-1: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-021_run-2: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-021_run-3: G:\Sternberg\SternbergWorking\sub-021\ses-01\eeg\sub-021_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-022_run-1: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-022_run-2: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-022_run-3: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-022_run-4: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-022_run-5: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-5_events_temp.tsv
# sub-022_run-6: G:\Sternberg\SternbergWorking\sub-022\ses-01\eeg\sub-022_ses-01_task-Experiment_run-6_events_temp.tsv
# sub-023_run-1: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-023_run-2: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-023_run-3: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-3_events_temp.tsv
# sub-023_run-4: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-4_events_temp.tsv
# sub-023_run-5: G:\Sternberg\SternbergWorking\sub-023\ses-01\eeg\sub-023_ses-01_task-Experiment_run-5_events_temp.tsv
# sub-024_run-1: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-1_events_temp.tsv
# sub-024_run-2: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-2_events_temp.tsv
# sub-024_run-3: G:\Sternberg\SternbergWorking\sub-024\ses-01\eeg\sub-024_ses-01_task-Experiment_run-3_events_temp.tsv

# %%
from hed.util.data_util import get_new_dataframe

print(f"\nBIDS style event file columns:")
for key, file in bids_file_dict.items():
    df = get_new_dataframe(file)
    print(f"{key}: {str(list(df.columns.values))}")

print(f"\nEEG.event style event file columns:")
for key, file in eeg_file_dict.items():
    df = get_new_dataframe(file)
    print(f"{key}: {str(list(df.columns.values))}")
# Out:
# BIDS style event file columns:
# sub-001_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-001_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-001_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-001_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-002_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-003_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-004_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-005_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-006_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-007_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-008_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-009_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-010_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-011_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-012_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-014_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-015_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-016_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-017_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-018_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-019_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-020_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-021_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_run-5: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-022_run-6: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_run-4: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-023_run-5: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_run-1: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_run-2: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
# sub-024_run-3: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value']
#
# EEG.event style event file columns:
# sub-001_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-001_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-001_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-001_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-002_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-003_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-004_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-005_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-006_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-007_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-008_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-009_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-010_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-011_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-012_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-014_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-015_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-016_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-017_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-018_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-019_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-020_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-021_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-022_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_run-4: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_run-5: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-022_run-6: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent', 'sample_offset', 'event_code', 'cond_code']
# sub-023_run-1: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_run-2: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_run-3: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_run-4: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-023_run-5: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'Trial', 'Event_Type', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_run-1: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_run-2: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']
# sub-024_run-3: ['Trial', 'Event_Type', 'type', 'latency', 'TTime', 'Uncertainty', 'duration', 'Uncertainty2', 'ReqTime', 'ReqDur', 'init_index', 'init_time', 'urevent']

# %%
from hed.tools import ColumnSummary

print('\nBIDS events summary:')
bids_dicts_all, bids_dicts =  ColumnSummary.make_combined_dicts(bids_file_dict, skip_cols=bids_skip)
bids_dicts_all.print()

print('\nEEG.event events summary:')
eeg_dicts_all, eeg_dicts =  ColumnSummary.make_combined_dicts(eeg_file_dict, skip_cols=eeg_skip)
eeg_dicts_all.print()
# Out:
# BIDS events summary:
# Summary for column dictionary :
#   Categorical columns (1):
#     value (71 distinct values):
#       1: 2395
#       255: 1831
#       B: 333
#       C: 438
#       D: 594
#       F: 461
#       G: 533
#       H: 502
#       J: 428
#       K: 604
#       L: 566
#       M: 626
#       N: 441
#       P: 404
#       Q: 418
#       R: 630
#       S: 582
#       T: 445
#       V: 528
#       W: 464
#       WM: 2097
#       X: 408
#       Y: 484
#       Z: 601
#       boundary: 70
#       correct: 1868
#       empty: 2
#       gB: 314
#       gC: 505
#       gD: 269
#       gF: 293
#       gG: 336
#       gH: 400
#       gJ: 327
#       gK: 217
#       gL: 140
#       gM: 436
#       gN: 238
#       gP: 333
#       gQ: 362
#       gR: 293
#       gS: 204
#       gT: 343
#       gV: 214
#       gW: 305
#       gX: 240
#       gY: 186
#       gZ: 338
#       nonWM: 2111
#       rB: 179
#       rC: 83
#       rD: 55
#       rF: 82
#       rG: 115
#       rH: 62
#       rJ: 134
#       rK: 116
#       rL: 177
#       rM: 60
#       rN: 37
#       rP: 94
#       rQ: 133
#       rR: 152
#       rS: 97
#       rT: 45
#       rV: 114
#       rW: 50
#       rX: 103
#       rY: 82
#       rZ: 127
#       wrong: 133
#   Value columns (0):
#
# EEG.event events summary:
# Summary for column dictionary :
#   Categorical columns (5):
#     Event_Type (5 distinct values):
#       : 70
#       Picture: 23088
#       Quit: 2
#       Response: 4226
#       Sound: 2001
#     Trial (52 distinct values):
#       : 70
#       0: 6
#       1: 990
#       10: 176
#       11: 1000
#       12: 176
#       13: 1010
#       14: 176
#       15: 1001
#       16: 186
#       17: 1002
#       18: 206
#       19: 980
#       2: 166
#       20: 206
#       21: 970
#       22: 207
#       23: 991
#       24: 208
#       25: 1000
#       26: 186
#       27: 1000
#       28: 186
#       29: 988
#       3: 1010
#       30: 185
#       31: 998
#       32: 174
#       33: 998
#       34: 174
#       35: 998
#       36: 174
#       37: 998
#       38: 174
#       39: 998
#       4: 166
#       40: 174
#       41: 999
#       42: 184
#       43: 978
#       44: 184
#       45: 976
#       46: 182
#       47: 964
#       48: 180
#       49: 930
#       5: 1008
#       50: 152
#       6: 176
#       7: 1000
#       8: 176
#       9: 990
#     Uncertainty (16 distinct values):
#       : 72
#       1: 10601
#       13: 2
#       2: 17697
#       3: 726
#       4: 264
#       5: 12
#       57: 1
#       6: 3
#       70: 2
#       71: 1
#       76: 2
#       77: 1
#       81: 1
#       83: 1
#       84: 1
#     Uncertainty2 (12 distinct values):
#       : 6299
#       14: 2
#       15: 2
#       16: 1
#       2: 5735
#       3: 10848
#       4: 5852
#       5: 507
#       59: 1
#       6: 116
#       7: 12
#       8: 12
#     type (71 distinct values):
#       1: 2395
#       255: 1831
#       B: 333
#       C: 438
#       D: 594
#       F: 461
#       G: 533
#       H: 502
#       J: 428
#       K: 604
#       L: 566
#       M: 626
#       N: 441
#       P: 404
#       Q: 418
#       R: 630
#       S: 582
#       T: 445
#       V: 528
#       W: 464
#       WM: 2097
#       X: 408
#       Y: 484
#       Z: 601
#       boundary: 70
#       correct: 1868
#       empty: 2
#       gB: 314
#       gC: 505
#       gD: 269
#       gF: 293
#       gG: 336
#       gH: 400
#       gJ: 327
#       gK: 217
#       gL: 140
#       gM: 436
#       gN: 238
#       gP: 333
#       gQ: 362
#       gR: 293
#       gS: 204
#       gT: 343
#       gV: 214
#       gW: 305
#       gX: 240
#       gY: 186
#       gZ: 338
#       nonWM: 2111
#       rB: 179
#       rC: 83
#       rD: 55
#       rF: 82
#       rG: 115
#       rH: 62
#       rJ: 134
#       rK: 116
#       rL: 177
#       rM: 60
#       rN: 37
#       rP: 94
#       rQ: 133
#       rR: 152
#       rS: 97
#       rT: 45
#       rV: 114
#       rW: 50
#       rX: 103
#       rY: 82
#       rZ: 127
#       wrong: 133
#   Value columns (0):
