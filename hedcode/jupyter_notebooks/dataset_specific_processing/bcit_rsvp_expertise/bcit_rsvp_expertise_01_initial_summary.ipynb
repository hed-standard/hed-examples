# %% [markdown]
# ## Initial summary of event files
#
# **Dataset** BCIT RSVP Expertise (in process)
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
# Keys are specified by a `entities` tuple lists the BIDS entity names
# to include in the key.
# BIDS base file names are constructed of entity *name*-*value* pairs separated
# by underbars and followed by an ending *_suffix*.
#
# For a file name `sub-001_ses-3_task-target_run-01_events.tsv`,
# the tuple ('sub', 'task') gives a key of `sub-001_task-target`,
# while the tuple ('sub', 'ses', 'run) gives a key of `sub-001_ses-3_run-01`.
# The use of dictionaries of file names with such keys makes it
# easier to associate related files in the BIDS naming structure.
#
# The setup requires the setting of the following variables for your dataset:
#
# | Variable | Purpose |
# | -------- | ------- |
# | bids_root_path | Full path to root directory of dataset.|
# | exclude_dirs | List of directories to exclude when constructing file lists. |
# | entities  | Tuple of entity names used to construct a unique keys representing filenames. <br>(See [Dictionaries of filenames](https://hed-examples.readthedocs.io/en/latest/HedInPython.html#dictionaries-of-filenames-anchor) for examples of how to choose the keys.)|
# | bids_skip_columns  |  List of column names in the `events.tsv` files to skip in the analysis. |
# | eeg_skip_columns  | List of column names in the `events_temp.tsv` files form EEG.events to skip in analysis.|
# | log_file_name | Name of the log file (saved in the `code` subdirectory). |

# %%
import os
from hed.tools import BidsTsvDictionary, BidsTsvSummary, HedLogger, report_tsv_diffs
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/RSVPExpertiseWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
bids_skip_columns = ['onset']
eeg_skip_columns = ['latency', 'urevent', 'imageid', 'gid', 'buttonpressduration', 'reactiontime',
                    'luminance', 'tgtsize',	'tgtdistfromcenter', 'usertags']
log_file_name = 'bcit_rsvp_expertise_01_initial_summary_log.json'

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary("Bids event files", files_bids, entities=entities)
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary("EEG event files", files_eeg, entities=entities)

# Set logger and Output a list of files for the two cases
logger = HedLogger()
report_tsv_diffs(bids_dict, eeg_dict, logger)

# Create summary dictionaries of the original BIDS events files and output column names
bids_sum_all, bids_sum =  BidsTsvSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip_columns)
bids_sum_all.print('\nBIDS events summary')

eeg_sum_all, eeg_sum =  BidsTsvSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip_columns)
eeg_sum_all.print('\nEEG.event events summary')

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# Summarizing Bids event files...
#
# Bids event files event files (59 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-01_ses-02_run-1: sub-01_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-01_ses-03_run-1: sub-01_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-01_ses-04_run-1: sub-01_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-01_ses-05_run-1: sub-01_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-02_ses-02_run-1: sub-02_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-02_ses-03_run-1: sub-02_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-02_ses-04_run-1: sub-02_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-02_ses-05_run-1: sub-02_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-03_ses-01_run-2: sub-03_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-03_ses-02_run-1: sub-03_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-03_ses-03_run-1: sub-03_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-03_ses-04_run-1: sub-03_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-03_ses-05_run-1: sub-03_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-04_ses-02_run-1: sub-04_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-04_ses-03_run-1: sub-04_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-04_ses-04_run-1: sub-04_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-04_ses-05_run-1: sub-04_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-04_ses-05_run-2: sub-04_ses-05_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-05_ses-02_run-1: sub-05_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-05_ses-03_run-1: sub-05_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-05_ses-04_run-1: sub-05_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-05_ses-05_run-1: sub-05_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-06_ses-02_run-1: sub-06_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-06_ses-03_run-1: sub-06_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-06_ses-04_run-1: sub-06_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-06_ses-05_run-1: sub-06_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-07_ses-01_run-2: sub-07_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-07_ses-02_run-1: sub-07_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-07_ses-03_run-1: sub-07_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-07_ses-04_run-1: sub-07_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-07_ses-04_run-2: sub-07_ses-04_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-07_ses-05_run-1: sub-07_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-08_ses-01_run-2: sub-08_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-08_ses-02_run-1: sub-08_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-08_ses-03_run-1: sub-08_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-08_ses-04_run-1: sub-08_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-08_ses-05_run-1: sub-08_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-01_run-2: sub-09_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-09_ses-02_run-1: sub-09_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-02_run-2: sub-09_ses-02_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-09_ses-03_run-1: sub-09_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-04_run-1: sub-09_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-05_run-1: sub-09_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-06_run-1: sub-09_ses-06_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-09_ses-06_run-2: sub-09_ses-06_task-RSVPObjectRestBlink_run-2_events.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-10_ses-02_run-1: sub-10_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-10_ses-03_run-1: sub-10_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-10_ses-04_run-1: sub-10_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv
# sub-10_ses-05_run-1: sub-10_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv
#
# EEG event files event files (59 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-01_ses-02_run-1: sub-01_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-01_ses-03_run-1: sub-01_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-01_ses-04_run-1: sub-01_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-01_ses-05_run-1: sub-01_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-02_ses-02_run-1: sub-02_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-02_ses-03_run-1: sub-02_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-02_ses-04_run-1: sub-02_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-02_ses-05_run-1: sub-02_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-03_ses-01_run-2: sub-03_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-03_ses-02_run-1: sub-03_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-03_ses-03_run-1: sub-03_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-03_ses-04_run-1: sub-03_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-03_ses-05_run-1: sub-03_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-04_ses-02_run-1: sub-04_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-04_ses-03_run-1: sub-04_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-04_ses-04_run-1: sub-04_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-04_ses-05_run-1: sub-04_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-04_ses-05_run-2: sub-04_ses-05_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-05_ses-02_run-1: sub-05_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-05_ses-03_run-1: sub-05_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-05_ses-04_run-1: sub-05_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-05_ses-05_run-1: sub-05_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-06_ses-02_run-1: sub-06_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-06_ses-03_run-1: sub-06_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-06_ses-04_run-1: sub-06_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-06_ses-05_run-1: sub-06_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-07_ses-01_run-2: sub-07_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-07_ses-02_run-1: sub-07_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-07_ses-03_run-1: sub-07_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-07_ses-04_run-1: sub-07_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-07_ses-04_run-2: sub-07_ses-04_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-07_ses-05_run-1: sub-07_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-08_ses-01_run-2: sub-08_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-08_ses-02_run-1: sub-08_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-08_ses-03_run-1: sub-08_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-08_ses-04_run-1: sub-08_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-08_ses-05_run-1: sub-08_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-01_run-2: sub-09_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-09_ses-02_run-1: sub-09_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-02_run-2: sub-09_ses-02_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-09_ses-03_run-1: sub-09_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-04_run-1: sub-09_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-05_run-1: sub-09_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-06_run-1: sub-09_ses-06_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-09_ses-06_run-2: sub-09_ses-06_task-RSVPObjectRestBlink_run-2_events_temp.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-10_ses-02_run-1: sub-10_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-10_ses-03_run-1: sub-10_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-10_ses-04_run-1: sub-10_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv
# sub-10_ses-05_run-1: sub-10_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv
#
# Bids event files event file columns:
# sub-01_ses-01_run-1 []: Bids event files: [20245 events] ['onset', 'duration', 'event_code']
# sub-01_ses-02_run-1 []: Bids event files: [20569 events] ['onset', 'duration', 'event_code']
# sub-01_ses-03_run-1 []: Bids event files: [21119 events] ['onset', 'duration', 'event_code']
# sub-01_ses-04_run-1 []: Bids event files: [19836 events] ['onset', 'duration', 'event_code']
# sub-01_ses-05_run-1 []: Bids event files: [20150 events] ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-1 []: Bids event files: [20397 events] ['onset', 'duration', 'event_code']
# sub-02_ses-02_run-1 []: Bids event files: [20028 events] ['onset', 'duration', 'event_code']
# sub-02_ses-03_run-1 []: Bids event files: [19723 events] ['onset', 'duration', 'event_code']
# sub-02_ses-04_run-1 []: Bids event files: [19705 events] ['onset', 'duration', 'event_code']
# sub-02_ses-05_run-1 []: Bids event files: [19513 events] ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-1 []: Bids event files: [9727 events] ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-2 []: Bids event files: [9727 events] ['onset', 'duration', 'event_code']
# sub-03_ses-02_run-1 []: Bids event files: [20021 events] ['onset', 'duration', 'event_code']
# sub-03_ses-03_run-1 []: Bids event files: [19357 events] ['onset', 'duration', 'event_code']
# sub-03_ses-04_run-1 []: Bids event files: [19392 events] ['onset', 'duration', 'event_code']
# sub-03_ses-05_run-1 []: Bids event files: [19037 events] ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-1 []: Bids event files: [20279 events] ['onset', 'duration', 'event_code']
# sub-04_ses-02_run-1 []: Bids event files: [20188 events] ['onset', 'duration', 'event_code']
# sub-04_ses-03_run-1 []: Bids event files: [21371 events] ['onset', 'duration', 'event_code']
# sub-04_ses-04_run-1 []: Bids event files: [21330 events] ['onset', 'duration', 'event_code']
# sub-04_ses-05_run-1 []: Bids event files: [3276 events] ['onset', 'duration', 'event_code']
# sub-04_ses-05_run-2 []: Bids event files: [3276 events] ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-1 []: Bids event files: [20169 events] ['onset', 'duration', 'event_code']
# sub-05_ses-02_run-1 []: Bids event files: [20283 events] ['onset', 'duration', 'event_code']
# sub-05_ses-03_run-1 []: Bids event files: [20429 events] ['onset', 'duration', 'event_code']
# sub-05_ses-04_run-1 []: Bids event files: [20645 events] ['onset', 'duration', 'event_code']
# sub-05_ses-05_run-1 []: Bids event files: [21098 events] ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-1 []: Bids event files: [19413 events] ['onset', 'duration', 'event_code']
# sub-06_ses-02_run-1 []: Bids event files: [18915 events] ['onset', 'duration', 'event_code']
# sub-06_ses-03_run-1 []: Bids event files: [19356 events] ['onset', 'duration', 'event_code']
# sub-06_ses-04_run-1 []: Bids event files: [21080 events] ['onset', 'duration', 'event_code']
# sub-06_ses-05_run-1 []: Bids event files: [19565 events] ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-1 []: Bids event files: [8074 events] ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-2 []: Bids event files: [8074 events] ['onset', 'duration', 'event_code']
# sub-07_ses-02_run-1 []: Bids event files: [23253 events] ['onset', 'duration', 'event_code']
# sub-07_ses-03_run-1 []: Bids event files: [22787 events] ['onset', 'duration', 'event_code']
# sub-07_ses-04_run-1 []: Bids event files: [8271 events] ['onset', 'duration', 'event_code']
# sub-07_ses-04_run-2 []: Bids event files: [8271 events] ['onset', 'duration', 'event_code']
# sub-07_ses-05_run-1 []: Bids event files: [24761 events] ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-1 []: Bids event files: [12969 events] ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-2 []: Bids event files: [12969 events] ['onset', 'duration', 'event_code']
# sub-08_ses-02_run-1 []: Bids event files: [19557 events] ['onset', 'duration', 'event_code']
# sub-08_ses-03_run-1 []: Bids event files: [19421 events] ['onset', 'duration', 'event_code']
# sub-08_ses-04_run-1 []: Bids event files: [20006 events] ['onset', 'duration', 'event_code']
# sub-08_ses-05_run-1 []: Bids event files: [19247 events] ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-1 []: Bids event files: [6521 events] ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-2 []: Bids event files: [6521 events] ['onset', 'duration', 'event_code']
# sub-09_ses-02_run-1 []: Bids event files: [10505 events] ['onset', 'duration', 'event_code']
# sub-09_ses-02_run-2 []: Bids event files: [10505 events] ['onset', 'duration', 'event_code']
# sub-09_ses-03_run-1 []: Bids event files: [20423 events] ['onset', 'duration', 'event_code']
# sub-09_ses-04_run-1 []: Bids event files: [19915 events] ['onset', 'duration', 'event_code']
# sub-09_ses-05_run-1 []: Bids event files: [19015 events] ['onset', 'duration', 'event_code']
# sub-09_ses-06_run-1 []: Bids event files: [12789 events] ['onset', 'duration', 'event_code']
# sub-09_ses-06_run-2 []: Bids event files: [12789 events] ['onset', 'duration', 'event_code']
# sub-10_ses-01_run-1 []: Bids event files: [19956 events] ['onset', 'duration', 'event_code']
# sub-10_ses-02_run-1 []: Bids event files: [19483 events] ['onset', 'duration', 'event_code']
# sub-10_ses-03_run-1 []: Bids event files: [19741 events] ['onset', 'duration', 'event_code']
# sub-10_ses-04_run-1 []: Bids event files: [20149 events] ['onset', 'duration', 'event_code']
# sub-10_ses-05_run-1 []: Bids event files: [19738 events] ['onset', 'duration', 'event_code']
#
# EEG event files event file columns:
# sub-01_ses-01_run-1 []: EEG event files: [20245 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-01_ses-02_run-1 []: EEG event files: [20569 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-01_ses-03_run-1 []: EEG event files: [21119 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-01_ses-04_run-1 []: EEG event files: [19836 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-01_ses-05_run-1 []: EEG event files: [20150 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-02_ses-01_run-1 []: EEG event files: [20397 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-02_ses-02_run-1 []: EEG event files: [20028 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-02_ses-03_run-1 []: EEG event files: [19723 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-02_ses-04_run-1 []: EEG event files: [19705 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-02_ses-05_run-1 []: EEG event files: [19513 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-03_ses-01_run-1 []: EEG event files: [9834 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-03_ses-01_run-2 []: EEG event files: [9727 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-03_ses-02_run-1 []: EEG event files: [20021 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-03_ses-03_run-1 []: EEG event files: [19357 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-03_ses-04_run-1 []: EEG event files: [19392 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-03_ses-05_run-1 []: EEG event files: [19037 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-04_ses-01_run-1 []: EEG event files: [20279 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-04_ses-02_run-1 []: EEG event files: [20188 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-04_ses-03_run-1 []: EEG event files: [21371 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-04_ses-04_run-1 []: EEG event files: [21330 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-04_ses-05_run-1 []: EEG event files: [17207 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-04_ses-05_run-2 []: EEG event files: [3276 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-05_ses-01_run-1 []: EEG event files: [20169 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-05_ses-02_run-1 []: EEG event files: [20283 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-05_ses-03_run-1 []: EEG event files: [20429 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-05_ses-04_run-1 []: EEG event files: [20645 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-05_ses-05_run-1 []: EEG event files: [21098 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-06_ses-01_run-1 []: EEG event files: [19413 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-06_ses-02_run-1 []: EEG event files: [18915 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-06_ses-03_run-1 []: EEG event files: [19356 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-06_ses-04_run-1 []: EEG event files: [21080 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-06_ses-05_run-1 []: EEG event files: [19565 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-01_run-1 []: EEG event files: [12289 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-01_run-2 []: EEG event files: [8074 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-02_run-1 []: EEG event files: [23253 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-03_run-1 []: EEG event files: [22787 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-04_run-1 []: EEG event files: [15066 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-04_run-2 []: EEG event files: [8271 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-07_ses-05_run-1 []: EEG event files: [24761 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-08_ses-01_run-1 []: EEG event files: [6469 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-08_ses-01_run-2 []: EEG event files: [12969 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-08_ses-02_run-1 []: EEG event files: [19557 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-08_ses-03_run-1 []: EEG event files: [19421 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-08_ses-04_run-1 []: EEG event files: [20006 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-08_ses-05_run-1 []: EEG event files: [19247 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-01_run-1 []: EEG event files: [15037 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-01_run-2 []: EEG event files: [6521 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-02_run-1 []: EEG event files: [10277 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-02_run-2 []: EEG event files: [10505 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-03_run-1 []: EEG event files: [20423 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-04_run-1 []: EEG event files: [19915 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-05_run-1 []: EEG event files: [19015 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-06_run-1 []: EEG event files: [7095 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-09_ses-06_run-2 []: EEG event files: [12789 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-10_ses-01_run-1 []: EEG event files: [19956 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-10_ses-02_run-1 []: EEG event files: [19483 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-10_ses-03_run-1 []: EEG event files: [19741 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-10_ses-04_run-1 []: EEG event files: [20149 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
# sub-10_ses-05_run-1 []: EEG event files: [19738 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']
#
# The number of Bids event files events and EEG event files events differ for the following files:
# sub-03_ses-01_run-1 [ERROR]: The Bids event files file has 9727 rows and the EEG event files event file has 9834 rows
# sub-04_ses-05_run-1 [ERROR]: The Bids event files file has 3276 rows and the EEG event files event file has 17207 rows
# sub-07_ses-01_run-1 [ERROR]: The Bids event files file has 8074 rows and the EEG event files event file has 12289 rows
# sub-07_ses-04_run-1 [ERROR]: The Bids event files file has 8271 rows and the EEG event files event file has 15066 rows
# sub-08_ses-01_run-1 [ERROR]: The Bids event files file has 12969 rows and the EEG event files event file has 6469 rows
# sub-09_ses-01_run-1 [ERROR]: The Bids event files file has 6521 rows and the EEG event files event file has 15037 rows
# sub-09_ses-02_run-1 [ERROR]: The Bids event files file has 10505 rows and the EEG event files event file has 10277 rows
# sub-09_ses-06_run-1 [ERROR]: The Bids event files file has 12789 rows and the EEG event files event file has 7095 rows
#
# BIDS events summary
#   Categorical columns (2):
#     duration (1 distinct values):
#       n/a: 1014929
#     event_code (30 distinct values):
#       11201: 43
#       11202: 53
#       12101: 54
#       12102: 54
#       12201: 58
#       12202: 56
#       12301: 60
#       12302: 58
#       12401: 68
#       12402: 66
#       12501: 60
#       12502: 60
#       13110: 38230
#       13120: 26312
#       13210: 812163
#       13220: 12212
#       21121: 19168
#       21122: 19168
#       21131: 26774
#       21132: 26774
#       21221: 4042
#       21222: 4042
#       21231: 12415
#       21232: 12415
#       31101: 241
#       31102: 241
#       32202: 4
#       32302: 14
#       32401: 10
#       32402: 14
#   Value columns (0):
#
# EEG.event events summary
#   Categorical columns (10):
#     cameradistance (6 distinct values):
#       0: 133132
#       1: 317857
#       2: 317104
#       3: 227892
#       4: 30832
#       5: 9254
#     imagecategory (7 distinct values):
#       0: 133132
#       1: 60200
#       2: 89717
#       3: 63560
#       4: 101931
#       5: 94020
#       6: 493511
#     imageclutter (6 distinct values):
#       0: 133132
#       1: 79117
#       2: 563293
#       3: 238305
#       4: 18966
#       5: 3258
#     imagelocation (3 distinct values):
#       0: 133132
#       1: 774774
#       2: 128165
#     numberofclasses (5 distinct values):
#       0: 626643
#       1: 332212
#       2: 71320
#       3: 5248
#       4: 648
#     numberoftargets (6 distinct values):
#       0: 626643
#       1: 299338
#       2: 89237
#       3: 16785
#       4: 3638
#       5: 430
#     tgtcontrast (4 distinct values):
#       0: 626643
#       1: 55232
#       2: 220917
#       3: 133279
#     tgtocclusion (6 distinct values):
#       0: 626643
#       1: 150339
#       2: 157610
#       3: 61507
#       4: 27886
#       5: 12086
#     tgtorientation (5 distinct values):
#       0: 802343
#       135: 22091
#       180: 15495
#       45: 139824
#       90: 56318
#     type (31 distinct values):
#       11201: 51
#       11202: 46
#       12101: 60
#       12102: 59
#       12201: 60
#       12202: 57
#       12301: 59
#       12302: 57
#       12401: 66
#       12402: 65
#       12501: 60
#       12502: 60
#       13110: 39757
#       13120: 26773
#       13210: 823632
#       13220: 12777
#       21121: 21247
#       21122: 21247
#       21131: 28624
#       21132: 28624
#       21221: 3822
#       21222: 3822
#       21231: 12257
#       21232: 12257
#       31101: 246
#       31102: 246
#       32202: 2
#       32301: 7
#       32302: 7
#       32401: 12
#       32402: 12
#   Value columns (0):
# overall:
# 	[ Bids event files has 59 event files]
# 	[ EEG event files has 59 event files]
# sub-01_ses-01_run-1:
# 	[ Bids event files: sub-01_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20245 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20245 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-01_ses-02_run-1:
# 	[ Bids event files: sub-01_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20569 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20569 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-01_ses-03_run-1:
# 	[ Bids event files: sub-01_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [21119 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [21119 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-01_ses-04_run-1:
# 	[ Bids event files: sub-01_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19836 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19836 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-01_ses-05_run-1:
# 	[ Bids event files: sub-01_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-01_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20150 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20150 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-02_ses-01_run-1:
# 	[ Bids event files: sub-02_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20397 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20397 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-02_ses-02_run-1:
# 	[ Bids event files: sub-02_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20028 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20028 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-02_ses-03_run-1:
# 	[ Bids event files: sub-02_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19723 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19723 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-02_ses-04_run-1:
# 	[ Bids event files: sub-02_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19705 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19705 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-02_ses-05_run-1:
# 	[ Bids event files: sub-02_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-02_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19513 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19513 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-03_ses-01_run-1:
# 	[ Bids event files: sub-03_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-03_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [9727 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [9834 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# 	[ERROR The Bids event files file has 9727 rows and the EEG event files event file has 9834 rows]
# sub-03_ses-01_run-2:
# 	[ Bids event files: sub-03_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv]
# 	[ EEG event files: sub-03_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv]
# 	[ Bids event files: [9727 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [9727 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-03_ses-02_run-1:
# 	[ Bids event files: sub-03_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-03_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20021 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20021 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-03_ses-03_run-1:
# 	[ Bids event files: sub-03_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-03_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19357 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19357 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-03_ses-04_run-1:
# ...
# 	[ Bids event files: [8271 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [15066 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# 	[ERROR The Bids event files file has 8271 rows and the EEG event files event file has 15066 rows]
# sub-07_ses-04_run-2:
# 	[ Bids event files: sub-07_ses-04_task-RSVPObjectRestBlink_run-2_events.tsv]
# 	[ EEG event files: sub-07_ses-04_task-RSVPObjectRestBlink_run-2_events_temp.tsv]
# 	[ Bids event files: [8271 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [8271 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-07_ses-05_run-1:
# 	[ Bids event files: sub-07_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-07_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [24761 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [24761 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-08_ses-01_run-1:
# 	[ Bids event files: sub-08_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [12969 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [6469 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# 	[ERROR The Bids event files file has 12969 rows and the EEG event files event file has 6469 rows]
# sub-08_ses-01_run-2:
# 	[ Bids event files: sub-08_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv]
# 	[ EEG event files: sub-08_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv]
# 	[ Bids event files: [12969 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [12969 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-08_ses-02_run-1:
# 	[ Bids event files: sub-08_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19557 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19557 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-08_ses-03_run-1:
# 	[ Bids event files: sub-08_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19421 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19421 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-08_ses-04_run-1:
# 	[ Bids event files: sub-08_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20006 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20006 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-08_ses-05_run-1:
# 	[ Bids event files: sub-08_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-08_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19247 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19247 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-09_ses-01_run-1:
# 	[ Bids event files: sub-09_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [6521 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [15037 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# 	[ERROR The Bids event files file has 6521 rows and the EEG event files event file has 15037 rows]
# sub-09_ses-01_run-2:
# 	[ Bids event files: sub-09_ses-01_task-RSVPObjectRestBlink_run-2_events.tsv]
# 	[ EEG event files: sub-09_ses-01_task-RSVPObjectRestBlink_run-2_events_temp.tsv]
# 	[ Bids event files: [6521 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [6521 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-09_ses-02_run-1:
# 	[ Bids event files: sub-09_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [10505 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [10277 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# 	[ERROR The Bids event files file has 10505 rows and the EEG event files event file has 10277 rows]
# sub-09_ses-02_run-2:
# 	[ Bids event files: sub-09_ses-02_task-RSVPObjectRestBlink_run-2_events.tsv]
# 	[ EEG event files: sub-09_ses-02_task-RSVPObjectRestBlink_run-2_events_temp.tsv]
# 	[ Bids event files: [10505 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [10505 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-09_ses-03_run-1:
# 	[ Bids event files: sub-09_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20423 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20423 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-09_ses-04_run-1:
# 	[ Bids event files: sub-09_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19915 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19915 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-09_ses-05_run-1:
# 	[ Bids event files: sub-09_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19015 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19015 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-09_ses-06_run-1:
# 	[ Bids event files: sub-09_ses-06_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-09_ses-06_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [12789 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [7095 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# 	[ERROR The Bids event files file has 12789 rows and the EEG event files event file has 7095 rows]
# sub-09_ses-06_run-2:
# 	[ Bids event files: sub-09_ses-06_task-RSVPObjectRestBlink_run-2_events.tsv]
# 	[ EEG event files: sub-09_ses-06_task-RSVPObjectRestBlink_run-2_events_temp.tsv]
# 	[ Bids event files: [12789 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [12789 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-10_ses-01_run-1:
# 	[ Bids event files: sub-10_ses-01_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-01_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19956 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19956 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-10_ses-02_run-1:
# 	[ Bids event files: sub-10_ses-02_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-02_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19483 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19483 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-10_ses-03_run-1:
# 	[ Bids event files: sub-10_ses-03_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-03_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19741 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19741 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-10_ses-04_run-1:
# 	[ Bids event files: sub-10_ses-04_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-04_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [20149 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [20149 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
# sub-10_ses-05_run-1:
# 	[ Bids event files: sub-10_ses-05_task-RSVPObjectRestBlink_run-1_events.tsv]
# 	[ EEG event files: sub-10_ses-05_task-RSVPObjectRestBlink_run-1_events_temp.tsv]
# 	[ Bids event files: [19738 events] ['onset', 'duration', 'event_code']]
# 	[ EEG event files: [19738 events] ['type', 'latency', 'urevent', 'gid', 'imageid', 'buttonpressduration', 'reactiontime', 'imagecategory', 'cameradistance', 'imagelocation', 'imageclutter', 'luminance', 'tgtorientation', 'tgtocclusion', 'tgtcontrast', 'tgtsize', 'tgtdistfromcenter', 'numberoftargets', 'numberofclasses', 'usertags']]
#
# ERROR Summary:
# overall:
# sub-01_ses-01_run-1:
# sub-01_ses-02_run-1:
# sub-01_ses-03_run-1:
# sub-01_ses-04_run-1:
# sub-01_ses-05_run-1:
# sub-02_ses-01_run-1:
# sub-02_ses-02_run-1:
# sub-02_ses-03_run-1:
# sub-02_ses-04_run-1:
# sub-02_ses-05_run-1:
# sub-03_ses-01_run-1:
# 	[ERROR The Bids event files file has 9727 rows and the EEG event files event file has 9834 rows]
# sub-03_ses-01_run-2:
# sub-03_ses-02_run-1:
# sub-03_ses-03_run-1:
# sub-03_ses-04_run-1:
# sub-03_ses-05_run-1:
# sub-04_ses-01_run-1:
# sub-04_ses-02_run-1:
# sub-04_ses-03_run-1:
# sub-04_ses-04_run-1:
# sub-04_ses-05_run-1:
# 	[ERROR The Bids event files file has 3276 rows and the EEG event files event file has 17207 rows]
# sub-04_ses-05_run-2:
# sub-05_ses-01_run-1:
# sub-05_ses-02_run-1:
# sub-05_ses-03_run-1:
# sub-05_ses-04_run-1:
# sub-05_ses-05_run-1:
# sub-06_ses-01_run-1:
# sub-06_ses-02_run-1:
# sub-06_ses-03_run-1:
# sub-06_ses-04_run-1:
# sub-06_ses-05_run-1:
# sub-07_ses-01_run-1:
# 	[ERROR The Bids event files file has 8074 rows and the EEG event files event file has 12289 rows]
# sub-07_ses-01_run-2:
# sub-07_ses-02_run-1:
# sub-07_ses-03_run-1:
# sub-07_ses-04_run-1:
# 	[ERROR The Bids event files file has 8271 rows and the EEG event files event file has 15066 rows]
# sub-07_ses-04_run-2:
# sub-07_ses-05_run-1:
# sub-08_ses-01_run-1:
# 	[ERROR The Bids event files file has 12969 rows and the EEG event files event file has 6469 rows]
# sub-08_ses-01_run-2:
# sub-08_ses-02_run-1:
# sub-08_ses-03_run-1:
# sub-08_ses-04_run-1:
# sub-08_ses-05_run-1:
# sub-09_ses-01_run-1:
# 	[ERROR The Bids event files file has 6521 rows and the EEG event files event file has 15037 rows]
# sub-09_ses-01_run-2:
# sub-09_ses-02_run-1:
# 	[ERROR The Bids event files file has 10505 rows and the EEG event files event file has 10277 rows]
# sub-09_ses-02_run-2:
# sub-09_ses-03_run-1:
# sub-09_ses-04_run-1:
# sub-09_ses-05_run-1:
# sub-09_ses-06_run-1:
# 	[ERROR The Bids event files file has 12789 rows and the EEG event files event file has 7095 rows]
# sub-09_ses-06_run-2:
# sub-10_ses-01_run-1:
# sub-10_ses-02_run-1:
# sub-10_ses-03_run-1:
# sub-10_ses-04_run-1:
# sub-10_ses-05_run-1:
