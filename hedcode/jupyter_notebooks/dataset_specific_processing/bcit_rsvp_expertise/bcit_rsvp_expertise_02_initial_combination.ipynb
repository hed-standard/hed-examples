# %% [markdown]
# ## Produce a consolidated events file for BCIT Rsvp Expertise
#
# A copy of the EEG.event structure is dumped to the dataset as `events_temp.tsv` files.
# The `bcit_rsvp_expertise_01_initial_summary.ipynb` has already been run.
# Manual review has confirmed that either both versions of the event files have the same
# number of events or that the session had two runs and due to a bug in `ess2bids`,
# the `events.tsv` file for run 1 is actually a copy of the `events.tsv` file from run 2.
#
# This notebook creates a `events_temp1.tsv` for each:
# 1. Read the eeg events.
# 2. Remove unwanted columns and add `onset` and `duration` columns.
# 3. Reorder the columns to the `final_column_order`.
# 4. Replace all empty string and NaN entries with n/a.
# 5. Save as `_events_temp1.tsv`.

# %%
import os
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list, get_new_dataframe, get_value_dict, replace_values

# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/RsvpExpertiseWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
eeg_drop_columns = ['urevent', 'usertags', 'gid']
final_column_order = ['onset', 'duration', 'sample', 'value', 'imageid', 'buttonpressduration', 'reactiontime',
                      'luminance',	'tgtsize',	'tgtdistfromcenter',]
log_file_name = 'bcit_rsvp_expertise_02_initial_combination_log.json'
sampling_rate_file = os.path.realpath(os.path.join(bids_root_path, 'code/samplingRates.tsv'))

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary("EEG event files", files_eeg, entities=entities)
sampling_dict = get_value_dict(sampling_rate_file)

# Set up the logger and perform  the operations to combine the two versions of the event files
logger = HedLogger()
for key, file, rowcount, column_count in eeg_dict.iter_tsv_info():
    filename = eeg_dict.get_file_path(key)
    df_eeg = get_new_dataframe(filename)
    logger.add(key, f"Created a dataframe for {filename}")

    basename = os.path.basename(filename)
    samplingRate = float(sampling_dict[basename[:-16]])
    logger.add(key, f"Looked up sampling rate of {samplingRate}")

    df_eeg.drop(columns=eeg_drop_columns, inplace=True)
    logger.add(key, f"Dropped {str(eeg_drop_columns)} drop_columns")
    df_eeg['onset'] = df_eeg['latency']
    df_eeg['onset'] = df_eeg['onset'].subtract(1.0)
    df_eeg['onset'] = df_eeg['onset'].divide(samplingRate)
    logger.add(key, f"Calculate onset from latency and add an onset column")
    df_eeg['duration'] = 'n/a'
    logger.add(key, f"Add a duration column")
    df_eeg = df_eeg.rename(columns={"latency": "sample", "type": "value"})
    logger.add(key, f"Rename the latency column as sample and type as value")
    df_eeg = df_eeg.reindex(columns=final_column_order)
    logger.add(key, f"Reordered the columns as {str(final_column_order)}")
    num_replaced = replace_values(df_eeg, values=[' ', 'NaN'], replace_value='n/a')
    logger.add(key, f"Replaced {num_replaced} blank or NaN values with n/a")
    filename_out = filename[:-9] + "_temp1.tsv"
    df_eeg.to_csv(filename_out, sep='\t', index=False)
    logger.add(key, f"Saved as {filename_out}")

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# sub-01_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-01\ses-01\eeg\sub-01_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-01\ses-01\eeg\sub-01_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-02_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub
ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-87\ses-01\eeg\sub-87_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-88_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-88\ses-01\eeg\sub-88_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-88\ses-01\eeg\sub-88_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-89_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-89\ses-01\eeg\sub-89_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-89\ses-01\eeg\sub-89_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-90_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-90\ses-01\eeg\sub-90_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-90\ses-01\eeg\sub-90_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-91_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-91\ses-01\eeg\sub-91_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-91\ses-01\eeg\sub-91_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-92_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-92\ses-01\eeg\sub-92_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-92\ses-01\eeg\sub-92_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-93_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-93\ses-01\eeg\sub-93_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-93\ses-01\eeg\sub-93_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-94_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-94\ses-01\eeg\sub-94_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-94\ses-01\eeg\sub-94_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-95_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-95\ses-01\eeg\sub-95_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-95\ses-01\eeg\sub-95_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-96_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-96\ses-01\eeg\sub-96_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-96\ses-01\eeg\sub-96_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-97_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-97\ses-01\eeg\sub-97_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-97\ses-01\eeg\sub-97_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-98_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-98\ses-01\eeg\sub-98_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-98\ses-01\eeg\sub-98_ses-01_task-Drive_run-1_events_temp1.tsv]
# sub-99_ses-01_run-1:
# 	[ Created a dataframe for F:\ARLBidsStart\CalibrationDrivingWorking\sub-99\ses-01\eeg\sub-99_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Dropped ['urevent', 'usertags'] drop_columns]
# 	[ Calculate onset from latency and add an onset column]
# 	[ Add a duration column]
# 	[ Rename the latency column as sample and type as value]
# 	[ Reordered the columns as ['onset', 'duration', 'sample', 'value']]
# 	[ Replaced 0 blank or NaN values with n/a]
# 	[ Saved as F:\ARLBidsStart\CalibrationDrivingWorking\sub-99\ses-01\eeg\sub-99_ses-01_task-Drive_run-1_events_temp1.tsv]
#
# ERROR Summary:
# sub-01_ses-01_run-1:
# sub-02_ses-01_run-1:
# sub-03_ses-01_run-1:
# sub-04_ses-01_run-1:
# sub-05_ses-01_run-1:
# sub-06_ses-01_run-1:
# sub-07_ses-01_run-1:
# sub-08_ses-01_run-1:
# sub-09_ses-01_run-1:
# sub-10_ses-01_run-1:
# sub-100_ses-01_run-1:
# sub-100_ses-02_run-1:
# sub-100_ses-03_run-1:
# sub-100_ses-04_run-1:
# sub-100_ses-05_run-1:
# sub-100_ses-06_run-1:
# sub-100_ses-07_run-1:
# sub-101_ses-01_run-1:
# sub-102_ses-01_run-1:
# sub-103_ses-01_run-1:
# sub-104_ses-01_run-1:
# sub-105_ses-01_run-1:
# sub-106_ses-01_run-1:
# sub-106_ses-02_run-1:
# sub-107_ses-01_run-1:
# sub-108_ses-01_run-1:
# sub-109_ses-01_run-1:
# sub-11_ses-01_run-1:
# sub-110_ses-01_run-1:
# sub-111_ses-01_run-1:
# sub-112_ses-01_run-1:
# sub-112_ses-02_run-1:
# sub-112_ses-03_run-1:
# sub-112_ses-04_run-1:
# sub-112_ses-05_run-1:
# sub-112_ses-06_run-1:
# sub-112_ses-07_run-1:
# sub-113_ses-01_run-1:
# sub-114_ses-01_run-1:
# sub-115_ses-01_run-1:
# sub-116_ses-01_run-1:
# sub-117_ses-01_run-1:
# sub-117_ses-02_run-1:
# sub-117_ses-03_run-1:
# sub-117_ses-04_run-1:
# sub-117_ses-05_run-1:
# sub-117_ses-06_run-1:
# sub-118_ses-01_run-1:
# sub-119_ses-01_run-1:
# sub-12_ses-01_run-1:
# sub-120_ses-01_run-1:
# sub-120_ses-02_run-1:
# sub-120_ses-03_run-1:
# sub-120_ses-04_run-1:
# sub-120_ses-05_run-1:
# sub-120_ses-06_run-1:
# sub-120_ses-07_run-1:
# sub-121_ses-01_run-1:
# sub-121_ses-02_run-1:
# sub-121_ses-03_run-1:
# sub-121_ses-04_run-1:
# sub-121_ses-05_run-1:
# sub-121_ses-06_run-1:
# sub-121_ses-07_run-1:
# sub-122_ses-01_run-1:
# sub-122_ses-02_run-1:
# sub-122_ses-03_run-1:
# sub-122_ses-04_run-1:
# sub-122_ses-05_run-1:
# sub-122_ses-06_run-1:
# sub-122_ses-07_run-1:
# sub-123_ses-01_run-1:
# sub-123_ses-02_run-1:
# sub-123_ses-03_run-1:
# sub-123_ses-04_run-1:
# sub-123_ses-05_run-1:
# sub-123_ses-06_run-1:
# sub-124_ses-01_run-1:
# sub-124_ses-02_run-1:
# sub-124_ses-03_run-1:
# sub-124_ses-04_run-1:
# sub-124_ses-05_run-1:
# sub-124_ses-06_run-1:
# sub-124_ses-07_run-1:
# sub-125_ses-01_run-1:
# sub-125_ses-02_run-1:
# sub-125_ses-03_run-1:
# sub-125_ses-04_run-1:
# sub-125_ses-05_run-1:
# sub-125_ses-06_run-1:
# sub-125_ses-07_run-1:
# sub-126_ses-01_run-1:
# sub-126_ses-02_run-1:
# sub-126_ses-03_run-1:
# sub-126_ses-04_run-1:
# sub-126_ses-05_run-1:
# sub-126_ses-06_run-1:
# sub-127_ses-01_run-1:
# sub-128_ses-01_run-1:
# sub-128_ses-02_run-1:
# sub-129_ses-01_run-1:
# sub-13_ses-01_run-1:
# sub-130_ses-01_run-1:
# sub-130_ses-02_run-1:
# sub-131_ses-01_run-1:
# sub-131_ses-02_run-1:
# sub-132_ses-01_run-1:
# sub-133_ses-01_run-1:
# sub-133_ses-02_run-1:
# sub-134_ses-01_run-1:
# sub-135_ses-01_run-1:
# sub-136_ses-01_run-1:
# sub-137_ses-01_run-1:
# sub-138_ses-01_run-1:
# sub-139_ses-01_run-1:
# sub-14_ses-01_run-1:
# sub-140_ses-01_run-1:
# sub-140_ses-02_run-1:
# sub-140_ses-03_run-1:
# sub-141_ses-01_run-1:
# sub-142_ses-01_run-1:
# sub-143_ses-01_run-1:
# sub-143_ses-02_run-1:
# sub-144_ses-01_run-1:
# sub-145_ses-01_run-1:
# sub-146_ses-01_run-1:
# sub-146_ses-02_run-1:
# sub-147_ses-01_run-1:
# sub-148_ses-01_run-1:
# sub-149_ses-01_run-1:
# sub-149_ses-02_run-1:
# sub-15_ses-01_run-1:
# sub-150_ses-01_run-1:
# sub-150_ses-02_run-1:
# sub-151_ses-01_run-1:
# sub-152_ses-01_run-1:
# sub-153_ses-01_run-1:
# sub-154_ses-01_run-1:
# sub-155_ses-01_run-1:
# sub-155_ses-02_run-1:
# sub-156_ses-01_run-1:
# sub-16_ses-01_run-1:
# sub-17_ses-01_run-1:
# sub-18_ses-01_run-1:
# sub-19_ses-01_run-1:
# sub-20_ses-01_run-1:
# sub-21_ses-01_run-1:
# sub-22_ses-01_run-1:
# sub-23_ses-01_run-1:
# sub-24_ses-01_run-1:
# sub-25_ses-01_run-1:
# sub-26_ses-01_run-1:
# sub-27_ses-01_run-1:
# sub-28_ses-01_run-1:
# sub-29_ses-01_run-1:
# sub-30_ses-01_run-1:
# sub-31_ses-01_run-1:
# sub-31_ses-02_run-1:
# sub-32_ses-01_run-1:
# sub-33_ses-01_run-1:
# sub-33_ses-02_run-1:
# sub-33_ses-03_run-1:
# sub-34_ses-01_run-1:
# sub-35_ses-01_run-1:
# sub-36_ses-01_run-1:
# sub-37_ses-01_run-1:
# sub-38_ses-01_run-1:
# sub-39_ses-01_run-1:
# sub-40_ses-01_run-1:
# sub-41_ses-01_run-1:
# sub-42_ses-01_run-1:
# sub-43_ses-01_run-1:
# sub-44_ses-01_run-1:
# sub-44_ses-02_run-1:
# sub-45_ses-01_run-1:
# sub-46_ses-01_run-1:
# sub-47_ses-01_run-1:
# sub-47_ses-02_run-1:
# sub-48_ses-01_run-1:
# sub-49_ses-01_run-1:
# sub-50_ses-01_run-1:
# sub-51_ses-01_run-1:
# sub-52_ses-01_run-1:
# sub-53_ses-01_run-1:
# sub-54_ses-01_run-1:
# sub-55_ses-01_run-1:
# sub-56_ses-01_run-1:
# sub-57_ses-01_run-1:
# sub-58_ses-01_run-1:
# sub-58_ses-02_run-1:
# sub-58_ses-03_run-1:
# sub-59_ses-01_run-1:
# sub-59_ses-02_run-1:
# sub-59_ses-03_run-1:
# sub-60_ses-01_run-1:
# sub-61_ses-01_run-1:
# sub-61_ses-02_run-1:
# sub-62_ses-01_run-1:
# sub-63_ses-01_run-1:
# sub-63_ses-02_run-1:
# sub-63_ses-03_run-1:
# sub-64_ses-01_run-1:
# sub-65_ses-01_run-1:
# sub-66_ses-01_run-1:
# sub-66_ses-02_run-1:
# sub-66_ses-03_run-1:
# sub-67_ses-01_run-1:
# sub-68_ses-01_run-1:
# sub-69_ses-01_run-1:
# sub-70_ses-01_run-1:
# sub-70_ses-02_run-1:
# sub-70_ses-03_run-1:
# sub-71_ses-01_run-1:
# sub-71_ses-02_run-1:
# sub-71_ses-03_run-1:
# sub-72_ses-01_run-1:
# sub-73_ses-01_run-1:
# sub-74_ses-01_run-1:
# sub-75_ses-01_run-1:
# sub-76_ses-01_run-1:
# sub-76_ses-02_run-1:
# sub-76_ses-03_run-1:
# sub-77_ses-01_run-1:
# sub-78_ses-01_run-1:
# sub-78_ses-02_run-1:
# sub-78_ses-03_run-1:
# sub-79_ses-01_run-1:
# sub-80_ses-01_run-1:
# sub-81_ses-01_run-1:
# sub-82_ses-01_run-1:
# sub-83_ses-01_run-1:
# sub-84_ses-01_run-1:
# sub-85_ses-01_run-1:
# sub-86_ses-01_run-1:
# sub-87_ses-01_run-1:
# sub-88_ses-01_run-1:
# sub-89_ses-01_run-1:
# sub-90_ses-01_run-1:
# sub-91_ses-01_run-1:
# sub-92_ses-01_run-1:
# sub-93_ses-01_run-1:
# sub-94_ses-01_run-1:
# sub-95_ses-01_run-1:
# sub-96_ses-01_run-1:
# sub-97_ses-01_run-1:
# sub-98_ses-01_run-1:
# sub-99_ses-01_run-1:
