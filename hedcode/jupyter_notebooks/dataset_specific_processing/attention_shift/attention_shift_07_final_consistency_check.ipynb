# %% [markdown]
# ## Checks that the event codes are consistent with conditions
#
# This script cross-checks for consistency in `_events_temp3.tsv` after
# all corrections have been made notebook.
#
# ### Checking for forbidden codes
#        Codes 1 and 2 can appear anywhere
#        Codes 3 through 6 should appear only in the focus condition.
#        Codes 7 through 14 should appear only in the shift condition.
#        Codes 199, 201, 202, and 255 are not related to condition.

# %%
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list, get_new_dataframe

# Set up the directories and make a dictionary for _events_temp3.tsv
bids_root_path = 'G:\AttentionShift\AttentionShiftWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'run')
skip_cols = ['onset', 'duration', 'sample']

bids_files = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp3",
                           exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary(bids_files, entities=entities)

# %%
status = HedLogger()
print("Isolating the bad codes:")
for key, file, rowcount, columns in bids_dict.iter_tsv_info():
    df_bids = get_new_dataframe(file.file_path)

    focus_cond_mask = df_bids['cond_code'].map(str).isin(['1', '2'])
    shift_cond_mask = df_bids['cond_code'].map(str).isin(['3'])
    focus_event_mask = df_bids['event_code'].map(str).isin(['3', '4', '5', '6'])
    shift_event_mask = df_bids['event_code'].map(str).isin(['7', '8', '9', '10', '11', '12', '13', '14'])
    bad_focus = sum(focus_cond_mask & shift_event_mask)
    if bad_focus:
        indices = df_bids.index[focus_cond_mask & shift_event_mask]
        status.add(key, f"{key} has {bad_focus} shift event codes in a focus condition")
        status.add(key, f"{str(list(indices))}")
    bad_shift = sum(shift_cond_mask & focus_event_mask)
    if bad_shift:
        indices = df_bids.index[shift_cond_mask & focus_event_mask]
        status.add(key, f"{key} has {bad_shift} focus event codes in a shift condition")
        status.add(key, f"{str(list(indices))}")
    bad_cond_mask = df_bids['cond_code'].map(str).isin(['0'])
    if sum(bad_cond_mask):
        status.add(key, f"{key} has {sum(bad_cond_mask)} cond_code values of 0")
        status.add(key, f"{str(list(df_bids.index[bad_cond_mask]))}")
    unknown_mask = df_bids['event_code'].map(str).isin(['255'])
    if sum(unknown_mask):
        status.add(key, f"{key} has {sum(unknown_mask)} event_code values of 255")
        status.add(key, f"{str(list(df_bids.index[unknown_mask]))}")
    auditory_shift_mask = df_bids['event_code'].map(str).isin(['7', '10', '11',  '14'])
    visual_shift_mask = df_bids['event_code'].map(str).isin(['8', '9', '12', '13'])
    visual_mask = df_bids['focus_modality'].map(str).isin(['visual', 'n/a'])
    auditory_mask = df_bids['focus_modality'].map(str).isin(['auditory', 'n/a'])
    bad_visual = shift_cond_mask & auditory_mask & visual_shift_mask
    if sum(bad_visual):
        status.add(key, f"{key} has {sum(bad_visual)} visual event_code values in auditory focus modality")
        status.add(key, f"{str(list(df_bids.index[bad_visual]))}")
    bad_auditory = shift_cond_mask & visual_mask & auditory_shift_mask
    if sum(bad_auditory):
        status.add(key, f"{key} has {sum(bad_auditory)} auditory event_code values in visual focus modality")
        status.add(key, f"{str(list(df_bids.index[bad_auditory]))}")
# Out:
# Isolating the bad codes:

# %%
status.print_log()
status.save_log(bids_root_path, sub_path='code', log_name='as_hed_06_final_consistency_check_log.json')
# Out:
# sub-001_run-01
# 	sub-001_run-01 has 13 visual event_code values in auditory focus modality
# 	[820, 2456, 2457, 2458, 2459, 2460, 2461, 2462, 2463, 2464, 2465, 2466, 2467]
# 	sub-001_run-01 has 4 auditory event_code values in visual focus modality
# 	[883, 884, 1192, 1193]
# sub-002_run-01
# 	sub-002_run-01 has 1 visual event_code values in auditory focus modality
# 	[815]
# 	sub-002_run-01 has 4 auditory event_code values in visual focus modality
# 	[880, 881, 1193, 1194]
# sub-003_run-01
# 	sub-003_run-01 has 1 visual event_code values in auditory focus modality
# 	[814]
# 	sub-003_run-01 has 4 auditory event_code values in visual focus modality
# 	[877, 878, 1187, 1188]
# sub-004_run-02
# 	sub-004_run-02 has 1 visual event_code values in auditory focus modality
# 	[523]
# 	sub-004_run-02 has 4 auditory event_code values in visual focus modality
# 	[587, 588, 900, 901]
# sub-005_run-01
# 	sub-005_run-01 has 6 event_code values of 255
# 	[266, 267, 268, 269, 270, 271]
# 	sub-005_run-01 has 1 visual event_code values in auditory focus modality
# 	[770]
# 	sub-005_run-01 has 4 auditory event_code values in visual focus modality
# 	[827, 828, 1106, 1107]
# sub-006_run-01
# 	sub-006_run-01 has 1 visual event_code values in auditory focus modality
# 	[820]
# 	sub-006_run-01 has 4 auditory event_code values in visual focus modality
# 	[883, 884, 1192, 1193]
# sub-007_run-01
# 	sub-007_run-01 has 1 visual event_code values in auditory focus modality
# 	[809]
# 	sub-007_run-01 has 10 auditory event_code values in visual focus modality
# 	[629, 630, 631, 632, 633, 634, 872, 873, 1182, 1183]
# sub-008_run-01
# 	sub-008_run-01 has 1 visual event_code values in auditory focus modality
# 	[896]
# 	sub-008_run-01 has 4 auditory event_code values in visual focus modality
# 	[960, 961, 1269, 1270]
# sub-009_run-01
# 	sub-009_run-01 has 1 visual event_code values in auditory focus modality
# 	[813]
# 	sub-009_run-01 has 4 auditory event_code values in visual focus modality
# 	[876, 877, 1183, 1184]
# sub-010_run-01
# 	sub-010_run-01 has 1 visual event_code values in auditory focus modality
# 	[818]
# 	sub-010_run-01 has 4 auditory event_code values in visual focus modality
# 	[881, 882, 1194, 1195]
# sub-011_run-01
# 	sub-011_run-01 has 1 visual event_code values in auditory focus modality
# 	[859]
# 	sub-011_run-01 has 4 auditory event_code values in visual focus modality
# 	[921, 922, 1233, 1234]
# sub-012_run-01
# 	sub-012_run-01 has 1 visual event_code values in auditory focus modality
# 	[812]
# 	sub-012_run-01 has 4 auditory event_code values in visual focus modality
# 	[875, 876, 1186, 1187]
# sub-013_run-01
# 	sub-013_run-01 has 1 visual event_code values in auditory focus modality
# 	[815]
# 	sub-013_run-01 has 4 auditory event_code values in visual focus modality
# 	[879, 880, 1190, 1191]
# sub-014_run-01
# 	sub-014_run-01 has 1 visual event_code values in auditory focus modality
# 	[809]
# 	sub-014_run-01 has 4 auditory event_code values in visual focus modality
# 	[872, 873, 1179, 1180]
# sub-015_run-01
# 	sub-015_run-01 has 1 visual event_code values in auditory focus modality
# 	[813]
# 	sub-015_run-01 has 4 auditory event_code values in visual focus modality
# 	[877, 878, 1190, 1191]
# sub-016_run-01
# 	sub-016_run-01 has 1 visual event_code values in auditory focus modality
# 	[812]
# 	sub-016_run-01 has 4 auditory event_code values in visual focus modality
# 	[876, 877, 1188, 1189]
# sub-017_run-01
# 	sub-017_run-01 has 1 visual event_code values in auditory focus modality
# 	[818]
# 	sub-017_run-01 has 4 auditory event_code values in visual focus modality
# 	[882, 883, 1191, 1192]
# sub-018_run-01
# 	sub-018_run-01 has 1 visual event_code values in auditory focus modality
# 	[814]
# 	sub-018_run-01 has 4 auditory event_code values in visual focus modality
# 	[878, 879, 1189, 1190]
# sub-019_run-01
# 	sub-019_run-01 has 1 visual event_code values in auditory focus modality
# 	[236]
# 	sub-019_run-01 has 4 auditory event_code values in visual focus modality
# 	[300, 301, 610, 611]
# sub-020_run-02
# 	sub-020_run-02 has 1 visual event_code values in auditory focus modality
# 	[821]
# 	sub-020_run-02 has 4 auditory event_code values in visual focus modality
# 	[886, 887, 1197, 1198]
# sub-021_run-02
# 	sub-021_run-02 has 1 visual event_code values in auditory focus modality
# 	[815]
# 	sub-021_run-02 has 12 auditory event_code values in visual focus modality
# 	[577, 578, 579, 580, 581, 582, 583, 585, 878, 879, 1187, 1188]
# sub-022_run-02
# 	sub-022_run-02 has 1 visual event_code values in auditory focus modality
# 	[886]
# 	sub-022_run-02 has 25 auditory event_code values in visual focus modality
# 	[946, 947, 948, 949, 950, 951, 952, 953, 954, 1201, 1202, 1489, 1491, 1493, 1494, 1495, 1496, 1497, 1499, 1500, 1501, 1503, 1504, 1505, 1506]
# sub-023_run-01
# 	sub-023_run-01 has 1 visual event_code values in auditory focus modality
# 	[810]
# 	sub-023_run-01 has 4 auditory event_code values in visual focus modality
# 	[874, 875, 1183, 1184]
# sub-024_run-01
# 	sub-024_run-01 has 1 visual event_code values in auditory focus modality
# 	[532]
# 	sub-024_run-01 has 4 auditory event_code values in visual focus modality
# 	[597, 598, 911, 912]
# sub-025_run-01
# 	sub-025_run-01 has 1 visual event_code values in auditory focus modality
# 	[824]
# 	sub-025_run-01 has 4 auditory event_code values in visual focus modality
# 	[890, 891, 1206, 1207]
# sub-026_run-01
# 	sub-026_run-01 has 1 visual event_code values in auditory focus modality
# 	[813]
# 	sub-026_run-01 has 19 auditory event_code values in visual focus modality
# 	[758, 759, 760, 761, 762, 763, 764, 766, 767, 768, 769, 770, 772, 773, 774, 878, 879, 1188, 1189]
# sub-027_run-01
# 	sub-027_run-01 has 13 visual event_code values in auditory focus modality
# 	[806, 2437, 2438, 2439, 2440, 2441, 2442, 2443, 2444, 2445, 2446, 2447, 2448]
# 	sub-027_run-01 has 4 auditory event_code values in visual focus modality
# 	[871, 872, 1180, 1181]
# sub-028_run-01
# 	sub-028_run-01 has 1 visual event_code values in auditory focus modality
# 	[822]
# 	sub-028_run-01 has 4 auditory event_code values in visual focus modality
# 	[886, 887, 1200, 1201]
# sub-029_run-01
# 	sub-029_run-01 has 1 visual event_code values in auditory focus modality
# 	[813]
# 	sub-029_run-01 has 4 auditory event_code values in visual focus modality
# 	[877, 878, 1190, 1191]
# sub-030_run-01
# 	sub-030_run-01 has 1 visual event_code values in auditory focus modality
# 	[844]
# 	sub-030_run-01 has 4 auditory event_code values in visual focus modality
# 	[909, 910, 1227, 1228]
# sub-031_run-01
# 	sub-031_run-01 has 1 visual event_code values in auditory focus modality
# 	[904]
# 	sub-031_run-01 has 4 auditory event_code values in visual focus modality
# 	[974, 975, 1307, 1308]
# sub-032_run-01
# 	sub-032_run-01 has 1 visual event_code values in auditory focus modality
# 	[816]
# 	sub-032_run-01 has 4 auditory event_code values in visual focus modality
# 	[879, 880, 1190, 1191]
# sub-033_run-01
# 	sub-033_run-01 has 1 visual event_code values in auditory focus modality
# 	[835]
# 	sub-033_run-01 has 4 auditory event_code values in visual focus modality
# 	[901, 902, 1230, 1231]
# sub-034_run-01
# 	sub-034_run-01 has 1 visual event_code values in auditory focus modality
# 	[814]
# 	sub-034_run-01 has 4 auditory event_code values in visual focus modality
# 	[878, 879, 1189, 1190]
# sub-035_run-01
# 	sub-035_run-01 has 1 visual event_code values in auditory focus modality
# 	[264]
# 	sub-035_run-01 has 4 auditory event_code values in visual focus modality
# 	[333, 334, 677, 678]
# sub-036_run-02
# 	sub-036_run-02 has 1 visual event_code values in auditory focus modality
# 	[535]
# 	sub-036_run-02 has 4 auditory event_code values in visual focus modality
# 	[600, 601, 916, 917]
# sub-037_run-01
# 	sub-037_run-01 has 1 visual event_code values in auditory focus modality
# 	[847]
# 	sub-037_run-01 has 4 auditory event_code values in visual focus modality
# 	[911, 912, 1219, 1220]
# sub-038_run-01
# 	sub-038_run-01 has 1 visual event_code values in auditory focus modality
# 	[812]
# 	sub-038_run-01 has 4 auditory event_code values in visual focus modality
# 	[873, 874, 1182, 1183]
# sub-039_run-01
# 	sub-039_run-01 has 1 visual event_code values in auditory focus modality
# 	[806]
# 	sub-039_run-01 has 4 auditory event_code values in visual focus modality
# 	[870, 871, 1176, 1177]
# sub-040_run-01
# 	sub-040_run-01 has 1 visual event_code values in auditory focus modality
# 	[819]
# 	sub-040_run-01 has 4 auditory event_code values in visual focus modality
# 	[883, 884, 1195, 1196]
# sub-041_run-01
# 	sub-041_run-01 has 1 visual event_code values in auditory focus modality
# 	[829]
# 	sub-041_run-01 has 4 auditory event_code values in visual focus modality
# 	[895, 896, 1205, 1206]
# sub-042_run-01
# 	sub-042_run-01 has 11 visual event_code values in auditory focus modality
# 	[720, 721, 723, 724, 725, 726, 727, 728, 729, 730, 838]
# 	sub-042_run-01 has 4 auditory event_code values in visual focus modality
# 	[904, 905, 1222, 1223]
# sub-043_run-01
# 	sub-043_run-01 has 1 visual event_code values in auditory focus modality
# 	[825]
# 	sub-043_run-01 has 4 auditory event_code values in visual focus modality
# 	[889, 890, 1210, 1211]
# sub-044_run-01
# 	sub-044_run-01 has 1 visual event_code values in auditory focus modality
# 	[827]
# 	sub-044_run-01 has 4 auditory event_code values in visual focus modality
# 	[891, 892, 1204, 1205]
# sub-045_run-01
# 	sub-045_run-01 has 1 visual event_code values in auditory focus modality
# 	[825]
# 	sub-045_run-01 has 4 auditory event_code values in visual focus modality
# 	[889, 890, 1207, 1208]
# sub-046_run-01
# 	sub-046_run-01 has 1 visual event_code values in auditory focus modality
# 	[849]
# 	sub-046_run-01 has 4 auditory event_code values in visual focus modality
# 	[913, 914, 1226, 1227]
# sub-047_run-01
# 	sub-047_run-01 has 1 visual event_code values in auditory focus modality
# 	[832]
# 	sub-047_run-01 has 4 auditory event_code values in visual focus modality
# 	[896, 897, 1218, 1219]
# sub-048_run-01
# 	sub-048_run-01 has 1 visual event_code values in auditory focus modality
# 	[1098]
# 	sub-048_run-01 has 6 auditory event_code values in visual focus modality
# 	[1161, 1162, 1184, 1185, 1493, 1494]
# sub-049_run-01
# 	sub-049_run-01 has 10 visual event_code values in auditory focus modality
# 	[625, 626, 627, 628, 629, 630, 632, 633, 634, 849]
# 	sub-049_run-01 has 4 auditory event_code values in visual focus modality
# 	[912, 913, 1222, 1223]
