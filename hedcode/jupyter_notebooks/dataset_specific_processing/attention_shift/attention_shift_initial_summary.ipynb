# %% [markdown]
# ## Preliminary column summary of events
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.

# %%
import os
from hed.util import get_file_list, make_file_dict

bids_root_path = 'G:\AttentionShift\AttentionShiftWorking'
name_indices = (0, 2)
bids_skip = ['onset',  'sample', 'HED']
eeg_skip = ['latency', 'sample_offset', 'urevent', 'usertags']
exclude_dir = os.path.join(bids_root_path, 'sourcedata')
print(f"Summarizing {bids_root_path}...")
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=[exclude_dir])
bids_dict = make_file_dict(files_bids, name_indices=name_indices)
print(f"\n{len(list(bids_dict))} BIDS style event files")
for key, value in bids_dict.items():
    print(f"{key}: {os.path.basename(value)}")

# Construct the dictionary for EEG.event files
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp")
eeg_dict = make_file_dict(files_eeg, name_indices=name_indices)
print(f"\n{len(list(eeg_dict))} EEG.event style event files")
for key, value in eeg_dict.items():
    print(f"{key}: {os.path.basename(value)}")
# Out:
# Summarizing G:\AttentionShift\AttentionShiftWorking...
#
# 52 BIDS style event files
# sub-020_run-01: sub-020_task-AuditoryVisualShift_run-01_events.tsv
# sub-021_run-01: sub-021_task-AuditoryVisualShift_run-01_events.tsv
# sub-022_run-01: sub-022_task-AuditoryVisualShift_run-01_events.tsv
# sub-001_run-01: sub-001_task-AuditoryVisualShift_run-01_events.tsv
# sub-002_run-01: sub-002_task-AuditoryVisualShift_run-01_events.tsv
# sub-003_run-01: sub-003_task-AuditoryVisualShift_run-01_events.tsv
# sub-004_run-01: sub-004_task-AuditoryVisualShift_run-01_events.tsv
# sub-005_run-01: sub-005_task-AuditoryVisualShift_run-01_events.tsv
# sub-006_run-01: sub-006_task-AuditoryVisualShift_run-01_events.tsv
# sub-007_run-01: sub-007_task-AuditoryVisualShift_run-01_events.tsv
# sub-008_run-01: sub-008_task-AuditoryVisualShift_run-01_events.tsv
# sub-009_run-01: sub-009_task-AuditoryVisualShift_run-01_events.tsv
# sub-010_run-01: sub-010_task-AuditoryVisualShift_run-01_events.tsv
# sub-011_run-01: sub-011_task-AuditoryVisualShift_run-01_events.tsv
# sub-012_run-01: sub-012_task-AuditoryVisualShift_run-01_events.tsv
# sub-013_run-01: sub-013_task-AuditoryVisualShift_run-01_events.tsv
# sub-014_run-01: sub-014_task-AuditoryVisualShift_run-01_events.tsv
# sub-015_run-01: sub-015_task-AuditoryVisualShift_run-01_events.tsv
# sub-016_run-01: sub-016_task-AuditoryVisualShift_run-01_events.tsv
# sub-017_run-01: sub-017_task-AuditoryVisualShift_run-01_events.tsv
# sub-018_run-01: sub-018_task-AuditoryVisualShift_run-01_events.tsv
# sub-019_run-01: sub-019_task-AuditoryVisualShift_run-01_events.tsv
# sub-020_run-02: sub-020_task-AuditoryVisualShift_run-02_events.tsv
# sub-021_run-02: sub-021_task-AuditoryVisualShift_run-02_events.tsv
# sub-022_run-02: sub-022_task-AuditoryVisualShift_run-02_events.tsv
# sub-023_run-01: sub-023_task-AuditoryVisualShift_run-01_events.tsv
# sub-024_run-01: sub-024_task-AuditoryVisualShift_run-01_events.tsv
# sub-025_run-01: sub-025_task-AuditoryVisualShift_run-01_events.tsv
# sub-026_run-01: sub-026_task-AuditoryVisualShift_run-01_events.tsv
# sub-027_run-01: sub-027_task-AuditoryVisualShift_run-01_events.tsv
# sub-028_run-01: sub-028_task-AuditoryVisualShift_run-01_events.tsv
# sub-029_run-01: sub-029_task-AuditoryVisualShift_run-01_events.tsv
# sub-030_run-01: sub-030_task-AuditoryVisualShift_run-01_events.tsv
# sub-031_run-01: sub-031_task-AuditoryVisualShift_run-01_events.tsv
# sub-032_run-01: sub-032_task-AuditoryVisualShift_run-01_events.tsv
# sub-033_run-01: sub-033_task-AuditoryVisualShift_run-01_events.tsv
# sub-034_run-01: sub-034_task-AuditoryVisualShift_run-01_events.tsv
# sub-035_run-01: sub-035_task-AuditoryVisualShift_run-01_events.tsv
# sub-036_run-01: sub-036_task-AuditoryVisualShift_run-01_events.tsv
# sub-037_run-01: sub-037_task-AuditoryVisualShift_run-01_events.tsv
# sub-038_run-01: sub-038_task-AuditoryVisualShift_run-01_events.tsv
# sub-039_run-01: sub-039_task-AuditoryVisualShift_run-01_events.tsv
# sub-040_run-01: sub-040_task-AuditoryVisualShift_run-01_events.tsv
# sub-041_run-01: sub-041_task-AuditoryVisualShift_run-01_events.tsv
# sub-042_run-01: sub-042_task-AuditoryVisualShift_run-01_events.tsv
# sub-043_run-01: sub-043_task-AuditoryVisualShift_run-01_events.tsv
# sub-044_run-01: sub-044_task-AuditoryVisualShift_run-01_events.tsv
# sub-045_run-01: sub-045_task-AuditoryVisualShift_run-01_events.tsv
# sub-046_run-01: sub-046_task-AuditoryVisualShift_run-01_events.tsv
# sub-047_run-01: sub-047_task-AuditoryVisualShift_run-01_events.tsv
# sub-048_run-01: sub-048_task-AuditoryVisualShift_run-01_events.tsv
# sub-049_run-01: sub-049_task-AuditoryVisualShift_run-01_events.tsv
#
# 49 EEG.event style event files
# sub-001_run-01: sub-001_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-002_run-01: sub-002_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-003_run-01: sub-003_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-004_run-01: sub-004_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-005_run-01: sub-005_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-006_run-01: sub-006_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-007_run-01: sub-007_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-008_run-01: sub-008_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-009_run-01: sub-009_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-010_run-01: sub-010_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-011_run-01: sub-011_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-012_run-01: sub-012_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-013_run-01: sub-013_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-014_run-01: sub-014_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-015_run-01: sub-015_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-016_run-01: sub-016_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-017_run-01: sub-017_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-018_run-01: sub-018_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-019_run-01: sub-019_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-020_run-02: sub-020_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-021_run-02: sub-021_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-022_run-02: sub-022_task-AuditoryVisualShift_run-02_events_temp.tsv
# sub-023_run-01: sub-023_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-024_run-01: sub-024_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-025_run-01: sub-025_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-026_run-01: sub-026_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-027_run-01: sub-027_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-028_run-01: sub-028_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-029_run-01: sub-029_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-030_run-01: sub-030_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-031_run-01: sub-031_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-032_run-01: sub-032_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-033_run-01: sub-033_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-034_run-01: sub-034_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-035_run-01: sub-035_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-036_run-01: sub-036_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-037_run-01: sub-037_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-038_run-01: sub-038_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-039_run-01: sub-039_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-040_run-01: sub-040_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-041_run-01: sub-041_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-042_run-01: sub-042_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-043_run-01: sub-043_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-044_run-01: sub-044_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-045_run-01: sub-045_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-046_run-01: sub-046_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-047_run-01: sub-047_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-048_run-01: sub-048_task-AuditoryVisualShift_run-01_events_temp.tsv
# sub-049_run-01: sub-049_task-AuditoryVisualShift_run-01_events_temp.tsv

# %%
print("Verifying that both dictionaries have the same keys")
keys_bids = set(bids_dict.keys())
keys_eeg = set(eeg_dict.keys())
list_bids = list(keys_bids.difference(keys_eeg))
list_eeg = list(keys_eeg.difference(keys_bids))
print(f"Bids extra keys {str(list_bids)}")
print(f"EEG extra keys {str(list_eeg)}")
# Out:
# Verifying that both dictionaries have the same keys
# Bids extra keys ['sub-022_run-01', 'sub-020_run-01', 'sub-021_run-01']
# EEG extra keys []

# %%
from hed.util import get_new_dataframe

print(f"\nBIDS style event file columns:")
bids_count_dict = {}
for key, file in bids_dict.items():
    df = get_new_dataframe(file)
    bids_count_dict[key] = len(df.index)
    print(f"{key} [{len(df.index)} events]: {str(list(df.columns.values))}")

print(f"\nEEG.event style event file columns:")
eeg_count_dict = {}
for key, file in eeg_dict.items():
    df = get_new_dataframe(file)
    eeg_count_dict[key] = len(df.index)
    print(f"{key} [{len(df.index)} events]: {str(list(df.columns.values))}")
# Out:
# BIDS style event file columns:
# sub-020_run-01 [109 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-021_run-01 [130 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-022_run-01 [67 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-001_run-01 [5856 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-002_run-01 [5874 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-003_run-01 [5867 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-004_run-01 [5862 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-005_run-01 [5769 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-006_run-01 [5860 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-007_run-01 [5825 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-008_run-01 [5920 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-009_run-01 [5848 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-010_run-01 [5856 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-011_run-01 [5892 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-012_run-01 [5859 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-013_run-01 [5857 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-014_run-01 [5832 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-015_run-01 [5812 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-016_run-01 [5832 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-017_run-01 [5858 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-018_run-01 [5865 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-019_run-01 [5277 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-020_run-02 [5868 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-021_run-02 [5848 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-022_run-02 [5922 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-023_run-01 [5848 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-024_run-01 [5639 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-025_run-01 [5897 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-026_run-01 [5852 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-027_run-01 [5830 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-028_run-01 [5862 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED', 'Unnamed: 8', 'Unnamed: 9']
# sub-029_run-01 [5857 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-030_run-01 [5948 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-031_run-01 [6067 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-032_run-01 [5872 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-033_run-01 [6095 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-034_run-01 [5849 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-035_run-01 [5290 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-036_run-01 [5910 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED', 'Unnamed: 8', 'Unnamed: 9']
# sub-037_run-01 [5858 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-038_run-01 [5827 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-039_run-01 [5866 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-040_run-01 [5860 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-041_run-01 [5897 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-042_run-01 [5969 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-043_run-01 [5965 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-044_run-01 [6006 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-045_run-01 [5876 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-046_run-01 [5898 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-047_run-01 [5979 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-048_run-01 [6177 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
# sub-049_run-01 [5890 events]: ['onset', 'duration', 'sample', 'trial_type', 'response_time', 'stim_file', 'value', 'HED']
#
# EEG.event style event file columns:
# sub-001_run-01 [5856 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-002_run-01 [5874 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-003_run-01 [5867 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-004_run-01 [5862 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags', 'duration']
# sub-005_run-01 [5769 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-006_run-01 [5860 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-007_run-01 [5825 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-008_run-01 [5920 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-009_run-01 [5848 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-010_run-01 [5856 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-011_run-01 [5892 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-012_run-01 [5859 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-013_run-01 [5857 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-014_run-01 [5832 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-015_run-01 [5812 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-016_run-01 [5832 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-017_run-01 [5858 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-018_run-01 [5865 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-019_run-01 [5277 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-020_run-02 [5868 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-021_run-02 [5848 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-022_run-02 [5922 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-023_run-01 [5848 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-024_run-01 [5639 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-025_run-01 [5897 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-026_run-01 [5852 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-027_run-01 [5830 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-028_run-01 [5861 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags', 'duration']
# sub-029_run-01 [5857 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-030_run-01 [5948 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-031_run-01 [6067 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-032_run-01 [5872 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-033_run-01 [6095 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-034_run-01 [5849 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-035_run-01 [5290 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-036_run-01 [5910 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags', 'duration']
# sub-037_run-01 [5858 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-038_run-01 [5827 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-039_run-01 [5866 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-040_run-01 [5860 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-041_run-01 [5897 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-042_run-01 [5969 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-043_run-01 [5965 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-044_run-01 [6006 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-045_run-01 [5876 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-046_run-01 [5898 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-047_run-01 [5979 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-048_run-01 [6177 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']
# sub-049_run-01 [5890 events]: ['sample_offset', 'event_code', 'cond_code', 'type', 'latency', 'urevent', 'usertags']

# %%
from hed.tools import ColumnSummary
print('\nBIDS events summary:')
bids_dicts_all, bids_dicts =  ColumnSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip)
bids_dicts_all.print()

print('\nEEG.event events summary:')
eeg_dicts_all, eeg_dicts =  ColumnSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip)
eeg_dicts_all.print()
# Out:
# BIDS events summary:
# Summary for column dictionary :
#   Categorical columns (7):
#     Unnamed: 8 (1 distinct values):
#       : 11772
#     Unnamed: 9 (1 distinct values):
#       : 11772
#     duration (2 distinct values):
#       : 12924
#       n/a: 274525
#     response_time (2 distinct values):
#       : 12924
#       n/a: 274525
#     stim_file (2 distinct values):
#       : 12924
#       n/a: 274525
#     trial_type (5 distinct values):
#       0: 6373
#       1: 58185
#       2: 54048
#       3: 168840
#       []: 3
#     value (54 distinct values):
#       1: 240
#       10: 96
#       11: 3179
#       110: 96
#       111: 766
#       112: 766
#       113: 384
#       114: 382
#       12: 3173
#       1201: 5075
#       13: 4909
#       14: 4907
#       15: 18089
#       16: 18090
#       17: 192
#       18: 192
#       19: 96
#       199: 306
#       2: 240
#       201: 764
#       202: 929
#       21: 2242
#       212: 3
#       22: 2245
#       2201: 4545
#       2255: 3
#       23: 4484
#       24: 4489
#       25: 17927
#       26: 17923
#       28: 2
#       3: 192
#       31: 6810
#       310: 4510
#       311: 36014
#       312: 35989
#       313: 18009
#       314: 18014
#       32: 6809
#       3201: 18644
#       33: 96
#       34: 96
#       35: 383
#       36: 385
#       37: 9022
#       38: 9022
#       39: 4504
#       4: 192
#       5: 772
#       6: 769
#       7: 192
#       8: 192
#       9: 96
#       boundary: 3
#   Value columns (0):
#
# EEG.event events summary:
# Summary for column dictionary :
#   Categorical columns (4):
#     cond_code (5 distinct values):
#       : 3
#       0: 6067
#       1: 58184
#       2: 54048
#       3: 168840
#     duration (2 distinct values):
#       0: 17630
#       NaN: 3
#     event_code (18 distinct values):
#       : 3
#       1: 11703
#       10: 4702
#       11: 37548
#       12: 37524
#       13: 18778
#       14: 18779
#       2: 11701
#       201: 29028
#       202: 928
#       255: 3
#       3: 9296
#       4: 9301
#       5: 37171
#       6: 37167
#       7: 9406
#       8: 9408
#       9: 4696
#     type (53 distinct values):
#       1: 240
#       10: 96
#       11: 3179
#       110: 96
#       111: 766
#       112: 766
#       113: 384
#       114: 382
#       12: 3173
#       1201: 5075
#       13: 4909
#       14: 4907
#       15: 18089
#       16: 18090
#       17: 192
#       18: 192
#       19: 96
#       2: 240
#       201: 764
#       202: 928
#       21: 2242
#       212: 3
#       22: 2245
#       2201: 4545
#       2255: 3
#       23: 4484
#       24: 4489
#       25: 17927
#       26: 17923
#       28: 2
#       3: 192
#       31: 6810
#       310: 4510
#       311: 36014
#       312: 35989
#       313: 18009
#       314: 18014
#       32: 6809
#       3201: 18644
#       33: 96
#       34: 96
#       35: 383
#       36: 385
#       37: 9022
#       38: 9022
#       39: 4504
#       4: 192
#       5: 772
#       6: 769
#       7: 192
#       8: 192
#       9: 96
#       boundary: 3
#   Value columns (0):
