# %% [markdown]
# ## Remove the extra files from BCIT Calibration Driving Duty
#
# This script assumes that you have copied the CalibrationDrivingWorking directory into
# the CalibrationDrivingWorkingPhaseTwo directory.
#
# This script removes `_events.tsv` and `_events_temp.tsv` and then
# renames `_events_temp1.tsv` to `_events.tsv`.

# %%
import os
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 's:/bcit/CalibrationDrivingWorkingPhaseTwo'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
log_file_name = 'bcit_calibration_driving_03_remove_files_log.json'


# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary("Bids event files", files_bids, entities=entities)

# Set logger and remove the appropriate files
logger = HedLogger()
for key, file in bids_dict.iter_files():
    # Remove events.tsv
    filename = file.file_path
    os.remove(filename)
    logger.add(key, f"Remove {os.path.basename(filename)}")

    # Remove events_temp.tsv
    filename_temp = filename[:-4] + "_temp.tsv"
    if os.path.isfile(filename_temp):
        os.remove(filename_temp)
        logger.add(key, f"Removed {os.path.basename(filename_temp)}")
    else:
        logger.add(key, f"{os.path.basename(filename_temp)} does not exist and could not be removed", level="ERROR", also_print=True)

    # Move events_temp1.tsv to events.tsv
    filename_temp1 = filename[:-4] + "_temp1.tsv"
    if os.path.isfile(filename_temp1):
        os.rename(filename_temp1, filename)
        logger.add(key, f"Renamed {os.path.basename(filename_temp1)}\n\t\tto {os.path.basename(filename)}")
    else:
        logger.add(key, f"{os.path.basename(filename_temp1)} does not exist and could not be moved", level="ERROR", also_print=True)

# Now make sure there aren't any unexpected leftovers
temp_files = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
if temp_files:
    for file in temp_files:
        logger.add('', f"{os.path.basename(file)} is unexpectedly left over", level="ERROR", also_print=True)

temp1_files = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp1",
                           exclude_dirs=exclude_dirs)
if temp1_files:
    for file in temp1_files:
        logger.add('', f"{os.path.basename(file)} is unexpectedly left over", level="ERROR", also_print=True)

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# sub-01_ses-01_run-1:
# 	[ Remove sub-01_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-01_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-01_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-01_ses-01_task-Drive_run-1_events.tsv]
# sub-02_ses-01_run-1:
# 	[ Remove sub-02_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-02_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-02_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-02_ses-01_task-Drive_run-1_events.tsv]
# sub-03_ses-01_run-1:
# 	[ Remove sub-03_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-03_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-03_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-03_ses-01_task-Drive_run-1_events.tsv]
# sub-04_ses-01_run-1:
# 	[ Remove sub-04_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-04_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-04_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-04_ses-01_task-Drive_run-1_events.tsv]
# sub-05_ses-01_run-1:
# 	[ Remove sub-05_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-05_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-05_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-05_ses-01_task-Drive_run-1_events.tsv]
# sub-06_ses-01_run-1:
# 	[ Remove sub-06_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-06_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-06_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-06_ses-01_task-Drive_run-1_events.tsv]
# sub-07_ses-01_run-1:
# 	[ Remove sub-07_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-07_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-07_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-07_ses-01_task-Drive_run-1_events.tsv]
# sub-08_ses-01_run-1:
# 	[ Remove sub-08_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-08_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-08_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-08_ses-01_task-Drive_run-1_events.tsv]
# sub-09_ses-01_run-1:
# 	[ Remove sub-09_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-09_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-09_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-09_ses-01_task-Drive_run-1_events.tsv]
# sub-10_ses-01_run-1:
# 	[ Remove sub-10_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-10_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-10_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-10_ses-01_task-Drive_run-1_events.tsv]
# sub-100_ses-01_run-1:
# 	[ Remove sub-100_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-01_task-Drive_run-1_events.tsv]
# sub-100_ses-02_run-1:
# 	[ Remove sub-100_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-02_task-Drive_run-1_events.tsv]
# sub-100_ses-03_run-1:
# 	[ Remove sub-100_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-03_task-Drive_run-1_events.tsv]
# sub-100_ses-04_run-1:
# 	[ Remove sub-100_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-04_task-Drive_run-1_events.tsv]
# sub-100_ses-05_run-1:
# 	[ Remove sub-100_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-05_task-Drive_run-1_events.tsv]
# sub-100_ses-06_run-1:
# 	[ Remove sub-100_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-06_task-Drive_run-1_events.tsv]
# sub-100_ses-07_run-1:
# 	[ Remove sub-100_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-100_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-100_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-100_ses-07_task-Drive_run-1_events.tsv]
# sub-101_ses-01_run-1:
# 	[ Remove sub-101_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-101_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-101_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-101_ses-01_task-Drive_run-1_events.tsv]
# sub-102_ses-01_run-1:
# 	[ Remove sub-102_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-102_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-102_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-102_ses-01_task-Drive_run-1_events.tsv]
# sub-103_ses-01_run-1:
# 	[ Remove sub-103_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-103_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-103_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-103_ses-01_task-Drive_run-1_events.tsv]
# sub-104_ses-01_run-1:
# 	[ Remove sub-104_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-104_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-104_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-104_ses-01_task-Drive_run-1_events.tsv]
# sub-105_ses-01_run-1:
# 	[ Remove sub-105_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-105_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-105_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-105_ses-01_task-Drive_run-1_events.tsv]
# sub-106_ses-01_run-1:
# 	[ Remove sub-106_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-106_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-106_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-106_ses-01_task-Drive_run-1_events.tsv]
# sub-106_ses-02_run-1:
# 	[ Remove sub-106_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-106_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-106_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-106_ses-02_task-Drive_run-1_events.tsv]
# sub-107_ses-01_run-1:
# 	[ Remove sub-107_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-107_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-107_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-107_ses-01_task-Drive_run-1_events.tsv]
# sub-108_ses-01_run-1:
# 	[ Remove sub-108_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-108_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-108_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-108_ses-01_task-Drive_run-1_events.tsv]
# sub-109_ses-01_run-1:
# 	[ Remove sub-109_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-109_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-109_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-109_ses-01_task-Drive_run-1_events.tsv]
# sub-11_ses-01_run-1:
# 	[ Remove sub-11_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-11_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-11_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-11_ses-01_task-Drive_run-1_events.tsv]
# sub-110_ses-01_run-1:
# 	[ Remove sub-110_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-110_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-110_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-110_ses-01_task-Drive_run-1_events.tsv]
# sub-111_ses-01_run-1:
# 	[ Remove sub-111_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-111_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-111_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-111_ses-01_task-Drive_run-1_events.tsv]
# sub-112_ses-01_run-1:
# 	[ Remove sub-112_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-01_task-Drive_run-1_events.tsv]
# sub-112_ses-02_run-1:
# 	[ Remove sub-112_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-02_task-Drive_run-1_events.tsv]
# sub-112_ses-03_run-1:
# 	[ Remove sub-112_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-03_task-Drive_run-1_events.tsv]
# sub-112_ses-04_run-1:
# 	[ Remove sub-112_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-04_task-Drive_run-1_events.tsv]
# sub-112_ses-05_run-1:
# 	[ Remove sub-112_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-05_task-Drive_run-1_events.tsv]
# sub-112_ses-06_run-1:
# 	[ Remove sub-112_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-06_task-Drive_run-1_events.tsv]
# sub-112_ses-07_run-1:
# 	[ Remove sub-112_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-112_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-112_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-112_ses-07_task-Drive_run-1_events.tsv]
# sub-113_ses-01_run-1:
# 	[ Remove sub-113_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-113_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-113_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-113_ses-01_task-Drive_run-1_events.tsv]
# sub-114_ses-01_run-1:
# 	[ Remove sub-114_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-114_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-114_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-114_ses-01_task-Drive_run-1_events.tsv]
# sub-115_ses-01_run-1:
# 	[ Remove sub-115_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-115_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-115_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-115_ses-01_task-Drive_run-1_events.tsv]
# sub-116_ses-01_run-1:
# 	[ Remove sub-116_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-116_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-116_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-116_ses-01_task-Drive_run-1_events.tsv]
# sub-117_ses-01_run-1:
# 	[ Remove sub-117_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-117_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-117_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-117_ses-01_task-Drive_run-1_events.tsv]
# sub-117_ses-02_run-1:
# 	[ Remove sub-117_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-117_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-117_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-117_ses-02_task-Drive_run-1_events.tsv]
# sub-117_ses-03_run-1:
# 	[ Remove sub-117_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-117_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-117_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-117_ses-03_task-Drive_run-1_events.tsv]
# sub-117_ses-04_run-1:
# 	[ Remove sub-117_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-117_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-117_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-117_ses-04_task-Drive_run-1_events.tsv]
# sub-117_ses-05_run-1:
# 	[ Remove sub-117_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-117_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-117_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-117_ses-05_task-Drive_run-1_events.tsv]
# sub-117_ses-06_run-1:
# 	[ Remove sub-117_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-117_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-117_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-117_ses-06_task-Drive_run-1_events.tsv]
# sub-118_ses-01_run-1:
# 	[ Remove sub-118_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-118_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-118_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-118_ses-01_task-Drive_run-1_events.tsv]
# sub-119_ses-01_run-1:
# 	[ Remove sub-119_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-119_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-119_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-119_ses-01_task-Drive_run-1_events.tsv]
# sub-12_ses-01_run-1:
# 	[ Remove sub-12_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-12_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-12_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-12_ses-01_task-Drive_run-1_events.tsv]
# sub-120_ses-01_run-1:
# 	[ Remove sub-120_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-01_task-Drive_run-1_events.tsv]
# sub-120_ses-02_run-1:
# 	[ Remove sub-120_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-02_task-Drive_run-1_events.tsv]
# sub-120_ses-03_run-1:
# 	[ Remove sub-120_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-03_task-Drive_run-1_events.tsv]
# sub-120_ses-04_run-1:
# 	[ Remove sub-120_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-04_task-Drive_run-1_events.tsv]
# sub-120_ses-05_run-1:
# 	[ Remove sub-120_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-05_task-Drive_run-1_events.tsv]
# sub-120_ses-06_run-1:
# 	[ Remove sub-120_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-06_task-Drive_run-1_events.tsv]
# sub-120_ses-07_run-1:
# 	[ Remove sub-120_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-120_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-120_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-120_ses-07_task-Drive_run-1_events.tsv]
# sub-121_ses-01_run-1:
# 	[ Remove sub-121_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-01_task-Drive_run-1_events.tsv]
# sub-121_ses-02_run-1:
# 	[ Remove sub-121_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-02_task-Drive_run-1_events.tsv]
# sub-121_ses-03_run-1:
# 	[ Remove sub-121_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-03_task-Drive_run-1_events.tsv]
# sub-121_ses-04_run-1:
# 	[ Remove sub-121_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-04_task-Drive_run-1_events.tsv]
# sub-121_ses-05_run-1:
# 	[ Remove sub-121_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-05_task-Drive_run-1_events.tsv]
# sub-121_ses-06_run-1:
# 	[ Remove sub-121_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-06_task-Drive_run-1_events.tsv]
# sub-121_ses-07_run-1:
# 	[ Remove sub-121_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-121_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-121_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-121_ses-07_task-Drive_run-1_events.tsv]
# sub-122_ses-01_run-1:
# 	[ Remove sub-122_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-01_task-Drive_run-1_events.tsv]
# sub-122_ses-02_run-1:
# 	[ Remove sub-122_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-02_task-Drive_run-1_events.tsv]
# sub-122_ses-03_run-1:
# 	[ Remove sub-122_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-03_task-Drive_run-1_events.tsv]
# sub-122_ses-04_run-1:
# 	[ Remove sub-122_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-04_task-Drive_run-1_events.tsv]
# sub-122_ses-05_run-1:
# 	[ Remove sub-122_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-05_task-Drive_run-1_events.tsv]
# sub-122_ses-06_run-1:
# 	[ Remove sub-122_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-06_task-Drive_run-1_events.tsv]
# sub-122_ses-07_run-1:
# 	[ Remove sub-122_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-122_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-122_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-122_ses-07_task-Drive_run-1_events.tsv]
# sub-123_ses-01_run-1:
# 	[ Remove sub-123_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-123_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-123_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-123_ses-01_task-Drive_run-1_events.tsv]
# sub-123_ses-02_run-1:
# 	[ Remove sub-123_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-123_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-123_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-123_ses-02_task-Drive_run-1_events.tsv]
# sub-123_ses-03_run-1:
# 	[ Remove sub-123_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-123_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-123_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-123_ses-03_task-Drive_run-1_events.tsv]
# sub-123_ses-04_run-1:
# 	[ Remove sub-123_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-123_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-123_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-123_ses-04_task-Drive_run-1_events.tsv]
# sub-123_ses-05_run-1:
# 	[ Remove sub-123_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-123_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-123_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-123_ses-05_task-Drive_run-1_events.tsv]
# sub-123_ses-06_run-1:
# 	[ Remove sub-123_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-123_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-123_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-123_ses-06_task-Drive_run-1_events.tsv]
# sub-124_ses-01_run-1:
# 	[ Remove sub-124_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-01_task-Drive_run-1_events.tsv]
# sub-124_ses-02_run-1:
# 	[ Remove sub-124_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-02_task-Drive_run-1_events.tsv]
# sub-124_ses-03_run-1:
# 	[ Remove sub-124_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-03_task-Drive_run-1_events.tsv]
# sub-124_ses-04_run-1:
# 	[ Remove sub-124_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-04_task-Drive_run-1_events.tsv]
# sub-124_ses-05_run-1:
# 	[ Remove sub-124_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-05_task-Drive_run-1_events.tsv]
# sub-124_ses-06_run-1:
# 	[ Remove sub-124_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-06_task-Drive_run-1_events.tsv]
# sub-124_ses-07_run-1:
# 	[ Remove sub-124_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-124_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-124_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-124_ses-07_task-Drive_run-1_events.tsv]
# sub-125_ses-01_run-1:
# 	[ Remove sub-125_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-01_task-Drive_run-1_events.tsv]
# sub-125_ses-02_run-1:
# 	[ Remove sub-125_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-02_task-Drive_run-1_events.tsv]
# sub-125_ses-03_run-1:
# 	[ Remove sub-125_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-03_task-Drive_run-1_events.tsv]
# sub-125_ses-04_run-1:
# 	[ Remove sub-125_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-04_task-Drive_run-1_events.tsv]
# sub-125_ses-05_run-1:
# 	[ Remove sub-125_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-05_task-Drive_run-1_events.tsv]
# sub-125_ses-06_run-1:
# 	[ Remove sub-125_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-06_task-Drive_run-1_events.tsv]
# sub-125_ses-07_run-1:
# 	[ Remove sub-125_ses-07_task-Drive_run-1_events.tsv]
# 	[ Removed sub-125_ses-07_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-125_ses-07_task-Drive_run-1_events_temp1.tsv
# 		to sub-125_ses-07_task-Drive_run-1_events.tsv]
# sub-126_ses-01_run-1:
# 	[ Remove sub-126_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-126_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-126_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-126_ses-01_task-Drive_run-1_events.tsv]
# sub-126_ses-02_run-1:
# 	[ Remove sub-126_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-126_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-126_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-126_ses-02_task-Drive_run-1_events.tsv]
# sub-126_ses-03_run-1:
# 	[ Remove sub-126_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-126_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-126_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-126_ses-03_task-Drive_run-1_events.tsv]
# sub-126_ses-04_run-1:
# 	[ Remove sub-126_ses-04_task-Drive_run-1_events.tsv]
# 	[ Removed sub-126_ses-04_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-126_ses-04_task-Drive_run-1_events_temp1.tsv
# 		to sub-126_ses-04_task-Drive_run-1_events.tsv]
# sub-126_ses-05_run-1:
# 	[ Remove sub-126_ses-05_task-Drive_run-1_events.tsv]
# 	[ Removed sub-126_ses-05_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-126_ses-05_task-Drive_run-1_events_temp1.tsv
# 		to sub-126_ses-05_task-Drive_run-1_events.tsv]
# sub-126_ses-06_run-1:
# 	[ Remove sub-126_ses-06_task-Drive_run-1_events.tsv]
# 	[ Removed sub-126_ses-06_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-126_ses-06_task-Drive_run-1_events_temp1.tsv
# 		to sub-126_ses-06_task-Drive_run-1_events.tsv]
# sub-127_ses-01_run-1:
# 	[ Remove sub-127_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-127_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-127_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-127_ses-01_task-Drive_run-1_events.tsv]
# sub-128_ses-01_run-1:
# 	[ Remove sub-128_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-128_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-128_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-128_ses-01_task-Drive_run-1_events.tsv]
# sub-128_ses-02_run-1:
# 	[ Remove sub-128_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-128_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-128_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-128_ses-02_task-Drive_run-1_events.tsv]
# sub-129_ses-01_run-1:
# 	[ Remove sub-129_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-129_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-129_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-129_ses-01_task-Drive_run-1_events.tsv]
# sub-13_ses-01_run-1:
# 	[ Remove sub-13_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-13_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-13_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-13_ses-01_task-Drive_run-1_events.tsv]
# sub-130_ses-01_run-1:
# 	[ Remove sub-130_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-130_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-130_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-130_ses-01_task-Drive_run-1_events.tsv]
# sub-130_ses-02_run-1:
# 	[ Remove sub-130_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-130_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-130_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-130_ses-02_task-Drive_run-1_events.tsv]
# sub-131_ses-01_run-1:
# 	[ Remove sub-131_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-131_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-131_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-131_ses-01_task-Drive_run-1_events.tsv]
# sub-131_ses-02_run-1:
# 	[ Remove sub-131_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-131_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-131_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-131_ses-02_task-Drive_run-1_events.tsv]
# sub-132_ses-01_run-1:
# 	[ Remove sub-132_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-132_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-132_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-132_ses-01_task-Drive_run-1_events.tsv]
# sub-133_ses-01_run-1:
# 	[ Remove sub-133_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-133_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-133_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-133_ses-01_task-Drive_run-1_events.tsv]
# sub-133_ses-02_run-1:
# 	[ Remove sub-133_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-133_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-133_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-133_ses-02_task-Drive_run-1_events.tsv]
# sub-134_ses-01_run-1:
# 	[ Remove sub-134_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-134_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-134_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-134_ses-01_task-Drive_run-1_events.tsv]
# sub-135_ses-01_run-1:
# 	[ Remove sub-135_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-135_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-135_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-135_ses-01_task-Drive_run-1_events.tsv]
# sub-136_ses-01_run-1:
# 	[ Remove sub-136_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-136_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-136_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-136_ses-01_task-Drive_run-1_events.tsv]
# sub-137_ses-01_run-1:
# 	[ Remove sub-137_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-137_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-137_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-137_ses-01_task-Drive_run-1_events.tsv]
# sub-138_ses-01_run-1:
# 	[ Remove sub-138_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-138_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-138_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-138_ses-01_task-Drive_run-1_events.tsv]
# sub-139_ses-01_run-1:
# 	[ Remove sub-139_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-139_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-139_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-139_ses-01_task-Drive_run-1_events.tsv]
# sub-14_ses-01_run-1:
# 	[ Remove sub-14_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-14_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-14_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-14_ses-01_task-Drive_run-1_events.tsv]
# sub-140_ses-01_run-1:
# 	[ Remove sub-140_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-140_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-140_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-140_ses-01_task-Drive_run-1_events.tsv]
# sub-140_ses-02_run-1:
# 	[ Remove sub-140_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-140_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-140_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-140_ses-02_task-Drive_run-1_events.tsv]
# sub-140_ses-03_run-1:
# 	[ Remove sub-140_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-140_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-140_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-140_ses-03_task-Drive_run-1_events.tsv]
# sub-141_ses-01_run-1:
# 	[ Remove sub-141_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-141_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-141_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-141_ses-01_task-Drive_run-1_events.tsv]
# sub-142_ses-01_run-1:
# 	[ Remove sub-142_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-142_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-142_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-142_ses-01_task-Drive_run-1_events.tsv]
# sub-143_ses-01_run-1:
# 	[ Remove sub-143_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-143_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-143_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-143_ses-01_task-Drive_run-1_events.tsv]
# sub-143_ses-02_run-1:
# 	[ Remove sub-143_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-143_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-143_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-143_ses-02_task-Drive_run-1_events.tsv]
# sub-144_ses-01_run-1:
# 	[ Remove sub-144_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-144_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-144_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-144_ses-01_task-Drive_run-1_events.tsv]
# sub-145_ses-01_run-1:
# 	[ Remove sub-145_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-145_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-145_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-145_ses-01_task-Drive_run-1_events.tsv]
# sub-146_ses-01_run-1:
# 	[ Remove sub-146_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-146_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-146_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-146_ses-01_task-Drive_run-1_events.tsv]
# sub-146_ses-02_run-1:
# 	[ Remove sub-146_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-146_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-146_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-146_ses-02_task-Drive_run-1_events.tsv]
# sub-147_ses-01_run-1:
# 	[ Remove sub-147_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-147_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-147_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-147_ses-01_task-Drive_run-1_events.tsv]
# sub-148_ses-01_run-1:
# 	[ Remove sub-148_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-148_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-148_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-148_ses-01_task-Drive_run-1_events.tsv]
# sub-149_ses-01_run-1:
# 	[ Remove sub-149_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-149_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-149_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-149_ses-01_task-Drive_run-1_events.tsv]
# sub-149_ses-02_run-1:
# 	[ Remove sub-149_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-149_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-149_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-149_ses-02_task-Drive_run-1_events.tsv]
# sub-15_ses-01_run-1:
# 	[ Remove sub-15_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-15_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-15_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-15_ses-01_task-Drive_run-1_events.tsv]
# sub-150_ses-01_run-1:
# 	[ Remove sub-150_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-150_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-150_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-150_ses-01_task-Drive_run-1_events.tsv]
# sub-150_ses-02_run-1:
# 	[ Remove sub-150_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-150_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-150_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-150_ses-02_task-Drive_run-1_events.tsv]
# sub-151_ses-01_run-1:
# 	[ Remove sub-151_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-151_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-151_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-151_ses-01_task-Drive_run-1_events.tsv]
# sub-152_ses-01_run-1:
# 	[ Remove sub-152_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-152_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-152_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-152_ses-01_task-Drive_run-1_events.tsv]
# sub-153_ses-01_run-1:
# 	[ Remove sub-153_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-153_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-153_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-153_ses-01_task-Drive_run-1_events.tsv]
# sub-154_ses-01_run-1:
# 	[ Remove sub-154_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-154_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-154_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-154_ses-01_task-Drive_run-1_events.tsv]
# sub-155_ses-01_run-1:
# 	[ Remove sub-155_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-155_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-155_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-155_ses-01_task-Drive_run-1_events.tsv]
# sub-155_ses-02_run-1:
# 	[ Remove sub-155_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-155_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-155_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-155_ses-02_task-Drive_run-1_events.tsv]
# sub-156_ses-01_run-1:
# 	[ Remove sub-156_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-156_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-156_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-156_ses-01_task-Drive_run-1_events.tsv]
# sub-16_ses-01_run-1:
# 	[ Remove sub-16_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-16_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-16_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-16_ses-01_task-Drive_run-1_events.tsv]
# sub-17_ses-01_run-1:
# 	[ Remove sub-17_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-17_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-17_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-17_ses-01_task-Drive_run-1_events.tsv]
# sub-18_ses-01_run-1:
# 	[ Remove sub-18_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-18_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-18_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-18_ses-01_task-Drive_run-1_events.tsv]
# sub-19_ses-01_run-1:
# 	[ Remove sub-19_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-19_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-19_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-19_ses-01_task-Drive_run-1_events.tsv]
# sub-20_ses-01_run-1:
# 	[ Remove sub-20_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-20_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-20_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-20_ses-01_task-Drive_run-1_events.tsv]
# sub-21_ses-01_run-1:
# 	[ Remove sub-21_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-21_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-21_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-21_ses-01_task-Drive_run-1_events.tsv]
# sub-22_ses-01_run-1:
# 	[ Remove sub-22_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-22_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-22_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-22_ses-01_task-Drive_run-1_events.tsv]
# sub-23_ses-01_run-1:
# 	[ Remove sub-23_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-23_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-23_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-23_ses-01_task-Drive_run-1_events.tsv]
# sub-24_ses-01_run-1:
# 	[ Remove sub-24_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-24_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-24_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-24_ses-01_task-Drive_run-1_events.tsv]
# sub-25_ses-01_run-1:
# 	[ Remove sub-25_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-25_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-25_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-25_ses-01_task-Drive_run-1_events.tsv]
# sub-26_ses-01_run-1:
# 	[ Remove sub-26_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-26_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-26_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-26_ses-01_task-Drive_run-1_events.tsv]
# sub-27_ses-01_run-1:
# 	[ Remove sub-27_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-27_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-27_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-27_ses-01_task-Drive_run-1_events.tsv]
# sub-28_ses-01_run-1:
# 	[ Remove sub-28_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-28_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-28_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-28_ses-01_task-Drive_run-1_events.tsv]
# sub-29_ses-01_run-1:
# 	[ Remove sub-29_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-29_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-29_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-29_ses-01_task-Drive_run-1_events.tsv]
# sub-30_ses-01_run-1:
# 	[ Remove sub-30_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-30_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-30_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-30_ses-01_task-Drive_run-1_events.tsv]
# sub-31_ses-01_run-1:
# 	[ Remove sub-31_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-31_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-31_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-31_ses-01_task-Drive_run-1_events.tsv]
# sub-31_ses-02_run-1:
# 	[ Remove sub-31_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-31_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-31_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-31_ses-02_task-Drive_run-1_events.tsv]
# sub-32_ses-01_run-1:
# 	[ Remove sub-32_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-32_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-32_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-32_ses-01_task-Drive_run-1_events.tsv]
# sub-33_ses-01_run-1:
# 	[ Remove sub-33_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-33_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-33_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-33_ses-01_task-Drive_run-1_events.tsv]
# sub-33_ses-02_run-1:
# 	[ Remove sub-33_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-33_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-33_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-33_ses-02_task-Drive_run-1_events.tsv]
# sub-33_ses-03_run-1:
# 	[ Remove sub-33_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-33_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-33_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-33_ses-03_task-Drive_run-1_events.tsv]
# sub-34_ses-01_run-1:
# 	[ Remove sub-34_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-34_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-34_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-34_ses-01_task-Drive_run-1_events.tsv]
# sub-35_ses-01_run-1:
# 	[ Remove sub-35_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-35_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-35_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-35_ses-01_task-Drive_run-1_events.tsv]
# sub-36_ses-01_run-1:
# 	[ Remove sub-36_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-36_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-36_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-36_ses-01_task-Drive_run-1_events.tsv]
# sub-37_ses-01_run-1:
# 	[ Remove sub-37_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-37_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-37_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-37_ses-01_task-Drive_run-1_events.tsv]
# sub-38_ses-01_run-1:
# 	[ Remove sub-38_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-38_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-38_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-38_ses-01_task-Drive_run-1_events.tsv]
# sub-39_ses-01_run-1:
# 	[ Remove sub-39_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-39_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-39_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-39_ses-01_task-Drive_run-1_events.tsv]
# sub-40_ses-01_run-1:
# 	[ Remove sub-40_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-40_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-40_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-40_ses-01_task-Drive_run-1_events.tsv]
# sub-41_ses-01_run-1:
# 	[ Remove sub-41_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-41_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-41_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-41_ses-01_task-Drive_run-1_events.tsv]
# sub-42_ses-01_run-1:
# 	[ Remove sub-42_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-42_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-42_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-42_ses-01_task-Drive_run-1_events.tsv]
# sub-43_ses-01_run-1:
# 	[ Remove sub-43_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-43_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-43_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-43_ses-01_task-Drive_run-1_events.tsv]
# sub-44_ses-01_run-1:
# 	[ Remove sub-44_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-44_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-44_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-44_ses-01_task-Drive_run-1_events.tsv]
# sub-44_ses-02_run-1:
# 	[ Remove sub-44_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-44_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-44_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-44_ses-02_task-Drive_run-1_events.tsv]
# sub-45_ses-01_run-1:
# 	[ Remove sub-45_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-45_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-45_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-45_ses-01_task-Drive_run-1_events.tsv]
# sub-46_ses-01_run-1:
# 	[ Remove sub-46_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-46_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-46_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-46_ses-01_task-Drive_run-1_events.tsv]
# sub-47_ses-01_run-1:
# 	[ Remove sub-47_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-47_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-47_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-47_ses-01_task-Drive_run-1_events.tsv]
# sub-47_ses-02_run-1:
# 	[ Remove sub-47_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-47_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-47_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-47_ses-02_task-Drive_run-1_events.tsv]
# sub-48_ses-01_run-1:
# 	[ Remove sub-48_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-48_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-48_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-48_ses-01_task-Drive_run-1_events.tsv]
# sub-49_ses-01_run-1:
# 	[ Remove sub-49_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-49_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-49_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-49_ses-01_task-Drive_run-1_events.tsv]
# sub-50_ses-01_run-1:
# 	[ Remove sub-50_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-50_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-50_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-50_ses-01_task-Drive_run-1_events.tsv]
# sub-51_ses-01_run-1:
# 	[ Remove sub-51_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-51_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-51_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-51_ses-01_task-Drive_run-1_events.tsv]
# sub-52_ses-01_run-1:
# 	[ Remove sub-52_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-52_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-52_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-52_ses-01_task-Drive_run-1_events.tsv]
# sub-53_ses-01_run-1:
# 	[ Remove sub-53_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-53_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-53_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-53_ses-01_task-Drive_run-1_events.tsv]
# sub-54_ses-01_run-1:
# 	[ Remove sub-54_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-54_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-54_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-54_ses-01_task-Drive_run-1_events.tsv]
# sub-55_ses-01_run-1:
# 	[ Remove sub-55_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-55_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-55_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-55_ses-01_task-Drive_run-1_events.tsv]
# sub-56_ses-01_run-1:
# 	[ Remove sub-56_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-56_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-56_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-56_ses-01_task-Drive_run-1_events.tsv]
# sub-57_ses-01_run-1:
# 	[ Remove sub-57_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-57_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-57_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-57_ses-01_task-Drive_run-1_events.tsv]
# sub-58_ses-01_run-1:
# 	[ Remove sub-58_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-58_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-58_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-58_ses-01_task-Drive_run-1_events.tsv]
# sub-58_ses-02_run-1:
# 	[ Remove sub-58_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-58_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-58_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-58_ses-02_task-Drive_run-1_events.tsv]
# sub-58_ses-03_run-1:
# 	[ Remove sub-58_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-58_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-58_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-58_ses-03_task-Drive_run-1_events.tsv]
# sub-59_ses-01_run-1:
# 	[ Remove sub-59_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-59_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-59_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-59_ses-01_task-Drive_run-1_events.tsv]
# sub-59_ses-02_run-1:
# 	[ Remove sub-59_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-59_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-59_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-59_ses-02_task-Drive_run-1_events.tsv]
# sub-59_ses-03_run-1:
# 	[ Remove sub-59_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-59_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-59_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-59_ses-03_task-Drive_run-1_events.tsv]
# sub-60_ses-01_run-1:
# 	[ Remove sub-60_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-60_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-60_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-60_ses-01_task-Drive_run-1_events.tsv]
# sub-61_ses-01_run-1:
# 	[ Remove sub-61_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-61_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-61_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-61_ses-01_task-Drive_run-1_events.tsv]
# sub-61_ses-02_run-1:
# 	[ Remove sub-61_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-61_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-61_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-61_ses-02_task-Drive_run-1_events.tsv]
# sub-62_ses-01_run-1:
# 	[ Remove sub-62_ses-01_task-Drive_run-1_events.tsv]
# ...
# 	[ Renamed sub-65_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-65_ses-01_task-Drive_run-1_events.tsv]
# sub-66_ses-01_run-1:
# 	[ Remove sub-66_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-66_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-66_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-66_ses-01_task-Drive_run-1_events.tsv]
# sub-66_ses-02_run-1:
# 	[ Remove sub-66_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-66_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-66_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-66_ses-02_task-Drive_run-1_events.tsv]
# sub-66_ses-03_run-1:
# 	[ Remove sub-66_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-66_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-66_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-66_ses-03_task-Drive_run-1_events.tsv]
# sub-67_ses-01_run-1:
# 	[ Remove sub-67_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-67_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-67_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-67_ses-01_task-Drive_run-1_events.tsv]
# sub-68_ses-01_run-1:
# 	[ Remove sub-68_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-68_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-68_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-68_ses-01_task-Drive_run-1_events.tsv]
# sub-69_ses-01_run-1:
# 	[ Remove sub-69_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-69_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-69_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-69_ses-01_task-Drive_run-1_events.tsv]
# sub-70_ses-01_run-1:
# 	[ Remove sub-70_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-70_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-70_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-70_ses-01_task-Drive_run-1_events.tsv]
# sub-70_ses-02_run-1:
# 	[ Remove sub-70_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-70_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-70_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-70_ses-02_task-Drive_run-1_events.tsv]
# sub-70_ses-03_run-1:
# 	[ Remove sub-70_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-70_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-70_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-70_ses-03_task-Drive_run-1_events.tsv]
# sub-71_ses-01_run-1:
# 	[ Remove sub-71_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-71_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-71_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-71_ses-01_task-Drive_run-1_events.tsv]
# sub-71_ses-02_run-1:
# 	[ Remove sub-71_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-71_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-71_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-71_ses-02_task-Drive_run-1_events.tsv]
# sub-71_ses-03_run-1:
# 	[ Remove sub-71_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-71_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-71_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-71_ses-03_task-Drive_run-1_events.tsv]
# sub-72_ses-01_run-1:
# 	[ Remove sub-72_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-72_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-72_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-72_ses-01_task-Drive_run-1_events.tsv]
# sub-73_ses-01_run-1:
# 	[ Remove sub-73_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-73_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-73_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-73_ses-01_task-Drive_run-1_events.tsv]
# sub-74_ses-01_run-1:
# 	[ Remove sub-74_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-74_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-74_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-74_ses-01_task-Drive_run-1_events.tsv]
# sub-75_ses-01_run-1:
# 	[ Remove sub-75_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-75_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-75_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-75_ses-01_task-Drive_run-1_events.tsv]
# sub-76_ses-01_run-1:
# 	[ Remove sub-76_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-76_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-76_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-76_ses-01_task-Drive_run-1_events.tsv]
# sub-76_ses-02_run-1:
# 	[ Remove sub-76_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-76_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-76_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-76_ses-02_task-Drive_run-1_events.tsv]
# sub-76_ses-03_run-1:
# 	[ Remove sub-76_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-76_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-76_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-76_ses-03_task-Drive_run-1_events.tsv]
# sub-77_ses-01_run-1:
# 	[ Remove sub-77_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-77_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-77_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-77_ses-01_task-Drive_run-1_events.tsv]
# sub-78_ses-01_run-1:
# 	[ Remove sub-78_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-78_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-78_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-78_ses-01_task-Drive_run-1_events.tsv]
# sub-78_ses-02_run-1:
# 	[ Remove sub-78_ses-02_task-Drive_run-1_events.tsv]
# 	[ Removed sub-78_ses-02_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-78_ses-02_task-Drive_run-1_events_temp1.tsv
# 		to sub-78_ses-02_task-Drive_run-1_events.tsv]
# sub-78_ses-03_run-1:
# 	[ Remove sub-78_ses-03_task-Drive_run-1_events.tsv]
# 	[ Removed sub-78_ses-03_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-78_ses-03_task-Drive_run-1_events_temp1.tsv
# 		to sub-78_ses-03_task-Drive_run-1_events.tsv]
# sub-79_ses-01_run-1:
# 	[ Remove sub-79_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-79_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-79_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-79_ses-01_task-Drive_run-1_events.tsv]
# sub-80_ses-01_run-1:
# 	[ Remove sub-80_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-80_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-80_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-80_ses-01_task-Drive_run-1_events.tsv]
# sub-81_ses-01_run-1:
# 	[ Remove sub-81_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-81_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-81_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-81_ses-01_task-Drive_run-1_events.tsv]
# sub-82_ses-01_run-1:
# 	[ Remove sub-82_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-82_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-82_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-82_ses-01_task-Drive_run-1_events.tsv]
# sub-83_ses-01_run-1:
# 	[ Remove sub-83_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-83_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-83_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-83_ses-01_task-Drive_run-1_events.tsv]
# sub-84_ses-01_run-1:
# 	[ Remove sub-84_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-84_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-84_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-84_ses-01_task-Drive_run-1_events.tsv]
# sub-85_ses-01_run-1:
# 	[ Remove sub-85_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-85_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-85_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-85_ses-01_task-Drive_run-1_events.tsv]
# sub-86_ses-01_run-1:
# 	[ Remove sub-86_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-86_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-86_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-86_ses-01_task-Drive_run-1_events.tsv]
# sub-87_ses-01_run-1:
# 	[ Remove sub-87_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-87_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-87_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-87_ses-01_task-Drive_run-1_events.tsv]
# sub-88_ses-01_run-1:
# 	[ Remove sub-88_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-88_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-88_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-88_ses-01_task-Drive_run-1_events.tsv]
# sub-89_ses-01_run-1:
# 	[ Remove sub-89_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-89_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-89_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-89_ses-01_task-Drive_run-1_events.tsv]
# sub-90_ses-01_run-1:
# 	[ Remove sub-90_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-90_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-90_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-90_ses-01_task-Drive_run-1_events.tsv]
# sub-91_ses-01_run-1:
# 	[ Remove sub-91_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-91_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-91_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-91_ses-01_task-Drive_run-1_events.tsv]
# sub-92_ses-01_run-1:
# 	[ Remove sub-92_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-92_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-92_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-92_ses-01_task-Drive_run-1_events.tsv]
# sub-93_ses-01_run-1:
# 	[ Remove sub-93_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-93_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-93_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-93_ses-01_task-Drive_run-1_events.tsv]
# sub-94_ses-01_run-1:
# 	[ Remove sub-94_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-94_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-94_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-94_ses-01_task-Drive_run-1_events.tsv]
# sub-95_ses-01_run-1:
# 	[ Remove sub-95_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-95_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-95_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-95_ses-01_task-Drive_run-1_events.tsv]
# sub-96_ses-01_run-1:
# 	[ Remove sub-96_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-96_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-96_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-96_ses-01_task-Drive_run-1_events.tsv]
# sub-97_ses-01_run-1:
# 	[ Remove sub-97_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-97_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-97_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-97_ses-01_task-Drive_run-1_events.tsv]
# sub-98_ses-01_run-1:
# 	[ Remove sub-98_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-98_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-98_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-98_ses-01_task-Drive_run-1_events.tsv]
# sub-99_ses-01_run-1:
# 	[ Remove sub-99_ses-01_task-Drive_run-1_events.tsv]
# 	[ Removed sub-99_ses-01_task-Drive_run-1_events_temp.tsv]
# 	[ Renamed sub-99_ses-01_task-Drive_run-1_events_temp1.tsv
# 		to sub-99_ses-01_task-Drive_run-1_events.tsv]
#
# ERROR Summary:
# sub-01_ses-01_run-1:
# sub-02_ses-01_run-1:
# sub-03_ses-01_run-1:
# sub-04_ses-01_run-1:
# sub-05_ses-01_run-1:
# sub-06_ses-01_run-1:
# sub-07_ses-01_run-1:
# sub-08_ses-01_run-1:
# sub-09_ses-01_run-1:
# sub-10_ses-01_run-1:
# sub-100_ses-01_run-1:
# sub-100_ses-02_run-1:
# sub-100_ses-03_run-1:
# sub-100_ses-04_run-1:
# sub-100_ses-05_run-1:
# sub-100_ses-06_run-1:
# sub-100_ses-07_run-1:
# sub-101_ses-01_run-1:
# sub-102_ses-01_run-1:
# sub-103_ses-01_run-1:
# sub-104_ses-01_run-1:
# sub-105_ses-01_run-1:
# sub-106_ses-01_run-1:
# sub-106_ses-02_run-1:
# sub-107_ses-01_run-1:
# sub-108_ses-01_run-1:
# sub-109_ses-01_run-1:
# sub-11_ses-01_run-1:
# sub-110_ses-01_run-1:
# sub-111_ses-01_run-1:
# sub-112_ses-01_run-1:
# sub-112_ses-02_run-1:
# sub-112_ses-03_run-1:
# sub-112_ses-04_run-1:
# sub-112_ses-05_run-1:
# sub-112_ses-06_run-1:
# sub-112_ses-07_run-1:
# sub-113_ses-01_run-1:
# sub-114_ses-01_run-1:
# sub-115_ses-01_run-1:
# sub-116_ses-01_run-1:
# sub-117_ses-01_run-1:
# sub-117_ses-02_run-1:
# sub-117_ses-03_run-1:
# sub-117_ses-04_run-1:
# sub-117_ses-05_run-1:
# sub-117_ses-06_run-1:
# sub-118_ses-01_run-1:
# sub-119_ses-01_run-1:
# sub-12_ses-01_run-1:
# sub-120_ses-01_run-1:
# sub-120_ses-02_run-1:
# sub-120_ses-03_run-1:
# sub-120_ses-04_run-1:
# sub-120_ses-05_run-1:
# sub-120_ses-06_run-1:
# sub-120_ses-07_run-1:
# sub-121_ses-01_run-1:
# sub-121_ses-02_run-1:
# sub-121_ses-03_run-1:
# sub-121_ses-04_run-1:
# sub-121_ses-05_run-1:
# sub-121_ses-06_run-1:
# sub-121_ses-07_run-1:
# sub-122_ses-01_run-1:
# sub-122_ses-02_run-1:
# sub-122_ses-03_run-1:
# sub-122_ses-04_run-1:
# sub-122_ses-05_run-1:
# sub-122_ses-06_run-1:
# sub-122_ses-07_run-1:
# sub-123_ses-01_run-1:
# sub-123_ses-02_run-1:
# sub-123_ses-03_run-1:
# sub-123_ses-04_run-1:
# sub-123_ses-05_run-1:
# sub-123_ses-06_run-1:
# sub-124_ses-01_run-1:
# sub-124_ses-02_run-1:
# sub-124_ses-03_run-1:
# sub-124_ses-04_run-1:
# sub-124_ses-05_run-1:
# sub-124_ses-06_run-1:
# sub-124_ses-07_run-1:
# sub-125_ses-01_run-1:
# sub-125_ses-02_run-1:
# sub-125_ses-03_run-1:
# sub-125_ses-04_run-1:
# sub-125_ses-05_run-1:
# sub-125_ses-06_run-1:
# sub-125_ses-07_run-1:
# sub-126_ses-01_run-1:
# sub-126_ses-02_run-1:
# sub-126_ses-03_run-1:
# sub-126_ses-04_run-1:
# sub-126_ses-05_run-1:
# sub-126_ses-06_run-1:
# sub-127_ses-01_run-1:
# sub-128_ses-01_run-1:
# sub-128_ses-02_run-1:
# sub-129_ses-01_run-1:
# sub-13_ses-01_run-1:
# sub-130_ses-01_run-1:
# sub-130_ses-02_run-1:
# sub-131_ses-01_run-1:
# sub-131_ses-02_run-1:
# sub-132_ses-01_run-1:
# sub-133_ses-01_run-1:
# sub-133_ses-02_run-1:
# sub-134_ses-01_run-1:
# sub-135_ses-01_run-1:
# sub-136_ses-01_run-1:
# sub-137_ses-01_run-1:
# sub-138_ses-01_run-1:
# sub-139_ses-01_run-1:
# sub-14_ses-01_run-1:
# sub-140_ses-01_run-1:
# sub-140_ses-02_run-1:
# sub-140_ses-03_run-1:
# sub-141_ses-01_run-1:
# sub-142_ses-01_run-1:
# sub-143_ses-01_run-1:
# sub-143_ses-02_run-1:
# sub-144_ses-01_run-1:
# sub-145_ses-01_run-1:
# sub-146_ses-01_run-1:
# sub-146_ses-02_run-1:
# sub-147_ses-01_run-1:
# sub-148_ses-01_run-1:
# sub-149_ses-01_run-1:
# sub-149_ses-02_run-1:
# sub-15_ses-01_run-1:
# sub-150_ses-01_run-1:
# sub-150_ses-02_run-1:
# sub-151_ses-01_run-1:
# sub-152_ses-01_run-1:
# sub-153_ses-01_run-1:
# sub-154_ses-01_run-1:
# sub-155_ses-01_run-1:
# sub-155_ses-02_run-1:
# sub-156_ses-01_run-1:
# sub-16_ses-01_run-1:
# sub-17_ses-01_run-1:
# sub-18_ses-01_run-1:
# sub-19_ses-01_run-1:
# sub-20_ses-01_run-1:
# sub-21_ses-01_run-1:
# sub-22_ses-01_run-1:
# sub-23_ses-01_run-1:
# sub-24_ses-01_run-1:
# sub-25_ses-01_run-1:
# sub-26_ses-01_run-1:
# sub-27_ses-01_run-1:
# sub-28_ses-01_run-1:
# sub-29_ses-01_run-1:
# sub-30_ses-01_run-1:
# sub-31_ses-01_run-1:
# sub-31_ses-02_run-1:
# sub-32_ses-01_run-1:
# sub-33_ses-01_run-1:
# sub-33_ses-02_run-1:
# sub-33_ses-03_run-1:
# sub-34_ses-01_run-1:
# sub-35_ses-01_run-1:
# sub-36_ses-01_run-1:
# sub-37_ses-01_run-1:
# sub-38_ses-01_run-1:
# sub-39_ses-01_run-1:
# sub-40_ses-01_run-1:
# sub-41_ses-01_run-1:
# sub-42_ses-01_run-1:
# sub-43_ses-01_run-1:
# sub-44_ses-01_run-1:
# sub-44_ses-02_run-1:
# sub-45_ses-01_run-1:
# sub-46_ses-01_run-1:
# sub-47_ses-01_run-1:
# sub-47_ses-02_run-1:
# sub-48_ses-01_run-1:
# sub-49_ses-01_run-1:
# sub-50_ses-01_run-1:
# sub-51_ses-01_run-1:
# sub-52_ses-01_run-1:
# sub-53_ses-01_run-1:
# sub-54_ses-01_run-1:
# sub-55_ses-01_run-1:
# sub-56_ses-01_run-1:
# sub-57_ses-01_run-1:
# sub-58_ses-01_run-1:
# sub-58_ses-02_run-1:
# sub-58_ses-03_run-1:
# sub-59_ses-01_run-1:
# sub-59_ses-02_run-1:
# sub-59_ses-03_run-1:
# sub-60_ses-01_run-1:
# sub-61_ses-01_run-1:
# sub-61_ses-02_run-1:
# sub-62_ses-01_run-1:
# sub-63_ses-01_run-1:
# sub-63_ses-02_run-1:
# sub-63_ses-03_run-1:
# sub-64_ses-01_run-1:
# sub-65_ses-01_run-1:
# sub-66_ses-01_run-1:
# sub-66_ses-02_run-1:
# sub-66_ses-03_run-1:
# sub-67_ses-01_run-1:
# sub-68_ses-01_run-1:
# sub-69_ses-01_run-1:
# sub-70_ses-01_run-1:
# sub-70_ses-02_run-1:
# sub-70_ses-03_run-1:
# sub-71_ses-01_run-1:
# sub-71_ses-02_run-1:
# sub-71_ses-03_run-1:
# sub-72_ses-01_run-1:
# sub-73_ses-01_run-1:
# sub-74_ses-01_run-1:
# sub-75_ses-01_run-1:
# sub-76_ses-01_run-1:
# sub-76_ses-02_run-1:
# sub-76_ses-03_run-1:
# sub-77_ses-01_run-1:
# sub-78_ses-01_run-1:
# sub-78_ses-02_run-1:
# sub-78_ses-03_run-1:
# sub-79_ses-01_run-1:
# sub-80_ses-01_run-1:
# sub-81_ses-01_run-1:
# sub-82_ses-01_run-1:
# sub-83_ses-01_run-1:
# sub-84_ses-01_run-1:
# sub-85_ses-01_run-1:
# sub-86_ses-01_run-1:
# sub-87_ses-01_run-1:
# sub-88_ses-01_run-1:
# sub-89_ses-01_run-1:
# sub-90_ses-01_run-1:
# sub-91_ses-01_run-1:
# sub-92_ses-01_run-1:
# sub-93_ses-01_run-1:
# sub-94_ses-01_run-1:
# sub-95_ses-01_run-1:
# sub-96_ses-01_run-1:
# sub-97_ses-01_run-1:
# sub-98_ses-01_run-1:
# sub-99_ses-01_run-1:
