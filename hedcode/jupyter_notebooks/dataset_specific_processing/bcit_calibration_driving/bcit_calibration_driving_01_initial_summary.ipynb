# %% [markdown]
# ## Initial summary of event files
#
# **Dataset**: BCIT Calibration Driving (in process)
#
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
# Keys are specified by a `entities` tuple lists the BIDS entity names
# to include in the key.
# BIDS base file names are constructed of entity *name*-*value* pairs separated
# by underbars and followed by an ending *_suffix*.
#
# For a file name `sub-001_ses-3_task-target_run-01_events.tsv`,
# the tuple ('sub', 'task') gives a key of `sub-001_task-target`,
# while the tuple ('sub', 'ses', 'run) gives a key of `sub-001_ses-3_run-01`.
# The use of dictionaries of file names with such keys makes it
# easier to associate related files in the BIDS naming structure.
#
# The setup requires the setting of the following variables for your dataset:
#
# | Variable | Purpose |
# | -------- | ------- |
# | bids_root_path | Full path to root directory of dataset.|
# | exclude_dirs | List of directories to exclude when constructing file lists. |
# | entities  | Tuple of entity names used to construct a unique keys representing filenames. <br>(See [Dictionaries of filenames](https://hed-examples.readthedocs.io/en/latest/HedInPython.html#dictionaries-of-filenames-anchor) for examples of how to choose the keys.)|
# | bids_skip_columns  |  List of column names in the `events.tsv` files to skip in the analysis. |
# | eeg_skip_columns  | List of column names in the `events_temp.tsv` files form EEG.events to skip in analysis.|

# %%
from hed.tools import BidsTsvDictionary
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/CalibrationDrivingWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
bids_skip_columns = ['onset']
eeg_skip_columns = ['latency', 'urevent', 'usertags']

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary(files_bids, entities=entities)
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary(files_eeg, entities=entities)

# %%
print(f"Summarizing {bids_root_path}...")
bids_dict.print_files(title="\nBIDS style event files")
eeg_dict.print_files(title="\nEEG.event style event files")
# Out:
# Summarizing F:/ARLBidsStart/CalibrationDrivingWorking...
#
# BIDS style event files (247 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-Drive_run-1_events.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-Drive_run-1_events.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-Drive_run-1_events.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-Drive_run-1_events.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-Drive_run-1_events.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-Drive_run-1_events.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-Drive_run-1_events.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-Drive_run-1_events.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-Drive_run-1_events.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-Drive_run-1_events.tsv
# sub-100_ses-01_run-1: sub-100_ses-01_task-Drive_run-1_events.tsv
# sub-100_ses-02_run-1: sub-100_ses-02_task-Drive_run-1_events.tsv
# sub-100_ses-03_run-1: sub-100_ses-03_task-Drive_run-1_events.tsv
# sub-100_ses-04_run-1: sub-100_ses-04_task-Drive_run-1_events.tsv
# sub-100_ses-05_run-1: sub-100_ses-05_task-Drive_run-1_events.tsv
# sub-100_ses-06_run-1: sub-100_ses-06_task-Drive_run-1_events.tsv
# sub-100_ses-07_run-1: sub-100_ses-07_task-Drive_run-1_events.tsv
# sub-101_ses-01_run-1: sub-101_ses-01_task-Drive_run-1_events.tsv
# sub-102_ses-01_run-1: sub-102_ses-01_task-Drive_run-1_events.tsv
# sub-103_ses-01_run-1: sub-103_ses-01_task-Drive_run-1_events.tsv
# sub-104_ses-01_run-1: sub-104_ses-01_task-Drive_run-1_events.tsv
# sub-105_ses-01_run-1: sub-105_ses-01_task-Drive_run-1_events.tsv
# sub-106_ses-01_run-1: sub-106_ses-01_task-Drive_run-1_events.tsv
# sub-106_ses-02_run-1: sub-106_ses-02_task-Drive_run-1_events.tsv
# sub-107_ses-01_run-1: sub-107_ses-01_task-Drive_run-1_events.tsv
# sub-108_ses-01_run-1: sub-108_ses-01_task-Drive_run-1_events.tsv
# sub-109_ses-01_run-1: sub-109_ses-01_task-Drive_run-1_events.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-Drive_run-1_events.tsv
# sub-110_ses-01_run-1: sub-110_ses-01_task-Drive_run-1_events.tsv
# sub-111_ses-01_run-1: sub-111_ses-01_task-Drive_run-1_events.tsv
# sub-112_ses-01_run-1: sub-112_ses-01_task-Drive_run-1_events.tsv
# sub-112_ses-02_run-1: sub-112_ses-02_task-Drive_run-1_events.tsv
# sub-112_ses-03_run-1: sub-112_ses-03_task-Drive_run-1_events.tsv
# sub-112_ses-04_run-1: sub-112_ses-04_task-Drive_run-1_events.tsv
# sub-112_ses-05_run-1: sub-112_ses-05_task-Drive_run-1_events.tsv
# sub-112_ses-06_run-1: sub-112_ses-06_task-Drive_run-1_events.tsv
# sub-112_ses-07_run-1: sub-112_ses-07_task-Drive_run-1_events.tsv
# sub-113_ses-01_run-1: sub-113_ses-01_task-Drive_run-1_events.tsv
# sub-114_ses-01_run-1: sub-114_ses-01_task-Drive_run-1_events.tsv
# sub-115_ses-01_run-1: sub-115_ses-01_task-Drive_run-1_events.tsv
# sub-116_ses-01_run-1: sub-116_ses-01_task-Drive_run-1_events.tsv
# sub-117_ses-01_run-1: sub-117_ses-01_task-Drive_run-1_events.tsv
# sub-117_ses-02_run-1: sub-117_ses-02_task-Drive_run-1_events.tsv
# sub-117_ses-03_run-1: sub-117_ses-03_task-Drive_run-1_events.tsv
# sub-117_ses-04_run-1: sub-117_ses-04_task-Drive_run-1_events.tsv
# sub-117_ses-05_run-1: sub-117_ses-05_task-Drive_run-1_events.tsv
# sub-117_ses-06_run-1: sub-117_ses-06_task-Drive_run-1_events.tsv
# sub-118_ses-01_run-1: sub-118_ses-01_task-Drive_run-1_events.tsv
# sub-119_ses-01_run-1: sub-119_ses-01_task-Drive_run-1_events.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-Drive_run-1_events.tsv
# sub-120_ses-01_run-1: sub-120_ses-01_task-Drive_run-1_events.tsv
# sub-120_ses-02_run-1: sub-120_ses-02_task-Drive_run-1_events.tsv
# sub-120_ses-03_run-1: sub-120_ses-03_task-Drive_run-1_events.tsv
# sub-120_ses-04_run-1: sub-120_ses-04_task-Drive_run-1_events.tsv
# sub-120_ses-05_run-1: sub-120_ses-05_task-Drive_run-1_events.tsv
# sub-120_ses-06_run-1: sub-120_ses-06_task-Drive_run-1_events.tsv
# sub-120_ses-07_run-1: sub-120_ses-07_task-Drive_run-1_events.tsv
# sub-121_ses-01_run-1: sub-121_ses-01_task-Drive_run-1_events.tsv
# sub-121_ses-02_run-1: sub-121_ses-02_task-Drive_run-1_events.tsv
# sub-121_ses-03_run-1: sub-121_ses-03_task-Drive_run-1_events.tsv
# sub-121_ses-04_run-1: sub-121_ses-04_task-Drive_run-1_events.tsv
# sub-121_ses-05_run-1: sub-121_ses-05_task-Drive_run-1_events.tsv
# sub-121_ses-06_run-1: sub-121_ses-06_task-Drive_run-1_events.tsv
# sub-121_ses-07_run-1: sub-121_ses-07_task-Drive_run-1_events.tsv
# sub-122_ses-01_run-1: sub-122_ses-01_task-Drive_run-1_events.tsv
# sub-122_ses-02_run-1: sub-122_ses-02_task-Drive_run-1_events.tsv
# sub-122_ses-03_run-1: sub-122_ses-03_task-Drive_run-1_events.tsv
# sub-122_ses-04_run-1: sub-122_ses-04_task-Drive_run-1_events.tsv
# sub-122_ses-05_run-1: sub-122_ses-05_task-Drive_run-1_events.tsv
# sub-122_ses-06_run-1: sub-122_ses-06_task-Drive_run-1_events.tsv
# sub-122_ses-07_run-1: sub-122_ses-07_task-Drive_run-1_events.tsv
# sub-123_ses-01_run-1: sub-123_ses-01_task-Drive_run-1_events.tsv
# sub-123_ses-02_run-1: sub-123_ses-02_task-Drive_run-1_events.tsv
# sub-123_ses-03_run-1: sub-123_ses-03_task-Drive_run-1_events.tsv
# sub-123_ses-04_run-1: sub-123_ses-04_task-Drive_run-1_events.tsv
# sub-123_ses-05_run-1: sub-123_ses-05_task-Drive_run-1_events.tsv
# sub-123_ses-06_run-1: sub-123_ses-06_task-Drive_run-1_events.tsv
# sub-124_ses-01_run-1: sub-124_ses-01_task-Drive_run-1_events.tsv
# sub-124_ses-02_run-1: sub-124_ses-02_task-Drive_run-1_events.tsv
# sub-124_ses-03_run-1: sub-124_ses-03_task-Drive_run-1_events.tsv
# sub-124_ses-04_run-1: sub-124_ses-04_task-Drive_run-1_events.tsv
# sub-124_ses-05_run-1: sub-124_ses-05_task-Drive_run-1_events.tsv
# sub-124_ses-06_run-1: sub-124_ses-06_task-Drive_run-1_events.tsv
# sub-124_ses-07_run-1: sub-124_ses-07_task-Drive_run-1_events.tsv
# sub-125_ses-01_run-1: sub-125_ses-01_task-Drive_run-1_events.tsv
# sub-125_ses-02_run-1: sub-125_ses-02_task-Drive_run-1_events.tsv
# sub-125_ses-03_run-1: sub-125_ses-03_task-Drive_run-1_events.tsv
# sub-125_ses-04_run-1: sub-125_ses-04_task-Drive_run-1_events.tsv
# sub-125_ses-05_run-1: sub-125_ses-05_task-Drive_run-1_events.tsv
# sub-125_ses-06_run-1: sub-125_ses-06_task-Drive_run-1_events.tsv
# sub-125_ses-07_run-1: sub-125_ses-07_task-Drive_run-1_events.tsv
# sub-126_ses-01_run-1: sub-126_ses-01_task-Drive_run-1_events.tsv
# sub-126_ses-02_run-1: sub-126_ses-02_task-Drive_run-1_events.tsv
# sub-126_ses-03_run-1: sub-126_ses-03_task-Drive_run-1_events.tsv
# sub-126_ses-04_run-1: sub-126_ses-04_task-Drive_run-1_events.tsv
# sub-126_ses-05_run-1: sub-126_ses-05_task-Drive_run-1_events.tsv
# sub-126_ses-06_run-1: sub-126_ses-06_task-Drive_run-1_events.tsv
# sub-127_ses-01_run-1: sub-127_ses-01_task-Drive_run-1_events.tsv
# sub-128_ses-01_run-1: sub-128_ses-01_task-Drive_run-1_events.tsv
# sub-128_ses-02_run-1: sub-128_ses-02_task-Drive_run-1_events.tsv
# sub-129_ses-01_run-1: sub-129_ses-01_task-Drive_run-1_events.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-Drive_run-1_events.tsv
# sub-130_ses-01_run-1: sub-130_ses-01_task-Drive_run-1_events.tsv
# sub-130_ses-02_run-1: sub-130_ses-02_task-Drive_run-1_events.tsv
# sub-131_ses-01_run-1: sub-131_ses-01_task-Drive_run-1_events.tsv
# sub-131_ses-02_run-1: sub-131_ses-02_task-Drive_run-1_events.tsv
# sub-132_ses-01_run-1: sub-132_ses-01_task-Drive_run-1_events.tsv
# sub-133_ses-01_run-1: sub-133_ses-01_task-Drive_run-1_events.tsv
# sub-133_ses-02_run-1: sub-133_ses-02_task-Drive_run-1_events.tsv
# sub-134_ses-01_run-1: sub-134_ses-01_task-Drive_run-1_events.tsv
# sub-135_ses-01_run-1: sub-135_ses-01_task-Drive_run-1_events.tsv
# sub-136_ses-01_run-1: sub-136_ses-01_task-Drive_run-1_events.tsv
# sub-137_ses-01_run-1: sub-137_ses-01_task-Drive_run-1_events.tsv
# sub-138_ses-01_run-1: sub-138_ses-01_task-Drive_run-1_events.tsv
# sub-139_ses-01_run-1: sub-139_ses-01_task-Drive_run-1_events.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-Drive_run-1_events.tsv
# sub-140_ses-01_run-1: sub-140_ses-01_task-Drive_run-1_events.tsv
# sub-140_ses-02_run-1: sub-140_ses-02_task-Drive_run-1_events.tsv
# sub-140_ses-03_run-1: sub-140_ses-03_task-Drive_run-1_events.tsv
# sub-141_ses-01_run-1: sub-141_ses-01_task-Drive_run-1_events.tsv
# sub-142_ses-01_run-1: sub-142_ses-01_task-Drive_run-1_events.tsv
# sub-143_ses-01_run-1: sub-143_ses-01_task-Drive_run-1_events.tsv
# sub-143_ses-02_run-1: sub-143_ses-02_task-Drive_run-1_events.tsv
# sub-144_ses-01_run-1: sub-144_ses-01_task-Drive_run-1_events.tsv
# sub-145_ses-01_run-1: sub-145_ses-01_task-Drive_run-1_events.tsv
# sub-146_ses-01_run-1: sub-146_ses-01_task-Drive_run-1_events.tsv
# sub-146_ses-02_run-1: sub-146_ses-02_task-Drive_run-1_events.tsv
# sub-147_ses-01_run-1: sub-147_ses-01_task-Drive_run-1_events.tsv
# sub-148_ses-01_run-1: sub-148_ses-01_task-Drive_run-1_events.tsv
# sub-149_ses-01_run-1: sub-149_ses-01_task-Drive_run-1_events.tsv
# sub-149_ses-02_run-1: sub-149_ses-02_task-Drive_run-1_events.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-Drive_run-1_events.tsv
# sub-150_ses-01_run-1: sub-150_ses-01_task-Drive_run-1_events.tsv
# sub-150_ses-02_run-1: sub-150_ses-02_task-Drive_run-1_events.tsv
# sub-151_ses-01_run-1: sub-151_ses-01_task-Drive_run-1_events.tsv
# sub-152_ses-01_run-1: sub-152_ses-01_task-Drive_run-1_events.tsv
# sub-153_ses-01_run-1: sub-153_ses-01_task-Drive_run-1_events.tsv
# sub-154_ses-01_run-1: sub-154_ses-01_task-Drive_run-1_events.tsv
# sub-155_ses-01_run-1: sub-155_ses-01_task-Drive_run-1_events.tsv
# sub-155_ses-02_run-1: sub-155_ses-02_task-Drive_run-1_events.tsv
# sub-156_ses-01_run-1: sub-156_ses-01_task-Drive_run-1_events.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-Drive_run-1_events.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-Drive_run-1_events.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-Drive_run-1_events.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-Drive_run-1_events.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-Drive_run-1_events.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-Drive_run-1_events.tsv
# sub-22_ses-01_run-1: sub-22_ses-01_task-Drive_run-1_events.tsv
# sub-23_ses-01_run-1: sub-23_ses-01_task-Drive_run-1_events.tsv
# sub-24_ses-01_run-1: sub-24_ses-01_task-Drive_run-1_events.tsv
# sub-25_ses-01_run-1: sub-25_ses-01_task-Drive_run-1_events.tsv
# sub-26_ses-01_run-1: sub-26_ses-01_task-Drive_run-1_events.tsv
# sub-27_ses-01_run-1: sub-27_ses-01_task-Drive_run-1_events.tsv
# sub-28_ses-01_run-1: sub-28_ses-01_task-Drive_run-1_events.tsv
# sub-29_ses-01_run-1: sub-29_ses-01_task-Drive_run-1_events.tsv
# sub-30_ses-01_run-1: sub-30_ses-01_task-Drive_run-1_events.tsv
# sub-31_ses-01_run-1: sub-31_ses-01_task-Drive_run-1_events.tsv
# sub-31_ses-02_run-1: sub-31_ses-02_task-Drive_run-1_events.tsv
# sub-32_ses-01_run-1: sub-32_ses-01_task-Drive_run-1_events.tsv
# sub-33_ses-01_run-1: sub-33_ses-01_task-Drive_run-1_events.tsv
# sub-33_ses-02_run-1: sub-33_ses-02_task-Drive_run-1_events.tsv
# sub-33_ses-03_run-1: sub-33_ses-03_task-Drive_run-1_events.tsv
# sub-34_ses-01_run-1: sub-34_ses-01_task-Drive_run-1_events.tsv
# sub-35_ses-01_run-1: sub-35_ses-01_task-Drive_run-1_events.tsv
# sub-36_ses-01_run-1: sub-36_ses-01_task-Drive_run-1_events.tsv
# sub-37_ses-01_run-1: sub-37_ses-01_task-Drive_run-1_events.tsv
# sub-38_ses-01_run-1: sub-38_ses-01_task-Drive_run-1_events.tsv
# sub-39_ses-01_run-1: sub-39_ses-01_task-Drive_run-1_events.tsv
# sub-40_ses-01_run-1: sub-40_ses-01_task-Drive_run-1_events.tsv
# sub-41_ses-01_run-1: sub-41_ses-01_task-Drive_run-1_events.tsv
# sub-42_ses-01_run-1: sub-42_ses-01_task-Drive_run-1_events.tsv
# sub-43_ses-01_run-1: sub-43_ses-01_task-Drive_run-1_events.tsv
# sub-44_ses-01_run-1: sub-44_ses-01_task-Drive_run-1_events.tsv
# sub-44_ses-02_run-1: sub-44_ses-02_task-Drive_run-1_events.tsv
# sub-45_ses-01_run-1: sub-45_ses-01_task-Drive_run-1_events.tsv
# sub-46_ses-01_run-1: sub-46_ses-01_task-Drive_run-1_events.tsv
# sub-47_ses-01_run-1: sub-47_ses-01_task-Drive_run-1_events.tsv
# sub-47_ses-02_run-1: sub-47_ses-02_task-Drive_run-1_events.tsv
# sub-48_ses-01_run-1: sub-48_ses-01_task-Drive_run-1_events.tsv
# sub-49_ses-01_run-1: sub-49_ses-01_task-Drive_run-1_events.tsv
# sub-50_ses-01_run-1: sub-50_ses-01_task-Drive_run-1_events.tsv
# sub-51_ses-01_run-1: sub-51_ses-01_task-Drive_run-1_events.tsv
# sub-52_ses-01_run-1: sub-52_ses-01_task-Drive_run-1_events.tsv
# sub-53_ses-01_run-1: sub-53_ses-01_task-Drive_run-1_events.tsv
# sub-54_ses-01_run-1: sub-54_ses-01_task-Drive_run-1_events.tsv
# sub-55_ses-01_run-1: sub-55_ses-01_task-Drive_run-1_events.tsv
# sub-56_ses-01_run-1: sub-56_ses-01_task-Drive_run-1_events.tsv
# sub-57_ses-01_run-1: sub-57_ses-01_task-Drive_run-1_events.tsv
# sub-58_ses-01_run-1: sub-58_ses-01_task-Drive_run-1_events.tsv
# sub-58_ses-02_run-1: sub-58_ses-02_task-Drive_run-1_events.tsv
# sub-58_ses-03_run-1: sub-58_ses-03_task-Drive_run-1_events.tsv
# sub-59_ses-01_run-1: sub-59_ses-01_task-Drive_run-1_events.tsv
# sub-59_ses-02_run-1: sub-59_ses-02_task-Drive_run-1_events.tsv
# sub-59_ses-03_run-1: sub-59_ses-03_task-Drive_run-1_events.tsv
# sub-60_ses-01_run-1: sub-60_ses-01_task-Drive_run-1_events.tsv
# sub-61_ses-01_run-1: sub-61_ses-01_task-Drive_run-1_events.tsv
# sub-61_ses-02_run-1: sub-61_ses-02_task-Drive_run-1_events.tsv
# sub-62_ses-01_run-1: sub-62_ses-01_task-Drive_run-1_events.tsv
# sub-63_ses-01_run-1: sub-63_ses-01_task-Drive_run-1_events.tsv
# sub-63_ses-02_run-1: sub-63_ses-02_task-Drive_run-1_events.tsv
# sub-63_ses-03_run-1: sub-63_ses-03_task-Drive_run-1_events.tsv
# sub-64_ses-01_run-1: sub-64_ses-01_task-Drive_run-1_events.tsv
# sub-65_ses-01_run-1: sub-65_ses-01_task-Drive_run-1_events.tsv
# sub-66_ses-01_run-1: sub-66_ses-01_task-Drive_run-1_events.tsv
# sub-66_ses-02_run-1: sub-66_ses-02_task-Drive_run-1_events.tsv
# sub-66_ses-03_run-1: sub-66_ses-03_task-Drive_run-1_events.tsv
# sub-67_ses-01_run-1: sub-67_ses-01_task-Drive_run-1_events.tsv
# sub-68_ses-01_run-1: sub-68_ses-01_task-Drive_run-1_events.tsv
# sub-69_ses-01_run-1: sub-69_ses-01_task-Drive_run-1_events.tsv
# sub-70_ses-01_run-1: sub-70_ses-01_task-Drive_run-1_events.tsv
# sub-70_ses-02_run-1: sub-70_ses-02_task-Drive_run-1_events.tsv
# sub-70_ses-03_run-1: sub-70_ses-03_task-Drive_run-1_events.tsv
# sub-71_ses-01_run-1: sub-71_ses-01_task-Drive_run-1_events.tsv
# sub-71_ses-02_run-1: sub-71_ses-02_task-Drive_run-1_events.tsv
# sub-71_ses-03_run-1: sub-71_ses-03_task-Drive_run-1_events.tsv
# sub-72_ses-01_run-1: sub-72_ses-01_task-Drive_run-1_events.tsv
# sub-73_ses-01_run-1: sub-73_ses-01_task-Drive_run-1_events.tsv
# sub-74_ses-01_run-1: sub-74_ses-01_task-Drive_run-1_events.tsv
# sub-75_ses-01_run-1: sub-75_ses-01_task-Drive_run-1_events.tsv
# sub-76_ses-01_run-1: sub-76_ses-01_task-Drive_run-1_events.tsv
# sub-76_ses-02_run-1: sub-76_ses-02_task-Drive_run-1_events.tsv
# sub-76_ses-03_run-1: sub-76_ses-03_task-Drive_run-1_events.tsv
# sub-77_ses-01_run-1: sub-77_ses-01_task-Drive_run-1_events.tsv
# sub-78_ses-01_run-1: sub-78_ses-01_task-Drive_run-1_events.tsv
# sub-78_ses-02_run-1: sub-78_ses-02_task-Drive_run-1_events.tsv
# sub-78_ses-03_run-1: sub-78_ses-03_task-Drive_run-1_events.tsv
# sub-79_ses-01_run-1: sub-79_ses-01_task-Drive_run-1_events.tsv
# sub-80_ses-01_run-1: sub-80_ses-01_task-Drive_run-1_events.tsv
# sub-81_ses-01_run-1: sub-81_ses-01_task-Drive_run-1_events.tsv
# sub-82_ses-01_run-1: sub-82_ses-01_task-Drive_run-1_events.tsv
# sub-83_ses-01_run-1: sub-83_ses-01_task-Drive_run-1_events.tsv
# sub-84_ses-01_run-1: sub-84_ses-01_task-Drive_run-1_events.tsv
# sub-85_ses-01_run-1: sub-85_ses-01_task-Drive_run-1_events.tsv
# sub-86_ses-01_run-1: sub-86_ses-01_task-Drive_run-1_events.tsv
# sub-87_ses-01_run-1: sub-87_ses-01_task-Drive_run-1_events.tsv
# sub-88_ses-01_run-1: sub-88_ses-01_task-Drive_run-1_events.tsv
# sub-89_ses-01_run-1: sub-89_ses-01_task-Drive_run-1_events.tsv
# sub-90_ses-01_run-1: sub-90_ses-01_task-Drive_run-1_events.tsv
# sub-91_ses-01_run-1: sub-91_ses-01_task-Drive_run-1_events.tsv
# sub-92_ses-01_run-1: sub-92_ses-01_task-Drive_run-1_events.tsv
# sub-93_ses-01_run-1: sub-93_ses-01_task-Drive_run-1_events.tsv
# sub-94_ses-01_run-1: sub-94_ses-01_task-Drive_run-1_events.tsv
# sub-95_ses-01_run-1: sub-95_ses-01_task-Drive_run-1_events.tsv
# sub-96_ses-01_run-1: sub-96_ses-01_task-Drive_run-1_events.tsv
# sub-97_ses-01_run-1: sub-97_ses-01_task-Drive_run-1_events.tsv
# sub-98_ses-01_run-1: sub-98_ses-01_task-Drive_run-1_events.tsv
# sub-99_ses-01_run-1: sub-99_ses-01_task-Drive_run-1_events.tsv
#
# EEG.event style event files (247 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-Drive_run-1_events_temp.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-Drive_run-1_events_temp.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-Drive_run-1_events_temp.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-Drive_run-1_events_temp.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-Drive_run-1_events_temp.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-Drive_run-1_events_temp.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-Drive_run-1_events_temp.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-Drive_run-1_events_temp.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-Drive_run-1_events_temp.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-Drive_run-1_events_temp.tsv
# sub-100_ses-01_run-1: sub-100_ses-01_task-Drive_run-1_events_temp.tsv
# sub-100_ses-02_run-1: sub-100_ses-02_task-Drive_run-1_events_temp.tsv
# sub-100_ses-03_run-1: sub-100_ses-03_task-Drive_run-1_events_temp.tsv
# sub-100_ses-04_run-1: sub-100_ses-04_task-Drive_run-1_events_temp.tsv
# sub-100_ses-05_run-1: sub-100_ses-05_task-Drive_run-1_events_temp.tsv
# sub-100_ses-06_run-1: sub-100_ses-06_task-Drive_run-1_events_temp.tsv
# sub-100_ses-07_run-1: sub-100_ses-07_task-Drive_run-1_events_temp.tsv
# sub-101_ses-01_run-1: sub-101_ses-01_task-Drive_run-1_events_temp.tsv
# sub-102_ses-01_run-1: sub-102_ses-01_task-Drive_run-1_events_temp.tsv
# sub-103_ses-01_run-1: sub-103_ses-01_task-Drive_run-1_events_temp.tsv
# sub-104_ses-01_run-1: sub-104_ses-01_task-Drive_run-1_events_temp.tsv
# sub-105_ses-01_run-1: sub-105_ses-01_task-Drive_run-1_events_temp.tsv
# sub-106_ses-01_run-1: sub-106_ses-01_task-Drive_run-1_events_temp.tsv
# sub-106_ses-02_run-1: sub-106_ses-02_task-Drive_run-1_events_temp.tsv
# sub-107_ses-01_run-1: sub-107_ses-01_task-Drive_run-1_events_temp.tsv
# sub-108_ses-01_run-1: sub-108_ses-01_task-Drive_run-1_events_temp.tsv
# sub-109_ses-01_run-1: sub-109_ses-01_task-Drive_run-1_events_temp.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-Drive_run-1_events_temp.tsv
# sub-110_ses-01_run-1: sub-110_ses-01_task-Drive_run-1_events_temp.tsv
# sub-111_ses-01_run-1: sub-111_ses-01_task-Drive_run-1_events_temp.tsv
# sub-112_ses-01_run-1: sub-112_ses-01_task-Drive_run-1_events_temp.tsv
# sub-112_ses-02_run-1: sub-112_ses-02_task-Drive_run-1_events_temp.tsv
# sub-112_ses-03_run-1: sub-112_ses-03_task-Drive_run-1_events_temp.tsv
# sub-112_ses-04_run-1: sub-112_ses-04_task-Drive_run-1_events_temp.tsv
# sub-112_ses-05_run-1: sub-112_ses-05_task-Drive_run-1_events_temp.tsv
# sub-112_ses-06_run-1: sub-112_ses-06_task-Drive_run-1_events_temp.tsv
# sub-112_ses-07_run-1: sub-112_ses-07_task-Drive_run-1_events_temp.tsv
# sub-113_ses-01_run-1: sub-113_ses-01_task-Drive_run-1_events_temp.tsv
# sub-114_ses-01_run-1: sub-114_ses-01_task-Drive_run-1_events_temp.tsv
# sub-115_ses-01_run-1: sub-115_ses-01_task-Drive_run-1_events_temp.tsv
# sub-116_ses-01_run-1: sub-116_ses-01_task-Drive_run-1_events_temp.tsv
# sub-117_ses-01_run-1: sub-117_ses-01_task-Drive_run-1_events_temp.tsv
# sub-117_ses-02_run-1: sub-117_ses-02_task-Drive_run-1_events_temp.tsv
# sub-117_ses-03_run-1: sub-117_ses-03_task-Drive_run-1_events_temp.tsv
# sub-117_ses-04_run-1: sub-117_ses-04_task-Drive_run-1_events_temp.tsv
# sub-117_ses-05_run-1: sub-117_ses-05_task-Drive_run-1_events_temp.tsv
# sub-117_ses-06_run-1: sub-117_ses-06_task-Drive_run-1_events_temp.tsv
# sub-118_ses-01_run-1: sub-118_ses-01_task-Drive_run-1_events_temp.tsv
# sub-119_ses-01_run-1: sub-119_ses-01_task-Drive_run-1_events_temp.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-Drive_run-1_events_temp.tsv
# sub-120_ses-01_run-1: sub-120_ses-01_task-Drive_run-1_events_temp.tsv
# sub-120_ses-02_run-1: sub-120_ses-02_task-Drive_run-1_events_temp.tsv
# sub-120_ses-03_run-1: sub-120_ses-03_task-Drive_run-1_events_temp.tsv
# sub-120_ses-04_run-1: sub-120_ses-04_task-Drive_run-1_events_temp.tsv
# sub-120_ses-05_run-1: sub-120_ses-05_task-Drive_run-1_events_temp.tsv
# sub-120_ses-06_run-1: sub-120_ses-06_task-Drive_run-1_events_temp.tsv
# sub-120_ses-07_run-1: sub-120_ses-07_task-Drive_run-1_events_temp.tsv
# sub-121_ses-01_run-1: sub-121_ses-01_task-Drive_run-1_events_temp.tsv
# sub-121_ses-02_run-1: sub-121_ses-02_task-Drive_run-1_events_temp.tsv
# sub-121_ses-03_run-1: sub-121_ses-03_task-Drive_run-1_events_temp.tsv
# sub-121_ses-04_run-1: sub-121_ses-04_task-Drive_run-1_events_temp.tsv
# sub-121_ses-05_run-1: sub-121_ses-05_task-Drive_run-1_events_temp.tsv
# sub-121_ses-06_run-1: sub-121_ses-06_task-Drive_run-1_events_temp.tsv
# sub-121_ses-07_run-1: sub-121_ses-07_task-Drive_run-1_events_temp.tsv
# sub-122_ses-01_run-1: sub-122_ses-01_task-Drive_run-1_events_temp.tsv
# sub-122_ses-02_run-1: sub-122_ses-02_task-Drive_run-1_events_temp.tsv
# sub-122_ses-03_run-1: sub-122_ses-03_task-Drive_run-1_events_temp.tsv
# sub-122_ses-04_run-1: sub-122_ses-04_task-Drive_run-1_events_temp.tsv
# sub-122_ses-05_run-1: sub-122_ses-05_task-Drive_run-1_events_temp.tsv
# sub-122_ses-06_run-1: sub-122_ses-06_task-Drive_run-1_events_temp.tsv
# sub-122_ses-07_run-1: sub-122_ses-07_task-Drive_run-1_events_temp.tsv
# sub-123_ses-01_run-1: sub-123_ses-01_task-Drive_run-1_events_temp.tsv
# sub-123_ses-02_run-1: sub-123_ses-02_task-Drive_run-1_events_temp.tsv
# sub-123_ses-03_run-1: sub-123_ses-03_task-Drive_run-1_events_temp.tsv
# sub-123_ses-04_run-1: sub-123_ses-04_task-Drive_run-1_events_temp.tsv
# sub-123_ses-05_run-1: sub-123_ses-05_task-Drive_run-1_events_temp.tsv
# sub-123_ses-06_run-1: sub-123_ses-06_task-Drive_run-1_events_temp.tsv
# sub-124_ses-01_run-1: sub-124_ses-01_task-Drive_run-1_events_temp.tsv
# sub-124_ses-02_run-1: sub-124_ses-02_task-Drive_run-1_events_temp.tsv
# sub-124_ses-03_run-1: sub-124_ses-03_task-Drive_run-1_events_temp.tsv
# sub-124_ses-04_run-1: sub-124_ses-04_task-Drive_run-1_events_temp.tsv
# sub-124_ses-05_run-1: sub-124_ses-05_task-Drive_run-1_events_temp.tsv
# sub-124_ses-06_run-1: sub-124_ses-06_task-Drive_run-1_events_temp.tsv
# sub-124_ses-07_run-1: sub-124_ses-07_task-Drive_run-1_events_temp.tsv
# sub-125_ses-01_run-1: sub-125_ses-01_task-Drive_run-1_events_temp.tsv
# sub-125_ses-02_run-1: sub-125_ses-02_task-Drive_run-1_events_temp.tsv
# sub-125_ses-03_run-1: sub-125_ses-03_task-Drive_run-1_events_temp.tsv
# sub-125_ses-04_run-1: sub-125_ses-04_task-Drive_run-1_events_temp.tsv
# sub-125_ses-05_run-1: sub-125_ses-05_task-Drive_run-1_events_temp.tsv
# sub-125_ses-06_run-1: sub-125_ses-06_task-Drive_run-1_events_temp.tsv
# sub-125_ses-07_run-1: sub-125_ses-07_task-Drive_run-1_events_temp.tsv
# sub-126_ses-01_run-1: sub-126_ses-01_task-Drive_run-1_events_temp.tsv
# sub-126_ses-02_run-1: sub-126_ses-02_task-Drive_run-1_events_temp.tsv
# sub-126_ses-03_run-1: sub-126_ses-03_task-Drive_run-1_events_temp.tsv
# sub-126_ses-04_run-1: sub-126_ses-04_task-Drive_run-1_events_temp.tsv
# sub-126_ses-05_run-1: sub-126_ses-05_task-Drive_run-1_events_temp.tsv
# sub-126_ses-06_run-1: sub-126_ses-06_task-Drive_run-1_events_temp.tsv
# sub-127_ses-01_run-1: sub-127_ses-01_task-Drive_run-1_events_temp.tsv
# sub-128_ses-01_run-1: sub-128_ses-01_task-Drive_run-1_events_temp.tsv
# sub-128_ses-02_run-1: sub-128_ses-02_task-Drive_run-1_events_temp.tsv
# sub-129_ses-01_run-1: sub-129_ses-01_task-Drive_run-1_events_temp.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-Drive_run-1_events_temp.tsv
# sub-130_ses-01_run-1: sub-130_ses-01_task-Drive_run-1_events_temp.tsv
# sub-130_ses-02_run-1: sub-130_ses-02_task-Drive_run-1_events_temp.tsv
# sub-131_ses-01_run-1: sub-131_ses-01_task-Drive_run-1_events_temp.tsv
# sub-131_ses-02_run-1: sub-131_ses-02_task-Drive_run-1_events_temp.tsv
# sub-132_ses-01_run-1: sub-132_ses-01_task-Drive_run-1_events_temp.tsv
# sub-133_ses-01_run-1: sub-133_ses-01_task-Drive_run-1_events_temp.tsv
# sub-133_ses-02_run-1: sub-133_ses-02_task-Drive_run-1_events_temp.tsv
# sub-134_ses-01_run-1: sub-134_ses-01_task-Drive_run-1_events_temp.tsv
# sub-135_ses-01_run-1: sub-135_ses-01_task-Drive_run-1_events_temp.tsv
# sub-136_ses-01_run-1: sub-136_ses-01_task-Drive_run-1_events_temp.tsv
# sub-137_ses-01_run-1: sub-137_ses-01_task-Drive_run-1_events_temp.tsv
# sub-138_ses-01_run-1: sub-138_ses-01_task-Drive_run-1_events_temp.tsv
# sub-139_ses-01_run-1: sub-139_ses-01_task-Drive_run-1_events_temp.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-Drive_run-1_events_temp.tsv
# sub-140_ses-01_run-1: sub-140_ses-01_task-Drive_run-1_events_temp.tsv
# sub-140_ses-02_run-1: sub-140_ses-02_task-Drive_run-1_events_temp.tsv
# sub-140_ses-03_run-1: sub-140_ses-03_task-Drive_run-1_events_temp.tsv
# sub-141_ses-01_run-1: sub-141_ses-01_task-Drive_run-1_events_temp.tsv
# sub-142_ses-01_run-1: sub-142_ses-01_task-Drive_run-1_events_temp.tsv
# sub-143_ses-01_run-1: sub-143_ses-01_task-Drive_run-1_events_temp.tsv
# sub-143_ses-02_run-1: sub-143_ses-02_task-Drive_run-1_events_temp.tsv
# sub-144_ses-01_run-1: sub-144_ses-01_task-Drive_run-1_events_temp.tsv
# sub-145_ses-01_run-1: sub-145_ses-01_task-Drive_run-1_events_temp.tsv
# sub-146_ses-01_run-1: sub-146_ses-01_task-Drive_run-1_events_temp.tsv
# sub-146_ses-02_run-1: sub-146_ses-02_task-Drive_run-1_events_temp.tsv
# sub-147_ses-01_run-1: sub-147_ses-01_task-Drive_run-1_events_temp.tsv
# sub-148_ses-01_run-1: sub-148_ses-01_task-Drive_run-1_events_temp.tsv
# sub-149_ses-01_run-1: sub-149_ses-01_task-Drive_run-1_events_temp.tsv
# sub-149_ses-02_run-1: sub-149_ses-02_task-Drive_run-1_events_temp.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-Drive_run-1_events_temp.tsv
# sub-150_ses-01_run-1: sub-150_ses-01_task-Drive_run-1_events_temp.tsv
# sub-150_ses-02_run-1: sub-150_ses-02_task-Drive_run-1_events_temp.tsv
# sub-151_ses-01_run-1: sub-151_ses-01_task-Drive_run-1_events_temp.tsv
# sub-152_ses-01_run-1: sub-152_ses-01_task-Drive_run-1_events_temp.tsv
# sub-153_ses-01_run-1: sub-153_ses-01_task-Drive_run-1_events_temp.tsv
# sub-154_ses-01_run-1: sub-154_ses-01_task-Drive_run-1_events_temp.tsv
# sub-155_ses-01_run-1: sub-155_ses-01_task-Drive_run-1_events_temp.tsv
# sub-155_ses-02_run-1: sub-155_ses-02_task-Drive_run-1_events_temp.tsv
# sub-156_ses-01_run-1: sub-156_ses-01_task-Drive_run-1_events_temp.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-Drive_run-1_events_temp.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-Drive_run-1_events_temp.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-Drive_run-1_events_temp.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-Drive_run-1_events_temp.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-Drive_run-1_events_temp.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-Drive_run-1_events_temp.tsv
# sub-22_ses-01_run-1: sub-22_ses-01_task-Drive_run-1_events_temp.tsv
# sub-23_ses-01_run-1: sub-23_ses-01_task-Drive_run-1_events_temp.tsv
# sub-24_ses-01_run-1: sub-24_ses-01_task-Drive_run-1_events_temp.tsv
# sub-25_ses-01_run-1: sub-25_ses-01_task-Drive_run-1_events_temp.tsv
# sub-26_ses-01_run-1: sub-26_ses-01_task-Drive_run-1_events_temp.tsv
# sub-27_ses-01_run-1: sub-27_ses-01_task-Drive_run-1_events_temp.tsv
# sub-28_ses-01_run-1: sub-28_ses-01_task-Drive_run-1_events_temp.tsv
# sub-29_ses-01_run-1: sub-29_ses-01_task-Drive_run-1_events_temp.tsv
# sub-30_ses-01_run-1: sub-30_ses-01_task-Drive_run-1_events_temp.tsv
# sub-31_ses-01_run-1: sub-31_ses-01_task-Drive_run-1_events_temp.tsv
# sub-31_ses-02_run-1: sub-31_ses-02_task-Drive_run-1_events_temp.tsv
# sub-32_ses-01_run-1: sub-32_ses-01_task-Drive_run-1_events_temp.tsv
# sub-33_ses-01_run-1: sub-33_ses-01_task-Drive_run-1_events_temp.tsv
# sub-33_ses-02_run-1: sub-33_ses-02_task-Drive_run-1_events_temp.tsv
# sub-33_ses-03_run-1: sub-33_ses-03_task-Drive_run-1_events_temp.tsv
# sub-34_ses-01_run-1: sub-34_ses-01_task-Drive_run-1_events_temp.tsv
# sub-35_ses-01_run-1: sub-35_ses-01_task-Drive_run-1_events_temp.tsv
# sub-36_ses-01_run-1: sub-36_ses-01_task-Drive_run-1_events_temp.tsv
# sub-37_ses-01_run-1: sub-37_ses-01_task-Drive_run-1_events_temp.tsv
# sub-38_ses-01_run-1: sub-38_ses-01_task-Drive_run-1_events_temp.tsv
# sub-39_ses-01_run-1: sub-39_ses-01_task-Drive_run-1_events_temp.tsv
# sub-40_ses-01_run-1: sub-40_ses-01_task-Drive_run-1_events_temp.tsv
# sub-41_ses-01_run-1: sub-41_ses-01_task-Drive_run-1_events_temp.tsv
# sub-42_ses-01_run-1: sub-42_ses-01_task-Drive_run-1_events_temp.tsv
# sub-43_ses-01_run-1: sub-43_ses-01_task-Drive_run-1_events_temp.tsv
# sub-44_ses-01_run-1: sub-44_ses-01_task-Drive_run-1_events_temp.tsv
# sub-44_ses-02_run-1: sub-44_ses-02_task-Drive_run-1_events_temp.tsv
# sub-45_ses-01_run-1: sub-45_ses-01_task-Drive_run-1_events_temp.tsv
# sub-46_ses-01_run-1: sub-46_ses-01_task-Drive_run-1_events_temp.tsv
# sub-47_ses-01_run-1: sub-47_ses-01_task-Drive_run-1_events_temp.tsv
# sub-47_ses-02_run-1: sub-47_ses-02_task-Drive_run-1_events_temp.tsv
# sub-48_ses-01_run-1: sub-48_ses-01_task-Drive_run-1_events_temp.tsv
# sub-49_ses-01_run-1: sub-49_ses-01_task-Drive_run-1_events_temp.tsv
# sub-50_ses-01_run-1: sub-50_ses-01_task-Drive_run-1_events_temp.tsv
# sub-51_ses-01_run-1: sub-51_ses-01_task-Drive_run-1_events_temp.tsv
# sub-52_ses-01_run-1: sub-52_ses-01_task-Drive_run-1_events_temp.tsv
# sub-53_ses-01_run-1: sub-53_ses-01_task-Drive_run-1_events_temp.tsv
# sub-54_ses-01_run-1: sub-54_ses-01_task-Drive_run-1_events_temp.tsv
# sub-55_ses-01_run-1: sub-55_ses-01_task-Drive_run-1_events_temp.tsv
# sub-56_ses-01_run-1: sub-56_ses-01_task-Drive_run-1_events_temp.tsv
# sub-57_ses-01_run-1: sub-57_ses-01_task-Drive_run-1_events_temp.tsv
# sub-58_ses-01_run-1: sub-58_ses-01_task-Drive_run-1_events_temp.tsv
# sub-58_ses-02_run-1: sub-58_ses-02_task-Drive_run-1_events_temp.tsv
# sub-58_ses-03_run-1: sub-58_ses-03_task-Drive_run-1_events_temp.tsv
# sub-59_ses-01_run-1: sub-59_ses-01_task-Drive_run-1_events_temp.tsv
# sub-59_ses-02_run-1: sub-59_ses-02_task-Drive_run-1_events_temp.tsv
# sub-59_ses-03_run-1: sub-59_ses-03_task-Drive_run-1_events_temp.tsv
# sub-60_ses-01_run-1: sub-60_ses-01_task-Drive_run-1_events_temp.tsv
# sub-61_ses-01_run-1: sub-61_ses-01_task-Drive_run-1_events_temp.tsv
# sub-61_ses-02_run-1: sub-61_ses-02_task-Drive_run-1_events_temp.tsv
# sub-62_ses-01_run-1: sub-62_ses-01_task-Drive_run-1_events_temp.tsv
# sub-63_ses-01_run-1: sub-63_ses-01_task-Drive_run-1_events_temp.tsv
# sub-63_ses-02_run-1: sub-63_ses-02_task-Drive_run-1_events_temp.tsv
# sub-63_ses-03_run-1: sub-63_ses-03_task-Drive_run-1_events_temp.tsv
# sub-64_ses-01_run-1: sub-64_ses-01_task-Drive_run-1_events_temp.tsv
# sub-65_ses-01_run-1: sub-65_ses-01_task-Drive_run-1_events_temp.tsv
# sub-66_ses-01_run-1: sub-66_ses-01_task-Drive_run-1_events_temp.tsv
# sub-66_ses-02_run-1: sub-66_ses-02_task-Drive_run-1_events_temp.tsv
# sub-66_ses-03_run-1: sub-66_ses-03_task-Drive_run-1_events_temp.tsv
# sub-67_ses-01_run-1: sub-67_ses-01_task-Drive_run-1_events_temp.tsv
# sub-68_ses-01_run-1: sub-68_ses-01_task-Drive_run-1_events_temp.tsv
# sub-69_ses-01_run-1: sub-69_ses-01_task-Drive_run-1_events_temp.tsv
# sub-70_ses-01_run-1: sub-70_ses-01_task-Drive_run-1_events_temp.tsv
# sub-70_ses-02_run-1: sub-70_ses-02_task-Drive_run-1_events_temp.tsv
# sub-70_ses-03_run-1: sub-70_ses-03_task-Drive_run-1_events_temp.tsv
# sub-71_ses-01_run-1: sub-71_ses-01_task-Drive_run-1_events_temp.tsv
# sub-71_ses-02_run-1: sub-71_ses-02_task-Drive_run-1_events_temp.tsv
# sub-71_ses-03_run-1: sub-71_ses-03_task-Drive_run-1_events_temp.tsv
# sub-72_ses-01_run-1: sub-72_ses-01_task-Drive_run-1_events_temp.tsv
# sub-73_ses-01_run-1: sub-73_ses-01_task-Drive_run-1_events_temp.tsv
# sub-74_ses-01_run-1: sub-74_ses-01_task-Drive_run-1_events_temp.tsv
# sub-75_ses-01_run-1: sub-75_ses-01_task-Drive_run-1_events_temp.tsv
# sub-76_ses-01_run-1: sub-76_ses-01_task-Drive_run-1_events_temp.tsv
# sub-76_ses-02_run-1: sub-76_ses-02_task-Drive_run-1_events_temp.tsv
# sub-76_ses-03_run-1: sub-76_ses-03_task-Drive_run-1_events_temp.tsv
# sub-77_ses-01_run-1: sub-77_ses-01_task-Drive_run-1_events_temp.tsv
# sub-78_ses-01_run-1: sub-78_ses-01_task-Drive_run-1_events_temp.tsv
# sub-78_ses-02_run-1: sub-78_ses-02_task-Drive_run-1_events_temp.tsv
# sub-78_ses-03_run-1: sub-78_ses-03_task-Drive_run-1_events_temp.tsv
# sub-79_ses-01_run-1: sub-79_ses-01_task-Drive_run-1_events_temp.tsv
# sub-80_ses-01_run-1: sub-80_ses-01_task-Drive_run-1_events_temp.tsv
# sub-81_ses-01_run-1: sub-81_ses-01_task-Drive_run-1_events_temp.tsv
# sub-82_ses-01_run-1: sub-82_ses-01_task-Drive_run-1_events_temp.tsv
# sub-83_ses-01_run-1: sub-83_ses-01_task-Drive_run-1_events_temp.tsv
# sub-84_ses-01_run-1: sub-84_ses-01_task-Drive_run-1_events_temp.tsv
# sub-85_ses-01_run-1: sub-85_ses-01_task-Drive_run-1_events_temp.tsv
# sub-86_ses-01_run-1: sub-86_ses-01_task-Drive_run-1_events_temp.tsv
# sub-87_ses-01_run-1: sub-87_ses-01_task-Drive_run-1_events_temp.tsv
# sub-88_ses-01_run-1: sub-88_ses-01_task-Drive_run-1_events_temp.tsv
# sub-89_ses-01_run-1: sub-89_ses-01_task-Drive_run-1_events_temp.tsv
# sub-90_ses-01_run-1: sub-90_ses-01_task-Drive_run-1_events_temp.tsv
# sub-91_ses-01_run-1: sub-91_ses-01_task-Drive_run-1_events_temp.tsv
# sub-92_ses-01_run-1: sub-92_ses-01_task-Drive_run-1_events_temp.tsv
# sub-93_ses-01_run-1: sub-93_ses-01_task-Drive_run-1_events_temp.tsv
# sub-94_ses-01_run-1: sub-94_ses-01_task-Drive_run-1_events_temp.tsv
# sub-95_ses-01_run-1: sub-95_ses-01_task-Drive_run-1_events_temp.tsv
# sub-96_ses-01_run-1: sub-96_ses-01_task-Drive_run-1_events_temp.tsv
# sub-97_ses-01_run-1: sub-97_ses-01_task-Drive_run-1_events_temp.tsv
# sub-98_ses-01_run-1: sub-98_ses-01_task-Drive_run-1_events_temp.tsv
# sub-99_ses-01_run-1: sub-99_ses-01_task-Drive_run-1_events_temp.tsv

# %%
key_diff = bids_dict.key_diffs(eeg_dict)
print(f"Key differences between EEG and BIDS events: {str(key_diff)}")
# Out:
# Key differences between EEG and BIDS events: []

# %%
print(f"\nBIDS style event file columns:")
for key, file, rowcount, columns in bids_dict.iter_tsv_info():
    print(f"{key} [{rowcount} events]: {str(columns)}")

print(f"\nEEG.event style event file columns:")
for key, file, rowcount, columns in eeg_dict.iter_tsv_info():
    print(f"{key} [{rowcount} events]: {str(columns)}")
# Out:
# BIDS style event file columns:
# sub-01_ses-01_run-1 [292 events]: ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-1 [348 events]: ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-1 [287 events]: ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-1 [313 events]: ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-1 [277 events]: ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-1 [273 events]: ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-1 [285 events]: ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-1 [285 events]: ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-1 [366 events]: ['onset', 'duration', 'event_code']
# sub-10_ses-01_run-1 [367 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-01_run-1 [379 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-02_run-1 [355 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-03_run-1 [363 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-04_run-1 [353 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-05_run-1 [350 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-06_run-1 [348 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-07_run-1 [331 events]: ['onset', 'duration', 'event_code']
# sub-101_ses-01_run-1 [363 events]: ['onset', 'duration', 'event_code']
# sub-102_ses-01_run-1 [367 events]: ['onset', 'duration', 'event_code']
# sub-103_ses-01_run-1 [384 events]: ['onset', 'duration', 'event_code']
# sub-104_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-105_ses-01_run-1 [355 events]: ['onset', 'duration', 'event_code']
# sub-106_ses-01_run-1 [418 events]: ['onset', 'duration', 'event_code']
# sub-106_ses-02_run-1 [374 events]: ['onset', 'duration', 'event_code']
# sub-107_ses-01_run-1 [352 events]: ['onset', 'duration', 'event_code']
# sub-108_ses-01_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-109_ses-01_run-1 [365 events]: ['onset', 'duration', 'event_code']
# sub-11_ses-01_run-1 [366 events]: ['onset', 'duration', 'event_code']
# sub-110_ses-01_run-1 [373 events]: ['onset', 'duration', 'event_code']
# sub-111_ses-01_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-01_run-1 [375 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-02_run-1 [449 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-03_run-1 [433 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-04_run-1 [432 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-05_run-1 [457 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-06_run-1 [447 events]: ['onset', 'duration', 'event_code']
# sub-112_ses-07_run-1 [415 events]: ['onset', 'duration', 'event_code']
# sub-113_ses-01_run-1 [355 events]: ['onset', 'duration', 'event_code']
# sub-114_ses-01_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-115_ses-01_run-1 [399 events]: ['onset', 'duration', 'event_code']
# sub-116_ses-01_run-1 [373 events]: ['onset', 'duration', 'event_code']
# sub-117_ses-01_run-1 [389 events]: ['onset', 'duration', 'event_code']
# sub-117_ses-02_run-1 [403 events]: ['onset', 'duration', 'event_code']
# sub-117_ses-03_run-1 [380 events]: ['onset', 'duration', 'event_code']
# sub-117_ses-04_run-1 [400 events]: ['onset', 'duration', 'event_code']
# sub-117_ses-05_run-1 [367 events]: ['onset', 'duration', 'event_code']
# sub-117_ses-06_run-1 [414 events]: ['onset', 'duration', 'event_code']
# sub-118_ses-01_run-1 [363 events]: ['onset', 'duration', 'event_code']
# sub-119_ses-01_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-12_ses-01_run-1 [375 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-01_run-1 [367 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-02_run-1 [363 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-03_run-1 [365 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-04_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-05_run-1 [359 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-06_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-120_ses-07_run-1 [371 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-02_run-1 [375 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-03_run-1 [379 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-04_run-1 [371 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-05_run-1 [370 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-06_run-1 [349 events]: ['onset', 'duration', 'event_code']
# sub-121_ses-07_run-1 [375 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-01_run-1 [415 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-02_run-1 [407 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-03_run-1 [410 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-04_run-1 [405 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-05_run-1 [406 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-06_run-1 [419 events]: ['onset', 'duration', 'event_code']
# sub-122_ses-07_run-1 [435 events]: ['onset', 'duration', 'event_code']
# sub-123_ses-01_run-1 [388 events]: ['onset', 'duration', 'event_code']
# sub-123_ses-02_run-1 [346 events]: ['onset', 'duration', 'event_code']
# sub-123_ses-03_run-1 [353 events]: ['onset', 'duration', 'event_code']
# sub-123_ses-04_run-1 [351 events]: ['onset', 'duration', 'event_code']
# sub-123_ses-05_run-1 [340 events]: ['onset', 'duration', 'event_code']
# sub-123_ses-06_run-1 [314 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-01_run-1 [363 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-02_run-1 [369 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-03_run-1 [388 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-04_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-05_run-1 [390 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-06_run-1 [368 events]: ['onset', 'duration', 'event_code']
# sub-124_ses-07_run-1 [381 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-01_run-1 [380 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-02_run-1 [381 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-03_run-1 [391 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-04_run-1 [379 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-05_run-1 [402 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-06_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-125_ses-07_run-1 [393 events]: ['onset', 'duration', 'event_code']
# sub-126_ses-01_run-1 [365 events]: ['onset', 'duration', 'event_code']
# sub-126_ses-02_run-1 [365 events]: ['onset', 'duration', 'event_code']
# sub-126_ses-03_run-1 [365 events]: ['onset', 'duration', 'event_code']
# sub-126_ses-04_run-1 [364 events]: ['onset', 'duration', 'event_code']
# sub-126_ses-05_run-1 [353 events]: ['onset', 'duration', 'event_code']
# sub-126_ses-06_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-127_ses-01_run-1 [374 events]: ['onset', 'duration', 'event_code']
# sub-128_ses-01_run-1 [358 events]: ['onset', 'duration', 'event_code']
# sub-128_ses-02_run-1 [367 events]: ['onset', 'duration', 'event_code']
# sub-129_ses-01_run-1 [397 events]: ['onset', 'duration', 'event_code']
# sub-13_ses-01_run-1 [385 events]: ['onset', 'duration', 'event_code']
# sub-130_ses-01_run-1 [374 events]: ['onset', 'duration', 'event_code']
# sub-130_ses-02_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-131_ses-01_run-1 [393 events]: ['onset', 'duration', 'event_code']
# sub-131_ses-02_run-1 [402 events]: ['onset', 'duration', 'event_code']
# sub-132_ses-01_run-1 [406 events]: ['onset', 'duration', 'event_code']
# sub-133_ses-01_run-1 [384 events]: ['onset', 'duration', 'event_code']
# sub-133_ses-02_run-1 [403 events]: ['onset', 'duration', 'event_code']
# sub-134_ses-01_run-1 [415 events]: ['onset', 'duration', 'event_code']
# sub-135_ses-01_run-1 [433 events]: ['onset', 'duration', 'event_code']
# sub-136_ses-01_run-1 [377 events]: ['onset', 'duration', 'event_code']
# sub-137_ses-01_run-1 [369 events]: ['onset', 'duration', 'event_code']
# sub-138_ses-01_run-1 [339 events]: ['onset', 'duration', 'event_code']
# sub-139_ses-01_run-1 [393 events]: ['onset', 'duration', 'event_code']
# sub-14_ses-01_run-1 [358 events]: ['onset', 'duration', 'event_code']
# sub-140_ses-01_run-1 [434 events]: ['onset', 'duration', 'event_code']
# sub-140_ses-02_run-1 [371 events]: ['onset', 'duration', 'event_code']
# sub-140_ses-03_run-1 [396 events]: ['onset', 'duration', 'event_code']
# sub-141_ses-01_run-1 [395 events]: ['onset', 'duration', 'event_code']
# sub-142_ses-01_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-143_ses-01_run-1 [369 events]: ['onset', 'duration', 'event_code']
# sub-143_ses-02_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-144_ses-01_run-1 [397 events]: ['onset', 'duration', 'event_code']
# sub-145_ses-01_run-1 [366 events]: ['onset', 'duration', 'event_code']
# sub-146_ses-01_run-1 [405 events]: ['onset', 'duration', 'event_code']
# sub-146_ses-02_run-1 [420 events]: ['onset', 'duration', 'event_code']
# sub-147_ses-01_run-1 [403 events]: ['onset', 'duration', 'event_code']
# sub-148_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-149_ses-01_run-1 [406 events]: ['onset', 'duration', 'event_code']
# sub-149_ses-02_run-1 [380 events]: ['onset', 'duration', 'event_code']
# sub-15_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-150_ses-01_run-1 [391 events]: ['onset', 'duration', 'event_code']
# sub-150_ses-02_run-1 [389 events]: ['onset', 'duration', 'event_code']
# sub-151_ses-01_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-152_ses-01_run-1 [335 events]: ['onset', 'duration', 'event_code']
# sub-153_ses-01_run-1 [388 events]: ['onset', 'duration', 'event_code']
# sub-154_ses-01_run-1 [392 events]: ['onset', 'duration', 'event_code']
# sub-155_ses-01_run-1 [357 events]: ['onset', 'duration', 'event_code']
# sub-155_ses-02_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-156_ses-01_run-1 [374 events]: ['onset', 'duration', 'event_code']
# sub-16_ses-01_run-1 [6 events]: ['onset', 'duration', 'event_code']
# sub-17_ses-01_run-1 [377 events]: ['onset', 'duration', 'event_code']
# sub-18_ses-01_run-1 [386 events]: ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-1 [343 events]: ['onset', 'duration', 'event_code']
# sub-20_ses-01_run-1 [375 events]: ['onset', 'duration', 'event_code']
# sub-21_ses-01_run-1 [413 events]: ['onset', 'duration', 'event_code']
# sub-22_ses-01_run-1 [401 events]: ['onset', 'duration', 'event_code']
# sub-23_ses-01_run-1 [426 events]: ['onset', 'duration', 'event_code']
# sub-24_ses-01_run-1 [419 events]: ['onset', 'duration', 'event_code']
# sub-25_ses-01_run-1 [406 events]: ['onset', 'duration', 'event_code']
# sub-26_ses-01_run-1 [431 events]: ['onset', 'duration', 'event_code']
# sub-27_ses-01_run-1 [397 events]: ['onset', 'duration', 'event_code']
# sub-28_ses-01_run-1 [409 events]: ['onset', 'duration', 'event_code']
# sub-29_ses-01_run-1 [464 events]: ['onset', 'duration', 'event_code']
# sub-30_ses-01_run-1 [403 events]: ['onset', 'duration', 'event_code']
# sub-31_ses-01_run-1 [423 events]: ['onset', 'duration', 'event_code']
# sub-31_ses-02_run-1 [460 events]: ['onset', 'duration', 'event_code']
# sub-32_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-33_ses-01_run-1 [421 events]: ['onset', 'duration', 'event_code']
# sub-33_ses-02_run-1 [428 events]: ['onset', 'duration', 'event_code']
# sub-33_ses-03_run-1 [500 events]: ['onset', 'duration', 'event_code']
# sub-34_ses-01_run-1 [468 events]: ['onset', 'duration', 'event_code']
# sub-35_ses-01_run-1 [465 events]: ['onset', 'duration', 'event_code']
# sub-36_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-37_ses-01_run-1 [452 events]: ['onset', 'duration', 'event_code']
# sub-38_ses-01_run-1 [387 events]: ['onset', 'duration', 'event_code']
# sub-39_ses-01_run-1 [428 events]: ['onset', 'duration', 'event_code']
# sub-40_ses-01_run-1 [471 events]: ['onset', 'duration', 'event_code']
# sub-41_ses-01_run-1 [472 events]: ['onset', 'duration', 'event_code']
# sub-42_ses-01_run-1 [519 events]: ['onset', 'duration', 'event_code']
# sub-43_ses-01_run-1 [487 events]: ['onset', 'duration', 'event_code']
# sub-44_ses-01_run-1 [465 events]: ['onset', 'duration', 'event_code']
# sub-44_ses-02_run-1 [556 events]: ['onset', 'duration', 'event_code']
# sub-45_ses-01_run-1 [371 events]: ['onset', 'duration', 'event_code']
# sub-46_ses-01_run-1 [421 events]: ['onset', 'duration', 'event_code']
# sub-47_ses-01_run-1 [449 events]: ['onset', 'duration', 'event_code']
# sub-47_ses-02_run-1 [385 events]: ['onset', 'duration', 'event_code']
# sub-48_ses-01_run-1 [465 events]: ['onset', 'duration', 'event_code']
# sub-49_ses-01_run-1 [340 events]: ['onset', 'duration', 'event_code']
# sub-50_ses-01_run-1 [423 events]: ['onset', 'duration', 'event_code']
# sub-51_ses-01_run-1 [321 events]: ['onset', 'duration', 'event_code']
# sub-52_ses-01_run-1 [441 events]: ['onset', 'duration', 'event_code']
# sub-53_ses-01_run-1 [439 events]: ['onset', 'duration', 'event_code']
# sub-54_ses-01_run-1 [461 events]: ['onset', 'duration', 'event_code']
# sub-55_ses-01_run-1 [465 events]: ['onset', 'duration', 'event_code']
# sub-56_ses-01_run-1 [459 events]: ['onset', 'duration', 'event_code']
# sub-57_ses-01_run-1 [469 events]: ['onset', 'duration', 'event_code']
# sub-58_ses-01_run-1 [522 events]: ['onset', 'duration', 'event_code']
# sub-58_ses-02_run-1 [473 events]: ['onset', 'duration', 'event_code']
# sub-58_ses-03_run-1 [459 events]: ['onset', 'duration', 'event_code']
# sub-59_ses-01_run-1 [479 events]: ['onset', 'duration', 'event_code']
# sub-59_ses-02_run-1 [465 events]: ['onset', 'duration', 'event_code']
# sub-59_ses-03_run-1 [461 events]: ['onset', 'duration', 'event_code']
# sub-60_ses-01_run-1 [379 events]: ['onset', 'duration', 'event_code']
# sub-61_ses-01_run-1 [389 events]: ['onset', 'duration', 'event_code']
# sub-61_ses-02_run-1 [459 events]: ['onset', 'duration', 'event_code']
# sub-62_ses-01_run-1 [449 events]: ['onset', 'duration', 'event_code']
# sub-63_ses-01_run-1 [511 events]: ['onset', 'duration', 'event_code']
# sub-63_ses-02_run-1 [457 events]: ['onset', 'duration', 'event_code']
# sub-63_ses-03_run-1 [467 events]: ['onset', 'duration', 'event_code']
# sub-64_ses-01_run-1 [433 events]: ['onset', 'duration', 'event_code']
# sub-65_ses-01_run-1 [461 events]: ['onset', 'duration', 'event_code']
# sub-66_ses-01_run-1 [455 events]: ['onset', 'duration', 'event_code']
# sub-66_ses-02_run-1 [362 events]: ['onset', 'duration', 'event_code']
# sub-66_ses-03_run-1 [293 events]: ['onset', 'duration', 'event_code']
# sub-67_ses-01_run-1 [441 events]: ['onset', 'duration', 'event_code']
# sub-68_ses-01_run-1 [398 events]: ['onset', 'duration', 'event_code']
# sub-69_ses-01_run-1 [460 events]: ['onset', 'duration', 'event_code']
# sub-70_ses-01_run-1 [297 events]: ['onset', 'duration', 'event_code']
# sub-70_ses-02_run-1 [323 events]: ['onset', 'duration', 'event_code']
# sub-70_ses-03_run-1 [411 events]: ['onset', 'duration', 'event_code']
# sub-71_ses-01_run-1 [413 events]: ['onset', 'duration', 'event_code']
# sub-71_ses-02_run-1 [443 events]: ['onset', 'duration', 'event_code']
# sub-71_ses-03_run-1 [432 events]: ['onset', 'duration', 'event_code']
# sub-72_ses-01_run-1 [455 events]: ['onset', 'duration', 'event_code']
# sub-73_ses-01_run-1 [445 events]: ['onset', 'duration', 'event_code']
# sub-74_ses-01_run-1 [393 events]: ['onset', 'duration', 'event_code']
# sub-75_ses-01_run-1 [453 events]: ['onset', 'duration', 'event_code']
# sub-76_ses-01_run-1 [450 events]: ['onset', 'duration', 'event_code']
# sub-76_ses-02_run-1 [477 events]: ['onset', 'duration', 'event_code']
# sub-76_ses-03_run-1 [477 events]: ['onset', 'duration', 'event_code']
# sub-77_ses-01_run-1 [463 events]: ['onset', 'duration', 'event_code']
# sub-78_ses-01_run-1 [395 events]: ['onset', 'duration', 'event_code']
# sub-78_ses-02_run-1 [449 events]: ['onset', 'duration', 'event_code']
# sub-78_ses-03_run-1 [306 events]: ['onset', 'duration', 'event_code']
# sub-79_ses-01_run-1 [370 events]: ['onset', 'duration', 'event_code']
# sub-80_ses-01_run-1 [442 events]: ['onset', 'duration', 'event_code']
# sub-81_ses-01_run-1 [419 events]: ['onset', 'duration', 'event_code']
# sub-82_ses-01_run-1 [406 events]: ['onset', 'duration', 'event_code']
# sub-83_ses-01_run-1 [425 events]: ['onset', 'duration', 'event_code']
# sub-84_ses-01_run-1 [457 events]: ['onset', 'duration', 'event_code']
# sub-85_ses-01_run-1 [465 events]: ['onset', 'duration', 'event_code']
# sub-86_ses-01_run-1 [412 events]: ['onset', 'duration', 'event_code']
# sub-87_ses-01_run-1 [457 events]: ['onset', 'duration', 'event_code']
# sub-88_ses-01_run-1 [439 events]: ['onset', 'duration', 'event_code']
# sub-89_ses-01_run-1 [461 events]: ['onset', 'duration', 'event_code']
# sub-90_ses-01_run-1 [463 events]: ['onset', 'duration', 'event_code']
# sub-91_ses-01_run-1 [450 events]: ['onset', 'duration', 'event_code']
# sub-92_ses-01_run-1 [453 events]: ['onset', 'duration', 'event_code']
# sub-93_ses-01_run-1 [459 events]: ['onset', 'duration', 'event_code']
# sub-94_ses-01_run-1 [463 events]: ['onset', 'duration', 'event_code']
# sub-95_ses-01_run-1 [468 events]: ['onset', 'duration', 'event_code']
# sub-96_ses-01_run-1 [319 events]: ['onset', 'duration', 'event_code']
# sub-97_ses-01_run-1 [402 events]: ['onset', 'duration', 'event_code']
# sub-98_ses-01_run-1 [383 events]: ['onset', 'duration', 'event_code']
# sub-99_ses-01_run-1 [444 events]: ['onset', 'duration', 'event_code']
#
# EEG.event style event file columns:
# sub-01_ses-01_run-1 [292 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-02_ses-01_run-1 [348 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-03_ses-01_run-1 [287 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-04_ses-01_run-1 [313 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-05_ses-01_run-1 [277 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-06_ses-01_run-1 [273 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-07_ses-01_run-1 [285 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-08_ses-01_run-1 [285 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-09_ses-01_run-1 [366 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-10_ses-01_run-1 [367 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-01_run-1 [379 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-02_run-1 [355 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-03_run-1 [363 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-04_run-1 [353 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-05_run-1 [350 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-06_run-1 [348 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-07_run-1 [331 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-101_ses-01_run-1 [363 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-102_ses-01_run-1 [367 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-103_ses-01_run-1 [384 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-104_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-105_ses-01_run-1 [355 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-106_ses-01_run-1 [418 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-106_ses-02_run-1 [374 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-107_ses-01_run-1 [352 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-108_ses-01_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-109_ses-01_run-1 [365 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-11_ses-01_run-1 [366 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-110_ses-01_run-1 [373 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-111_ses-01_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-01_run-1 [375 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-02_run-1 [449 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-03_run-1 [433 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-04_run-1 [432 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-05_run-1 [457 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-06_run-1 [447 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-112_ses-07_run-1 [415 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-113_ses-01_run-1 [355 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-114_ses-01_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-115_ses-01_run-1 [399 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-116_ses-01_run-1 [373 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-117_ses-01_run-1 [389 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-117_ses-02_run-1 [403 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-117_ses-03_run-1 [380 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-117_ses-04_run-1 [400 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-117_ses-05_run-1 [367 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-117_ses-06_run-1 [414 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-118_ses-01_run-1 [363 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-119_ses-01_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-12_ses-01_run-1 [375 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-01_run-1 [367 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-02_run-1 [363 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-03_run-1 [365 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-04_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-05_run-1 [359 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-06_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-120_ses-07_run-1 [371 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-02_run-1 [375 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-03_run-1 [379 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-04_run-1 [371 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-05_run-1 [370 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-06_run-1 [349 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-121_ses-07_run-1 [375 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-01_run-1 [415 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-02_run-1 [407 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-03_run-1 [410 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-04_run-1 [405 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-05_run-1 [406 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-06_run-1 [419 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-122_ses-07_run-1 [435 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-123_ses-01_run-1 [388 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-123_ses-02_run-1 [346 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-123_ses-03_run-1 [353 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-123_ses-04_run-1 [351 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-123_ses-05_run-1 [340 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-123_ses-06_run-1 [314 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-01_run-1 [363 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-02_run-1 [369 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-03_run-1 [388 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-04_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-05_run-1 [390 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-06_run-1 [368 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-124_ses-07_run-1 [381 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-01_run-1 [380 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-02_run-1 [381 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-03_run-1 [391 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-04_run-1 [379 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-05_run-1 [402 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-06_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-125_ses-07_run-1 [393 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-126_ses-01_run-1 [365 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-126_ses-02_run-1 [365 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-126_ses-03_run-1 [365 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-126_ses-04_run-1 [364 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-126_ses-05_run-1 [353 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-126_ses-06_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-127_ses-01_run-1 [374 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-128_ses-01_run-1 [358 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-128_ses-02_run-1 [367 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-129_ses-01_run-1 [397 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-13_ses-01_run-1 [385 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-130_ses-01_run-1 [374 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-130_ses-02_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-131_ses-01_run-1 [393 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-131_ses-02_run-1 [402 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-132_ses-01_run-1 [406 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-133_ses-01_run-1 [384 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-133_ses-02_run-1 [403 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-134_ses-01_run-1 [415 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-135_ses-01_run-1 [433 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-136_ses-01_run-1 [377 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-137_ses-01_run-1 [369 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-138_ses-01_run-1 [339 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-139_ses-01_run-1 [393 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-14_ses-01_run-1 [358 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-140_ses-01_run-1 [434 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-140_ses-02_run-1 [371 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-140_ses-03_run-1 [396 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-141_ses-01_run-1 [395 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-142_ses-01_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-143_ses-01_run-1 [369 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-143_ses-02_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-144_ses-01_run-1 [397 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-145_ses-01_run-1 [366 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-146_ses-01_run-1 [405 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-146_ses-02_run-1 [420 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-147_ses-01_run-1 [403 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-148_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-149_ses-01_run-1 [406 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-149_ses-02_run-1 [380 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-15_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-150_ses-01_run-1 [391 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-150_ses-02_run-1 [389 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-151_ses-01_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-152_ses-01_run-1 [335 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-153_ses-01_run-1 [388 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-154_ses-01_run-1 [392 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-155_ses-01_run-1 [357 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-155_ses-02_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-156_ses-01_run-1 [374 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-16_ses-01_run-1 [6 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-17_ses-01_run-1 [377 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-18_ses-01_run-1 [386 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-1 [343 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-20_ses-01_run-1 [375 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-21_ses-01_run-1 [413 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-22_ses-01_run-1 [401 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-23_ses-01_run-1 [426 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-24_ses-01_run-1 [419 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-25_ses-01_run-1 [406 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-26_ses-01_run-1 [431 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-27_ses-01_run-1 [397 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-28_ses-01_run-1 [409 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-29_ses-01_run-1 [464 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-30_ses-01_run-1 [403 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-31_ses-01_run-1 [423 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-31_ses-02_run-1 [460 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-32_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-33_ses-01_run-1 [421 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-33_ses-02_run-1 [428 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-33_ses-03_run-1 [500 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-34_ses-01_run-1 [468 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-35_ses-01_run-1 [465 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-36_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-37_ses-01_run-1 [452 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-38_ses-01_run-1 [387 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-39_ses-01_run-1 [428 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-40_ses-01_run-1 [471 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-41_ses-01_run-1 [472 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-42_ses-01_run-1 [519 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-43_ses-01_run-1 [487 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-44_ses-01_run-1 [465 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-44_ses-02_run-1 [556 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-45_ses-01_run-1 [371 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-46_ses-01_run-1 [421 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-47_ses-01_run-1 [449 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-47_ses-02_run-1 [385 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-48_ses-01_run-1 [465 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-49_ses-01_run-1 [340 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-50_ses-01_run-1 [423 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-51_ses-01_run-1 [321 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-52_ses-01_run-1 [441 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-53_ses-01_run-1 [439 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-54_ses-01_run-1 [461 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-55_ses-01_run-1 [465 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-56_ses-01_run-1 [459 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-57_ses-01_run-1 [469 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-58_ses-01_run-1 [522 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-58_ses-02_run-1 [473 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-58_ses-03_run-1 [459 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-59_ses-01_run-1 [479 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-59_ses-02_run-1 [465 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-59_ses-03_run-1 [461 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-60_ses-01_run-1 [379 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-61_ses-01_run-1 [389 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-61_ses-02_run-1 [459 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-62_ses-01_run-1 [449 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-63_ses-01_run-1 [511 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-63_ses-02_run-1 [457 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-63_ses-03_run-1 [467 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-64_ses-01_run-1 [433 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-65_ses-01_run-1 [461 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-66_ses-01_run-1 [455 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-66_ses-02_run-1 [362 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-66_ses-03_run-1 [293 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-67_ses-01_run-1 [441 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-68_ses-01_run-1 [398 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-69_ses-01_run-1 [460 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-70_ses-01_run-1 [297 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-70_ses-02_run-1 [323 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-70_ses-03_run-1 [411 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-71_ses-01_run-1 [413 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-71_ses-02_run-1 [443 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-71_ses-03_run-1 [432 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-72_ses-01_run-1 [455 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-73_ses-01_run-1 [445 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-74_ses-01_run-1 [393 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-75_ses-01_run-1 [453 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-76_ses-01_run-1 [450 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-76_ses-02_run-1 [477 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-76_ses-03_run-1 [477 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-77_ses-01_run-1 [463 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-78_ses-01_run-1 [395 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-78_ses-02_run-1 [449 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-78_ses-03_run-1 [306 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-79_ses-01_run-1 [370 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-80_ses-01_run-1 [442 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-81_ses-01_run-1 [419 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-82_ses-01_run-1 [406 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-83_ses-01_run-1 [425 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-84_ses-01_run-1 [457 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-85_ses-01_run-1 [465 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-86_ses-01_run-1 [412 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-87_ses-01_run-1 [457 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-88_ses-01_run-1 [439 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-89_ses-01_run-1 [461 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-90_ses-01_run-1 [463 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-91_ses-01_run-1 [450 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-92_ses-01_run-1 [453 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-93_ses-01_run-1 [459 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-94_ses-01_run-1 [463 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-95_ses-01_run-1 [468 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-96_ses-01_run-1 [319 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-97_ses-01_run-1 [402 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-98_ses-01_run-1 [383 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-99_ses-01_run-1 [444 events]: ['type', 'latency', 'urevent', 'usertags']

# %%
count_diffs = bids_dict.count_diffs(eeg_dict)
if count_diffs:
    print("The number of BIDS events and EEG.event events differ for the following:")
    for item in count_diffs:
        print(f"{item[0]}: {item[1]} BIDS events and {item[2]} EEG.events")
else:
    print("The BIDS event files and EEG.event structures have the same number of events")
# Out:
# The BIDS event files and EEG.event structures have the same number of events

# %%
from hed.tools import BidsTsvSummary

bids_sum_all, bids_sum =  BidsTsvSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip_columns)
bids_sum_all.print('\nBIDS events summary')

eeg_sum_all, eeg_sum =  BidsTsvSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip_columns)
eeg_sum_all.print('\nEEG.event events summary')
# Out:
# BIDS events summary
#   Categorical columns (2):
#     duration (1 distinct values):
#       n/a: 97971
#     event_code (20 distinct values):
#       1111: 8507
#       1112: 8507
#       1121: 8664
#       1122: 8664
#       1211: 248
#       1212: 248
#       2621: 2237
#       2622: 2237
#       3111: 247
#       3112: 247
#       3200: 5695
#       3310: 247
#       4200: 3
#       4210: 9058
#       4220: 3208
#       4230: 6040
#       4311: 17060
#       4312: 16818
#       4611: 18
#       4612: 18
#   Value columns (0):
#
# EEG.event events summary
#   Categorical columns (1):
#     type (20 distinct values):
#       1111: 8507
#       1112: 8507
#       1121: 8664
#       1122: 8664
#       1211: 248
#       1212: 248
#       2621: 2237
#       2622: 2237
#       3111: 247
#       3112: 247
#       3200: 5695
#       3310: 247
#       4200: 3
#       4210: 9058
#       4220: 3208
#       4230: 6040
#       4311: 17060
#       4312: 16818
#       4611: 18
#       4612: 18
#   Value columns (0):
