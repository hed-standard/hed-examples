# %% [markdown]
# ## Remove the _eeg.json files generated by ESS.
#
# This notebook removes the `_eeg.json` files generated by ESS for the BCIT Baseline Driving data.

# %%
import os
import json
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list, get_new_dataframe, get_value_dict, replace_values

# Variables to set for the specific dataset
bids_root_path = 's:/bcit/BaselineDrivingWorkingPhaseTwo'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
log_file_name = 'bcit_baseline_driving_06_remove_eeg_json_log.json'

# Construct the list of .event files
logger = HedLogger()
json_files = get_file_list(bids_root_path, extensions=[".json"], name_suffix="_eeg", exclude_dirs=exclude_dirs)

for file in json_files:
    os.remove(file)
    logger.add(os.path.basename(file), f"Remove the file")

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-01_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-02_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-03_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-04_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-05_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-06_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-07_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-08_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-09_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-10_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-100_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-101_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-102_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-103_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-104_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-105_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-106_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-107_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-108_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-109_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-11_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-12_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-13_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-14_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-15_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-16_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-17_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-18_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-19_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-20_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-21_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-22_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-23_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-24_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-25_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-26_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-27_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-28_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-29_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-30_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-31_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-32_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-33_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-34_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-35_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-36_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-37_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-38_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-39_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-40_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-41_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-42_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-43_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-44_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-45_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-46_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-47_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-48_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-49_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-50_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-51_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-52_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-53_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-54_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-55_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-56_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-57_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-58_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-59_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-60_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-61_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-62_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-63_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-64_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-65_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-66_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-67_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-68_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-69_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-70_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-71_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-72_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-73_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-74_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-75_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-76_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-77_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-78_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-79_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-80_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-81_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-82_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-83_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-84_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-85_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-86_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-87_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-88_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-89_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-90_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-91_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-92_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-93_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-94_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-95_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-96_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-97_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-98_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
# sub-99_task-DriveWithSpeedChange_eeg.json:
# 	[ Remove the file]
#
# ERROR Summary:
# task-DriveWithSpeedChange_eeg.json:
# sub-01_task-DriveWithSpeedChange_eeg.json:
# sub-02_task-DriveWithSpeedChange_eeg.json:
# sub-03_task-DriveWithSpeedChange_eeg.json:
# sub-04_task-DriveWithSpeedChange_eeg.json:
# sub-05_task-DriveWithSpeedChange_eeg.json:
# sub-06_task-DriveWithSpeedChange_eeg.json:
# sub-07_task-DriveWithSpeedChange_eeg.json:
# sub-08_task-DriveWithSpeedChange_eeg.json:
# sub-09_task-DriveWithSpeedChange_eeg.json:
# sub-10_task-DriveWithSpeedChange_eeg.json:
# sub-100_task-DriveWithSpeedChange_eeg.json:
# sub-101_task-DriveWithSpeedChange_eeg.json:
# sub-102_task-DriveWithSpeedChange_eeg.json:
# sub-103_task-DriveWithSpeedChange_eeg.json:
# sub-104_task-DriveWithSpeedChange_eeg.json:
# sub-105_task-DriveWithSpeedChange_eeg.json:
# sub-106_task-DriveWithSpeedChange_eeg.json:
# sub-107_task-DriveWithSpeedChange_eeg.json:
# sub-108_task-DriveWithSpeedChange_eeg.json:
# sub-109_task-DriveWithSpeedChange_eeg.json:
# sub-11_task-DriveWithSpeedChange_eeg.json:
# sub-12_task-DriveWithSpeedChange_eeg.json:
# sub-13_task-DriveWithSpeedChange_eeg.json:
# sub-14_task-DriveWithSpeedChange_eeg.json:
# sub-15_task-DriveWithSpeedChange_eeg.json:
# sub-16_task-DriveWithSpeedChange_eeg.json:
# sub-17_task-DriveWithSpeedChange_eeg.json:
# sub-18_task-DriveWithSpeedChange_eeg.json:
# sub-19_task-DriveWithSpeedChange_eeg.json:
# sub-20_task-DriveWithSpeedChange_eeg.json:
# sub-21_task-DriveWithSpeedChange_eeg.json:
# sub-22_task-DriveWithSpeedChange_eeg.json:
# sub-23_task-DriveWithSpeedChange_eeg.json:
# sub-24_task-DriveWithSpeedChange_eeg.json:
# sub-25_task-DriveWithSpeedChange_eeg.json:
# sub-26_task-DriveWithSpeedChange_eeg.json:
# sub-27_task-DriveWithSpeedChange_eeg.json:
# sub-28_task-DriveWithSpeedChange_eeg.json:
# sub-29_task-DriveWithSpeedChange_eeg.json:
# sub-30_task-DriveWithSpeedChange_eeg.json:
# sub-31_task-DriveWithSpeedChange_eeg.json:
# sub-32_task-DriveWithSpeedChange_eeg.json:
# sub-33_task-DriveWithSpeedChange_eeg.json:
# sub-34_task-DriveWithSpeedChange_eeg.json:
# sub-35_task-DriveWithSpeedChange_eeg.json:
# sub-36_task-DriveWithSpeedChange_eeg.json:
# sub-37_task-DriveWithSpeedChange_eeg.json:
# sub-38_task-DriveWithSpeedChange_eeg.json:
# sub-39_task-DriveWithSpeedChange_eeg.json:
# sub-40_task-DriveWithSpeedChange_eeg.json:
# sub-41_task-DriveWithSpeedChange_eeg.json:
# sub-42_task-DriveWithSpeedChange_eeg.json:
# sub-43_task-DriveWithSpeedChange_eeg.json:
# sub-44_task-DriveWithSpeedChange_eeg.json:
# sub-45_task-DriveWithSpeedChange_eeg.json:
# sub-46_task-DriveWithSpeedChange_eeg.json:
# sub-47_task-DriveWithSpeedChange_eeg.json:
# sub-48_task-DriveWithSpeedChange_eeg.json:
# sub-49_task-DriveWithSpeedChange_eeg.json:
# sub-50_task-DriveWithSpeedChange_eeg.json:
# sub-51_task-DriveWithSpeedChange_eeg.json:
# sub-52_task-DriveWithSpeedChange_eeg.json:
# sub-53_task-DriveWithSpeedChange_eeg.json:
# sub-54_task-DriveWithSpeedChange_eeg.json:
# sub-55_task-DriveWithSpeedChange_eeg.json:
# sub-56_task-DriveWithSpeedChange_eeg.json:
# sub-57_task-DriveWithSpeedChange_eeg.json:
# sub-58_task-DriveWithSpeedChange_eeg.json:
# sub-59_task-DriveWithSpeedChange_eeg.json:
# sub-60_task-DriveWithSpeedChange_eeg.json:
# sub-61_task-DriveWithSpeedChange_eeg.json:
# sub-62_task-DriveWithSpeedChange_eeg.json:
# sub-63_task-DriveWithSpeedChange_eeg.json:
# sub-64_task-DriveWithSpeedChange_eeg.json:
# sub-65_task-DriveWithSpeedChange_eeg.json:
# sub-66_task-DriveWithSpeedChange_eeg.json:
# sub-67_task-DriveWithSpeedChange_eeg.json:
# sub-68_task-DriveWithSpeedChange_eeg.json:
# sub-69_task-DriveWithSpeedChange_eeg.json:
# sub-70_task-DriveWithSpeedChange_eeg.json:
# sub-71_task-DriveWithSpeedChange_eeg.json:
# sub-72_task-DriveWithSpeedChange_eeg.json:
# sub-73_task-DriveWithSpeedChange_eeg.json:
# sub-74_task-DriveWithSpeedChange_eeg.json:
# sub-75_task-DriveWithSpeedChange_eeg.json:
# sub-76_task-DriveWithSpeedChange_eeg.json:
# sub-77_task-DriveWithSpeedChange_eeg.json:
# sub-78_task-DriveWithSpeedChange_eeg.json:
# sub-79_task-DriveWithSpeedChange_eeg.json:
# sub-80_task-DriveWithSpeedChange_eeg.json:
# sub-81_task-DriveWithSpeedChange_eeg.json:
# sub-82_task-DriveWithSpeedChange_eeg.json:
# sub-83_task-DriveWithSpeedChange_eeg.json:
# sub-84_task-DriveWithSpeedChange_eeg.json:
# sub-85_task-DriveWithSpeedChange_eeg.json:
# sub-86_task-DriveWithSpeedChange_eeg.json:
# sub-87_task-DriveWithSpeedChange_eeg.json:
# sub-88_task-DriveWithSpeedChange_eeg.json:
# sub-89_task-DriveWithSpeedChange_eeg.json:
# sub-90_task-DriveWithSpeedChange_eeg.json:
# sub-91_task-DriveWithSpeedChange_eeg.json:
# sub-92_task-DriveWithSpeedChange_eeg.json:
# sub-93_task-DriveWithSpeedChange_eeg.json:
# sub-94_task-DriveWithSpeedChange_eeg.json:
# sub-95_task-DriveWithSpeedChange_eeg.json:
# sub-96_task-DriveWithSpeedChange_eeg.json:
# sub-97_task-DriveWithSpeedChange_eeg.json:
# sub-98_task-DriveWithSpeedChange_eeg.json:
# sub-99_task-DriveWithSpeedChange_eeg.json:
