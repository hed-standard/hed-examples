# %% [markdown]
# ## Fix the coordsystem.json files generated by ESS.
#
# This notebook replaces the `coordsystem.json` files of ESS with those generated by EEGLAB BidsTools
# for the BCIT Baseline Driving data.

# %%
import os
import json
from hed.tools import BidsTsvDictionary, HedLogger
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 's:/bcit/BaselineDrivingWorkingPhaseTwo'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
log_file_name = 'bcit_baseline_driving_05_fix_coordsystem_log.json'

# Construct the list of .event files
logger = HedLogger()
coord_files = get_file_list(bids_root_path, extensions=[".json"], name_suffix="_coordsystem", exclude_dirs=exclude_dirs)
coord_dict = BidsTsvDictionary("EEG coordsystem files", coord_files, entities=entities)

# Coordsystem.json template
coordsystem_template = {"EEGCoordinateUnits":"mm",
                        "EEGCoordinateSystem":"CTF",
                        "EEGCoordinateSystemDescription":"EEGLAB"}

for key, file, rowcount, column_count in coord_dict.iter_tsv_info():
    filename = file.file_path
    logger.add(key, f"Replacing {os.path.basename(filename)} with EEGLAB coordinate system template")
    with open(filename, 'w') as fp:
        json.dump(coordsystem_template, fp, indent=4)

# Output and save the log
logger.print_log()
save_path = os.path.join(bids_root_path, 'code')
logger.save_log(save_path, log_name=log_file_name)

# Output errors
print("\nERROR Summary:")
logger.print_log(level="ERROR")
# Out:
# sub-01_ses-01:
# 	[ Replacing sub-01_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-02_ses-01:
# 	[ Replacing sub-02_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-03_ses-01:
# 	[ Replacing sub-03_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-04_ses-01:
# 	[ Replacing sub-04_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-05_ses-01:
# 	[ Replacing sub-05_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-06_ses-01:
# 	[ Replacing sub-06_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-07_ses-01:
# 	[ Replacing sub-07_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-08_ses-01:
# 	[ Replacing sub-08_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-09_ses-01:
# 	[ Replacing sub-09_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-10_ses-01:
# 	[ Replacing sub-10_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-100_ses-01:
# 	[ Replacing sub-100_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-101_ses-01:
# 	[ Replacing sub-101_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-102_ses-01:
# 	[ Replacing sub-102_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-102_ses-02:
# 	[ Replacing sub-102_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-103_ses-01:
# 	[ Replacing sub-103_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-103_ses-02:
# 	[ Replacing sub-103_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-104_ses-01:
# 	[ Replacing sub-104_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-105_ses-01:
# 	[ Replacing sub-105_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-106_ses-01:
# 	[ Replacing sub-106_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-107_ses-01:
# 	[ Replacing sub-107_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-108_ses-01:
# 	[ Replacing sub-108_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-108_ses-02:
# 	[ Replacing sub-108_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-109_ses-01:
# 	[ Replacing sub-109_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-11_ses-01:
# 	[ Replacing sub-11_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-12_ses-01:
# 	[ Replacing sub-12_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-13_ses-01:
# 	[ Replacing sub-13_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-14_ses-01:
# 	[ Replacing sub-14_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-15_ses-01:
# 	[ Replacing sub-15_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-16_ses-01:
# 	[ Replacing sub-16_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-17_ses-01:
# 	[ Replacing sub-17_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-18_ses-01:
# 	[ Replacing sub-18_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-19_ses-01:
# 	[ Replacing sub-19_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-20_ses-01:
# 	[ Replacing sub-20_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-21_ses-01:
# 	[ Replacing sub-21_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-22_ses-01:
# 	[ Replacing sub-22_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-23_ses-01:
# 	[ Replacing sub-23_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-24_ses-01:
# 	[ Replacing sub-24_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-25_ses-01:
# 	[ Replacing sub-25_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-26_ses-01:
# 	[ Replacing sub-26_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-27_ses-01:
# 	[ Replacing sub-27_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-28_ses-01:
# 	[ Replacing sub-28_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-29_ses-01:
# 	[ Replacing sub-29_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-30_ses-01:
# 	[ Replacing sub-30_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-31_ses-01:
# 	[ Replacing sub-31_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-32_ses-01:
# 	[ Replacing sub-32_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-33_ses-01:
# 	[ Replacing sub-33_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-34_ses-01:
# 	[ Replacing sub-34_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-35_ses-01:
# 	[ Replacing sub-35_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-36_ses-01:
# 	[ Replacing sub-36_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-37_ses-01:
# 	[ Replacing sub-37_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-38_ses-01:
# 	[ Replacing sub-38_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-39_ses-01:
# 	[ Replacing sub-39_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-40_ses-01:
# 	[ Replacing sub-40_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-41_ses-01:
# 	[ Replacing sub-41_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-42_ses-01:
# 	[ Replacing sub-42_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-43_ses-01:
# 	[ Replacing sub-43_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-44_ses-01:
# 	[ Replacing sub-44_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-45_ses-01:
# 	[ Replacing sub-45_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-46_ses-01:
# 	[ Replacing sub-46_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-47_ses-01:
# 	[ Replacing sub-47_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-48_ses-01:
# 	[ Replacing sub-48_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-49_ses-01:
# 	[ Replacing sub-49_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-50_ses-01:
# 	[ Replacing sub-50_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-51_ses-01:
# 	[ Replacing sub-51_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-52_ses-01:
# 	[ Replacing sub-52_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-53_ses-01:
# 	[ Replacing sub-53_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-53_ses-02:
# 	[ Replacing sub-53_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-54_ses-01:
# 	[ Replacing sub-54_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-55_ses-01:
# 	[ Replacing sub-55_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-56_ses-01:
# 	[ Replacing sub-56_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-57_ses-01:
# 	[ Replacing sub-57_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-58_ses-01:
# 	[ Replacing sub-58_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-59_ses-01:
# 	[ Replacing sub-59_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-59_ses-02:
# 	[ Replacing sub-59_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-60_ses-01:
# 	[ Replacing sub-60_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-61_ses-01:
# 	[ Replacing sub-61_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-62_ses-01:
# 	[ Replacing sub-62_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-63_ses-01:
# 	[ Replacing sub-63_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-64_ses-01:
# 	[ Replacing sub-64_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-65_ses-01:
# 	[ Replacing sub-65_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-65_ses-02:
# 	[ Replacing sub-65_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-66_ses-01:
# 	[ Replacing sub-66_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-67_ses-01:
# 	[ Replacing sub-67_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-68_ses-01:
# 	[ Replacing sub-68_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-69_ses-01:
# 	[ Replacing sub-69_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-70_ses-01:
# 	[ Replacing sub-70_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-70_ses-02:
# 	[ Replacing sub-70_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-71_ses-01:
# 	[ Replacing sub-71_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-72_ses-01:
# 	[ Replacing sub-72_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-73_ses-01:
# 	[ Replacing sub-73_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-73_ses-02:
# 	[ Replacing sub-73_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-74_ses-01:
# 	[ Replacing sub-74_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-74_ses-02:
# 	[ Replacing sub-74_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-75_ses-01:
# 	[ Replacing sub-75_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-75_ses-02:
# 	[ Replacing sub-75_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-76_ses-01:
# 	[ Replacing sub-76_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-77_ses-01:
# 	[ Replacing sub-77_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-77_ses-02:
# 	[ Replacing sub-77_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-78_ses-01:
# 	[ Replacing sub-78_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-79_ses-01:
# 	[ Replacing sub-79_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-80_ses-01:
# 	[ Replacing sub-80_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-81_ses-01:
# 	[ Replacing sub-81_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-81_ses-02:
# 	[ Replacing sub-81_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-82_ses-01:
# 	[ Replacing sub-82_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-83_ses-01:
# 	[ Replacing sub-83_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-83_ses-02:
# 	[ Replacing sub-83_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-84_ses-01:
# 	[ Replacing sub-84_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-84_ses-02:
# 	[ Replacing sub-84_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-85_ses-01:
# 	[ Replacing sub-85_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-86_ses-01:
# 	[ Replacing sub-86_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-86_ses-02:
# 	[ Replacing sub-86_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-87_ses-01:
# 	[ Replacing sub-87_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-88_ses-01:
# 	[ Replacing sub-88_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-89_ses-01:
# 	[ Replacing sub-89_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-90_ses-01:
# 	[ Replacing sub-90_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-91_ses-01:
# 	[ Replacing sub-91_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-92_ses-01:
# 	[ Replacing sub-92_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-93_ses-01:
# 	[ Replacing sub-93_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-93_ses-02:
# 	[ Replacing sub-93_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-93_ses-03:
# 	[ Replacing sub-93_ses-03_coordsystem.json with EEGLAB coordinate system template]
# sub-94_ses-01:
# 	[ Replacing sub-94_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-95_ses-01:
# 	[ Replacing sub-95_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-96_ses-01:
# 	[ Replacing sub-96_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-96_ses-02:
# 	[ Replacing sub-96_ses-02_coordsystem.json with EEGLAB coordinate system template]
# sub-97_ses-01:
# 	[ Replacing sub-97_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-98_ses-01:
# 	[ Replacing sub-98_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-99_ses-01:
# 	[ Replacing sub-99_ses-01_coordsystem.json with EEGLAB coordinate system template]
# sub-99_ses-02:
# 	[ Replacing sub-99_ses-02_coordsystem.json with EEGLAB coordinate system template]
#
# ERROR Summary:
# sub-01_ses-01:
# sub-02_ses-01:
# sub-03_ses-01:
# sub-04_ses-01:
# sub-05_ses-01:
# sub-06_ses-01:
# sub-07_ses-01:
# sub-08_ses-01:
# sub-09_ses-01:
# sub-10_ses-01:
# sub-100_ses-01:
# sub-101_ses-01:
# sub-102_ses-01:
# sub-102_ses-02:
# sub-103_ses-01:
# sub-103_ses-02:
# sub-104_ses-01:
# sub-105_ses-01:
# sub-106_ses-01:
# sub-107_ses-01:
# sub-108_ses-01:
# sub-108_ses-02:
# sub-109_ses-01:
# sub-11_ses-01:
# sub-12_ses-01:
# sub-13_ses-01:
# sub-14_ses-01:
# sub-15_ses-01:
# sub-16_ses-01:
# sub-17_ses-01:
# sub-18_ses-01:
# sub-19_ses-01:
# sub-20_ses-01:
# sub-21_ses-01:
# sub-22_ses-01:
# sub-23_ses-01:
# sub-24_ses-01:
# sub-25_ses-01:
# sub-26_ses-01:
# sub-27_ses-01:
# sub-28_ses-01:
# sub-29_ses-01:
# sub-30_ses-01:
# sub-31_ses-01:
# sub-32_ses-01:
# sub-33_ses-01:
# sub-34_ses-01:
# sub-35_ses-01:
# sub-36_ses-01:
# sub-37_ses-01:
# sub-38_ses-01:
# sub-39_ses-01:
# sub-40_ses-01:
# sub-41_ses-01:
# sub-42_ses-01:
# sub-43_ses-01:
# sub-44_ses-01:
# sub-45_ses-01:
# sub-46_ses-01:
# sub-47_ses-01:
# sub-48_ses-01:
# sub-49_ses-01:
# sub-50_ses-01:
# sub-51_ses-01:
# sub-52_ses-01:
# sub-53_ses-01:
# sub-53_ses-02:
# sub-54_ses-01:
# sub-55_ses-01:
# sub-56_ses-01:
# sub-57_ses-01:
# sub-58_ses-01:
# sub-59_ses-01:
# sub-59_ses-02:
# sub-60_ses-01:
# sub-61_ses-01:
# sub-62_ses-01:
# sub-63_ses-01:
# sub-64_ses-01:
# sub-65_ses-01:
# sub-65_ses-02:
# sub-66_ses-01:
# sub-67_ses-01:
# sub-68_ses-01:
# sub-69_ses-01:
# sub-70_ses-01:
# sub-70_ses-02:
# sub-71_ses-01:
# sub-72_ses-01:
# sub-73_ses-01:
# sub-73_ses-02:
# sub-74_ses-01:
# sub-74_ses-02:
# sub-75_ses-01:
# sub-75_ses-02:
# sub-76_ses-01:
# sub-77_ses-01:
# sub-77_ses-02:
# sub-78_ses-01:
# sub-79_ses-01:
# sub-80_ses-01:
# sub-81_ses-01:
# sub-81_ses-02:
# sub-82_ses-01:
# sub-83_ses-01:
# sub-83_ses-02:
# sub-84_ses-01:
# sub-84_ses-02:
# sub-85_ses-01:
# sub-86_ses-01:
# sub-86_ses-02:
# sub-87_ses-01:
# sub-88_ses-01:
# sub-89_ses-01:
# sub-90_ses-01:
# sub-91_ses-01:
# sub-92_ses-01:
# sub-93_ses-01:
# sub-93_ses-02:
# sub-93_ses-03:
# sub-94_ses-01:
# sub-95_ses-01:
# sub-96_ses-01:
# sub-96_ses-02:
# sub-97_ses-01:
# sub-98_ses-01:
# sub-99_ses-01:
# sub-99_ses-02:
