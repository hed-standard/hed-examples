# %% [markdown]
# ## Initial summary of event files
#
# **Dataset**: BCIT Baseling Driving (in process)
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
#
# This script does a preliminary summary of the contents of the events files.
# The summary includes printing out the column names of each event file so
# that they can be manually checked for differences.
#
# The script assumes that the data is in BIDS format and that each BIDS events
# file of the form `_events.tsv` has a corresponding events file with
# suffix `_events_temp.tsv` that was previously dumped from the `EEG.set` files.
# Keys are specified by a `entities` tuple lists the BIDS entity names
# to include in the key.
# BIDS base file names are constructed of entity *name*-*value* pairs separated
# by underbars and followed by an ending *_suffix*.
#
# For a file name `sub-001_ses-3_task-target_run-01_events.tsv`,
# the tuple ('sub', 'task') gives a key of `sub-001_task-target`,
# while the tuple ('sub', 'ses', 'run) gives a key of `sub-001_ses-3_run-01`.
# The use of dictionaries of file names with such keys makes it
# easier to associate related files in the BIDS naming structure.
#
# The setup requires the setting of the following variables for your dataset:
#
# | Variable | Purpose |
# | -------- | ------- |
# | bids_root_path | Full path to root directory of dataset.|
# | exclude_dirs | List of directories to exclude when constructing file lists. |
# | entities  | Tuple of entity names used to construct a unique keys representing filenames. <br>(See [Dictionaries of filenames](https://hed-examples.readthedocs.io/en/latest/HedInPython.html#dictionaries-of-filenames-anchor) for examples of how to choose the keys.)|
# | bids_skip_columns  |  List of column names in the `events.tsv` files to skip in the analysis. |
# | eeg_skip_columns  | List of column names in the `events_temp.tsv` files form EEG.events to skip in analysis.|

# %%
from hed.tools import BidsTsvDictionary
from hed.util import get_file_list

# Variables to set for the specific dataset
bids_root_path = 'F:/ARLBidsStart/BaselineDrivingWorking'
exclude_dirs = ['sourcedata', 'stimuli', 'code']
entities = ('sub', 'ses', 'run')
bids_skip_columns = ['onset']
eeg_skip_columns = ['latency', 'urevent', 'usertags']

# Construct the event file dictionaries for the BIDS and for EEG.event files
files_bids = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events", exclude_dirs=exclude_dirs)
bids_dict = BidsTsvDictionary(files_bids, entities=entities)
files_eeg = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events_temp", exclude_dirs=exclude_dirs)
eeg_dict = BidsTsvDictionary(files_eeg, entities=entities)

# %%
print(f"Summarizing {bids_root_path}...")
bids_dict.print_files(title="\nBIDS style event files")
eeg_dict.print_files(title="\nEEG.event style event files")
# Out:
# Summarizing F:/ARLBidsStart/BaselineDrivingWorking...
#
# BIDS style event files (131 files)
# sub-01_ses-01_run-1: sub-01_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-02_ses-01_run-1: sub-02_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-03_ses-01_run-1: sub-03_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-04_ses-01_run-1: sub-04_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-05_ses-01_run-1: sub-05_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-06_ses-01_run-1: sub-06_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-07_ses-01_run-1: sub-07_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-08_ses-01_run-1: sub-08_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-09_ses-01_run-1: sub-09_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-10_ses-01_run-1: sub-10_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-100_ses-01_run-1: sub-100_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-101_ses-01_run-1: sub-101_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-102_ses-01_run-1: sub-102_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-102_ses-02_run-1: sub-102_ses-02_task-DriveWithSpeedChange_run-1_events.tsv
# sub-103_ses-01_run-1: sub-103_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-103_ses-02_run-1: sub-103_ses-02_task-DriveWithSpeedChange_run-1_events.tsv
# sub-104_ses-01_run-1: sub-104_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-105_ses-01_run-1: sub-105_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-106_ses-01_run-1: sub-106_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-107_ses-01_run-1: sub-107_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-108_ses-01_run-1: sub-108_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-108_ses-02_run-1: sub-108_ses-02_task-DriveWithSpeedChange_run-1_events.tsv
# sub-109_ses-01_run-1: sub-109_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-11_ses-01_run-1: sub-11_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-12_ses-01_run-1: sub-12_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-13_ses-01_run-1: sub-13_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-14_ses-01_run-1: sub-14_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-15_ses-01_run-1: sub-15_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-16_ses-01_run-1: sub-16_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-17_ses-01_run-1: sub-17_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-18_ses-01_run-1: sub-18_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-19_ses-01_run-1: sub-19_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-20_ses-01_run-1: sub-20_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-21_ses-01_run-1: sub-21_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-22_ses-01_run-1: sub-22_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-23_ses-01_run-1: sub-23_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-24_ses-01_run-1: sub-24_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-25_ses-01_run-1: sub-25_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-26_ses-01_run-1: sub-26_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-27_ses-01_run-1: sub-27_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-28_ses-01_run-1: sub-28_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-29_ses-01_run-1: sub-29_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-30_ses-01_run-1: sub-30_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-31_ses-01_run-1: sub-31_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-32_ses-01_run-1: sub-32_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub-33_ses-01_run-1: sub-33_ses-01_task-DriveWithSpeedChange_run-1_events.tsv
# sub
ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-73_ses-01_run-1: sub-73_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-73_ses-02_run-1: sub-73_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-74_ses-01_run-1: sub-74_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-74_ses-02_run-1: sub-74_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-75_ses-01_run-1: sub-75_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-75_ses-02_run-1: sub-75_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-76_ses-01_run-1: sub-76_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-77_ses-01_run-1: sub-77_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-77_ses-01_run-2: sub-77_ses-01_task-DriveWithSpeedChange_run-2_events_temp.tsv
# sub-77_ses-02_run-1: sub-77_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-77_ses-02_run-2: sub-77_ses-02_task-DriveWithSpeedChange_run-2_events_temp.tsv
# sub-78_ses-01_run-1: sub-78_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-79_ses-01_run-1: sub-79_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-80_ses-01_run-1: sub-80_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-81_ses-01_run-1: sub-81_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-81_ses-02_run-1: sub-81_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-82_ses-01_run-1: sub-82_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-83_ses-01_run-1: sub-83_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-83_ses-01_run-2: sub-83_ses-01_task-DriveWithSpeedChange_run-2_events_temp.tsv
# sub-83_ses-02_run-1: sub-83_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-84_ses-01_run-1: sub-84_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-84_ses-02_run-1: sub-84_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-85_ses-01_run-1: sub-85_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-86_ses-01_run-1: sub-86_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-86_ses-02_run-1: sub-86_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-87_ses-01_run-1: sub-87_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-88_ses-01_run-1: sub-88_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-89_ses-01_run-1: sub-89_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-90_ses-01_run-1: sub-90_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-91_ses-01_run-1: sub-91_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-92_ses-01_run-1: sub-92_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-93_ses-01_run-1: sub-93_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-93_ses-02_run-1: sub-93_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-93_ses-03_run-1: sub-93_ses-03_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-94_ses-01_run-1: sub-94_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-95_ses-01_run-1: sub-95_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-96_ses-01_run-1: sub-96_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-96_ses-02_run-1: sub-96_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-97_ses-01_run-1: sub-97_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-98_ses-01_run-1: sub-98_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-99_ses-01_run-1: sub-99_ses-01_task-DriveWithSpeedChange_run-1_events_temp.tsv
# sub-99_ses-02_run-1: sub-99_ses-02_task-DriveWithSpeedChange_run-1_events_temp.tsv

# %%
key_diff = bids_dict.key_diffs(eeg_dict)
print(f"Key differences between EEG and BIDS events: {str(key_diff)}")
# Out:
# Key differences between EEG and BIDS events: []

# %%
print(f"\nBIDS style event file columns:")
for key, file, rowcount, columns in bids_dict.iter_tsv_info():
    print(f"{key} [{rowcount} events]: {str(columns)}")

print(f"\nEEG.event style event file columns:")
for key, file, rowcount, columns in eeg_dict.iter_tsv_info():
    print(f"{key} [{rowcount} events]: {str(columns)}")
# Out:
# BIDS style event file columns:
# sub-01_ses-01_run-1 [1282 events]: ['onset', 'duration', 'event_code']
# sub-02_ses-01_run-1 [1227 events]: ['onset', 'duration', 'event_code']
# sub-03_ses-01_run-1 [1189 events]: ['onset', 'duration', 'event_code']
# sub-04_ses-01_run-1 [1191 events]: ['onset', 'duration', 'event_code']
# sub-05_ses-01_run-1 [1106 events]: ['onset', 'duration', 'event_code']
# sub-06_ses-01_run-1 [1134 events]: ['onset', 'duration', 'event_code']
# sub-07_ses-01_run-1 [971 events]: ['onset', 'duration', 'event_code']
# sub-08_ses-01_run-1 [1127 events]: ['onset', 'duration', 'event_code']
# sub-09_ses-01_run-1 [1400 events]: ['onset', 'duration', 'event_code']
# sub-10_ses-01_run-1 [1367 events]: ['onset', 'duration', 'event_code']
# sub-100_ses-01_run-1 [1611 events]: ['onset', 'duration', 'event_code']
# sub-101_ses-01_run-1 [1516 events]: ['onset', 'duration', 'event_code']
# sub-102_ses-01_run-1 [1532 events]: ['onset', 'duration', 'event_code']
# sub-102_ses-02_run-1 [1550 events]: ['onset', 'duration', 'event_code']
# sub-103_ses-01_run-1 [1614 events]: ['onset', 'duration', 'event_code']
# sub-103_ses-02_run-1 [1363 events]: ['onset', 'duration', 'event_code']
# sub-104_ses-01_run-1 [1432 events]: ['onset', 'duration', 'event_code']
# sub-105_ses-01_run-1 [135 events]: ['onset', 'duration', 'event_code']
# sub-106_ses-01_run-1 [1629 events]: ['onset', 'duration', 'event_code']
# sub-107_ses-01_run-1 [1495 events]: ['onset', 'duration', 'event_code']
# sub-108_ses-01_run-1 [1371 events]: ['onset', 'duration', 'event_code']
# sub-108_ses-02_run-1 [1622 events]: ['onset', 'duration', 'event_code']
# sub-109_ses-01_run-1 [1488 events]: ['onset', 'duration', 'event_code']
# sub-11_ses-01_run-1 [1095 events]: ['onset', 'duration', 'event_code']
# sub-12_ses-01_run-1 [1103 events]: ['onset', 'duration', 'event_code']
# sub-13_ses-01_run-1 [1093 events]: ['onset', 'duration', 'event_code']
# sub-14_ses-01_run-1 [1185 events]: ['onset', 'duration', 'event_code']
# sub-15_ses-01_run-1 [1110 events]: ['onset', 'duration', 'event_code']
# sub-16_ses-01_run-1 [1103 events]: ['onset', 'duration', 'event_code']
# sub-17_ses-01_run-1 [1124 events]: ['onset', 'duration', 'event_code']
# sub-18_ses-01_run-1 [1065 events]: ['onset', 'duration', 'event_code']
# sub-19_ses-01_run-1 [1133 events]: ['onset', 'duration', 'event_code']
# sub-20_ses-01_run-1 [1115 events]: ['onset', 'duration', 'event_code']
# sub-21_ses-01_run-1 [1073 events]: ['onset', 'duration', 'event_code']
# sub-22_ses-01_run-1 [1195 events]: ['onset', 'duration', 'event_code']
# sub-23_ses-01_run-1 [873 events]: ['onset', 'duration', 'event_code']
# sub-24_ses-01_run-1 [1015 events]: ['onset', 'duration', 'event_code']
# sub-25_ses-01_run-1 [1016 events]: ['onset', 'duration', 'event_code']
# sub-26_ses-01_run-1 [916 events]: ['onset', 'duration', 'event_code']
# sub-27_ses-01_run-1 [837 events]: ['onset', 'duration', 'event_code']
# sub-28_ses-01_run-1 [988 events]: ['onset', 'duration', 'event_code']
# sub-29_ses-01_run-1 [828 events]: ['onset', 'duration', 'event_code']
# sub-30_ses-01_run-1 [1064 events]: ['onset', 'duration', 'event_code']
# sub-31_ses-01_run-1 [1013 events]: ['onset', 'duration', 'event_code']
# sub-32_ses-01_run-1 [892 events]: ['onset', 'duration', 'event_code']
# sub-33_ses-01_run-1 [958 events]: ['onset', 'duration', 'event_code']
# sub-34_ses-01_run-1 [1011 events]: ['onset', 'duration', 'event_code']
# sub-35_ses-01_run-1 [1041 events]: ['onset', 'duration', 'event_code']
# sub-36_ses-01_run-1 [904 events]: ['onset', 'duration', 'event_code']
# sub-37_ses-01_run-1 [1028 events]: ['onset', 'duration', 'event_code']
# sub-38_ses-01_run-1 [918 events]: ['onset', 'duration', 'event_code']
# sub-39_ses-01_run-1 [1025 events]: ['onset', 'duration', 'event_code']
# sub-40_ses-01_run-1 [912 events]: ['onset', 'duration', 'event_code']
# sub-41_ses-01_run-1 [762 events]: ['onset', 'duration', 'event_code']
# sub-42_ses-01_run-1 [992 events]: ['onset', 'duration', 'event_code']
# sub-43_ses-01_run-1 [1018 events]: ['onset', 'duration', 'event_code']
# sub-44_ses-01_run-1 [1109 events]: ['onset', 'duration', 'event_code']
# sub-45_ses-01_run-1 [811 events]: ['onset', 'duration', 'event_code']
# sub-46_ses-01_run-1 [815 events]: ['onset', 'duration', 'event_code']
# sub-47_ses-01_run-1 [906 events]: ['onset', 'duration', 'event_code']
# sub-48_ses-01_run-1 [1032 events]: ['onset', 'duration', 'event_code']
# sub-49_ses-01_run-1 [1057 events]: ['onset', 'duration', 'event_code']
# sub-50_ses-01_run-1 [987 events]: ['onset', 'duration', 'event_code']
# sub-51_ses-01_run-1 [1564 events]: ['onset', 'duration', 'event_code']
# sub-52_ses-01_run-1 [1663 events]: ['onset', 'duration', 'event_code']
# sub-53_ses-01_run-1 [1457 events]: ['onset', 'duration', 'event_code']
# sub-53_ses-02_run-1 [1406 events]: ['onset', 'duration', 'event_code']
# sub-54_ses-01_run-1 [1459 events]: ['onset', 'duration', 'event_code']
# sub-55_ses-01_run-1 [1459 events]: ['onset', 'duration', 'event_code']
# sub-56_ses-01_run-1 [1528 events]: ['onset', 'duration', 'event_code']
# sub-57_ses-01_run-1 [1496 events]: ['onset', 'duration', 'event_code']
# sub-58_ses-01_run-1 [1454 events]: ['onset', 'duration', 'event_code']
# sub-59_ses-01_run-1 [1604 events]: ['onset', 'duration', 'event_code']
# sub-59_ses-02_run-1 [1609 events]: ['onset', 'duration', 'event_code']
# sub-60_ses-01_run-1 [1432 events]: ['onset', 'duration', 'event_code']
# sub-61_ses-01_run-1 [1568 events]: ['onset', 'duration', 'event_code']
# sub-62_ses-01_run-1 [1466 events]: ['onset', 'duration', 'event_code']
# sub-63_ses-01_run-1 [1559 events]: ['onset', 'duration', 'event_code']
# sub-64_ses-01_run-1 [1514 events]: ['onset', 'duration', 'event_code']
# sub-65_ses-01_run-1 [1627 events]: ['onset', 'duration', 'event_code']
# sub-65_ses-02_run-1 [1639 events]: ['onset', 'duration', 'event_code']
# sub-66_ses-01_run-1 [1574 events]: ['onset', 'duration', 'event_code']
# sub-67_ses-01_run-1 [1416 events]: ['onset', 'duration', 'event_code']
# sub-68_ses-01_run-1 [1561 events]: ['onset', 'duration', 'event_code']
# sub-69_ses-01_run-1 [1522 events]: ['onset', 'duration', 'event_code']
# sub-70_ses-01_run-1 [1589 events]: ['onset', 'duration', 'event_code']
# sub-70_ses-02_run-1 [1565 events]: ['onset', 'duration', 'event_code']
# sub-71_ses-01_run-1 [1461 events]: ['onset', 'duration', 'event_code']
# sub-72_ses-01_run-1 [1167 events]: ['onset', 'duration', 'event_code']
# sub-73_ses-01_run-1 [1436 events]: ['onset', 'duration', 'event_code']
# sub-73_ses-02_run-1 [1433 events]: ['onset', 'duration', 'event_code']
# sub-74_ses-01_run-1 [1455 events]: ['onset', 'duration', 'event_code']
# sub-74_ses-02_run-1 [1479 events]: ['onset', 'duration', 'event_code']
# sub-75_ses-01_run-1 [1602 events]: ['onset', 'duration', 'event_code']
# sub-75_ses-02_run-1 [1622 events]: ['onset', 'duration', 'event_code']
# sub-76_ses-01_run-1 [1412 events]: ['onset', 'duration', 'event_code']
# sub-77_ses-01_run-1 [730 events]: ['onset', 'duration', 'event_code']
# sub-77_ses-01_run-2 [730 events]: ['onset', 'duration', 'event_code']
# sub-77_ses-02_run-1 [963 events]: ['onset', 'duration', 'event_code']
# sub-77_ses-02_run-2 [963 events]: ['onset', 'duration', 'event_code']
# sub-78_ses-01_run-1 [1460 events]: ['onset', 'duration', 'event_code']
# sub-79_ses-01_run-1 [1476 events]: ['onset', 'duration', 'event_code']
# sub-80_ses-01_run-1 [1560 events]: ['onset', 'duration', 'event_code']
# sub-81_ses-01_run-1 [1515 events]: ['onset', 'duration', 'event_code']
# sub-81_ses-02_run-1 [1498 events]: ['onset', 'duration', 'event_code']
# sub-82_ses-01_run-1 [242 events]: ['onset', 'duration', 'event_code']
# sub-83_ses-01_run-1 [1123 events]: ['onset', 'duration', 'event_code']
# sub-83_ses-01_run-2 [1123 events]: ['onset', 'duration', 'event_code']
# sub-83_ses-02_run-1 [1474 events]: ['onset', 'duration', 'event_code']
# sub-84_ses-01_run-1 [1487 events]: ['onset', 'duration', 'event_code']
# sub-84_ses-02_run-1 [1352 events]: ['onset', 'duration', 'event_code']
# sub-85_ses-01_run-1 [1268 events]: ['onset', 'duration', 'event_code']
# sub-86_ses-01_run-1 [1560 events]: ['onset', 'duration', 'event_code']
# sub-86_ses-02_run-1 [1572 events]: ['onset', 'duration', 'event_code']
# sub-87_ses-01_run-1 [1610 events]: ['onset', 'duration', 'event_code']
# sub-88_ses-01_run-1 [1710 events]: ['onset', 'duration', 'event_code']
# sub-89_ses-01_run-1 [1532 events]: ['onset', 'duration', 'event_code']
# sub-90_ses-01_run-1 [1529 events]: ['onset', 'duration', 'event_code']
# sub-91_ses-01_run-1 [1337 events]: ['onset', 'duration', 'event_code']
# sub-92_ses-01_run-1 [1494 events]: ['onset', 'duration', 'event_code']
# sub-93_ses-01_run-1 [1574 events]: ['onset', 'duration', 'event_code']
# sub-93_ses-02_run-1 [1545 events]: ['onset', 'duration', 'event_code']
# sub-93_ses-03_run-1 [1591 events]: ['onset', 'duration', 'event_code']
# sub-94_ses-01_run-1 [1580 events]: ['onset', 'duration', 'event_code']
# sub-95_ses-01_run-1 [1433 events]: ['onset', 'duration', 'event_code']
# sub-96_ses-01_run-1 [1492 events]: ['onset', 'duration', 'event_code']
# sub-96_ses-02_run-1 [1455 events]: ['onset', 'duration', 'event_code']
# sub-97_ses-01_run-1 [1261 events]: ['onset', 'duration', 'event_code']
# sub-98_ses-01_run-1 [1498 events]: ['onset', 'duration', 'event_code']
# sub-99_ses-01_run-1 [1610 events]: ['onset', 'duration', 'event_code']
# sub-99_ses-02_run-1 [1669 events]: ['onset', 'duration', 'event_code']
#
# EEG.event style event file columns:
# sub-01_ses-01_run-1 [1282 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-02_ses-01_run-1 [1227 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-03_ses-01_run-1 [1189 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-04_ses-01_run-1 [1191 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-05_ses-01_run-1 [1106 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-06_ses-01_run-1 [1134 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-07_ses-01_run-1 [971 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-08_ses-01_run-1 [1127 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-09_ses-01_run-1 [1400 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-10_ses-01_run-1 [1367 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-100_ses-01_run-1 [1611 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-101_ses-01_run-1 [1516 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-102_ses-01_run-1 [1532 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-102_ses-02_run-1 [1550 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-103_ses-01_run-1 [1614 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-103_ses-02_run-1 [1363 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-104_ses-01_run-1 [1432 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-105_ses-01_run-1 [135 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-106_ses-01_run-1 [1629 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-107_ses-01_run-1 [1495 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-108_ses-01_run-1 [1371 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-108_ses-02_run-1 [1622 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-109_ses-01_run-1 [1488 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-11_ses-01_run-1 [1095 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-12_ses-01_run-1 [1103 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-13_ses-01_run-1 [1093 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-14_ses-01_run-1 [1185 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-15_ses-01_run-1 [1110 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-16_ses-01_run-1 [1103 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-17_ses-01_run-1 [1124 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-18_ses-01_run-1 [1065 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-19_ses-01_run-1 [1133 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-20_ses-01_run-1 [1115 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-21_ses-01_run-1 [1073 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-22_ses-01_run-1 [1195 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-23_ses-01_run-1 [873 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-24_ses-01_run-1 [1015 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-25_ses-01_run-1 [1016 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-26_ses-01_run-1 [916 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-27_ses-01_run-1 [837 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-28_ses-01_run-1 [988 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-29_ses-01_run-1 [828 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-30_ses-01_run-1 [1064 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-31_ses-01_run-1 [1013 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-32_ses-01_run-1 [892 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-33_ses-01_run-1 [958 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-34_ses-01_run-1 [1011 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-35_ses-01_run-1 [1041 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-36_ses-01_run-1 [904 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-37_ses-01_run-1 [1028 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-38_ses-01_run-1 [918 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-39_ses-01_run-1 [1025 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-40_ses-01_run-1 [912 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-41_ses-01_run-1 [762 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-42_ses-01_run-1 [992 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-43_ses-01_run-1 [1018 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-44_ses-01_run-1 [1109 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-45_ses-01_run-1 [811 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-46_ses-01_run-1 [815 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-47_ses-01_run-1 [906 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-48_ses-01_run-1 [1032 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-49_ses-01_run-1 [1057 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-50_ses-01_run-1 [987 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-51_ses-01_run-1 [1564 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-52_ses-01_run-1 [1663 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-53_ses-01_run-1 [1457 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-53_ses-02_run-1 [1406 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-54_ses-01_run-1 [1459 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-55_ses-01_run-1 [1459 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-56_ses-01_run-1 [1528 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-57_ses-01_run-1 [1496 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-58_ses-01_run-1 [1454 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-59_ses-01_run-1 [1604 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-59_ses-02_run-1 [1609 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-60_ses-01_run-1 [1432 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-61_ses-01_run-1 [1568 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-62_ses-01_run-1 [1466 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-63_ses-01_run-1 [1559 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-64_ses-01_run-1 [1514 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-65_ses-01_run-1 [1627 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-65_ses-02_run-1 [1639 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-66_ses-01_run-1 [1574 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-67_ses-01_run-1 [1416 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-68_ses-01_run-1 [1561 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-69_ses-01_run-1 [1522 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-70_ses-01_run-1 [1589 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-70_ses-02_run-1 [1565 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-71_ses-01_run-1 [1461 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-72_ses-01_run-1 [1167 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-73_ses-01_run-1 [1436 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-73_ses-02_run-1 [1433 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-74_ses-01_run-1 [1455 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-74_ses-02_run-1 [1479 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-75_ses-01_run-1 [1602 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-75_ses-02_run-1 [1622 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-76_ses-01_run-1 [1412 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-77_ses-01_run-1 [725 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-77_ses-01_run-2 [730 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-77_ses-02_run-1 [497 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-77_ses-02_run-2 [963 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-78_ses-01_run-1 [1460 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-79_ses-01_run-1 [1476 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-80_ses-01_run-1 [1560 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-81_ses-01_run-1 [1515 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-81_ses-02_run-1 [1498 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-82_ses-01_run-1 [242 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-83_ses-01_run-1 [316 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-83_ses-01_run-2 [1123 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-83_ses-02_run-1 [1474 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-84_ses-01_run-1 [1487 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-84_ses-02_run-1 [1352 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-85_ses-01_run-1 [1268 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-86_ses-01_run-1 [1560 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-86_ses-02_run-1 [1572 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-87_ses-01_run-1 [1610 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-88_ses-01_run-1 [1710 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-89_ses-01_run-1 [1532 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-90_ses-01_run-1 [1529 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-91_ses-01_run-1 [1337 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-92_ses-01_run-1 [1494 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-93_ses-01_run-1 [1574 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-93_ses-02_run-1 [1545 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-93_ses-03_run-1 [1591 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-94_ses-01_run-1 [1580 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-95_ses-01_run-1 [1433 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-96_ses-01_run-1 [1492 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-96_ses-02_run-1 [1455 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-97_ses-01_run-1 [1261 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-98_ses-01_run-1 [1498 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-99_ses-01_run-1 [1610 events]: ['type', 'latency', 'urevent', 'usertags']
# sub-99_ses-02_run-1 [1669 events]: ['type', 'latency', 'urevent', 'usertags']

# %%
count_diffs = bids_dict.count_diffs(eeg_dict)
if count_diffs:
    print("The number of BIDS events and EEG.event events differ for the following:")
    for item in count_diffs:
        print(f"{item[0]}: {item[1]} BIDS events and {item[2]} EEG.events")
else:
    print("The BIDS event files and EEG.event structures have the same number of events")
# Out:
# The number of BIDS events and EEG.event events differ for the following:
# sub-77_ses-01_run-1: 730 BIDS events and 725 EEG.events
# sub-77_ses-02_run-1: 963 BIDS events and 497 EEG.events
# sub-83_ses-01_run-1: 1123 BIDS events and 316 EEG.events

# %%
from hed.tools import BidsTsvSummary

bids_sum_all, bids_sum =  BidsTsvSummary.make_combined_dicts(bids_dict, skip_cols=bids_skip_columns)
bids_sum_all.print('\nBIDS events summary')

eeg_sum_all, eeg_sum =  BidsTsvSummary.make_combined_dicts(eeg_dict, skip_cols=eeg_skip_columns)
eeg_sum_all.print('\nEEG.event events summary')
# Out:
# BIDS events summary
#   Categorical columns (2):
#     duration (1 distinct values):
#       n/a: 168288
#     event_code (28 distinct values):
#       1111: 15771
#       1112: 15771
#       1121: 15690
#       1122: 15690
#       1211: 542
#       1212: 538
#       2611: 109
#       2612: 109
#       2621: 1755
#       2622: 1754
#       3111: 125
#       3112: 127
#       3200: 10192
#       3310: 131
#       4200: 4
#       4210: 14075
#       4220: 5361
#       4230: 8838
#       4311: 31100
#       4312: 30562
#       4411: 5
#       4421: 5
#       5221: 1
#       5222: 3
#       5231: 1
#       5232: 7
#       5241: 9
#       5242: 13
#   Value columns (0):
#
# EEG.event events summary
#   Categorical columns (1):
#     type (28 distinct values):
#       1111: 15641
#       1112: 15641
#       1121: 15585
#       1122: 15585
#       1211: 537
#       1212: 534
#       2611: 109
#       2612: 109
#       2621: 1755
#       2622: 1754
#       3111: 128
#       3112: 125
#       3200: 10119
#       3310: 131
#       4200: 4
#       4210: 13924
#       4220: 5286
#       4230: 8760
#       4311: 30882
#       4312: 30357
#       4411: 5
#       4421: 5
#       5221: 2
#       5222: 2
#       5231: 4
#       5232: 4
#       5241: 11
#       5242: 11
#   Value columns (0):
