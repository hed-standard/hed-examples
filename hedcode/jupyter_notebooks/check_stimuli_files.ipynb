# %% [markdown]
# ## Script checks stim_file
# This script creates a dictionary of the `stim_file` files used in the dataset and
# eliminates the unused stimuli files.

# %%
import os
from hed.tools.io_util import get_file_list, make_file_dict
from hed.tools.data_util import get_new_dataframe
from hed.tools.hed_logger import HedLogger

status = HedLogger()
dataset = "eeg_ds003654s"
bids_root_path =  os.path.join(os.path.dirname(os.path.abspath('')), os.path.join('../datasets/', dataset))
bids_root_path = os.path.abspath(bids_root_path)
status.add(dataset, f"Bids root path: {bids_root_path}", also_print=True)
bids_files = get_file_list(bids_root_path, extensions=[".tsv"], name_suffix="_events")
file_dict = make_file_dict(bids_files, indices=(0, -2))


status.add(dataset, f"\nBIDS event files: {len(file_dict)}", also_print=True)

total_events = 0
stim_dict = {}
for key, file in file_dict.items():
    df = get_new_dataframe(file)
    for ind, value in df['stim_file'].iteritems():
        stim_dict[value] = True
    total_events = total_events + len(df.index)
status.add(dataset, f"Total events: {total_events} unique stimuli: {len(stim_dict)}", also_print=True)

# Now get the stimuli files and remove those that aren't used:
# Out:
# Bids root path: D:\Research\HED\hed-examples\datasets\eeg_ds003654s
#
# BIDS event files: 6
# Total events: 3362 unique stimuli: 346

# %%
stimuli_path = os.path.abspath(os.path.join(bids_root_path, 'stimuli'))
status.add(dataset, f"Now removing unused files from {stimuli_path}", also_print=True)

remove_count = 0
stim_files = get_file_list(stimuli_path, extensions=[".bmp"])
for file in stim_files:
    basename = os.path.basename(file)
    if basename not in stim_dict:
        os.remove(file)
        status.add(dataset, f"Removing {basename}: {file}", also_print=True)
        remove_count += 1
status.add(dataset, f"Removed {remove_count} out of {len(stim_files)} files", also_print=True)

status.print_log()
# Out:
# Now removing unused files from D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli
# Removing f001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f001.bmp
# Removing f002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f002.bmp
# Removing f003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f003.bmp
# Removing f007.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f007.bmp
# Removing f008.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f008.bmp
# Removing f014.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f014.bmp
# Removing f016.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f016.bmp
# Removing f018.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f018.bmp
# Removing f019.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f019.bmp
# Removing f029.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f029.bmp
# Removing f030.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f030.bmp
# Removing f035.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f035.bmp
# Removing f042.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f042.bmp
# Removing f043.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f043.bmp
# Removing f044.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f044.bmp
# Removing f047.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f047.bmp
# Removing f050.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f050.bmp
# Removing f056.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f056.bmp
# Removing f061.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f061.bmp
# Removing f069.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f069.bmp
# Removing f070.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f070.bmp
# Removing f071.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f071.bmp
# Removing f079.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f079.bmp
# Removing f083.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f083.bmp
# Removing f085.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f085.bmp
# Removing f086.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f086.bmp
# Removing f088.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f088.bmp
# Removing f092.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f092.bmp
# Removing f107.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f107.bmp
# Removing f113.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f113.bmp
# Removing f114.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f114.bmp
# Removing f116.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f116.bmp
# Removing f118.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f118.bmp
# Removing f122.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f122.bmp
# Removing f125.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f125.bmp
# Removing f126.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f126.bmp
# Removing f134.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f134.bmp
# Removing f142.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f142.bmp
# Removing f144.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f144.bmp
# Removing i999.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\i999.bmp
# Removing pf001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf001.bmp
# Removing pf002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf002.bmp
# Removing pf003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf003.bmp
# Removing pf004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf004.bmp
# Removing ps001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps001.bmp
# Removing ps002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps002.bmp
# Removing ps003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps003.bmp
# Removing ps004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps004.bmp
# Removing pu001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu001.bmp
# Removing pu002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu002.bmp
# Removing pu003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu003.bmp
# Removing pu004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu004.bmp
# Removing s004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s004.bmp
# Removing s007.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s007.bmp
# Removing s013.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s013.bmp
# Removing s014.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s014.bmp
# Removing s019.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s019.bmp
# Removing s032.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s032.bmp
# Removing s038.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s038.bmp
# Removing s042.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s042.bmp
# Removing s047.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s047.bmp
# Removing s050.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s050.bmp
# Removing s054.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s054.bmp
# Removing s059.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s059.bmp
# Removing s061.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s061.bmp
# Removing s064.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s064.bmp
# Removing s069.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s069.bmp
# Removing s070.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s070.bmp
# Removing s075.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s075.bmp
# Removing s078.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s078.bmp
# Removing s079.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s079.bmp
# Removing s082.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s082.bmp
# Removing s089.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s089.bmp
# Removing s097.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s097.bmp
# Removing s104.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s104.bmp
# Removing s107.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s107.bmp
# Removing s117.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s117.bmp
# Removing s118.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s118.bmp
# Removing s120.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s120.bmp
# Removing s130.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s130.bmp
# Removing s133.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s133.bmp
# Removing s134.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s134.bmp
# Removing s145.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s145.bmp
# Removing s147.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s147.bmp
# Removing u001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u001.bmp
# Removing u006.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u006.bmp
# Removing u015.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u015.bmp
# Removing u025.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u025.bmp
# Removing u026.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u026.bmp
# Removing u030.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u030.bmp
# Removing u033.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u033.bmp
# Removing u035.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u035.bmp
# Removing u036.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u036.bmp
# Removing u038.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u038.bmp
# Removing u039.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u039.bmp
# Removing u043.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u043.bmp
# Removing u046.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u046.bmp
# Removing u047.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u047.bmp
# Removing u053.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u053.bmp
# Removing u059.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u059.bmp
# Removing u060.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u060.bmp
# Removing u062.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u062.bmp
# Removing u067.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u067.bmp
# Removing u072.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u072.bmp
# Removing u075.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u075.bmp
# Removing u076.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u076.bmp
# Removing u080.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u080.bmp
# Removing u082.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u082.bmp
# Removing u085.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u085.bmp
# Removing u087.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u087.bmp
# Removing u094.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u094.bmp
# Removing u096.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u096.bmp
# Removing u109.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u109.bmp
# Removing u110.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u110.bmp
# Removing u115.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u115.bmp
# Removing u119.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u119.bmp
# Removing u126.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u126.bmp
# Removing u133.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u133.bmp
# Removing u135.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u135.bmp
# Removing u142.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u142.bmp
# Removed 120 out of 465 files
# eeg_ds003654s
# 	Bids root path: D:\Research\HED\hed-examples\datasets\eeg_ds003654s
#
# BIDS event files: 6
# 	Total events: 3362 unique stimuli: 346
# 	Now removing unused files from D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli
# 	Removing f001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f001.bmp
# 	Removing f002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f002.bmp
# 	Removing f003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f003.bmp
# 	Removing f007.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f007.bmp
# 	Removing f008.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f008.bmp
# 	Removing f014.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f014.bmp
# 	Removing f016.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f016.bmp
# 	Removing f018.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f018.bmp
# 	Removing f019.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f019.bmp
# 	Removing f029.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f029.bmp
# 	Removing f030.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f030.bmp
# 	Removing f035.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f035.bmp
# 	Removing f042.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f042.bmp
# 	Removing f043.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f043.bmp
# 	Removing f044.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f044.bmp
# 	Removing f047.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f047.bmp
# 	Removing f050.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f050.bmp
# 	Removing f056.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f056.bmp
# 	Removing f061.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f061.bmp
# 	Removing f069.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f069.bmp
# 	Removing f070.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f070.bmp
# 	Removing f071.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f071.bmp
# 	Removing f079.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f079.bmp
# 	Removing f083.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f083.bmp
# 	Removing f085.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f085.bmp
# 	Removing f086.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f086.bmp
# 	Removing f088.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f088.bmp
# 	Removing f092.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f092.bmp
# 	Removing f107.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f107.bmp
# 	Removing f113.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f113.bmp
# 	Removing f114.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f114.bmp
# 	Removing f116.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f116.bmp
# 	Removing f118.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f118.bmp
# 	Removing f122.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f122.bmp
# 	Removing f125.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f125.bmp
# 	Removing f126.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f126.bmp
# 	Removing f134.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f134.bmp
# 	Removing f142.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f142.bmp
# 	Removing f144.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\f144.bmp
# 	Removing i999.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\i999.bmp
# 	Removing pf001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf001.bmp
# 	Removing pf002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf002.bmp
# 	Removing pf003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf003.bmp
# 	Removing pf004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pf004.bmp
# 	Removing ps001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps001.bmp
# 	Removing ps002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps002.bmp
# 	Removing ps003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps003.bmp
# 	Removing ps004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\ps004.bmp
# 	Removing pu001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu001.bmp
# 	Removing pu002.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu002.bmp
# 	Removing pu003.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu003.bmp
# 	Removing pu004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\pu004.bmp
# 	Removing s004.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s004.bmp
# 	Removing s007.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s007.bmp
# 	Removing s013.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s013.bmp
# 	Removing s014.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s014.bmp
# 	Removing s019.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s019.bmp
# 	Removing s032.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s032.bmp
# 	Removing s038.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s038.bmp
# 	Removing s042.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s042.bmp
# 	Removing s047.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s047.bmp
# 	Removing s050.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s050.bmp
# 	Removing s054.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s054.bmp
# 	Removing s059.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s059.bmp
# 	Removing s061.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s061.bmp
# 	Removing s064.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s064.bmp
# 	Removing s069.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s069.bmp
# 	Removing s070.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s070.bmp
# 	Removing s075.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s075.bmp
# 	Removing s078.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s078.bmp
# 	Removing s079.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s079.bmp
# 	Removing s082.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s082.bmp
# 	Removing s089.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s089.bmp
# 	Removing s097.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s097.bmp
# 	Removing s104.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s104.bmp
# 	Removing s107.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s107.bmp
# 	Removing s117.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s117.bmp
# 	Removing s118.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s118.bmp
# 	Removing s120.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s120.bmp
# 	Removing s130.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s130.bmp
# 	Removing s133.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s133.bmp
# 	Removing s134.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s134.bmp
# 	Removing s145.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s145.bmp
# 	Removing s147.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\s147.bmp
# 	Removing u001.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u001.bmp
# 	Removing u006.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u006.bmp
# 	Removing u015.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u015.bmp
# 	Removing u025.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u025.bmp
# 	Removing u026.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u026.bmp
# 	Removing u030.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u030.bmp
# 	Removing u033.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u033.bmp
# 	Removing u035.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u035.bmp
# 	Removing u036.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u036.bmp
# 	Removing u038.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u038.bmp
# 	Removing u039.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u039.bmp
# 	Removing u043.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u043.bmp
# 	Removing u046.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u046.bmp
# 	Removing u047.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u047.bmp
# 	Removing u053.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u053.bmp
# 	Removing u059.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u059.bmp
# 	Removing u060.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u060.bmp
# 	Removing u062.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u062.bmp
# 	Removing u067.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u067.bmp
# 	Removing u072.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u072.bmp
# 	Removing u075.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u075.bmp
# 	Removing u076.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u076.bmp
# 	Removing u080.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u080.bmp
# 	Removing u082.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u082.bmp
# 	Removing u085.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u085.bmp
# 	Removing u087.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u087.bmp
# 	Removing u094.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u094.bmp
# 	Removing u096.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u096.bmp
# 	Removing u109.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u109.bmp
# 	Removing u110.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u110.bmp
# 	Removing u115.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u115.bmp
# 	Removing u119.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u119.bmp
# 	Removing u126.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u126.bmp
# 	Removing u133.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u133.bmp
# 	Removing u135.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u135.bmp
# 	Removing u142.bmp: D:\Research\HED\hed-examples\datasets\eeg_ds003654s\stimuli\u142.bmp
# 	Removed 120 out of 465 files
