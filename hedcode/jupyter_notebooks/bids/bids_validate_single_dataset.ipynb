# %% [markdown]
# ## Validate HED in a BIDS dataset.
#
# Validating annotations HED as you develop them makes the annotation process much easier and
# faster to debug. This notebook validates HED in a BIDS dataset.
#
# The tool creates a `BidsDataset` object, which represents the information from a BIDS
# dataset that is relevant to HED, including the `dataset_description.json`,
# all `events.tsv` files, and all `events.json` sidecar files.
#
# The `validate` method of `BidsDataset` first validates all of the `events.json` sidecars
# and then assembles the relevant sidecars for each `events.tsv` file and validates it.
# The validation uses the HED schemas specified in the `HEDVersion` field of the
# dataset's `dataset_description.json` file.
#
# The script does the following steps:
#
# 1. Set the dataset location (`bids_root_path`) to the absolute path of the root of your BIDS dataset.
# 2. Indicates whether to check for warnings during validation (`check_for_warnings`).
# 3. Create a `BidsDataset` for the dataset.
# 4. Validate the dataset and output the issues.
#
# **Note:** This validation pertains to event files and HED annotation only. It does not do a full BIDS validation.
#
#
# For validation of a single `events.json` file during annotation development,
# users often find the [online sidecar tools](https://hedtools.ucsd.edu/hed/sidecar)
# convenient, but the online tool does not provide complete dataset-level validation.

# %%
import os
from hed.errors import get_printable_issue_string
from hed.tools import BidsDataset
from hed import _version as vr
from hedcode._version import get_versions

print(f"Using HEDTOOLS version: {str(vr.get_versions())}")
print(f"HED Examples version: {str(get_versions())}")

## Set the dataset location and the check_for_warnings flag
check_for_warnings = False
bids_root_path = 'Q:/PerceptionalON'

## Validate the dataset
bids = BidsDataset(bids_root_path)
issue_list = bids.validate(check_for_warnings=check_for_warnings)
if issue_list:
    issue_str = get_printable_issue_string(issue_list, "HED validation errors: ", skip_filename=False)
else:
    issue_str = "No HED validation errors"
print(issue_str)
# Out:
# Using HEDTOOLS version: {'date': '2022-11-23T18:29:08-0600', 'dirty': False, 'error': None, 'full-revisionid': '8e58c07ac9056dfac7187ab17438bffd6444afd1', 'version': '0.1.0+158.g8e58c07'}
# HED Examples version: {'version': '0.1.0+152.g2f43b15.dirty', 'full-revisionid': '2f43b1552c5c966942e0807873c799e2a1c41f29', 'dirty': True, 'error': None, 'date': '2022-10-13T11:23:38-0500'}
# HED validation errors:
#
# Errors in file 'D:\BUGFind\BIDS_EXPORT3\temp\BIDS_EXPORT3\sub-001\eeg\sub-001_task-auditoryoddball_events.tsv'
# 	Issues in row 0:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 1:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 2:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 3:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 4:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 5:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 6:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 7:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 8:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 9:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 10:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 11:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 12:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 13:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 14:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 15:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 16:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 17:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 18:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 19:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 20:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 21:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 22:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 23:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 24:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 25:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 26:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 27:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 28:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 29:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 30:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 31:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 32:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 33:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 34:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 35:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 36:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 37:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 38:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 39:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 40:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 41:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 42:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 43:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 44:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 45:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 46:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 47:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 48:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 49:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 50:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 51:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 52:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 53:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 54:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 55:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 56:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 57:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 58:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 59:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 60:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 61:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 62:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 63:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 64:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 65:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 66:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 67:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 68:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 69:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 70:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 71:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 72:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 73:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 74:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 75:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 76:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 77:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 78:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 79:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 80:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 81:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 82:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 83:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 84:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 85:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 86:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 87:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 88:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 89:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 90:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 91:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 92:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 93:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 94:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 95:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 96:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 97:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 98:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 99:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 100:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 101:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 102:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 103:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 104:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 105:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 106:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 107:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 108:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 109:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 110:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 111:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 112:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 113:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 114:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 115:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 116:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 117:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 118:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 119:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 120:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 121:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 122:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 123:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 124:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 125:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 126:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 127:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 128:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 129:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 130:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 131:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 132:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 133:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 134:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 135:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 136:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 137:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 138:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 139:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 140:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 141:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 142:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 143:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 144:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 145:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 146:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 147:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 148:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 149:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 150:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 151:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 152:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 153:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 154:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 155:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 156:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 157:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 158:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 159:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 160:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 161:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 162:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 163:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 164:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 165:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 166:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 167:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 168:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 169:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 170:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 171:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 172:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 173:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 174:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 175:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 176:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 177:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 178:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 179:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 180:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 181:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 182:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 183:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 184:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 185:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 186:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 187:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 188:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 189:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 190:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 191:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 192:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 193:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 194:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 195:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 196:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 197:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 198:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 199:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 200:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 201:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 202:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 203:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 204:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 205:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 206:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 207:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 208:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 209:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 210:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 211:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 212:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 213:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 214:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 215:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 216:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 217:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 218:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 219:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 220:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 221:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 222:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 223:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 224:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 225:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 226:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 227:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 228:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 229:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 230:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 231:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 232:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 233:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 234:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 235:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 236:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 237:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 238:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 239:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 240:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 241:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 242:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 243:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 244:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 245:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 246:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 247:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 248:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 249:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 250:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 251:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 252:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 253:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 254:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 255:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 256:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 257:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 258:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 259:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 260:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 261:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 262:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 263:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 264:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 265:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 266:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 267:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 268:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 269:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 270:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 271:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 272:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 273:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 274:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 275:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 276:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 277:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 278:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 279:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 280:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 281:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 282:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 283:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 284:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# ...
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 768:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 769:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 770:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 771:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 772:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 773:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 774:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 775:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 776:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 777:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 778:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 779:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 780:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 781:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 782:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 783:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 784:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 785:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 786:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 787:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 788:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 789:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 790:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 791:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 792:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 793:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 794:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 795:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 796:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 797:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 798:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 799:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 800:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 801:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 802:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 803:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 804:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 805:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 806:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 807:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 808:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 809:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 810:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 811:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 812:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 813:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 814:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 815:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 816:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 817:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 818:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 819:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 820:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 821:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 822:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 823:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 824:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 825:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 826:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 827:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 828:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 829:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 830:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 831:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 832:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 833:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 834:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 835:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 836:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 837:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 838:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 839:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 840:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 841:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 842:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 843:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 844:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 845:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 846:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 847:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 848:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 849:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 850:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 851:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 852:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 853:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 854:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 855:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 856:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 8' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 857:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 858:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 859:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 4' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 860:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 1' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 861:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
# 	Issues in row 862:
# 		Issues in column 3:
# 			WARNING: Category key 'condition 2' does not exist in column.  Valid keys are: ['condition1', 'condition4', 'condition8']
